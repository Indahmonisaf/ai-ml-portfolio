# %% [markdown]
# # **CRUD Operation**

# %% [markdown]
# Each function corresponds to a specific CRUD operation (create, read, update, or delete)

# %%
#Installation
# !pip install google-cloud-discoveryengine
# !pip install --upgrade --user --quiet google-cloud-aiplatform
# !pip install jsonlines
# Out:
# Collecting google-cloud-discoveryengine
#   Downloading google_cloud_discoveryengine-0.13.5-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.19.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (4.25.5)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2024.8.30)
# Downloading google_cloud_discoveryengine-0.13.5-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 27.8 MB/s eta 0:00:00
# Installing collected packages: google-cloud-discoveryengine
# Successfully installed google-cloud-discoveryengine-0.13.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 58.9 MB/s eta 0:00:00
#   WARNING: The script tb-gcp-uploader is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (24.2.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.

# %% [markdown]
# **1. Create One Record**
#
# To create a single record in the data store:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development" # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358" # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
print(ACCESS_TOKEN)
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def create_one_record(record):
    document_id = record["id"]
    url = f"{BASE_URL}?documentId={document_id}"
    payload = {"structData": record}
    response = requests.post(url, headers=HEADERS, data=json.dumps(payload))
    if response.status_code == 200:
        print(f"Record {document_id} created successfully!")
    else:
        print(f"Failed to create record {document_id}: {response.text}")

# Define record data inputs
record = {
    "id": "doc6",
    "question": "What is AI?",
    "answer": "AI is artificial intelligence.",
    "category": "Tech"
}
create_one_record(record)
# Out:
# ya29.a0ARW5m76EXL6fl_8KcZYZeH3842UrGM6HlNsdwvEC9uDW2VHdxO6NbmLhFG21agJckNkAktNKEvqVvlT2yIG5JkMimA6ouh1on8acjtlSdw20anxQWFEPxdKxNN8LY5b32Pea7zv44RtYLAgrhVuzlAHP5mnL3uvxI7M9eix6YOOQbL9pA9Ma9sLsaCgYKAX4SARASFQHGX2MiRVAFg5ET8_tVB4LT9Qpu0g0191
# Failed to create record doc6: {
#   "error": {
#     "code": 409,
#     "message": "Active document with the same name \"projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/doc6\" exists.",
#     "status": "ALREADY_EXISTS"
#   }
# }

# %% [markdown]
# **2. Create Multiple Records**
#
# To create several records at once:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def create_one_record(record):
    """Create a single record in the data store."""
    document_id = record["id"]
    url = f"{BASE_URL}?documentId={document_id}"
    payload = {"structData": record}

    response = requests.post(url, headers=HEADERS, data=json.dumps(payload))
    if response.status_code == 200:
        print(f"Record {document_id} created successfully!")
    else:
        print(f"Failed to create record {document_id}: {response.status_code} - {response.text}")

def create_multiple_records(records):
    """Create multiple records by calling create_one_record for each."""
    for record in records:
        create_one_record(record)

# Example records
records = [
    {"id": "doc4", "question": "What is AI?", "answer": "AI is artificial intelligence.", "category": "Tech"},
    {"id": "doc2", "question": "What is ML?", "answer": "ML is machine learning.", "category": "Tech"}
]

# Call the function to create multiple records
create_multiple_records(records)
# Out:
# Record doc4 created successfully!
# Record doc2 created successfully!

# %% [markdown]
# **3. Delete One Record**
#
# To delete a specific record:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def delete_one_record(document_id):
    url = f"{BASE_URL}/{document_id}"
    response = requests.delete(url, headers=HEADERS)
    if response.status_code == 200:
        print(f"Record {document_id} deleted successfully!")
    else:
        print(f"Failed to delete record {document_id}: {response.text}")

delete_one_record("doc1")
# Out:
# Record doc1 deleted successfully!

# %% [markdown]
# **4. Delete Multiple Records**
#
# To delete several records:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def delete_one_record(document_id):
    """Delete a single record by ID."""
    url = f"{BASE_URL}/{document_id}"
    response = requests.delete(url, headers=HEADERS)
    if response.status_code == 200:
        print(f"Record {document_id} deleted successfully!")
    else:
        print(f"Failed to delete record {document_id}: {response.status_code} - {response.text}")

def delete_multiple_records(document_ids):
    """Delete multiple records by their IDs."""
    for document_id in document_ids:
        delete_one_record(document_id)

# Call the function to delete multiple records
delete_multiple_records(["doc6", "doc4"])
# Out:
# Record doc6 deleted successfully!
# Record doc4 deleted successfully!

# %% [markdown]
# **5. Update a Record**
#
# To update a record:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def update_record(document_id, updated_data):
    url = f"{BASE_URL}/{document_id}"
    payload = {"structData": updated_data}
    response = requests.patch(url, headers=HEADERS, data=json.dumps(payload))
    if response.status_code == 200:
        print(f"Record {document_id} updated successfully!")
    else:
        print(f"Failed to update record {document_id}: {response.text}")


updated_record = {
    "id": "doc2",
    "question": "Updated thexxxx question?",
    "answer": "Updated the answer.",
    "category": "Updated the category"
}
update_record("doc2", updated_record)
# Out:
# Record doc2 updated successfully!

# %% [markdown]
# **6. Read One Record**
#
# To retrieve a single record:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def read_one_record(document_id):
    """
    Fetch a single document's data from the Discovery Engine.
    Args:
        document_id (str): The ID of the document to read.
    """
    if not document_id:
        print("Error: Document ID cannot be empty!")
        return

    url = f"{BASE_URL}/{document_id}"  # API endpoint for the document
    try:
        response = requests.get(url, headers=HEADERS)  # Send GET request
        if response.status_code == 200:
            print(f"Record {document_id} retrieved successfully!")
            print(json.dumps(response.json(), indent=2))  # Pretty print the JSON response
        elif response.status_code == 404:
            print(f"Record {document_id} not found.")
        else:
            print(f"Failed to retrieve record {document_id}: {response.status_code} - {response.text}")
    except requests.exceptions.RequestException as e:
        print(f"Error while trying to fetch record {document_id}: {e}")

# Example: Read the document with ID "doc2"
read_one_record("doc2")
# Out:
# Record doc2 retrieved successfully!
# {
#   "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/doc2",
#   "id": "doc2",
#   "schemaId": "default_schema",
#   "structData": {
#     "id": "doc2",
#     "question": "Updated thexxxx question?",
#     "category": "Updated the category",
#     "answer": "Updated the answer."
#   },
#   "parentDocumentId": "doc2",
#   "indexTime": "2024-12-31T02:59:58.531615Z"
# }

# %% [markdown]
# **7. Read Multiple Records**
#
# To retrieve several records:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def read_one_record(document_id):
    """
    Fetch a single document's data from the Discovery Engine.
    Args:
        document_id (str): The ID of the document to read.
    """
    if not document_id:
        print("Error: Document ID cannot be empty!")
        return

    url = f"{BASE_URL}/{document_id}"  # API endpoint for the document
    try:
        response = requests.get(url, headers=HEADERS)  # Send GET request
        if response.status_code == 200:
            print(f"Record {document_id} retrieved successfully!")
            print(json.dumps(response.json(), indent=2))  # Pretty print the JSON response
        elif response.status_code == 404:
            print(f"Record {document_id} not found.")
        else:
            print(f"Failed to retrieve record {document_id}: {response.status_code} - {response.text}")
    except requests.exceptions.RequestException as e:
        print(f"Error while trying to fetch record {document_id}: {e}")


def read_multiple_records(document_ids):
    for document_id in document_ids:
        read_one_record(document_id)


read_multiple_records(["doc34", "doc2"])
# Out:
# Record doc34 retrieved successfully!
# {
#   "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/doc34",
#   "id": "doc34",
#   "schemaId": "default_schema",
#   "structData": {
#     "id": "doc34",
#     "category": "Tech",
#     "answer": "AI is artificial intelligence.",
#     "question": "What is AI?"
#   },
#   "parentDocumentId": "doc34",
#   "indexTime": "2024-12-30T16:31:23.630975Z"
# }
# Record doc2 retrieved successfully!
# {
#   "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/doc2",
#   "id": "doc2",
#   "schemaId": "default_schema",
#   "structData": {
#     "category": "Updated the category",
#     "question": "Updated thexxxx question?",
#     "answer": "Updated the answer.",
#     "id": "doc2"
#   },
#   "parentDocumentId": "doc2",
#   "indexTime": "2024-12-31T02:59:58.531615Z"
# }

# %% [markdown]
# **8. Read All Records**
#
# To retrieve several records:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh1_1735396977358"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def read_all_records():
    """
    Fetch all documents from the Discovery Engine.
    """
    url = f"{BASE_URL}"  # API endpoint for listing documents
    records = []
    next_page_token = None

    try:
        while True:
            params = {}
            if next_page_token:
                params["pageToken"] = next_page_token

            response = requests.get(url, headers=HEADERS, params=params)
            if response.status_code == 200:
                data = response.json()
                records.extend(data.get("documents", []))  # Append retrieved documents
                next_page_token = data.get("nextPageToken")

                if not next_page_token:  # No more pages
                    break
            else:
                print(f"Failed to fetch records: {response.status_code} - {response.text}")
                break

        # Print all retrieved records
        if records:
            print(f"Retrieved {len(records)} records:")
            print(json.dumps(records, indent=2))  # Pretty print all records
        else:
            print("No records found.")
    except requests.exceptions.RequestException as e:
        print(f"Error while trying to fetch records: {e}")

# Call the function to read all records
read_all_records()
# Out:
# Retrieved 799 records:
# [
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/016b17c388d22ff07c337b69e91d7263",
#     "id": "016b17c388d22ff07c337b69e91d7263",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u3054\u56de\u7b54\u3001\u6dfb\u524a\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\u3002",
#       "id": "qa_107",
#       "category": "## \u8981\u7d04: \u304a\u5ba2\u69d8\u306f\u56de\u7b54\u3068\u6dfb\u524a\u306b\u611f\u8b1d\u306e\u610f\u3092\u8868\u660e\u3057\u3066\u3044\u307e\u3059\u3002",
#       "answer": "\u677e\u4e38\u3055\u3093\u672c\u65e5\u306f\u304a\u5fd9\u3057\u3044\u4e2d\u304a\u6642\u9593\u3044\u305f\u3060\u304d\u307e\u3057\u3066\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\u3002\u4eca\u5f8c\u30ab\u30ea\u30ad\u30e5\u30e9\u30e0\u3092\u9032\u3081\u3064\u3064\u3001\u52c9\u5f37\u4f1a\u3082\u6d3b\u7528\u3057\u306a\u304c\u3089\u5b9f\u52d9\u306b\u6d3b\u304b\u305b\u308b\u3068\u3053\u308d\u307e\u3067\u5f15\u304d\u7d9a\u304d\u304c\u3093\u3070\u3063\u3066\u3059\u3059\u3081\u3066\u3044\u304d\u307e\u3057\u3087\u3046\u263a\u3054\u4e0d\u660e\u70b9\u3084\u3054\u8cea\u554f\u3042\u308a\u307e\u3057\u305f\u3089\u9060\u616e\u306a\u304f\u3044\u3064\u3067\u3082\u3054\u76f8\u8ac7\u304f\u3060\u3055\u3044\u307e\u305b\u3002\u3054\u8cea\u554f\u9802\u304d\u307e\u3057\u305fQ\uff06A\u96c6\u306b\u3064\u304d\u307e\u3057\u3066\u306f\u3001\u904b\u55b6\u306b\u78ba\u8a8d\u3057\u305f\u3068\u3053\u308d\u3001\u73fe\u72b6\u3054\u7528\u610f\u304c\u306a\u3044\u72b6\u614b\u3067\u5927\u5909\u7533\u3057\u8a33\u3042\u308a\u307e\u305b\u3093\u3002\u91cd\u306d\u3066\u306e\u3054\u6848\u5185\u306b\u306f\u306a\u308a\u307e\u3059\u304c\u3001\u8b1b\u5e2b\u304c\u8907\u6570\u4eba\u3044\u307e\u3059\u306e\u3067\u3001\u304a\u6642\u9593\u3042\u308a\u307e\u3057\u305f\u3089\u4f55\u5ea6\u304b\u52c9\u5f37\u4f1a\u3078\u3054\u53c2\u52a0\u3044\u305f\u3060\u304d\u304a\u8a71\u3044\u305f\u3060\u3051\u308c\u3070\u3068\u5b58\u3058\u307e\u3059\u3002\u6700\u7d42\u9762\u8ac7\u306b\u3064\u304d\u307e\u3057\u3066\u306f\u3001\u9032\u6357\u3092\u898b\u3066\u4e0b\u8a18\u30ea\u30f3\u30af\u3088\u308a\u3054\u4e88\u7d04\u3044\u305f\u3060\u3051\u308c\u3070\u3068\u601d\u3044\u307e\u3059\u3002[https://timerex.net/s/HerTech-mentor-GAI2/289fc348 (\u77ed\u7e2e)] \u5f15\u304d\u7d9a\u304d\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002\u6c60\u7530"
#     },
#     "parentDocumentId": "016b17c388d22ff07c337b69e91d7263"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/01c316201b7631c399839c9a060ff013",
#     "id": "01c316201b7631c399839c9a060ff013",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "4-3\u5b8c\u4e86\u3057\u307e\u3057\u305f\u3002",
#       "category": "\u5b8c\u4e86\u3057\u307e\u3057\u305f\u3002",
#       "id": "qa_720",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\ud83d\ude0a"
#     },
#     "parentDocumentId": "01c316201b7631c399839c9a060ff013"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/01d9e1a21782d65e21a45f0e045c8cbc",
#     "id": "01d9e1a21782d65e21a45f0e045c8cbc",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\u2728",
#       "id": "qa_509",
#       "category": "\u9867\u5ba2\u30b5\u30dd\u30fc\u30c8: \u8ab2\u984c\u63d0\u51fa",
#       "question": "week7-1,2,3\u306e\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002"
#     },
#     "parentDocumentId": "01d9e1a21782d65e21a45f0e045c8cbc"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/02b3484e6bfbe1e4a0aacac01303fafe",
#     "id": "02b3484e6bfbe1e4a0aacac01303fafe",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_168",
#       "category": "## \u8ab2\u984c\u63d0\u51fa\u9023\u7d61\n\n\u3053\u306e\u30e1\u30c3\u30bb\u30fc\u30b8\u306f\u3001\u304a\u5ba2\u69d8\u304b\u3089\u8ab2\u984c\u306e\u63d0\u51fa\u3092\u4f1d\u3048\u308b\u9023\u7d61\u3067\u3059\u3002\n\n**\u30ab\u30c6\u30b4\u30ea:** \u8ab2\u984c\u63d0\u51fa",
#       "question": "WEEK1-4\u8ab2\u984c\u2463\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u307e\u3057\u305f\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf31"
#     },
#     "parentDocumentId": "02b3484e6bfbe1e4a0aacac01303fafe"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/02e2806f6bc7baaea1fe15696ae1eb5b",
#     "id": "02e2806f6bc7baaea1fe15696ae1eb5b",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u3059\u307f\u307e\u305b\u3093\u3001\u6628\u65e5\u9001\u308a\u640d\u306d\u307e\u3057\u305f\u3002\u3010\u4eca\u65e5(\u6628\u65e5)\u53d6\u308a\u7d44\u3093\u3060\u3053\u3068\u3011\u30fb1-3 \u5b9f\u8df5\u8ab2\u984c\u5b9f\u65bd\u30fb1-3 \u5b9f\u8df5\u8ab2\u984c\u63d0\u51fa\u4ee5\u4e0a\u3001\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u81f4\u3057\u307e\u3059\u3002",
#       "answer": "\u304a\u53d6\u308a\u7d44\u307f\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\u27281\u20103\u307e\u3067\u5b8c\u4e86\u3067\u3059\u306d\ud83d\ude0a\u30b3\u30c4\u30b3\u30c4\u53d6\u308a\u7d44\u3081\u3066\u3044\u308b\u306e\u3067\u3001\u5f15\u304d\u7d9a\u304d\u7121\u7406\u306a\u304f\u53d6\u308a\u7d44\u307f\u9032\u3081\u3066\u3044\u304d\u307e\u3057\u3087\u3046\ud83d\udcaa",
#       "category": "## 1-3 \u5b9f\u8df5\u8ab2\u984c\u306e\u63d0\u51fa\n\n## \u304a\u554f\u3044\u5408\u308f\u305b\u306e\u5185\u5bb9\n\n\u3053\u308c\u306f\u8ab2\u984c\u63d0\u51fa\u306b\u95a2\u3059\u308b\u9023\u7d61\u3067\u3059\u3002",
#       "id": "qa_965"
#     },
#     "parentDocumentId": "02e2806f6bc7baaea1fe15696ae1eb5b"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/03913a96f9ea8fec113a7dbce14652ca",
#     "id": "03913a96f9ea8fec113a7dbce14652ca",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_1408",
#       "category": "\u30d0\u30ca\u30fc\u306e\u8272\u5909\u66f4\u306b\u3064\u3044\u3066\u76f8\u8ac7",
#       "question": "\u5148\u307b\u3069\u306e\u8cea\u554f\u3001\u89e3\u6c7a\u3044\u305f\u3057\u307e\u3057\u305f\u3002\u753b\u50cf\u306e\u7d20\u6750\u304c\u6dfb\u4ed8\u3055\u308c\u3066\u3044\u3066\u3001\u305d\u308c\u304c\u6587\u5b57\u5316\u3051\u3057\u3066\u958b\u3051\u306a\u304b\u3063\u305f\u305f\u3081\u6c17\u3065\u304d\u307e\u305b\u3093\u3067\u3057\u305f\u3002\u3059\u307f\u307e\u305b\u3093\u3002\u3082\u3046\u4e00\u3064\u8cea\u554f\u306a\u306e\u3067\u3059\u304c\u3001\u30c8\u30f3\u30de\u30ca\u3067\u6c7a\u3081\u305f\u30ab\u30e9\u30fc\u3067\u30d0\u30ca\u30fc\u3092\u4f5c\u308d\u3046\u3068\u601d\u3063\u305f\u306e\u3067\u3059\u304c\u3084\u3063\u3066\u884c\u304f\u3046\u3061\u306b\u3001\u8272\u3092\u5909\u66f4\u3057\u305f\u3044\u3068\u601d\u3063\u305f\u306e\u3067\u3059\u304c\u30c8\u30f3\u30de\u30ca\u3067\u6c7a\u3081\u305f\u30ab\u30e9\u30fc\u306f\u305d\u306e\u4eba\u306e\u30a4\u30e1\u30fc\u30b8\u306e\u30ef\u30fc\u30c9\u304b\u3089\u95a2\u9023\u3057\u305f\u8272\u3092\u9078\u3093\u3060\u3068\u601d\u3046\u306e\u3067\u3059\u304c\u3001\u9014\u4e2d\u3067\u5909\u3048\u308b\u3068\u305d\u306e\u4eba\u306e\u30a4\u30e1\u30fc\u30b8\u30ef\u30fc\u30c9\u3068\u306f\u96e2\u308c\u3066\u3057\u307e\u3046\u3088\u3046\u306a\u6c17\u304c\u3057\u3066\u8ff7\u3063\u3066\u3044\u307e\u3059\u3002\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002",
#       "answer": "\u3054\u8cea\u554f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u25ce\u7d20\u6750\u306b\u3064\u3044\u3066\u306f\u89e3\u6c7a\u3057\u305f\u3088\u3046\u3067\u826f\u304b\u3063\u305f\u3067\u3059\ud83d\ude0a\u30c8\u30f3\u30de\u30ca\u306e\u30ab\u30e9\u30fc\u306b\u3064\u3044\u3066\u306f\u3001\u5236\u4f5c\u3057\u3066\u3044\u304f\u3068\u30a4\u30e1\u30fc\u30b8\u3068\u7570\u306a\u3063\u3066\u304f\u308b\u3053\u3068\u304c\u3042\u308a\u307e\u3059\u3088\u306d\ud83d\udca6\u4eca\u56de\u306f\u8ab2\u984c\u306a\u306e\u3067\u3001\u9014\u4e2d\u3067\u5909\u66f4\u3057\u306a\u304c\u3089\u5236\u4f5c\u3057\u3066\u3044\u305f\u3060\u3044\u3066\u5927\u4e08\u592b\u3067\u3059\u3088\ud83d\ude4c\u5909\u66f4\u3059\u308b\u969b\u306f\u3001\u53c2\u8003\u3068\u3057\u3066\u3044\u308b\u30c7\u30b6\u30a4\u30f3\u3092\u898b\u8fd4\u3057\u306a\u304c\u3089\u3001\u81ea\u5206\u306e\u8a2d\u5b9a\u3057\u305f\u30ab\u30e9\u30fc\u304c\u30da\u30eb\u30bd\u30ca\u306e\u30a4\u30e1\u30fc\u30b8\u306b\u5408\u3063\u3066\u3044\u308b\u306e\u304b\u3092\u78ba\u8a8d\u3057\u307e\u3057\u3087\u3046\ud83c\udf31\u5b9f\u52d9\u3067\u306f\u3001\u30af\u30e9\u30a4\u30a2\u30f3\u30c8\u306b\u306a\u305c\u5909\u66f4\u3059\u308b\u306e\u304b\u3092\u8aac\u660e\u3059\u308b\u5fc5\u8981\u304c\u3042\u308b\u306e\u3067\u3001\u5909\u66f4\u3059\u308b\u7406\u7531\u3092\u8a00\u8a9e\u5316\u3057\u306a\u304c\u3089\u53d6\u308a\u7d44\u3093\u3067\u307f\u3066\u304f\u3060\u3055\u3044\u306d\uff3e\uff3e"
#     },
#     "parentDocumentId": "03913a96f9ea8fec113a7dbce14652ca"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/040f2a0faaf962a6e8aeb879fbd2f1a0",
#     "id": "040f2a0faaf962a6e8aeb879fbd2f1a0",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_318",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u3002\u6dfb\u524a\u5b8c\u4e86\u3057\u307e\u3057\u305f\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf31",
#       "category": "\u8cea\u554f",
#       "question": "w6-2 \u307e\u3067\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002"
#     },
#     "parentDocumentId": "040f2a0faaf962a6e8aeb879fbd2f1a0"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/043dfda6e10fd09dce3ba0694dd65b2a",
#     "id": "043dfda6e10fd09dce3ba0694dd65b2a",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "\u5b66\u8a3c\u660e\u767a\u884c\u4f9d\u983c",
#       "question": "\u5728\u5b66\u8a3c\u660e\u306b\u3064\u3044\u3066\u3001\u5bfe\u5fdc\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u3002\u25cf\u30aa\u30f3\u30e9\u30a4\u30f3\u30b9\u30af\u30fc\u30eb\u3067\u306e\u5728\u5b66\u8a3c\u660e\u66f8\u767a\u884c\u306b\u3064\u3044\u3066\u306f\u78ba\u8a8d\u3057\u3066\u304a\u308a\u3001\u63d0\u51fa\u3057\u3066\u3082\u69cb\u308f\u306a\u3044\u3068\u306e\u3053\u3068\u3067\u3059\u3002\u25cf\u30d5\u30a9\u30fc\u30de\u30c3\u30c8\u306b\u3064\u3044\u3066\u3001\u30d5\u30ea\u30fc\u30d5\u30a9\u30fc\u30de\u30c3\u30c8\u3067\u304a\u9858\u3044\u3057\u307e\u3059\u3002\u60c5\u5831\u304c\u8db3\u308a\u306a\u3044\u7b49\u3001\u4e0d\u5099\u304c\u767a\u751f\u3057\u8a8d\u53ef\u3055\u308c\u306a\u3044\u5834\u5408\u3067\u3082\u6c42\u8077\u4e2d\u3067\u9078\u8003\u3055\u308c\u308b\u3068\u3044\u3046\u3053\u3068\u3067\u3059\u3002\u9001\u4ed8\u5148\u306f\u30e1\u30fc\u30eb\u3067\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002\u30e1\u30fc\u30eb\u30a2\u30c9\u30ec\u30b9\uff1alove.l.p.s.h.55@gmail.com",
#       "answer": "\u591c\u5206\u306b\u5931\u793c\u3044\u305f\u3057\u307e\u3059\ud83d\ude47\u200d\u2640\ufe0f\u3054\u78ba\u8a8d\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u25ce\u305d\u308c\u3067\u306f\u9031\u660e\u3051\u306b\u4f5c\u6210\u3044\u305f\u3057\u307e\u3059\u306e\u3067\u3001\u4e0b\u8a18\u306b\u3064\u3044\u3066\u304a\u624b\u3059\u304d\u3067\u304a\u8fd4\u4e8b\u3044\u305f\u3060\u3051\u307e\u3059\u3068\u5e78\u3044\u3067\u3059\u3002\u30fb\u304a\u540d\u524d\u6f22\u5b57\u30fb\u3075\u308a\u304c\u306a\u30fb\u751f\u5e74\u6708\u65e5\u30fb\u3054\u4f4f\u6240\u5bfe\u5fdc\u306f\u9031\u660e\u3051\u6708\u66dc\u304c\u6700\u77ed\u3068\u306a\u308a\u307e\u3059\u306e\u3067\u3001\u304a\u6642\u9593\u3092\u3044\u305f\u3060\u304d\u307e\u3059\u3053\u3068\u4f55\u5352\u3054\u4e86\u627f\u304f\u3060\u3055\u3044\u307e\u305b\ud83d\ude47\u200d\u2640\ufe0f",
#       "id": "qa_989"
#     },
#     "parentDocumentId": "043dfda6e10fd09dce3ba0694dd65b2a"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/0487f3acac9de51159067db80d808e0c",
#     "id": "0487f3acac9de51159067db80d808e0c",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u682a\u5f0f\u4f1a\u793e\u30a2\u30a6\u30ed\u30fc\u30e9\n\u6a4b\u672c\u69d8\u904b\u55b6\u4e8b\u52d9\u5c40\u3067\u3054\u3056\u3044\u307e\u3059\u3002\u901a\u5e38\u3001\u304a\u652f\u6255\u3044\u306e\u7de0\u3081\u5207\u308a\u306f10\u67083\u65e5\u307e\u3067\u3068\u3055\u305b\u3066\u3044\u305f\u3060\u3044\u3066\u304a\u308a\u307e\u3059\u304c\u3001\u4eca\u56de\u306f\u7279\u5225\u306b\u5bfe\u5fdc\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u307e\u3059\uff01\u671f\u65e5\u304c\u5dee\u3057\u8feb\u3063\u3066\u304a\u308a\u307e\u3059\u65e8\u3001\u4f55\u5352\u3054\u4e86\u627f\u3044\u305f\u3060\u3051\u307e\u3059\u3068\u5e78\u3044\u3067\u3059\u3002\u4e0b\u8a18\u306b\u3066\u304a\u652f\u6255\u3044\u4f9d\u983c\u66f8\u3092\u304a\u9001\u308a\u3044\u305f\u3057\u307e\u3059\u306e\u3067\u3001\u3054\u78ba\u8a8d\u306e\u307b\u3069\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002\u25bc\u304a\u652f\u6255\u3044\u4f9d\u983c\u66f8[https://drive.google.com/file/d/1R_PZ6VVYoodIRUFn5wr12iuszCl38cXm/view?usp=sharing (\u77ed\u7e2e)] \u25bc\u304a\u652f\u6255\u3044\u671f\u65e5\u672c\u65e510\u67084\u65e5(\u91d1)13\u6642\u307e\u3067\u304a\u624b\u6570\u3092\u304a\u304b\u3051\u3044\u305f\u3057\u307e\u3059\u304c\u3001\u5165\u91d1\u304c\u5b8c\u4e86\u3055\u308c\u307e\u3057\u305f\u3089\u3001\u304a\u632f\u8fbc\u307f\u3044\u305f\u3060\u3044\u305f\u53e3\u5ea7\u306e\u540d\u7fa9\u3092LINE\u306b\u3066\u3054\u9023\u7d61\u3044\u305f\u3060\u3051\u307e\u3059\u3088\u3046\u304a\u9858\u3044\u7533\u3057\u4e0a\u3052\u307e\u3059\ud83d\ude0c\u306a\u304a\u300113\u6642\u307e\u3067\u306b\u3054\u5165\u91d1\u306e\u78ba\u8a8d\u304c\u53d6\u308c\u306a\u3044\u5834\u5408\u306f\u3001\u6050\u308c\u5165\u308a\u307e\u3059\u304c\u3001\u53d7\u8b1b\u958b\u59cb\u65e5\u3092\u5909\u66f4\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u307e\u3059\u3053\u3068\u3092\u3054\u4e86\u627f\u304f\u3060\u3055\u3044\u307e\u305b\u3002\u5f15\u304d\u7d9a\u304d\u3001\u3069\u3046\u305e\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u7533\u3057\u4e0a\u3052\u307e\u3059\u3002   \u3044\u307e\u5165\u91d1\u3044\u305f\u3057\u307e\u3057\u305f\uff01",
#       "id": "qa_263",
#       "category": "\u304a\u652f\u6255\u3044\u671f\u9650\u306e\u7336\u4e88\u3092\u9858\u3044\u3001\u304a\u652f\u6255\u3044\u5b8c\u4e86\u306e\u5831\u544a.",
#       "answer": "\u3054\u9023\u7d61\u304f\u3060\u3055\u308a\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\u73fe\u5728\u3001\u9806\u756a\u306b\u3054\u8fd4\u7b54\u3092\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u304a\u5f85\u3061\u3044\u305f\u3060\u3051\u307e\u3059\u3068\u5e78\u3044\u3067\u3059\u3002\u203b\u304a\u554f\u5408\u305b\u53d7\u4ed8\u6642\u9593\u3000\u5e73\u65e5\u3001\u571f\u66dc\u65e5\u30009\u6642~21\u6642\u6642\u9593\u5916\u306e\u304a\u554f\u5408\u308f\u305b\u306b\u3064\u304d\u307e\u3057\u3066\u306f\u3001\u7fcc\u55b6\u696d\u65e5\u3088\u308a\u9806\u6b21\u3054\u5bfe\u5fdc\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u307e\u3059\u3002"
#     },
#     "parentDocumentId": "0487f3acac9de51159067db80d808e0c"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/050281b792cfa6785165ae5d28e1c87a",
#     "id": "050281b792cfa6785165ae5d28e1c87a",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_312",
#       "question": "\u8ab2\u984c\u63d0\u51fa\u306e\u5831\u544aw6-3\u7d42\u4e86\u81f4\u3057\u307e\u3057\u305f\u3002\u5b9c\u3057\u304f\u304a\u9858\u3044\u81f4\u3057\u307e\u3059\u3002",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\u5f15\u304d\u7d9a\u304d\u3054\u63d0\u51fa\u304a\u5f85\u3061\u3057\u3066\u304a\u308a\u307e\u3059\u266a",
#       "category": "\u8ab2\u984c\u306e\u63d0\u51fa\u5831\u544a"
#     },
#     "parentDocumentId": "050281b792cfa6785165ae5d28e1c87a"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/057930274402e5aecb36d9b8ab39aa20",
#     "id": "057930274402e5aecb36d9b8ab39aa20",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\u304a\u5f85\u305f\u305b\u3044\u305f\u3057\u307e\u3057\u305f\u3001\u6dfb\u524a\u5b8c\u4e86\u3057\u307e\u3057\u305f\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf31",
#       "category": "\u30d7\u30ed\u30f3\u30d7\u30c8\u306b\u95a2\u3059\u308b\u554f\u3044\u5408\u308f\u305b, 6-1\u5b9f\u8df5\u8ab2\u984c\u306e\u6dfb\u524a\u4f9d\u983c",
#       "question": "\u3054\u9023\u7d61\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\u3002\u30d7\u30ed\u30f3\u30d7\u30c8\u306e\u5171\u6709\u304c\u3067\u304d\u308b\u3088\u3046\u306b\u306a\u308a\u307e\u3057\u305f\u306e\u30676-1\u5b9f\u8df5\u8ab2\u984c\u306e\u30d7\u30ed\u30f3\u30d7\u30c8\u3092\u5165\u529b\u3057\u307e\u3057\u305f\u3002\u6dfb\u524a\u306e\u307b\u3069\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002",
#       "id": "qa_382"
#     },
#     "parentDocumentId": "057930274402e5aecb36d9b8ab39aa20"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/057abdd599f143dbe1279c7832cb6466",
#     "id": "057abdd599f143dbe1279c7832cb6466",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "\u8ab2\u984c\u306e\u63d0\u51fa",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\ud83d\ude0a",
#       "question": "Week6-4 \u5b9f\u8df5\u8ab2\u984c\u306e\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f",
#       "id": "qa_450"
#     },
#     "parentDocumentId": "057abdd599f143dbe1279c7832cb6466"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/06096196c6a614e08195038499152b6b",
#     "id": "06096196c6a614e08195038499152b6b",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\ud83d\ude0a",
#       "category": "\u90315-3\u306e\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002",
#       "id": "qa_143",
#       "question": "Week5-3\u306e\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002"
#     },
#     "parentDocumentId": "06096196c6a614e08195038499152b6b"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/0642c1eb5cd8c13323ca507c4922827a",
#     "id": "0642c1eb5cd8c13323ca507c4922827a",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u3054\u8cea\u554f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u25ce\u52d5\u753b\u306f\u5c3a\u306e\u95a2\u4fc2\u3067\u4e00\u77ac\u3067\u4f5c\u3063\u3066\u3044\u308b\u3088\u3046\u306b\u898b\u3048\u307e\u3059\u304c\u3001\u5b9f\u969b\u306f1\u3064\u305a\u3064\u4f5c\u6210\u3059\u308b\u5f62\u3068\u306a\u308a\u307e\u3059\ud83d\ude0c\ud83d\udca6\u53d6\u308a\u7d44\u307f\u65b9\u3068\u3057\u3066\u306f\u3001\u30c8\u30ec\u30fc\u30b9\u3067\u3057\u3066\u3044\u305f\u3060\u3044\u305f\u3088\u3046\u306b\u3001\u56db\u89d2\u306e\u56f3\u5f62\u3092\u914d\u7f6e\u3057\u3001\u30b9\u30dd\u30a4\u30c8\u306e\u30a2\u30a4\u30b3\u30f3\u3092\u4f7f\u3063\u3066\u753b\u50cf\u304b\u3089\u8272\u3092\u62bd\u51fa\u3057\u3066\u4f5c\u6210\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u306d\ud83d\ude4c\u64cd\u4f5c\u306b\u3064\u3044\u3066\u308f\u304b\u3089\u306a\u3044\u3053\u3068\u304c\u3042\u308c\u3070\u3001\u307e\u305f\u304a\u6c17\u8efd\u306b\u304a\u554f\u3044\u5408\u308f\u305b\u304f\u3060\u3055\u3044\uff3e\uff3e",
#       "id": "qa_991",
#       "question": "\u4e95\u95a2\u3055\u3093\u300c\u4eca\u65e5\u53d6\u308a\u7d44\u3093\u3060\u3053\u3068\u300d2-1 \u52d5\u753b\u8996\u80742-1 \u8ab2\u984c\u63d0\u51fa2-2\u52d5\u753b\u8996\u80742-2 \u5b9f\u8df5\u8ab2\u984c\u5b9f\u65bd2-2 \u5b9f\u8df5\u8ab2\u984c\u63d0\u51fa",
#       "category": "\u52d5\u753b\u8996\u8074\u3068\u8ab2\u984c\u306e\u63d0\u51fa\u306b\u95a2\u3059\u308b\u554f\u3044\u5408\u308f\u305b\u3002"
#     },
#     "parentDocumentId": "0642c1eb5cd8c13323ca507c4922827a"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/06c508bcde429f4f857eb8d98de96556",
#     "id": "06c508bcde429f4f857eb8d98de96556",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u8ab2\u984c2-3\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002\u5b9c\u3057\u304f\u304a\u9858\u3044\u3057\u307e\u3059",
#       "category": "\u8ab2\u984c\u306e\u63d0\u51fa\u3068\u78ba\u8a8d\u4f9d\u983c",
#       "id": "qa_441",
#       "answer": "\u83ca\u5730\u3055\u3093\u3001\u672c\u65e5\u306f\u52c9\u5f37\u4f1a\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\uff01\u3054\u8cea\u554f\u306e\u4ef6\u3001\u56de\u7b54\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u307e\u3059\u3002\u3010\u3054\u8cea\u554f\u3011Canva\u304b\u3089\u76f4\u63a5\u3001\u753b\u50cf\u3092\u8907\u6570\u679a\u6295\u7a3f\u3059\u308b\u3053\u3068\u306f\u53ef\u80fd\u304b\uff1f\u3010\u56de\u7b54\u3011\u8907\u6570\u679a\u306e\u6295\u7a3f\u306f\u3001\u3067\u304d\u307e\u305b\u3093\u3002Canva\u304b\u3089\u76f4\u63a5\u6295\u7a3f\u3059\u308b\u5834\u5408\u306f\u30011\u679a\u306e\u307f\u3067\u3059\u3002\u3044\u3063\u305f\u3093\u753b\u50cf\u3092\u4fdd\u5b58\u3057\u3001Instagram\u306e\u30a2\u30d7\u30ea\u3092\u958b\u3044\u3066\u6295\u7a3f\u3057\u3066\u304f\u3060\u3055\u3044\u3002\uff08Canva\u304b\u3089\u306f1\u679a\u3057\u304b\u6295\u7a3f\u3067\u304d\u306a\u3044\u305f\u3081\u3001\u83ca\u5730\u3055\u3093\u306e\u30b9\u30de\u30db\u306b\u300c\u6295\u7a3f\u300d\u304c\u8868\u793a\u3055\u308c\u306a\u304b\u3063\u305f\u53ef\u80fd\u6027\u304c\u3042\u308a\u307e\u3059\u3002\uff09\u3010\u3054\u8cea\u554f\u3011\u30ea\u30fc\u30eb\u6295\u7a3f\u3068\u3001\u30b9\u30c8\u30fc\u30ea\u30fc\u30ba\u3092\u52b9\u7387\u3088\u304f\u304a\u3053\u306a\u3046\u65b9\u6cd5\u306f\uff1f\u3010\u56de\u7b54\u3011\u8907\u6570\u679a\u306e\u5834\u5408\u3001Canva\u3067\u306f\u6295\u7a3f\u304c\u3067\u304d\u306a\u3044\u305f\u3081\u3001\u306f\u3058\u3081\u306bInstagram\u306e\u30a2\u30d7\u30ea\u304b\u3089\u30ea\u30fc\u30eb\u6295\u7a3f\u3092\u304a\u3053\u306a\u3044\u307e\u3059\u3002\u6b21\u306b\u3001\u6295\u7a3f\u753b\u9762\u4e0b\u306b\u3042\u308b\u7d19\u98db\u884c\u6a5f\u30de\u30fc\u30af\u3092\u62bc\u3057\u3066\u300c\u30b9\u30c8\u30fc\u30ea\u30fc\u30ba\u306b\u8ffd\u52a0\u300d\u3092\u9078\u629e\u3057\u307e\u3059\u3002\u3059\u308b\u3068\u3001\u30ea\u30fc\u30eb\u6295\u7a3f\u306e\u5185\u5bb9\uff08\u8907\u6570\u679a\uff09\u3092\u305d\u306e\u307e\u307e\u30b9\u30c8\u30fc\u30ea\u30fc\u30ba\u306b\u3042\u3052\u3089\u308c\u307e\u3059\u3002\u3010\u3054\u8cea\u554f\u3011Canva\u306e\u4fdd\u5b58\u30c7\u30fc\u30bf\u304c\u898b\u3064\u3051\u305a\u3089\u3044\u3001\u4f55\u304b\u826f\u3044\u65b9\u6cd5\u306f\uff1f\u3010\u56de\u7b54\u3011Canva\u5185\u306b\u30d5\u30a9\u30eb\u30c0\u3092\u4f5c\u3063\u3066\u7ba1\u7406\u3059\u308b\u3053\u3068\u304c\u3067\u304d\u307e\u3059\u3002\uff5e\u3084\u308a\u65b9\uff5e\u2460PC\u3067Canva\u3092\u958b\u304f\u2461\u5de6\u6b04\u304b\u3089\u300c\u30d7\u30ed\u30b8\u30a7\u30af\u30c8\u300d\u3092\u9078\u629e\u2462\u53f3\u4e0a\u306e\u300c\uff0b\u65b0\u3057\u304f\u8ffd\u52a0\u300d\u3092\u30af\u30ea\u30c3\u30af\u2463\u30d5\u30a9\u30eb\u30c0\u540d\u3092\u6c7a\u3081\u3066\u4f5c\u6210\u2464\u300c\u6700\u8fd1\u306e\u30c7\u30b6\u30a4\u30f3\u300d\u304b\u3089\u3001\u30d5\u30a9\u30eb\u30c0\u306b\u79fb\u884c\u3057\u305f\u3044\u753b\u50cf\u306e\u300c\u5de6\u4e0a\u306e\u767d\u3044\u30dc\u30c3\u30af\u30b9\u306b\u30c1\u30a7\u30c3\u30af\u300d\u3092\u3044\u308c\u308b\u2465\u753b\u50cf\u4e0b\u306e\u65b9\u306b\u767b\u5834\u3059\u308b\u30d5\u30a9\u30eb\u30c0\u30de\u30fc\u30af\u3068\u3054\u307f\u7bb1\u30de\u30fc\u30af\u306e\u3046\u3061\u3001\u300c\u30d5\u30a9\u30eb\u30c0\u30de\u30fc\u30af\u300d\u3092\u9078\u629e\u3059\u308b\u4e0b\u8a18YouTube\u52d5\u753b\u3082\u308f\u304b\u308a\u3084\u3059\u3044\u306e\u3067\u53c2\u8003\u306b\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u306d\u3002\u4e0b\u8a18\u52d5\u753b\u306e3\u520655\u79d2\uff5e\u89e3\u8aac\u3042\u308a[https://youtu.be/n7KseZ_HQY0?si=EeN6Wb3N09XjtfQL (\u77ed\u7e2e)] \u307e\u305f\u4f55\u304b\u3054\u3056\u3044\u307e\u3057\u305f\u3089\u3001\u52c9\u5f37\u4f1a\u3084LINE\u3054\u6d3b\u7528\u304f\u3060\u3055\u3044\u3002\u5f15\u304d\u7d9a\u304d\u3001\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3057\u307e\u3059\u3002"
#     },
#     "parentDocumentId": "06c508bcde429f4f857eb8d98de96556"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/06cb558881bd0a27bcdf674da2398132",
#     "id": "06cb558881bd0a27bcdf674da2398132",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u3053\u3093\u306b\u3061\u306f\u5b9f\u8df5\u8ab2\u984cweek2-4\uff5e3-2\u63d0\u51fa\u3044\u305f\u3057\u307e\u3057\u305f\u3002\u3054\u78ba\u8a8d\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3057\u307e\u3059\u3002",
#       "category": "\u9031\u9593\u8ab2\u984c2-4\uff5e3-2\u3092\u63d0\u51fa\u3057\u305f\u306e\u3067\u78ba\u8a8d\u304a\u9858\u3044\u3057\u307e\u3059\u3002 \n\n**\u76ee\u7684:** \u8ab2\u984c\u306e\u63d0\u51fa\u78ba\u8a8d\n\n**\u30ab\u30c6\u30b4\u30ea\u30fc:** \u8ab2\u984c\u63d0\u51fa",
#       "id": "qa_066",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u307e\u3057\u305f\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf31"
#     },
#     "parentDocumentId": "06cb558881bd0a27bcdf674da2398132"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/06fabc93fda33fe05d7ddb93a961361e",
#     "id": "06fabc93fda33fe05d7ddb93a961361e",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_1220",
#       "question": "\u3053\u3093\u3070\u3093\u306f\uff01\u6628\u65e5\u306f\u982d\u75db\u304c\u9177\u304f\u306a\u306b\u3082\u3067\u304d\u306a\u304b\u3063\u305f\u3067\u3059\u00b7\u00b7\u00b7\u00b7\u00b7\u4eca\u65e5\u306f4\u500b\u76ee\u306e\u52d5\u753b\u3092\u898b\u3066\u3001\u6dfb\u524a\u3057\u3066\u3044\u305f\u3060\u3044\u305f\u5185\u5bb9\u3092\u8aad\u3093\u3067\u3001\u660e\u65e5\u4ee5\u964d\u3067\u624b\u76f4\u3057\u3057\u3066\u3044\u3053\u3046\u3068\u601d\u3044\u307e\u3059\uff01",
#       "category": "\u982d\u304c\u75db\u304f\u3001\u6628\u65e5\u306e\u52d5\u753b\u306e\u6dfb\u524a\u3092\u660e\u65e5\u306b\u5ef6\u671f",
#       "answer": "\u3054\u5831\u544a\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\u6c17\u5727\u3067\u3059\u304b\u306d\uff1f\uff1e\uff1c\u4e00\u6628\u65e5\u306f\u306a\u3093\u3060\u304b\u4f53\u8abf\u4e0d\u826f\u306e\u65b9\u3082\u591a\u304b\u3063\u305f\u6c17\u304c\u3057\u3066\u304a\u308a\u307e\u3059\ud83e\udd72\u3054\u81ea\u8eab\u306e\u826f\u3044\u30da\u30fc\u30b9\u3067\u7121\u7406\u306f\u3057\u3059\u304e\u305a\u9032\u3081\u3066\u3044\u304d\u307e\u3057\u3087\u3046\u306d\ud83c\udf31\u304a\u53d6\u308a\u7d44\u307f\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\ud83d\udc4f\u2728"
#     },
#     "parentDocumentId": "06fabc93fda33fe05d7ddb93a961361e"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/070c431f78da179ad860bbf90d072f45",
#     "id": "070c431f78da179ad860bbf90d072f45",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u8c37\u6d25\u3055\u3093\u3001\u3053\u3093\u3070\u3093\u308f\u3002\u9045\u304f\u306b\u5931\u793c\u3044\u305f\u3057\u307e\u3059\u3002\u25bc\u65e5\u3005\u306e\u53d6\u308a\u7d44\u307f\u5831\u544a\u306b\u3064\u3044\u3066\u300c\u4eca\u65e5\u53d6\u308a\u7d44\u3093\u3060\u3053\u3068\u300d\u3092\u5831\u544a\u3044\u305f\u3057\u307e\u3059\u3002\u30fb\u6628\u65e5\u3086\u3063\u304f\u308a\u4f11\u307f\u307e\u3057\u305f\u306e\u3067\u672c\u65e51-3\u306e\u52d5\u753b\u8996\u8074\u5b8c\u4e86\u3001\u5b9f\u8df5\u3082\u304a\u304a\u307e\u304b\u306a\u3068\u3053\u308d\u307e\u3067\u5b8c\u4e86\u3057\u307e\u3057\u305f\u3002\u660e\u65e5\u3001\u3010\u5b9f\u8df5\u8ab2\u984c\u3067\u3064\u307e\u3065\u304d\u3084\u3059\u3044\u30dd\u30a4\u30f3\u30c8\u3011\u3092\u78ba\u8a8d\u3057\u3001\u7d30\u304b\u3044\u3068\u3053\u3092\u4fee\u6b63\u3057\u307e\u3059\u3002\u5f15\u304d\u7d9a\u304d\u3001\u5b9c\u3057\u304f\u304a\u9858\u3044\u3057\u307e\u3059\ud83d\ude42",
#       "answer": "\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\uff01\u4e01\u5be7\u306b\u9032\u3081\u3089\u308c\u3066\u304a\u308a\u7d20\u6575\u3067\u3059\ud83c\udf31\u5f15\u304d\u7d9a\u304d\u7121\u7406\u306a\u304f\u9032\u3081\u3066\u3044\u304d\u307e\u3057\u3087\u3046\u2728",
#       "id": "qa_943",
#       "category": "## \u65e5\u6b21\u5831\u544a: \u304a\u5ba2\u69d8\u306f 1-3 \u306e\u52d5\u753b\u8996\u8074\u3068\u5b9f\u8df5\u3092\u5b8c\u4e86\u3057\u3001\u660e\u65e5\u5b9f\u8df5\u8ab2\u984c\u306e\u4fee\u6b63\u3092\u884c\u3046\u4e88\u5b9a\u3067\u3059\u3002"
#     },
#     "parentDocumentId": "070c431f78da179ad860bbf90d072f45"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/0736af3259f448e68ec0c5887c73c662",
#     "id": "0736af3259f448e68ec0c5887c73c662",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "\u30d0\u30ca\u30fc\u5236\u4f5c\u306e\u5831\u544a",
#       "question": "\u9762\u8ac7\u65e5\u3092\u6539\u3081\u3055\u305b\u3066\u9802\u304d\u307e\u3057\u305f\u3002\u4eca\u65e5\u306e\u53d6\u308a\u7d44\u307f\u306f\u3001\u5348\u524d\u4e2d\u306bCanva\u81ea\u7fd2\u4f1a\u306b\u53c2\u52a0\u3092\u3057\u3066\u30d0\u30ca\u30fc\u5236\u4f5c\u3092\u3057\u307e\u3057\u305f\u3002",
#       "id": "qa_266",
#       "answer": "\u304a\u53d6\u308a\u7d44\u307f\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\ud83d\udcaa\u9762\u8ac7\u306e\u3054\u4e88\u7d04\u3082\u78ba\u8a8d\u3057\u307e\u3057\u305f\ud83d\ude0a11\u67089\u65e5 (\u571f) 14:00 - 14:30\u4e0a\u8a18\u304a\u65e5\u306b\u3061\u3067\u3001\u6539\u3081\u3066\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\uff01"
#     },
#     "parentDocumentId": "0736af3259f448e68ec0c5887c73c662"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/07f16fcc1d968e9b82d885f2cec99583",
#     "id": "07f16fcc1d968e9b82d885f2cec99583",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_644",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\u6dfb\u524a\u304c\u5b8c\u4e86\u3044\u305f\u3057\u307e\u3057\u305f\u3002\u30d7\u30ed\u30f3\u30d7\u30c8\u3068\u30a2\u30a6\u30c8\u30d7\u30c3\u30c8\u304c\u78ba\u8a8d\u3067\u304d\u307e\u3059\u306e\u3067\u3001\u8a18\u4e8b\u30c7\u30fc\u30bf\u306e\u3054\u63d0\u51fa\u306f\u306a\u304f\u3066\u3082\u554f\u984c\u306a\u3044\u3067\u3059\u3088\u25ce\u9762\u8ac7\u5e0c\u671b\u3057\u306a\u3044\u65e8\u3082\u627f\u77e5\u3044\u305f\u3057\u307e\u3057\u305f\u3002",
#       "category": "\u6700\u7d42\u9762\u63a5\u3092\u8f9e\u9000",
#       "question": "\u6700\u7d42\u9762\u8ac7\u306f\u3001\u3053\u3061\u3089\u304c\u304a\u6642\u9593\u306e\u90fd\u5408\u3092\u5408\u308f\u305b\u308b\u3053\u3068\u304c\u96e3\u3057\u3044\u305f\u3081\u5e0c\u671b\u3057\u306a\u3044\u3092\u9078\u629e\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u307e\u3059!!"
#     },
#     "parentDocumentId": "07f16fcc1d968e9b82d885f2cec99583"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/0825a8f1357cc5b0208a802def515ada",
#     "id": "0825a8f1357cc5b0208a802def515ada",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u5cf6\u6238\u3055\u3093\u3053\u3093\u306b\u3061\u306f\u304a\u75b2\u308c\u69d8\u3067\u3059\ud83d\ude03\u30d0\u30ca\u30fc\u5236\u4f5c\u3092\u3057\u3066\u3044\u305f\u306e\u3067\u3059\u304c\u30012-2\u306e\u8ab2\u984c\u3092\u9593\u9055\u3048\u30662-3\u306b\u63d0\u51fa\u3057\u3066\u3057\u307e\u3044\u307e\u3057\u305f\ud83d\udca62-3\u306e\u8ab2\u984c\u3092\u63d0\u51fa\u3059\u308b\u6642\u306b\u6c17\u3065\u3044\u305f\u306e\u3067\u3001\u3053\u306e\u5834\u5408\u306f\u5f8c\u65e5\u518d\u63d0\u51fa\u3068\u3044\u3046\u5f62\u306b\u306a\u308a\u307e\u3059\u3088\u306d\ud83e\udd72\u4eca\u65e5\u306f\u4f11\u307f\u306a\u306e\u3067\u3001\u52d5\u753b\u3092\u898b\u76f4\u3057\u305f\u308aweb\u8ab2\u984c\u306e\u518d\u63d0\u51fa\u3082\u3057\u3088\u3046\u3068\u601d\u3044\u307e\u3059\ud83d\ude4c\u4ed5\u4e8b\u306b\u8ffd\u308f\u308c\u3066\u3057\u307e\u3063\u3066\u306a\u304b\u306a\u304b\u51fa\u6765\u306a\u304b\u3063\u305f\u306e\u3067\u51fa\u6765\u308b\u6240\u307e\u3067\u3086\u3063\u304f\u308a\u884c\u3044\u307e\u3059\ud83d\ude03",
#       "id": "qa_1347",
#       "category": "\u30d0\u30ca\u30fc\u5236\u4f5c 2-3\u8ab2\u984c\u9593\u9055\u3048\u3066\u63d0\u51fa \u518d\u63d0\u51fa\u5e0c\u671b",
#       "answer": "\u3054\u9023\u7d61\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\u5148\u307b\u30692-3\u306b\u3064\u3044\u3066\u53d6\u308a\u4e0b\u3052\u3044\u305f\u3057\u307e\u3057\u305f\u306e\u3067\u3001\u6539\u3081\u30662\u20103\u3078\u306e\u3054\u63d0\u51fa\u3092\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\ud83d\ude0a\u3082\u3057\u8aa4\u3063\u3066\u63d0\u51fa\u3057\u3066\u3057\u307e\u3063\u305f\u969b\u306b\u3001\u63d0\u51fa\u5f8c10\u5206\u9593\u306f\u53d6\u308a\u6d88\u3057\u304c\u51fa\u6765\u308b\u3088\u3046\u306b\u306a\u308a\u307e\u3057\u305f\u306e\u3067\u3001\u63d0\u51fa\u5f8c\u4e00\u5ea6\u78ba\u8a8d\u3044\u305f\u3060\u304f\u3068\u5b89\u5fc3\u304b\u3082\u3057\u308c\u307e\u305b\u3093\u2728\u6700\u8fd1\u4f53\u8abf\u3092\u5d29\u3055\u308c\u308b\u65b9\u3082\u591a\u3044\u3067\u3059\u306e\u3067\u3001\u3086\u3063\u304f\u308a\u304a\u4f11\u307f\u3057\u3064\u3064\u3001\u7121\u7406\u306a\u3044\u7bc4\u56f2\u3067\u53d6\u308a\u7d44\u307f\u304f\u3060\u3055\u3044\u306d\ud83c\udf38"
#     },
#     "parentDocumentId": "0825a8f1357cc5b0208a802def515ada"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/088318d97393992de7a91999d37bc734",
#     "id": "088318d97393992de7a91999d37bc734",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u53d6\u308a\u7d44\u307f\u5831\u544a\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\u4eca\u65e5\u306f\u30d0\u30ca\u30fc\u306b\u305f\u304f\u3055\u3093\u89e6\u308c\u305f\u4e00\u65e5\u3060\u3063\u305f\u3088\u3046\u3067\u3059\u306d\ud83d\ude0a\u4eca\u9031\u3082\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\uff01\u7d20\u6575\u306a\u9031\u672b\u3092\u304a\u904e\u3054\u3057\u304f\u3060\u3055\u3044\ud83c\udf31",
#       "category": "\u90314-2\u306e\u8ab2\u984c\u306b\u304a\u3051\u308bPhotoshop\u306e\u4f7f\u7528\u306b\u95a2\u9023\u3057\u305f\u8cea\u554f\u3002",
#       "question": "\u3010\u53d6\u308a\u7d44\u3093\u3060\u3053\u3068\u3011\u7af9\u5185\u3055\u3093\u6628\u65e5\u30fb\u30af\u30e9\u30a6\u30c9\u30ef\u30fc\u30af\u30b9zoom\u9762\u8ac7\u4eca\u65e5\u30fbPhotoshop\u30fbweek4-2",
#       "id": "qa_1320"
#     },
#     "parentDocumentId": "088318d97393992de7a91999d37bc734"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/089b874861d8e2e58d6f451b0dca07bd",
#     "id": "089b874861d8e2e58d6f451b0dca07bd",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "\u30d0\u30ca\u30fc\u30c8\u30ec\u30fc\u30b5\u30fc\u8ab2\u984c\u306e\u5831\u544a\u3068\u4eca\u5f8c\u306e\u53d6\u308a\u7d44\u307f\u306e\u76f8\u8ac7",
#       "id": "qa_1143",
#       "question": "\u5343\u8cc0\u3055\u30933-5\u8ab2\u984c\u63d0\u51fa\u3057\u307e\u3057\u305f\uff01\u3053\u308c\u304b\u3089\u30d0\u30ca\u30fc\u30c8\u30ec\u30fc\u30b9\u306b\u3082\u53d6\u308a\u7d44\u3082\u3046\u3068\u601d\u3044\u307e\u3059\uff01",
#       "answer": "\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\uff01\uff01\u300a3-5\u63d0\u51fa\u306b\u3064\u3044\u3066\u300b\u73fe\u5728\u305f\u304f\u3055\u3093\u306e\u65b9\u306b\u3054\u4f9d\u983c\u3092\u3044\u305f\u3060\u3044\u3066\u304a\u308a\u3001\u7dcf\u51fa\u3067\u5bfe\u5fdc\u3057\u3066\u304a\u308a\u307e\u3059\u304c\u3001\u3054\u8fd4\u5374\u307e\u3067\u304a\u6642\u9593\u3092\u8981\u3057\u3066\u3044\u308b\u72b6\u6cc1\u3067\u3059\ud83d\ude47\u3054\u8ff7\u60d1\u3092\u304a\u304b\u3051\u3057\u307e\u3059\u304c\u3001\u3054\u8fd4\u5374\u307e\u3067\u697d\u3057\u307f\u306b\u4eca\u3057\u3070\u3089\u304f\u304a\u5f85\u3061\u3044\u305f\u3060\u3051\u308b\u3068\u5b09\u3057\u3044\u3067\u3059\uff1e\uff1c\u307e\u305f\u3053\u306e\u5148\u306e\u53d6\u308a\u7d44\u307f\u306b\u3064\u3044\u3066\u3082\u9032\u3081\u3066\u3044\u305f\u3060\u3044\u3066\u554f\u984c\u3054\u3056\u3044\u307e\u305b\u3093\u304c\u3001\u3082\u3057\u3088\u3051\u308c\u3070\u3053\u3053\u307e\u3067\u306e\u5fa9\u7fd2\u3092\u304b\u306d\u3066\u3001Canva\u306e\u30c6\u30f3\u30d7\u30ec\u30fc\u30c8\u3092\u4f7f\u3063\u305f\u30c8\u30ec\u30fc\u30b9\u7df4\u7fd2\u3084\u30d0\u30ca\u30fc\u306e\u30a2\u30ec\u30f3\u30b8\u7df4\u7fd2\u3001Figma\u306e\u64cd\u4f5c\u306b\u306a\u308c\u308b\u305f\u3081\u306b\u5b9f\u969b\u306eWeb\u30b5\u30a4\u30c8\u3092\u30ef\u30a4\u30e4\u30fc\u30d5\u30ec\u30fc\u30e0\u306b\u843d\u3068\u3057\u8fbc\u307f\u3059\u308b\u7df4\u7fd2\u306a\u3069\u3092\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044^^"
#     },
#     "parentDocumentId": "089b874861d8e2e58d6f451b0dca07bd"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/08b051aebfa5a6c93fdae05f4f721e12",
#     "id": "08b051aebfa5a6c93fdae05f4f721e12",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "WEEK2-1\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3057\u307e\u3059\u3002",
#       "id": "qa_169",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u2728\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u307e\u3057\u305f\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf31",
#       "category": "[\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u307e\u3057\u305f] \u8ab2\u984c\u63d0\u51fa\u306e\u5831\u544a"
#     },
#     "parentDocumentId": "08b051aebfa5a6c93fdae05f4f721e12"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/08d6a1f3286dafb56df39fb9db0bd175",
#     "id": "08d6a1f3286dafb56df39fb9db0bd175",
#     "schemaId": "default_schema",
#     "structData": {
#       "id": "qa_338",
#       "question": "week6-2\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002",
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\ud83d\ude0a",
#       "category": "\u304a\u5ba2\u69d8\u306f\u3001week6-2 \u306e\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u305f\u3053\u3068\u3092\u4f1d\u3048\u3066\u3044\u307e\u3059\u3002"
#     },
#     "parentDocumentId": "08d6a1f3286dafb56df39fb9db0bd175"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/0962234f008b79550787cc46f5df4a28",
#     "id": "0962234f008b79550787cc46f5df4a28",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u3010\u89e3\u6c7a\u3057\u305f\ud83d\udc4d\u3011",
#       "id": "qa_416",
#       "category": "\u300c\u89e3\u6c7a\u6e08\u307f\u300d\u306e\u30b9\u30c6\u30fc\u30bf\u30b9\u3067\u3001\u304a\u5ba2\u69d8\u304b\u3089\u9023\u7d61\u304c\u3042\u308a\u307e\u3057\u305f\u3002\u30ab\u30b9\u30bf\u30de\u30fc\u30b5\u30dd\u30fc\u30c8\u306e\u5206\u6790\u306b\u4f7f\u7528\u3055\u308c\u307e\u3059\u3002",
#       "answer": "\u4ed6\u306b\u3082\u3054\u8cea\u554f\u304c\u3042\u308a\u307e\u3057\u305f\u3089\u3001\u30e1\u30cb\u30e5\u30fc\u3088\u308a\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf3f"
#     },
#     "parentDocumentId": "0962234f008b79550787cc46f5df4a28"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/099f763f67b5518f99bbf658638840ad",
#     "id": "099f763f67b5518f99bbf658638840ad",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "\u300c\u3054\u78ba\u8a8d\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u3002\u5185\u5bb9\u3092\u78ba\u8a8d\u3044\u305f\u3057\u307e\u3059\u3002\u300d\n\n\u3053\u306e\u6587\u7ae0\u306f\u3001\u30ab\u30b9\u30bf\u30de\u30fc\u30b5\u30dd\u30fc\u30c8\u3078\u306e\u554f\u3044\u5408\u308f\u305b\u3078\u306e\u53d7\u9818\u30fb\u56de\u7b54\u3092\u793a\u3057\u3066\u3044\u307e\u3059\u3002 \u304a\u5ba2\u69d8\u306e\u5bfe\u5fdc\u72b6\u6cc1\u306e\u78ba\u8a8d\u3084\u3001\u5bfe\u5fdc\u6e96\u5099\u5b8c\u4e86\u306e\u5831\u544a\u304c\u76ee\u7684\u3068\u8003\u3048\u3089\u308c\u307e\u3059\u3002",
#       "answer": "\ud83c\udf38\u53d7\u8b1b\u7d42\u4e86\u3068\u4fee\u4e86\u8a3c\u9001\u4ed8\u306b\u3064\u3044\u3066\u306e\u3054\u6848\u5185\ud83c\udf38\u3044\u3088\u3044\u3088\u672c\u65e5\u30672\u30f6\u6708\u306e\u53d7\u8b1b\u7d42\u4e86\u3068\u306a\u308a\u307e\u3057\u305f\u305f\u3081\u3001\u4eca\u5f8c\u306e\u30b5\u30fc\u30d3\u30b9\u3054\u5229\u7528\u306b\u3064\u3044\u3066\u3001\u5148\u307b\u3069\u30e1\u30fc\u30eb\u306b\u3066\u3054\u9023\u7d61\u3044\u305f\u3057\u307e\u3057\u305f\ud83d\ude0a\u304a\u624b\u3059\u304d\u3067\u3054\u78ba\u8a8d\u3044\u305f\u3060\u304d\u3001\u3082\u3057\u5c4a\u3044\u3066\u3044\u306a\u3044\u5834\u5408\u306f\u3001\u3053\u3061\u3089\u306b\u3066\u304a\u77e5\u3089\u305b\u304f\u3060\u3055\u3044\ud83c\udf31\u3069\u3046\u305e\u3001\u3054\u78ba\u8a8d\u306e\u7a0b\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\ud83d\ude0c",
#       "question": "\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u3002\u78ba\u8a8d\u3057\u3066\u307f\u307e\u3059",
#       "id": "qa_640"
#     },
#     "parentDocumentId": "099f763f67b5518f99bbf658638840ad"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/09d2eae7546b7b3e0720c5a170077e8a",
#     "id": "09d2eae7546b7b3e0720c5a170077e8a",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\ud83d\ude0a",
#       "category": "\u78ba\u8a8d\u4f9d\u983c",
#       "question": "\u304a\u4e16\u8a71\u306b\u306a\u3063\u3066\u304a\u308a\u307e\u3059\ud83d\ude0a7-3\u306e\u8ab2\u984c\u3001\u3053\u3061\u3089\u3067\u306e\u672a\u5bfe\u5fdc\u3060\u3063\u305f\u3088\u3067\u3001\u5927\u5909\u5931\u793c\u81f4\u3057\u307e\u3057\u305f\ud83d\udca6\u6539\u3081\u307e\u3057\u3066\u3001\u30ea\u30f3\u30af\u3092\u8cbc\u308a\u4ed8\u3051\u81f4\u3057\u307e\u3057\u305f\u306e\u3067\u3001\u3054\u78ba\u8a8d\u306e\u307b\u3069\u3001\u3069\u3046\u305e\u5b9c\u3057\u304f\u304a\u9858\u3044\u81f4\u3057\u307e\u3059\ud83d\ude47\u200d\u2640\ufe0f",
#       "id": "qa_495"
#     },
#     "parentDocumentId": "09d2eae7546b7b3e0720c5a170077e8a"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/09e43bd4e4e275de33d3270e2d735c94",
#     "id": "09e43bd4e4e275de33d3270e2d735c94",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u85e4\u5ddd\u3055\u3093\u5b9b\u2728\u4eca\u65e5\u306f\u4e88\u5b9a\u901a\u308a\u9032\u3081\u3089\u308c\u305f\u306e\u3067\u826f\u304b\u3063\u305f\u3067\u3059\uff01\u660e\u65e5\u304b\u3089\u4ed5\u4e8b\u3067\u3059\u304c\u3001\u9811\u5f35\u308a\u307e\u3059\uff01",
#       "id": "qa_967",
#       "answer": "\u304a\u53d6\u308a\u7d44\u307f\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\u2728\ufe0f\u4eca\u65e5\u304b\u3089\u304a\u4ed5\u4e8b\u3067\u3059\u306d\uff01\u304a\u53d6\u308a\u7d44\u307f\u306b\u3064\u3044\u3066\u306f\u7121\u7406\u306a\u304f\u3001\u4f53\u8abf\u3092\u5d29\u3055\u306a\u3044\u3053\u3068\u3092\u7b2c\u4e00\u306b\u9032\u3081\u3066\u3044\u304d\u307e\u3057\u3087\u3046\u306d\ud83d\ude0a",
#       "category": "\u4e86\u89e3\u3057\u307e\u3057\u305f\u3002\u304a\u5ba2\u69d8\u306e\u9023\u7d61\u3092\u8981\u7d04\u3057\u307e\u3059\u3002\n\n**\u8981\u7d04:** \u304a\u5ba2\u69d8\u306f\u3001\u4eca\u65e5\u306e\u4e88\u5b9a\u901a\u308a\u306b\u9032\u3093\u3060\u3053\u3068\u3078\u306e\u611f\u8b1d\u3068\u3001\u660e\u65e5\u306e\u4ed5\u4e8b\u3078\u306e\u610f\u6b32\u3092\u8868\u660e\u3057\u3066\u3044\u307e\u3059\u3002\n\n**\u76ee\u7684:** \u5831\u544a\u3068\u610f\u6b32\u8868\u660e\n\n**\u30ab\u30c6\u30b4\u30ea:** \u305d\u306e\u4ed6 (\u660e\u78ba\u306a\u554f\u3044\u5408\u308f\u305b\u3067\u306f\u306a\u3044)"
#     },
#     "parentDocumentId": "09e43bd4e4e275de33d3270e2d735c94"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/0a131b4684a87c919e06993dcd8e86a3",
#     "id": "0a131b4684a87c919e06993dcd8e86a3",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton",
# ...
#       "question": "11\u671f\u751f\u3000\u59bb\u9e7f\u3067\u3059\u3002\u5148\u307b\u3069\u306b\u5f15\u304d\u7d9a\u304d\u3001\u4ee5\u4e0b\u8ab2\u984c\u3092\u884c\u3044\u307e\u3057\u305f\u3002\uff13Week\u30003-1ChatGPT\u3067\u7ffb\u8a33\u3092\u3057\u3066\u307f\u3088\u3046\u3068\u884c\u3044\u307e\u3057\u305f\u3002\u7d50\u679c\u30012week\u3000\uff12\uff0d\u304b\u3089\uff12\uff0d\uff14\u30013week\uff13\uff0d\uff11\u307e\u3067\u5b8c\u4e86\u3057\u307e\u3057\u305f\uff5e\u3002\u30c1\u30a7\u30c3\u30af\u306e\u307b\u3069\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002"
#     },
#     "parentDocumentId": "fd5940e63a50a3fbfb61c8fb8bab4c6e"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/fd8609904322f6aea7d3614e86099ad8",
#     "id": "fd8609904322f6aea7d3614e86099ad8",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "Canva\u64cd\u4f5c\u306b\u82e6\u6226\u3057\u3066\u304a\u308a\u3001\u660e\u65e5\u8abf\u6574\u3092\u7d9a\u3051\u308b\u4e88\u5b9a\u3068\u306e\u5831\u544a",
#       "id": "qa_1218",
#       "question": "\u4eca\u65e5\u306f\u30d0\u30ca\u30fc\u30c8\u30ec\u30fc\u30b9\u306e\u52d5\u753b\u3092\u898b\u306a\u304c\u3089\u3001Canva\u3092\u4f7f\u3063\u3066\u307f\u307e\u3057\u305f\u304c\u3001\u6163\u308c\u306a\u3044\u4f5c\u696d\u3067\u60aa\u6226\u82e6\u95d8\u4e2d\u3067\u3059\u2026\ud83d\udca6\u660e\u65e5\u306f\u7d9a\u304d\u304b\u3089\u5fae\u8abf\u6574\u3057\u3066\u3044\u304d\u305f\u3044\u3068\u601d\u3044\u307e\u3059",
#       "answer": "\u9031\u672b\u3082\u304a\u53d6\u308a\u7d44\u307f\u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\u2728\u306f\u3058\u3081\u3066\u306e\u30c4\u30fc\u30eb\u306f\u6700\u521d\u306f\u3069\u3046\u3057\u3066\u3082\u82e6\u6226\u3057\u307e\u3059\u3088\u306d\ud83d\udca6\u3067\u3082\u6163\u308c\u3066\u3044\u304f\u306e\u3067\u3001\u305c\u3072\u82e6\u624b\u610f\u8b58\u3092\u611f\u3058\u305a\u306b\u6ca2\u5c71\u89e6\u3063\u3066\u3044\u3063\u3066\u3082\u3089\u3048\u308b\u3068\u5b09\u3057\u3044\u3067\u3059\ud83d\udca1\u82e6\u624b\u610f\u8b58\u611f\u3058\u305d\u3046\u306b\u306a\u3063\u305f\u3089\u3001\u52c9\u5f37\u4f1a\u306a\u3069\u3092\u6d3b\u7528\u3057\u3066\u4f7f\u3044\u65b9\u3082\u805e\u3044\u3066\u307f\u305f\u308a\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u306d\ud83c\udf31\u4eca\u9031\u3082\u7121\u7406\u306f\u3057\u3059\u304e\u305a\u9811\u5f35\u3063\u3066\u3044\u304d\u307e\u3057\u3087\u3046\ud83d\ude0a\uff01"
#     },
#     "parentDocumentId": "fd8609904322f6aea7d3614e86099ad8"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/fdccd494757b38a77a1394cbdd8fd7e3",
#     "id": "fdccd494757b38a77a1394cbdd8fd7e3",
#     "schemaId": "default_schema",
#     "structData": {
#       "category": "\u304a\u5ba2\u69d8\u30b5\u30dd\u30fc\u30c8\u3078\u3054\u9023\u7d61\u3057\u307e\u3057\u305f.",
#       "id": "qa_246",
#       "question": "\u3010\u305d\u306e\u4ed6\u3011",
#       "answer": "\u305d\u306e\u4ed6\u306e\u3054\u8cea\u554f\u306f\u73fe\u5728\u6e96\u5099\u4e2d\u3067\u3059\u3002\u5927\u5909\u6050\u308c\u5165\u308a\u307e\u3059\u304c\u3001LINE\u3088\u308a\u76f4\u63a5\u3054\u8cea\u554f\u3044\u305f\u3060\u3051\u307e\u3059\u3068\u5e78\u3044\u3067\u3059\u3002"
#     },
#     "parentDocumentId": "fdccd494757b38a77a1394cbdd8fd7e3"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/fdf179b8f086c4962dcb3823797dd765",
#     "id": "fdf179b8f086c4962dcb3823797dd765",
#     "schemaId": "default_schema",
#     "structData": {
#       "question": "\u9752\u6728\u3055\u3093\u3001\u9577\u3089\u304f\u3054\u9023\u7d61\u3067\u304d\u3066\u304a\u3089\u305a\u3001\u7533\u3057\u8a33\u3054\u3056\u3044\u307e\u305b\u3093\u3002\u3002\u3002\u307e\u305f\u3001\u3054\u5831\u544a\u306e\u65e5\u306b\u3061\u3068\u66dc\u65e5\u304c\u5c11\u3057\u305a\u3064\u30ba\u30ec\u3066\u3057\u307e\u3063\u3066\u3044\u305f\u306e\u3067\u3059\u304c\u3001\u66dc\u65e5\u304c\u5408\u3063\u3066\u3044\u307e\u3057\u305f\ud83d\udca6\u3059\u307f\u307e\u305b\u3093\ud83d\ude23\u65e9\u901f\u3067\u3059\u304c\u3001\u4e0b\u8a18\u306b\u9032\u6357\u307e\u3068\u3081\u3066\u304a\u308a\u307e\u3059\ud83d\ude47\ud83c\udffb\u200d\u2640\ufe0f\u272810/16(\u6c34)\u301c18(\u91d1)\u30d0\u30ca\u30fc\u30c8\u30ec\u30fc\u30b9\u5b9f\u65bd10/19(\u571f)\u30aa\u30ea\u30b8\u30ca\u30eb\u30d0\u30ca\u30fc\u5236\u4f5c\u306e\u3084\u308a\u65b9\u78ba\u8a8d10/20(\u65e5)\u301c21(\u6708)\u4f11\u307f10/22(\u706b)\u30aa\u30ea\u30b8\u30ca\u30eb\u30d0\u30ca\u30fc\u5236\u4f5c\u958b\u59cb10/23(\u6c34)3-1,3-2\u52d5\u753b\u8996\u8074&\u8ab2\u984c\u63d0\u51fa\u30aa\u30ea\u30b8\u30ca\u30eb\u30d0\u30ca\u30fc\u5236\u4f5c\u4ee5\u4e0a\u3068\u306a\u308a\u307e\u3059\u3002\u5e30\u7701\u304b\u3089\u623b\u3063\u305f\u306e\u3067\u3001\u307e\u305f\u30da\u30fc\u30b9\u3092\u623b\u3057\u3066\u3044\u3051\u308c\u3070\u3068\u601d\u3044\u307e\u3059!!\u2728\u5f15\u304d\u7d9a\u304d\u3069\u3046\u305e\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\ud83d\ude42\u200d\u2195\ufe0f",
#       "answer": "\u4e01\u5be7\u306b\u3054\u5831\u544a\u3044\u305f\u3060\u304d\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\u5f15\u304d\u7d9a\u304d\u3054\u81ea\u8eab\u306e\u826f\u3044\u30da\u30fc\u30b9\u3067\u7121\u7406\u306f\u3057\u3059\u304e\u305a\u9032\u3081\u3066\u3044\u304d\u307e\u3057\u3087\u3046\ud83d\udcaa",
#       "category": "\u30aa\u30ea\u30b8\u30ca\u30eb\u30d0\u30ca\u30fc\u5236\u4f5c\u306e\u9032\u6357\u5831\u544a",
#       "id": "qa_1100"
#     },
#     "parentDocumentId": "fdf179b8f086c4962dcb3823797dd765"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/fdfd58621d7004775caf8c4679af5411",
#     "id": "fdfd58621d7004775caf8c4679af5411",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u263a\u6dfb\u524a\u5b8c\u4e86\u3044\u305f\u3057\u307e\u3057\u305f\u3002\u52c9\u5f37\u4f1a\u306e\u3054\u4e88\u7d04\u3082\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\ud83c\udf1f\u5b9c\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\u3002",
#       "category": "\u52c9\u5f37\u4f1a\u8cc7\u6599\u306e\u8981\u8acb",
#       "question": "\u8868\u793a\u7bc4\u56f2\u306b\u5f15\u7528\u5143\u30e1\u30c3\u30bb\u30fc\u30b8\u304c\u3042\u308a\u307e\u305b\u3093\u3002\u30b9\u30af\u30ed\u30fc\u30eb\u3057\u3066\u904e\u53bb\u30e1\u30c3\u30bb\u30fc\u30b8\u3092\u30ed\u30fc\u30c9\u3057\u3066\u304f\u3060\u3055\u3044\u3002\n\u660e\u65e5\u306e\u52c9\u5f37\u4f1a\u306f\u3053\u306e\u30d7\u30ed\u30f3\u30d7\u30c8\u306b\u3064\u3044\u3066\u6559\u3048\u3066\u3044\u305f\u3060\u304d\u305f\u3044\u3068\u601d\u3063\u3066\u3044\u307e\u3059\u3002\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3057\u305f\u3002https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f",
#       "id": "qa_755"
#     },
#     "parentDocumentId": "fdfd58621d7004775caf8c4679af5411"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/fe56bd9ed92bc6b30ddbe6a1d9d11845",
#     "id": "fe56bd9ed92bc6b30ddbe6a1d9d11845",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u5f15\u304d\u7d9a\u304d\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\ud83d\ude0a",
#       "question": "\u3053\u3093\u3070\u3093\u306f\u304a\u4e16\u8a71\u306b\u306a\u3063\u3066\u304a\u308a\u307e\u3059\u30022-3\u5b9f\u8df5\u8ab2\u984c\u3092\u63d0\u51fa\u3044\u305f\u3057\u307e\u3057\u305f\u3002\u5b9c\u3057\u304f\u304a\u9858\u3044\u81f4\u3057\u307e\u3059(emoji)",
#       "id": "qa_680",
#       "category": "2-3\u4ef6\u306e\u5b9f\u8df5\u8ab2\u984c\u3092\u63d0\u51fa\u3057\u305f\u3053\u3068\u3092\u5831\u544a\u3057\u3001\u5bfe\u5fdc\u3092\u4f9d\u983c\u3057\u3066\u3044\u307e\u3059\u3002"
#     },
#     "parentDocumentId": "fe56bd9ed92bc6b30ddbe6a1d9d11845"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/fe927a38a28f1f864603ef7ccf2c9515",
#     "id": "fe927a38a28f1f864603ef7ccf2c9515",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u3054\u8cea\u554f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u25ce\u52d5\u753b\u306e\u3088\u3046\u306b\u3059\u308b\u306e\u3067\u3042\u308c\u3070\u3001\u300cAlt\u300d\u30dc\u30bf\u30f3\u3092\u62bc\u3057\u306a\u304c\u3089\u30c9\u30e9\u30c3\u30b0\u3059\u308b\u3053\u3068\u3067\u3001\u30b3\u30d4\u30fc\u3059\u308b\u3053\u3068\u304c\u3067\u304d\u307e\u3059\ud83d\ude0a\u2728\u307e\u305f\u3001\u30b3\u30d4\u30fc\u3057\u305f\u3044\u3082\u306e\u3092\u9078\u629e\u3057\u3066\u3044\u308b\u72b6\u614b\u3067\u300cCtrl\uff0bC\u300d\u2192\u300cCtrl\uff0bV\u300d\u3067\u3082\u8907\u88fd\u3092\u3059\u308b\u3053\u3068\u304c\u3067\u304d\u307e\u3059\ud83d\ude4c\uff08Mac\u306e\u5834\u5408\u306fcommand+C\u3001V\uff09\u307e\u305f\u3001Figma\u3067\u64cd\u4f5c\u30921\u3064\u623b\u3057\u305f\u3044\u3068\u304d\u306f\u300cCtrl\uff0bZ\u300d\u3067\u64cd\u4f5c\u3092\u53d6\u308a\u6d88\u3059\u3053\u3068\u304c\u3067\u304d\u307e\u3059\ud83c\udf31\u305d\u306e\u4ed6\u306e\u30b7\u30e7\u30fc\u30c8\u30ab\u30c3\u30c8\u30ad\u30fc\u306b\u3064\u3044\u3066\u306f\u4ee5\u4e0b\u306e\u30b5\u30a4\u30c8\u3092\u53c2\u8003\u306b\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\uff3e\uff3e[https://noroshi.design/blog/figma-shortcut (\u77ed\u7e2e)]",
#       "question": "\u52d5\u753b\u306e\u3088\u3046\u306b\u6587\u5b57\u3092\u30b3\u30d4\u30fc\u306e\u3084\u308a\u65b9\u3092\u6559\u3048\u3066\u304f\u3060\u3055\u3044figma\u306b\u306f\u623b\u308b\u21a9\ufe0e\u30dc\u30bf\u30f3\u306f\u7121\u3044\u306e\u3067\u3059\u304b\u3002",
#       "category": "\u9867\u5ba2\u306f\u3001Figma\u3067\u30c6\u30ad\u30b9\u30c8\u3092\u30b3\u30d4\u30fc\u3059\u308b\u65b9\u6cd5\u3092\u5c0b\u306d\u3066\u3044\u307e\u3059\u3002",
#       "id": "qa_1130"
#     },
#     "parentDocumentId": "fe927a38a28f1f864603ef7ccf2c9515"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/ff59f3cbdfb56ba5e228539f14198bb1",
#     "id": "ff59f3cbdfb56ba5e228539f14198bb1",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u3054\u8cea\u554f\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u25ce\u4eca\u56de\u306e\u8ab2\u984c\u3067\u306f\u5b9a\u898f\u6a5f\u80fd\u306f\u3042\u307e\u308a\u4f7f\u308f\u306a\u3044\u306e\u3067\u3001\u30d5\u30ec\u30fc\u30e0\u306e\u4f4d\u7f6e\u306f\u305d\u306e\u307e\u307e\u3067\u3082\u554f\u984c\u3042\u308a\u307e\u305b\u3093\u3088\ud83d\ude0a\u3082\u3057\u4f4d\u7f6e\u3092\u8abf\u6574\u3057\u305f\u3044\u5834\u5408\u306f\u3001\u30d5\u30ec\u30fc\u30e0\u3092\u30ec\u30a4\u30e4\u30fc\u30d1\u30cd\u30eb\u306a\u3069\u304b\u3089\u9078\u629e\u3057\u3066\u3044\u305f\u3060\u304d\u3001\u53f3\u30d1\u30cd\u30eb\u306b\u3042\u308b\u300c\u4f4d\u7f6e > X\u300d\u306e\u9805\u76ee\u30920\u306b\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\ud83d\ude4c\u307e\u305f\u3001\u4eca\u56de\u306e\u5236\u4f5c\u624b\u9806\u306f\u8b1b\u7fa9\u52d5\u753b\u4e0b\u306b\u3042\u308b\u4ee5\u4e0b\u306e\u52d5\u753b\u304b\u3089\u78ba\u8a8d\u3067\u304d\u307e\u3059\u306e\u3067\u3001\u3053\u3061\u3089\u3092\u53c2\u8003\u306b\u3057\u306a\u304c\u3089\u53d6\u308a\u7d44\u3093\u3067\u307f\u3066\u304f\u3060\u3055\u3044\u306d\uff3e\uff3e\u25bc\u4eca\u56de\u306e\u5b9f\u8df5\u8ab2\u984c\u3067\u5fc5\u8981\u306a\u4e00\u9023\u306e\u64cd\u4f5c\u3092\u89e3\u8aac\u3057\u305f\u52d5\u753b[https://drive.google.com/file/d/1zqhPHP46D1bAbHDrqG09k4xE6tDshass/view?usp=sharing (\u77ed\u7e2e)]",
#       "question": "figma\u306e\u4f7f\u3044\u65b9\u306b\u3064\u3044\u3066\u8cea\u554f\u3067\u3059\u3002\uff10\u306b\u5de6\u7aef\u3092\u5408\u308f\u305b\u3044\u305f\u306e\u3067\u3059\u304c\u3084\u308a\u65b9\u304c\u308f\u304b\u308a\u307e\u305b\u3093\u3002\u6559\u3048\u3066\u304f\u3060\u3055\u3044(annoyed)",
#       "category": "\u305d\u306e\u4ed6",
#       "id": "qa_1112"
#     },
#     "parentDocumentId": "ff59f3cbdfb56ba5e228539f14198bb1"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/ff99ff9be9c19d92c4c6c7941f4740f7",
#     "id": "ff99ff9be9c19d92c4c6c7941f4740f7",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u8ab2\u984c\u306e\u3054\u63d0\u51fa\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\u266a\u3054\u63d0\u51fa\u3082\u554f\u984c\u3054\u3056\u3044\u307e\u305b\u3093\ud83d\ude0a\u6dfb\u524a\u304c\u5b8c\u4e86\u3057\u3066\u304a\u308a\u307e\u3059\u306e\u3067\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\u307e\u305b\u2728",
#       "id": "qa_535",
#       "category": "\u753b\u50cf\u751f\u6210\u306b\u95a2\u3059\u308b\u554f\u3044\u5408\u308f\u305b\u3067\u3059\u3002",
#       "question": "4-4\u63d0\u51fa\u3057\u307e\u3057\u305f\u3002\u753b\u50cf\u306e\u8cbc\u308a\u4ed8\u3051\u306f\u3067\u304d\u305f\u3068\u601d\u3046\u306e\u3067\u3059\u304c\u3001\u30d7\u30ed\u30f3\u30d7\u30c8\u306e\u30b3\u30d4\u30fc\u306e\u4ed5\u65b9\u304c\u308f\u304b\u308a\u307e\u305b\u3093\u3067\u3057\u305f\u3002\u753b\u50cf\u306e\u751f\u6210\u306f\u3001\u5165\u308c\u305f\u30d7\u30ed\u30f3\u30d7\u30c8\u304c\u5fc5\u305a\u3057\u3082\u305c\u3093\u3076\u53cd\u6620\u3055\u308c\u308b\u8a33\u3067\u306f\u306a\u3044\u306e\u304c\u9762\u767d\u304b\u3063\u305f\u3067\u3059\u3002"
#     },
#     "parentDocumentId": "ff99ff9be9c19d92c4c6c7941f4740f7"
#   },
#   {
#     "name": "projects/954273464710/locations/global/collections/default_collection/dataStores/contoh1_1735396977358/branches/0/documents/ffe5f70d5699c32a3d2dc9d77f2074ee",
#     "id": "ffe5f70d5699c32a3d2dc9d77f2074ee",
#     "schemaId": "default_schema",
#     "structData": {
#       "answer": "\u3054\u9023\u7d61\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff3e\uff3e\u5148\u307b\u3069\u53d6\u308a\u4e0b\u3052\uff08\u518d\u63d0\u51fa\uff09\u81f4\u3057\u307e\u3057\u305f\u306e\u3067\u3001\u3054\u78ba\u8a8d\u304f\u3060\u3055\u3044\ud83c\udf312-3\u3092\u3054\u63d0\u51fa\u3044\u305f\u3060\u304f\u969b\u306f\u30012\u56de\u76ee\u306e\u30bf\u30d6\u3088\u308a\u3054\u63d0\u51fa\u3092\u304a\u9858\u3044\u81f4\u3057\u307e\u3059\u25ce",
#       "question": "\u30d0\u30ca\u30fc\u5236\u4f5c\u7de82-2\u306e\u8ab2\u984c\u3092\u9593\u9055\u3048\u30662-3\u306b\u63d0\u51fa\u3057\u3066\u3057\u307e\u3044\u307e\u3057\u305f",
#       "category": "\u30d0\u30ca\u30fc\u5236\u4f5c\u8ab2\u984c\u306e\u63d0\u51fa\u5148\u3092\u8aa4\u3063\u305f\u65e8\u306e\u554f\u3044\u5408\u308f\u305b\u3067\u3059\u3002",
#       "id": "qa_959"
#     },
#     "parentDocumentId": "ffe5f70d5699c32a3d2dc9d77f2074ee"
#   }
# ]

# %% [markdown]
# **9. Delete All Records**
#
# To retrieve several records:

# %%
import requests
import json
import subprocess

# Configuration
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
DATA_STORE_ID = "contoh2_1735444434810"  # @param {type:"string"}
BASE_URL = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents"

# Fetch access token
ACCESS_TOKEN = subprocess.run(["gcloud", "auth", "print-access-token"], capture_output=True, text=True).stdout.strip()
HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}", "Content-Type": "application/json"}

def list_all_records():
    """
    Fetch all document IDs from the Discovery Engine.
    Returns:
        list: A list of document IDs.
    """
    url = f"{BASE_URL}"
    document_ids = []
    next_page_token = None

    try:
        while True:
            params = {}
            if next_page_token:
                params["pageToken"] = next_page_token

            response = requests.get(url, headers=HEADERS, params=params)
            if response.status_code == 200:
                data = response.json()
                documents = data.get("documents", [])
                for document in documents:
                    document_ids.append(document["id"])  # Extract the document ID
                next_page_token = data.get("nextPageToken")

                if not next_page_token:  # No more pages
                    break
            else:
                print(f"Failed to list records: {response.status_code} - {response.text}")
                break
    except requests.exceptions.RequestException as e:
        print(f"Error while listing records: {e}")

    return document_ids

def delete_one_record(document_id):
    """
    Delete a single document by its ID.
    Args:
        document_id (str): The ID of the document to delete.
    """
    url = f"{BASE_URL}/{document_id}"
    try:
        response = requests.delete(url, headers=HEADERS)
        if response.status_code == 200:
            print(f"Record {document_id} deleted successfully!")
        elif response.status_code == 404:
            print(f"Record {document_id} not found.")
        else:
            print(f"Failed to delete record {document_id}: {response.status_code} - {response.text}")
    except requests.exceptions.RequestException as e:
        print(f"Error while deleting record {document_id}: {e}")

def delete_all_records():
    """
    Delete all records from the Discovery Engine.
    """
    document_ids = list_all_records()  # Fetch all document IDs
    if not document_ids:
        print("No records found to delete.")
        return

    print(f"Found {len(document_ids)} records. Proceeding to delete them...")
    for document_id in document_ids:
        delete_one_record(document_id)

# Call the function to delete all records
delete_all_records()
# Out:
# Found 796 records. Proceeding to delete them...
# Record 016b17c388d22ff07c337b69e91d7263 deleted successfully!
# Record 01c316201b7631c399839c9a060ff013 deleted successfully!
# Record 01d9e1a21782d65e21a45f0e045c8cbc deleted successfully!
# Record 02b3484e6bfbe1e4a0aacac01303fafe deleted successfully!
# Record 02e2806f6bc7baaea1fe15696ae1eb5b deleted successfully!
# Record 03913a96f9ea8fec113a7dbce14652ca deleted successfully!
# Record 040f2a0faaf962a6e8aeb879fbd2f1a0 deleted successfully!
# Record 043dfda6e10fd09dce3ba0694dd65b2a deleted successfully!
# Record 0487f3acac9de51159067db80d808e0c deleted successfully!
# Record 050281b792cfa6785165ae5d28e1c87a deleted successfully!
# Record 057930274402e5aecb36d9b8ab39aa20 deleted successfully!
# Record 057abdd599f143dbe1279c7832cb6466 deleted successfully!
# Record 06096196c6a614e08195038499152b6b deleted successfully!
# Record 0642c1eb5cd8c13323ca507c4922827a deleted successfully!
# Record 06c508bcde429f4f857eb8d98de96556 deleted successfully!
# Record 06cb558881bd0a27bcdf674da2398132 deleted successfully!
# Record 06fabc93fda33fe05d7ddb93a961361e deleted successfully!
# Record 070c431f78da179ad860bbf90d072f45 deleted successfully!
# Record 0736af3259f448e68ec0c5887c73c662 deleted successfully!
# Record 07f16fcc1d968e9b82d885f2cec99583 deleted successfully!
# Record 0825a8f1357cc5b0208a802def515ada deleted successfully!
# Record 088318d97393992de7a91999d37bc734 deleted successfully!
# Record 089b874861d8e2e58d6f451b0dca07bd deleted successfully!
# Record 08b051aebfa5a6c93fdae05f4f721e12 deleted successfully!
# Record 08d6a1f3286dafb56df39fb9db0bd175 deleted successfully!
# Record 0962234f008b79550787cc46f5df4a28 deleted successfully!
# Record 099f763f67b5518f99bbf658638840ad deleted successfully!
# Record 09d2eae7546b7b3e0720c5a170077e8a deleted successfully!
# Record 09e43bd4e4e275de33d3270e2d735c94 deleted successfully!
# Record 0a131b4684a87c919e06993dcd8e86a3 deleted successfully!
# Record 0a1a86177c2efdd4cbe7e2f051f81414 deleted successfully!
# Record 0a234f1de07ea383843a1ddb25823931 deleted successfully!
# Record 0a3a19588accc88206299c802de99b63 deleted successfully!
# Record 0aba67bc960646f64b76edcbdf58ec0f deleted successfully!
# Record 0af82564c4fd707b1f186410392f3004 deleted successfully!
# Record 0b6c12baec6a4d6bc5036c0018c7b67b deleted successfully!
# Record 0bf58e92d7901e12916e63e4eff9f4c2 deleted successfully!
# Record 0c471867e6fd5f318c3b5658e6f99ddc deleted successfully!
# Record 0c66dd42792cc9bef03aa2bd642746de deleted successfully!
# Record 0cf2d6955240ea2af50f4e6f1026c13a deleted successfully!
# Record 0da14cae3e43b6be95ab3de100ea8563 deleted successfully!
# Record 0e223bf89ca1d1a6f98417342e987e88 deleted successfully!
# Record 0e3f0e259aeaec37f02503e0f2d1aa9b deleted successfully!
# Record 0e9ae4a5091dd4fd74252543bf7785a3 deleted successfully!
# Record 0e9b585a09c790244b9bfcebc5e486fc deleted successfully!
# Record 0ef5fb1c4fd7d8bff15c585ae52e7379 deleted successfully!
# Record 0f9338a61cba8e5f09d9a7beceaed5d8 deleted successfully!
# Record 0fc185b298749839cb59c35dfc4404b3 deleted successfully!
# Record 0fd046ca2abf59d006bf9ab1d223d737 deleted successfully!
# Record 10022ae02ec08920a7c5f90575051f5e deleted successfully!
# Record 102c3a51a13d81767f7c8b52772eb151 deleted successfully!
# Record 10640010c5fb0c14c9ee419b396aa2a9 deleted successfully!
# Record 116d23b4bfdf12f9f7610a8e7af5eb6d deleted successfully!
# Record 11cebfde470d779091385716cea0a18a deleted successfully!
# Record 11ffbfc38fa45abde05252760d2baf6d deleted successfully!
# Record 12628146499f5918e553272fd06f0889 deleted successfully!
# Record 12abc3b7677cf63d4a25f493fd8806e9 deleted successfully!
# Record 12c985d914ea80f443357b67e168fb16 deleted successfully!
# Record 12cf36e0ea91bd49acbce619f9779d52 deleted successfully!
# Record 12d90db0d6442aaea79e7a6d1ef485df deleted successfully!
# Record 13cb97de511cc29d47629f7f8899b0c2 deleted successfully!
# Record 13ff319c9051d5a5e060560acc079deb deleted successfully!
# Record 1413c71b559a469bfcbba3459f0b0e6e deleted successfully!
# Record 1460827633f88278f27538c607b1b69e deleted successfully!
# Record 14f31b2bd4e4ac46495c7788b8d059be deleted successfully!
# Record 1510e026b6d06baacdd74c2dd10c0eeb deleted successfully!
# Record 151a81f3aaa29c00cb122860f7327d90 deleted successfully!
# Record 15223cc561cec24e5cb20d9d5fb78167 deleted successfully!
# Record 1534fed93a2b6ac504871d22ac94a821 deleted successfully!
# Record 15792a81cce852056ee28e8405e29b8d deleted successfully!
# Record 15df1c4fdfb862ac5d7a8f1fce6fcadc deleted successfully!
# Record 15e183c99e7f06964ba7561b56f85beb deleted successfully!
# Record 16a4fc2d2836a026373322ab5988a24a deleted successfully!
# Record 16b9a32bb3be66a3b711ef872772c79d deleted successfully!
# Record 16e33ab59d364277ce7826c65d14651e deleted successfully!
# Record 16eaee9bd3ac81f10b422c7f5210993d deleted successfully!
# Record 1759385289ef255882742cb8de99b83c deleted successfully!
# Record 178974abd70db86ae3a167f76677e60e deleted successfully!
# Record 179f993b2bca26c121a08e5c5e68cc01 deleted successfully!
# Record 1814cdfec3211bf3a4cac9fcb9e9b034 deleted successfully!
# Record 18170864556c51cf436f1ef8613d7dbe deleted successfully!
# Record 18635ecd230b8446e60c1b6f4b353464 deleted successfully!
# Record 186c6904e47aabca40d6869a3aae11a7 deleted successfully!
# Record 187644d88e90240f2c30acef324c3da9 deleted successfully!
# Record 18976281cf21e9f0bcee07f72e6fd8ec deleted successfully!
# Record 18be7c1f9fde595e7932e052457e72c5 deleted successfully!
# Record 1914577214ee12acef9e0b0eec1e48a0 deleted successfully!
# Record 19aa0af19e00cf01b5775b68d71b25cc deleted successfully!
# Record 19bfa4902f40753005137b35ff56f907 deleted successfully!
# Record 1b4d62cf06cdc927fc6577a07dfa5aef deleted successfully!
# Record 1bdbd4612c3456d40823d8e22baec880 deleted successfully!
# Record 1c591f4262eaba89e9b030839eefed49 deleted successfully!
# Record 1c85085faf6b64627a556ef95dd64184 deleted successfully!
# Record 1c880ce90205399a19bdfdcb54bbac02 deleted successfully!
# Record 1c9dc7fb0b8986e511eca9cb6adb6736 deleted successfully!
# Record 1d274e03715b83d892db199897b04680 deleted successfully!
# Record 1d2ee6e58ef77558fb45f60f1c94cf8b deleted successfully!
# Record 1d442868781b999964617276dd924fc0 deleted successfully!
# Record 1d5db28549010f2734dc39866dfff157 deleted successfully!
# Record 1d9c2fe03cf382cec4e2161ca8e3c722 deleted successfully!
# Record 1dac19a984c5202f239cb46e2145f1b2 deleted successfully!
# Record 1ed05c2b93cc5eeaa65ceeaad23ca81f deleted successfully!
# Record 2060a5dfeafd9f29eaf15b366d327b47 deleted successfully!
# Record 207c3d488e655ac006564cf899469283 deleted successfully!
# Record 209e79ca4f2d87a605ed09ae1ffeb246 deleted successfully!
# Record 21143506c2adf3bc8779a7feb47f609b deleted successfully!
# Record 213cb3c5b35142e0f6d372e747ef2718 deleted successfully!
# Record 21494682eae3fdee9bf2e957e8b037a3 deleted successfully!
# Record 21fb70c2401e2f9f9d60c5d1c78aa56d deleted successfully!
# Record 22020cfd80a54e7768c9e95102e66c4c deleted successfully!
# Record 227495234bc90725d943bb8a15c34c0f deleted successfully!
# Record 2283dc1923202f002f652521a05a28f2 deleted successfully!
# Record 2289f61396fde49b418c99f8417e395b deleted successfully!
# Record 2297f57ed5a44be215ffa311df421c97 deleted successfully!
# Record 237c9dae28f13f4083842e69b34bfbec deleted successfully!
# Record 23b690d64c8e3c011854a38a6dd985d9 deleted successfully!
# Record 23c0bf44c363f4a3b3d8466ffc61bc31 deleted successfully!
# Record 23c49d5ecc1de8de8a4214e442654b8d deleted successfully!
# Record 247f750b582d2f6a89158bf4356aaf17 deleted successfully!
# Record 24ae250cd4e257444ff2bfafd6741f4c deleted successfully!
# Record 24f077bdd1376e59ee3149f1efb57655 deleted successfully!
# Record 255bf8777079722cf89e7a9093d4e46f deleted successfully!
# Record 25702bfe7464f80cb05fa5e637eca26a deleted successfully!
# Record 2574dc631ebbe0f43d732fea80efa5e8 deleted successfully!
# Record 2584e526d4a1a53ddaa6cc46f78190cc deleted successfully!
# Record 25b56accfd87e084930142aafc14c99c deleted successfully!
# Record 25c1cfe72edcbb892d7ed14359d582fa deleted successfully!
# Record 25cad3a64af985f010947cabadfa0960 deleted successfully!
# Record 26bdd3bd3bae467d6622db912ed87874 deleted successfully!
# Record 272ece208d903492ed4dca1d1e0dd29f deleted successfully!
# Record 273253de3eea6dffd7b737ab46031504 deleted successfully!
# Record 2782e7eb6e6e2c3e0f23bcf03f08d546 deleted successfully!
# Record 27f2d887576a93b9d25099e38f38c514 deleted successfully!
# Record 287bf6121dde961bf31aaa5c1594eaa7 deleted successfully!
# Record 28c5289005c78d17ff17a88ac7594770 deleted successfully!
# Record 2979484ebb6b4f087f13ec0bdcbd19c8 deleted successfully!
# Record 29ead34a799e09b3fc72a2cceaa9e918 deleted successfully!
# Record 29f2290f28cdd909e6ed16a8126c6e4d deleted successfully!
# Record 2a2f282f433f03f16b477801466c369e deleted successfully!
# Record 2a4e3fac45f533e155a298a9b611fdab deleted successfully!
# Record 2a6731048932a373aeca8c90dca48e81 deleted successfully!
# Record 2a7ba04272a71514fb4fe56e273910f2 deleted successfully!
# Record 2c1df3168c9acbd3b809b05ac6a032fe deleted successfully!
# Record 2c5296ac0f219ef48cfd43cda642b263 deleted successfully!
# Record 2c9e8a8525eff6d7226ef7d8e711dc79 deleted successfully!
# Record 2ccae46d926cfe92781995e8b20020bc deleted successfully!
# Record 2d6a59cb2c731b6bd9d6d6e54f90e485 deleted successfully!
# Record 2dc35e1a07654e5f4f7b57792758367a deleted successfully!
# Record 2e025263d043efaa16fdb799c965b17f deleted successfully!
# Record 2e48ba6a6e3eb9e7b14e580afb00e730 deleted successfully!
# Record 2eafec9d4d8d7d1a35b7632b603ce8ec deleted successfully!
# Record 2eca1fe4a2a2c1a873b6d03b3ec60fed deleted successfully!
# Record 2ef497f6d2543cd097ef6c196b52f8a5 deleted successfully!
# Record 2f2357c284248a4272c00e0ff97aa313 deleted successfully!
# Record 2f97f41b71dd6a139da54706a3867864 deleted successfully!
# Record 302f7a8e5e81e8bdfdef36dec0bfc0a9 deleted successfully!
# Record 30579f0ca1d1ec5f5ea03b9bd6bee0b1 deleted successfully!
# Record 3067ea080559a6116f8ebf96d1a0134e deleted successfully!
# Record 30d15a3bd0ffcbd11933afcb123fb501 deleted successfully!
# Record 310caeec343c51ddd70021e367946185 deleted successfully!
# Record 312464c052be1e88170ee4323e6c54a4 deleted successfully!
# Record 31fc79e11b165c1e07c3dddddb60346d deleted successfully!
# Record 320c77157c82997da9087f2270ba4ccf deleted successfully!
# Record 321d073211e01165a3ce60452360ad8d deleted successfully!
# Record 322a4178efd73685e76beedbb3f521dd deleted successfully!
# Record 3238faf6c711ed6969029e46ff54bcbc deleted successfully!
# Record 32817e635df968e94e5931682bdfc1d3 deleted successfully!
# Record 32854bbbf4c1172dbadac8802d530713 deleted successfully!
# Record 32989a348b22c244fe56865f9e97c853 deleted successfully!
# Record 330dbe86b992df71528d99b34d013dce deleted successfully!
# Record 333ce798ba637a5671a6984344582cd0 deleted successfully!
# Record 33e2901728a8f59220b0d04d03cdc398 deleted successfully!
# Record 34171d0b174360f5b763ed41e860247c deleted successfully!
# Record 3502a2431db2ae3a9ba3a82d9e889139 deleted successfully!
# Record 3506ef942b04d8825c2881b6cfb85dad deleted successfully!
# Record 353a78250c5b6e950143d8012dfd0974 deleted successfully!
# Record 35532aa02a3258f980f48a75fa31ea5c deleted successfully!
# Record 355e342c51dae8644704d9e171628e88 deleted successfully!
# Record 360f957b45c3dacb7c8da35d0f40ced7 deleted successfully!
# Record 3674cf9474c67165dc685777942079e5 deleted successfully!
# Record 3682db2df72facf3144f9d2d98a521a7 deleted successfully!
# Record 36f3311184d2ef1a2df56cf529d1cce2 deleted successfully!
# Record 37fe4625d36299283c3450a9ae2e398a deleted successfully!
# Record 383059a5f9c9764c31952d3ec099f7b1 deleted successfully!
# Record 384f351ae77e50ee8368bb0324f062f1 deleted successfully!
# Record 38629d642cc2a0c3f3c434c0ec80b5da deleted successfully!
# Record 386f495f7714cdd044cb2bea6e63f7d0 deleted successfully!
# Record 38aa5997de30c69893e051eb2af703b2 deleted successfully!
# Record 38b640972d9d779aebf4afe3ed6fd78b deleted successfully!
# Record 3930dbd017b120a721931c83c9d6c895 deleted successfully!
# Record 39431dc3779e415ad999416e5ce21163 deleted successfully!
# Record 3a5f055dfd84da104024226aa4969de9 deleted successfully!
# Record 3a987ef3e6066f1216e5027ef43c08b7 deleted successfully!
# Record 3b70c8a1d095cbd225060df5cce29d9f deleted successfully!
# Record 3c12ea06231b9ec6ec7a94d854f1575b deleted successfully!
# Record 3ce19a554b9d0f8732291169aaa70688 deleted successfully!
# Record 3cf8f2bd3b8e1e3848b07b20c76ec2a6 deleted successfully!
# Record 3d019db92325e3822f581fc8098a9ade deleted successfully!
# Record 3d1badc78a9b5e09ed3dbc3676a846b7 deleted successfully!
# Record 3db4899761ddbc5d6e06b9db7cfa61d9 deleted successfully!
# Record 3dc95a131a0f6f68c8dfb8b85b24cadf deleted successfully!
# Record 3e95810b94addd3d71a4dc790464fff1 deleted successfully!
# Record 3ecf97279ddd5b979787d10384042827 deleted successfully!
# Record 3ee46a0c14e797e7dbeb540d29856126 deleted successfully!
# Record 3f6a9ccf710b296fb66ecea9ab1f6e18 deleted successfully!
# Record 3fba818c15358c71f39e34e971d60e42 deleted successfully!
# Record 401dd426b1deafa7bb3f19714b4a4c29 deleted successfully!
# Record 40e2954308598f00196e1ad13331b7b9 deleted successfully!
# Record 4125f454e35fce97859a5a6002e2cc19 deleted successfully!
# Record 41aec8d28a5c40f2f9900e6adbb7d339 deleted successfully!
# Record 41e52abb906283ecac29a9058b103725 deleted successfully!
# Record 4211c83a644434cb41bedca7da79e2b9 deleted successfully!
# Record 4223815d91d6316669172c9f0cabce4f deleted successfully!
# Record 423120149ce147821cc61ef0d176cf92 deleted successfully!
# Record 4266099c0931d35d7d602355ab7d3476 deleted successfully!
# Record 42df02c2eddd4f17c26570683a2d6224 deleted successfully!
# Record 432d2453c1b0c4868732ab59d406bc17 deleted successfully!
# Record 43816ac66f7908daa144873f24d2acac deleted successfully!
# Record 43bbc02737e6e565cf2216c2655fe8e6 deleted successfully!
# Record 445318d2759871bc4cc9f9617c5c6892 deleted successfully!
# Record 4479962804d794e1d82b94edfade1f73 deleted successfully!
# Record 45274486884012dd2e71358ce1274243 deleted successfully!
# Record 456638a1136897c5518076884d4bf533 deleted successfully!
# Record 4582184a0da900846ae54ed7cb087b4f deleted successfully!
# Record 4601a8358304b4c2f3f8b229f8343ee5 deleted successfully!
# Record 4602e1356292058bd2a2ff73307076e3 deleted successfully!
# Record 463dc20a60bc8eec6e5adfea3042a832 deleted successfully!
# Record 47cf707adb964ac087cc3ca512b1a4ae deleted successfully!
# Record 4837e9bf18efb208d7ba5b23964fabc0 deleted successfully!
# Record 485c1f97ec5ee7213cd2c8303bd25b35 deleted successfully!
# Record 4a5c5c8dc4b513a374fcdb6f8025f911 deleted successfully!
# Record 4a93929dc4cb1f0838456f04734e6953 deleted successfully!
# Record 4b000c77c455b153fad1efa270625867 deleted successfully!
# Record 4b39bcf21d925987b9b09c1ca12bf01c deleted successfully!
# Record 4b4e3c17486eaccca70c2a3aee65ee7e deleted successfully!
# Record 4b8dd01121e5364d0b06e5547c216d92 deleted successfully!
# Record 4bedd26564b7af3e0032f406e7bd0d66 deleted successfully!
# Record 4c3435c968ed781eb646a7caf09f6f25 deleted successfully!
# Record 4c3b00ae923d91c213aaae7503da1626 deleted successfully!
# Record 4cb70557d3a46bdf3c5138e4b8801be8 deleted successfully!
# Record 4cea28afb8d6a7287d451a1d8df48de2 deleted successfully!
# Record 4d35f2df229abc35ea91f70ec0a75b2b deleted successfully!
# Record 4dbd033d680fb8300b1f47b895c13838 deleted successfully!
# Record 4de65af20050703500a5611811899d7e deleted successfully!
# Record 4e6baf87357fd5486641a64d355e7743 deleted successfully!
# Record 4e8bcf7c2c9f0bb684463d221265c5bf deleted successfully!
# Record 4f004968cef27947fc7e2ff85ff6f170 deleted successfully!
# Record 4f297777af5add0dab879db9c821ef23 deleted successfully!
# Record 4fb891d64a2ee8004e52d40500d67202 deleted successfully!
# Record 5176855ac9e91062399d3fc6d8067da7 deleted successfully!
# Record 526739842dc153e521aa48d88e37a5bb deleted successfully!
# Record 538fbab300aaafaf2aae0b04ae0afd4d deleted successfully!
# Record 54a634259133df4fa50a6a0e8af635b0 deleted successfully!
# Record 54c5ed7ca4b73070eb7bf104d080b26f deleted successfully!
# Record 5523a632877e58794da920e304742d3b deleted successfully!
# Record 55540d831ce087355b67014ab6d52f20 deleted successfully!
# Record 555708ec67a36b85d90232efa57bc126 deleted successfully!
# Record 55b1293005c84120cfaa715e9d0da562 deleted successfully!
# Record 55b5191cc7116286306d7c776698fab9 deleted successfully!
# Record 5611f390205ec943c8c33b9170aa4f63 deleted successfully!
# Record 5695da80760fd2c0c2c0aed4297817ba deleted successfully!
# Record 570738072702e44fdac086b7e2c21e62 deleted successfully!
# Record 573def99ab9dd07fd896d4278c65cfbe deleted successfully!
# Record 5766df54a0893794a61d7f5cd58503d3 deleted successfully!
# Record 578125672974781cbed144d191b10c18 deleted successfully!
# Record 57b117555f3b670b0b970a4c83bf2b1c deleted successfully!
# Record 57ea962265d949b0a1228739fed78974 deleted successfully!
# Record 57fd5536a5cd260c05b43793fb466020 deleted successfully!
# Record 5806727012adef0fd6e0bc273728af20 deleted successfully!
# Record 5810fb4e91a1a05eea965d040d0169f6 deleted successfully!
# Record 585034be9fece39d64d787bb479511f0 deleted successfully!
# Record 5877f7fc2969453adc1478c10c7475a8 deleted successfully!
# Record 5888bdd54049d3ab8da486cb0a076f93 deleted successfully!
# Record 58a87a264a4a81f90e18d17e71f25309 deleted successfully!
# Record 59000a6663bbda4a3d3b0f1818a8664d deleted successfully!
# Record 5976af1c110d32f038ad50b06bc6428e deleted successfully!
# Record 5adcbbc463e50717c6ef4d0c6d6d527b deleted successfully!
# Record 5b51736f55338eea13a09999c644b1f0 deleted successfully!
# Record 5bdff7fa2edbde677e20e78c66291256 deleted successfully!
# Record 5c257c2aeea81e1c0a343b3516a64268 deleted successfully!
# Record 5c6257767abbd8425f09552842d6b70a deleted successfully!
# Record 5c84a272acc4852e1b614638f4c2904e deleted successfully!
# Record 5c8aca520a3f6c6b85f00f52d575dec7 deleted successfully!
# Record 5ced0c660675a81669d129626bedf7e9 deleted successfully!
# Record 5d46ad95236e35a5b81c2a56151cf859 deleted successfully!
# Record 5dd7de27778487aceaec9dd957d7d8b7 deleted successfully!
# Record 5e3e250adbbf8fa31ff93b90a0759640 deleted successfully!
# Record 5e504173e1caaa0e0b5b49232ed6d66d deleted successfully!
# Record 5e925aa744fdb1305ed55eb6e4bf4ce5 deleted successfully!
# Record 5ea6c342ea08d8b8134c8a507e8d7673 deleted successfully!
# Record 5f22aa03aa214e97d8a7b2b8c58342ac deleted successfully!
# Record 5f4b73899e5452c4787e173797d3e872 deleted successfully!
# Record 5fa167cbfc23a04c00b80eb3893a53b9 deleted successfully!
# Record 602c5e4cc341d109e7971f6d532f1e6f deleted successfully!
# Record 6050764feabea07177fac5562388696e deleted successfully!
# Record 60633a185bcd17f2753f1c84b657e66f deleted successfully!
# Record 60729525cd18c1bda544ae4df11c28c5 deleted successfully!
# Record 60f662395963bd9722b2ad6db178fe7b deleted successfully!
# Record 61748bdc63f7d61fe22d7d61f0d9f135 deleted successfully!
# Record 619459a667495f3bb184e1b0a1f459a6 deleted successfully!
# Record 61e217d312b37710e54209329a798fa6 deleted successfully!
# Record 61e7b54f7a05d870f87035844a33ab72 deleted successfully!
# Record 62eab366b271e5d8cd20f1ebc694aefa deleted successfully!
# Record 6321ad66cbbd593471a5b43e9f1d0044 deleted successfully!
# Record 6389c54cee7b462c91ab755a6efa2700 deleted successfully!
# Record 63f4762f4798bef8b540c9b5687b0ddb deleted successfully!
# Record 641c3e7e29b0795b7d055dbe44536621 deleted successfully!
# Record 64e9a4d54eb5a9479fea14ca27fa36cc deleted successfully!
# Record 6678cb66e7ea22a64a2b17301a3a23a3 deleted successfully!
# Record 66c5dc1e93e59141a647d03039e5c2db deleted successfully!
# Record 6702529a9d47a6d579b6ed6d48cf58c3 deleted successfully!
# Record 671c91a52f641d07f2850ea020915d6b deleted successfully!
# Record 671d326e8abf640508ec98eb5fdb5384 deleted successfully!
# Record 6741dd0b886d0157768586b6e4b6a631 deleted successfully!
# Record 6778f779a32d406701d661db37c90c18 deleted successfully!
# Record 67808a9ad4cfbfadf0a3674a2511da72 deleted successfully!
# Record 6810aaa5ff065e7d170f8b399ad2cd81 deleted successfully!
# Record 689b0f5de3398e9889d210c0e9d264e4 deleted successfully!
# Record 689e53a95d756964410e53e00114ff23 deleted successfully!
# Record 68b5955a7cf34aa97d24f960a69458bd deleted successfully!
# Record 6928cde69a73604d10dc3428d49a7579 deleted successfully!
# Record 6979e29227b54d750fcec1f9f7082469 deleted successfully!
# Record 69ae5346d2b4caefd7fd037e39a01273 deleted successfully!
# Record 6a04e288accacc4b17e1d516189e3f30 deleted successfully!
# Record 6a634ed802c47f7fb2edea51256e6e99 deleted successfully!
# Record 6a73633cf39376dc1140ff9f7aed8733 deleted successfully!
# Record 6adedf42642d4a866a1baa8efc509334 deleted successfully!
# Record 6aff7fec9936a82d3e109e35289bbf0e deleted successfully!
# Record 6b28cd8aa548b7391f1d76b3b0043694 deleted successfully!
# Record 6bfcbab51f66ea36b296ad0327eb9f4f deleted successfully!
# Record 6c557cd580896dcab4745272e61d4dea deleted successfully!
# Record 6cb2c6667aa04c3d5ddfdb58a5604869 deleted successfully!
# Record 6d68f0a30d62d02ffb9d2539c71f2694 deleted successfully!
# Record 6daaf8961f3cbd4380f5b3d4db9c4e56 deleted successfully!
# Record 6e9b23c7ebd77d65a7391e2bcd37480b deleted successfully!
# Record 6ef4c79d57c352fc46e4986b3f2068bf deleted successfully!
# Record 6f25fb80241428e00b4dbc4d07a69156 deleted successfully!
# Record 6f5089b43eeac3355bcf469217861a13 deleted successfully!
# Record 70490eb83d1d84c114eae6e7030aa8fc deleted successfully!
# Record 709fc9241e67bfc68378dde5ac177aaa deleted successfully!
# Record 70b337cf19222c83c44b3b686bb37090 deleted successfully!
# Record 7155cf35cf5e168f6e1fe34e663aa882 deleted successfully!
# Record 71e38cc965a6e2bcd9c94498ea0518f1 deleted successfully!
# Record 722b6693b842f0ec6d7bc2a6a5d0f3fe deleted successfully!
# Record 7291ecc901e22a94e85e8c58d33d1984 deleted successfully!
# Record 72be409b8471d2734d86ad37e178c6c1 deleted successfully!
# Record 72ea05dbf1b746ddc03269457b212405 deleted successfully!
# Record 73de83d9576b052c04957c03ae9700f9 deleted successfully!
# Record 7425110690563bffa972faa419e671c9 deleted successfully!
# Record 744987d81bfa9298f2d86b5b3cb8ff92 deleted successfully!
# Record 7457e0c72ce6762c12859e8d1cab657a deleted successfully!
# Record 7461c1c35c11ab6363c46a546422520d deleted successfully!
# Record 7499dc06e5b8354fb7e3bdd2f207b235 deleted successfully!
# Record 750325d219ac42104ec38473e9b5cbc1 deleted successfully!
# Record 7554084b2c2dd8a0e0edac9860c644a3 deleted successfully!
# Record 75a1061977c26eeea57161e91587800f deleted successfully!
# Record 75d26e5d04e1cad4652e4628223de3bc deleted successfully!
# Record 762ac9b7c86985f5f2a8b88cb44c5f07 deleted successfully!
# Record 763276c93bcc2b35038b4228c55630e9 deleted successfully!
# Record 763f1aab6b6cea162ae7129476c3cd34 deleted successfully!
# Record 778804748064d64d991ab28fe5a9b5e6 deleted successfully!
# Record 77c013d18699c458ce2822ae5a9fcdae deleted successfully!
# Record 7807ce0e276a9fe0a796ad73b5d6186b deleted successfully!
# Record 7825d91c94f25c3de8d330216b06027e deleted successfully!
# Record 786169b369831bedc67e7ad7fc85c2a6 deleted successfully!
# Record 78dbc439044d720ab193bad7307a039b deleted successfully!
# Record 78f2f8046a9546fe11a38694ff4b98a6 deleted successfully!
# Record 7975770478e4538f2025eb85015854b6 deleted successfully!
# Record 799b8f91662cd093e8bebf3cf61f1dea deleted successfully!
# Record 7a121eb79cb55c89aff126b1b3f05c2b deleted successfully!
# Record 7a8a550a2ea8ca3fec81af08bb0ee08a deleted successfully!
# Record 7ab83b922c00191184f03b28612779f6 deleted successfully!
# Record 7b45155e7fdacd94995d316d9547b034 deleted successfully!
# Record 7b766b32c7e895a3d913ae388cc2d7b8 deleted successfully!
# Record 7c065d092fbb4625acd0cf294514884b deleted successfully!
# Record 7c19da2e1e458f0e52dde27a9ff5c5b8 deleted successfully!
# Record 7c4d6a6e585f366cc34190406c62edd3 deleted successfully!
# Record 7c8edae3846823770b0d5475e22e69e5 deleted successfully!
# Record 7c9ec0a922b20be411647c120ac1e762 deleted successfully!
# Record 7cd5d7b28c9e3946f146690f399b563b deleted successfully!
# Record 7d0326ccfd59102d10fe8fa41b305d46 deleted successfully!
# Record 7d1a52fc6e7296c085ba1f17549a8325 deleted successfully!
# Record 7d5d7de4213bdff5af69442f073c0fbd deleted successfully!
# Record 7d8a26ab0c29f0b3628ef93e8391b72a deleted successfully!
# Record 7df080641c4fcee7b8dc063ef676c193 deleted successfully!
# Record 7e5e9cd889d945e34ac039c1d865232b deleted successfully!
# Record 7e90eb2d5d7b67f4b7defc31c7ebc854 deleted successfully!
# Record 7e950b01c12bb1e1b0b8576797675484 deleted successfully!
# Record 7f022bfb02578529ae9e01033432ecb9 deleted successfully!
# Record 7f133b45c5c46faa8f1860f8348a5727 deleted successfully!
# Record 7f4e20cb8e0daab478e144c527dc6196 deleted successfully!
# Record 7f5911338001a8c5a606ebfce02b56d3 deleted successfully!
# Record 7f9427ad01b2599b9e2a24ccd74ab2ef deleted successfully!
# Record 7fb5a0dde6c14d1175c5bbd111c0ed66 deleted successfully!
# Record 7fe81c00888e6c1026996a0208ad17e9 deleted successfully!
# Record 8035bc5cd99607f162b3cd9af8f9f864 deleted successfully!
# Record 80413c761796a5b278c2902f4729a6d4 deleted successfully!
# Record 8042c51ebdf5976377fe33a8cb6b7fa1 deleted successfully!
# Record 804b31fe28afba862f02cc47369c5856 deleted successfully!
# Record 80846a2caaa179ef3be23fe39a6e3caf deleted successfully!
# Record 80b8e4fef65a49f4327d14edcd6ce1af deleted successfully!
# Record 80d2abd4ad1628eb925b5772629cf8e5 deleted successfully!
# Record 80ea0a27cd3caf4cf3b75e5875419f6f deleted successfully!
# Record 81aa7ca439e75bf3826f4a3ba873ea43 deleted successfully!
# Record 81d7d5103b72870a5ccda58766dd481a deleted successfully!
# Record 82bb0dad270959058c3b7b83c0fda1c4 deleted successfully!
# Record 82f61bbaa0becedae3559a62a76b6d51 deleted successfully!
# Record 832dc558ab9366caf762fd54c34e9876 deleted successfully!
# Record 83f7eae1430e39e4d080fc09ab94aee2 deleted successfully!
# Record 845b494f563074d3f9ee59fdac924a96 deleted successfully!
# Record 846c74b8fb0c58d91c9fe16a04e1c5f1 deleted successfully!
# Record 846d32b3712d6488c5d5642305d56b74 deleted successfully!
# Record 8471d1ef9c9c69beef4d324927957c35 deleted successfully!
# Record 84a0c5582fc490feff1d45fa224abfe4 deleted successfully!
# Record 85099b608ab53e847e109f8f8307a55c deleted successfully!
# Record 856e5f9ba734c591ffd16a9183ce62aa deleted successfully!
# Record 85b2fef2cf8b5e2fba4c61b2f1b1371d deleted successfully!
# Record 869d2f63b0bfa62ddd6e107921d0459c deleted successfully!
# Record 877907d3adc4d968d74224b742cb83db deleted successfully!
# Record 87b2a9f28ac3bad692813d7d80c996ac deleted successfully!
# Record 87fda7131be5f7181dac00e54b31c160 deleted successfully!
# Record 8832b06a5fd028b0ae0123194bd94778 deleted successfully!
# Record 8861b165ca934f563d535ebc133de6a7 deleted successfully!
# Record 887c48d7e089a1759699ba5b0c55e5b8 deleted successfully!
# Record 89bfb06c337865592e2930cfacfec481 deleted successfully!
# Record 8a23ca16113bcdd007e9d4988a6d61a5 deleted successfully!
# Record 8a5dacf96b205293b240eb828c217a9d deleted successfully!
# Record 8b122090b8a1f4aabeb77d7980310166 deleted successfully!
# Record 8b559f96c0a3921947202dc9ac62f072 deleted successfully!
# Record 8c22da1cf15573accac6351fbc612a37 deleted successfully!
# Record 8cab4ba7e91055e557e6e288e0e4f8f6 deleted successfully!
# Record 8cee4880e897e83104979e09a34f4c4d deleted successfully!
# Record 8cfa2b816cadd40beca7c2f538df277e deleted successfully!
# Record 8d5a4a5754dd5b254d213c8a90cc4ccc deleted successfully!
# Record 8d82d77448dcedad9260de43e36baa49 deleted successfully!
# Record 8da09636b70f5760bdf73a7fb9ef5faa deleted successfully!
# Record 8e9dbeeaca59d035381f6399e1df40bb deleted successfully!
# Record 8ec48c87a86fe89634e3433fa8fa88a9 deleted successfully!
# Record 8f20d4ae7ac5cc61ec833a17b88b84f3 deleted successfully!
# Record 8f46d2c67ddca0f303f89ccc0ff9bf17 deleted successfully!
# Record 8fb1e3da2957a5de44b93fcc93f81fb2 deleted successfully!
# Record 8fdee3adec753b1e501a8bd1e18fcbe3 deleted successfully!
# Record 8ff5f3b0908d9217d3118ffb0713b549 deleted successfully!
# Record 9065707fb2c1a8f47ce77a67cedcc2ba deleted successfully!
# Record 90707f89492c9b2f3e246ab1b1c39279 deleted successfully!
# Record 90840028994b5ba70ca849bd8decb65d deleted successfully!
# Record 91e86065855d9903a1103bcbfbb27e07 deleted successfully!
# Record 9250052e499efbc7050653719b2bf46b deleted successfully!
# Record 92a8b5667800ec310d59393f99acb94c deleted successfully!
# Record 92c4681fce0fabc78a531b0f95d5d6d2 deleted successfully!
# Record 92feec64ca6aefda8ecd7118c0438e32 deleted successfully!
# Record 932251368cc9461f5eac6f652fdf0267 deleted successfully!
# Record 934d6c51d2cbe569eb6b69face320ea4 deleted successfully!
# Record 9357f84e2a741e6ee8639f7c81907b26 deleted successfully!
# Record 936cfe747b5f8ff5bef5243ca1ec954f deleted successfully!
# Record 93f62b1515be390428dc196c2d1d5fda deleted successfully!
# Record 9415b195677471363ce2520baa9555b1 deleted successfully!
# Record 9568a685fe0bd874e90510b410994595 deleted successfully!
# Record 958bbf073b411ce83869a13b5a364807 deleted successfully!
# Record 95f1773d1c1c1480eccec5f288e90464 deleted successfully!
# Record 95fd6f1ae6d1a3a342b7aa077fccfa20 deleted successfully!
# Record 96ca5f34408153f2aad0c15a34eea338 deleted successfully!
# Record 97407ce96c80e9e66604cc26c5b0f4c7 deleted successfully!
# Record 97465b82228c7a929afaf43118c5e395 deleted successfully!
# Record 974b40c6bdd8994db32221b888fbe157 deleted successfully!
# Record 9787ea5bc48c43a7f8b1f555faf5952e deleted successfully!
# Record 97c20848cae4072e2629ed7770006885 deleted successfully!
# Record 97e120db0dd1ca0c90cc0cc5375ad2e4 deleted successfully!
# Record 9813da89040bb081b8f4d7c2631d8e8c deleted successfully!
# Record 986b61644f4241dc31f1ee97176ea9f2 deleted successfully!
# Record 98b53b87766e6aae6783b7feaea6a54e deleted successfully!
# Record 992d585441619270e38e53fd5198183c deleted successfully!
# Record 99370e34294de477139347b157b98ed5 deleted successfully!
# Record 99a7871cb98e1883d384e17e16a6f646 deleted successfully!
# Record 99da293c012c3a9ec70f1b75acafc388 deleted successfully!
# Record 9a09691cc51ada1b2a161bd9a175ee7f deleted successfully!
# Record 9accb3c0089762ca615d620c8ff17c8e deleted successfully!
# Record 9ad40d71c00f583a12c2d5c4d48daaa6 deleted successfully!
# Record 9b90b5e8842d911b67e3eebad2cc49d9 deleted successfully!
# Record 9baeb78659537018106cd9f3eb8845b7 deleted successfully!
# Record 9bd0aeb71d55432aedfe05f7e728ac38 deleted successfully!
# Record 9c4dfb54f9b5afff641cb7f8a2955656 deleted successfully!
# Record 9cbf89d02afc528ec4b79828522d13f5 deleted successfully!
# Record 9da2459ce388cd0d4c387f2cf04ba05c deleted successfully!
# Record 9e4f64780e4bb54254046a7511666133 deleted successfully!
# Record 9e7caef957c359ae34bad8d310b92569 deleted successfully!
# Record 9ea57048a7ecda8abd1e2d7db7705b24 deleted successfully!
# Record 9f0e4168756ecdecd21d0b6413244c45 deleted successfully!
# Record a05b1710fe1fc596e3c756c93d896d2a deleted successfully!
# Record a0c6a2f55dd33a4f2d89e13b3b63c3b1 deleted successfully!
# Record a1215f067691a56c87426aef362ecb4d deleted successfully!
# Record a133fb130424fa866c346412c2438b41 deleted successfully!
# Record a1355243453265712634f483a54a9edc deleted successfully!
# Record a14034398f27f948ad79a287efdf8f12 deleted successfully!
# Record a15217fd0c374fab2dac1ada0d291deb deleted successfully!
# Record a182b08a2fc61625eb9a669389714ab7 deleted successfully!
# Record a18bff660d22da31a6d7f53b10c9362b deleted successfully!
# Record a1d537eacaf866cf759258c4ba2a7aed deleted successfully!
# Record a2bf901154f09d720fcf24b50ca51b9a deleted successfully!
# Record a2ed41ec3f2e7228b94e12f50f55096a deleted successfully!
# Record a3aaec8180b95192f1a464e9e05b25f4 deleted successfully!
# Record a3bf6003d2e504cb4bce50762c467e08 deleted successfully!
# Record a3ffcaa5572c34b11617de45683cdd00 deleted successfully!
# Record a4f08555b4d363e79f286d765709bff5 deleted successfully!
# Record a54387541366a5c4194378e315300483 deleted successfully!
# Record a54c5fdaf54418f3b0a70145973e09de deleted successfully!
# Record a550b5dda54a4014380dd6c6eabfb388 deleted successfully!
# Record a600a2e4540308a4d8cd2720c384346a deleted successfully!
# Record a61692ec65681d9cb98b1deb4831e1a0 deleted successfully!
# Record a6971976eb5050dfb78b8404da577449 deleted successfully!
# Record a69ba7bf52efe14e0b79c1d9f7fa49e4 deleted successfully!
# Record a77bac4cc4e9f941351400a8365ad4c5 deleted successfully!
# Record a792838330b33382e4edac16d0890e18 deleted successfully!
# Record a7a8bd2f18408acfc0dc0b2f4f5ce0ae deleted successfully!
# Record a7e052d3573d3a3f589eba51fc1b6e8b deleted successfully!
# Record a83c91bff37a08cd5b723f4ffb5edcc3 deleted successfully!
# Record a8584507a8502d5bbd3322cf57d0760d deleted successfully!
# Record a87523c1db4e372e9fb23c55ee2e9a1d deleted successfully!
# Record a8cd33321f119ff4b60cabde5a623b42 deleted successfully!
# Record a9c697033fff00c0d3e53e8cd9541d3c deleted successfully!
# Record aa11716352a9729f104bde58d8673c70 deleted successfully!
# Record aa1946a4c6856e785c53895e289de17d deleted successfully!
# Record aa2aa1067fabb5639f8c444b23b7bd50 deleted successfully!
# Record aa53b60982c712d672bade2e432834b3 deleted successfully!
# Record abe585d846cb6c1bd3d98c5e073ec6e8 deleted successfully!
# Record abea1526634e2514675ab3f25d8de856 deleted successfully!
# Record ac30dea8314da1bc0341b0e2f1e46292 deleted successfully!
# Record ac341593bc2075944afa2da55ca24b39 deleted successfully!
# Record ac8e9f3a57dac71682c760c0b6567db8 deleted successfully!
# Record acbdcec5ce68ede4f2c2a045f9ee6db1 deleted successfully!
# Record acbf4d06adfbd04371f4f1bc91b532b5 deleted successfully!
# Record ad77513002f0a00625a80aa4c1b4381f deleted successfully!
# Record ad8766d9800dbd12ebe2c8ae028bdf2b deleted successfully!
# Record ada81c1a03774780349b7e21817addf6 deleted successfully!
# Record adc0da14c6019ae885afdefdc0737c79 deleted successfully!
# Record adfa1b7167d0f89fb351cbf4330d3ec2 deleted successfully!
# Record ae10942f54bf5b65ce9c0a019bda535a deleted successfully!
# Record ae82c20d01bab0a12f9592f167270d81 deleted successfully!
# Record aef25581e4a19ecbbbaf6dae66cd1f20 deleted successfully!
# Record af00edff8d1e935a7d4c5c9084ca7f9b deleted successfully!
# Record af6f686de4fa8b3acdf0055ece3fd7d6 deleted successfully!
# Record af8f6e6c7c74eb0ac2ded997c797a9c9 deleted successfully!
# Record af9a125db77c2d8dd9c5c8307a3f1351 deleted successfully!
# Record af9c1446d985e7f29954d08ce07893cc deleted successfully!
# Record aff0c2646cda3b8eb58f28abd66eaf39 deleted successfully!
# Record b0a5852605ec87c298ba281db86413f0 deleted successfully!
# Record b0c6eb08711cfb9ae930a55aca28130e deleted successfully!
# Record b0e32e5db7ca57292a1c74ba67220561 deleted successfully!
# Record b1a369106108f07b6a5c2b17f2533479 deleted successfully!
# Record b20819dddb011ec38743c610d8eb4f61 deleted successfully!
# Record b23fa6151ab3cc6ad2678e7b89404075 deleted successfully!
# Record b25a210610ab2196f601440849ff61f5 deleted successfully!
# Record b2bddabdc4fc25f02c0c5b00ae15d619 deleted successfully!
# Record b3b49f7a8b4734cd3199774827907a66 deleted successfully!
# Record b432632b926448cebf094a656174b168 deleted successfully!
# Record b45a380efaaf04d5728a9acc75eff00c deleted successfully!
# Record b4a96c362029675f5de5c34427950b0c deleted successfully!
# Record b52fdfd1f861a9e693e72754ded0c2d6 deleted successfully!
# Record b5940342202aca23da89ed59aff63e46 deleted successfully!
# Record b595d979261cbd39ea848f9b3b85ea6f deleted successfully!
# Record b5c9e4d221a098b0062764bda7c7a037 deleted successfully!
# Record b68ce1ea544c24cd574fc061215ca6f7 deleted successfully!
# Record b6a2e2934cdd6444116c2ab296668518 deleted successfully!
# Record b6a59d757c93baa7751368213fbdecb2 deleted successfully!
# Record b72657fba92839f25c43f15fb64cd9a7 deleted successfully!
# Record b7585f0b419678519e77a91ed4d9ecdb deleted successfully!
# Record b7ccbadbc5b3e89cca30a2342703201d deleted successfully!
# Record b7e1f8025bfcd94df99c792cd4cb49ff deleted successfully!
# Record b852ba8ee7662b6349f34408640807bc deleted successfully!
# Record b90d170226bcb494bbf78fd6a29418f3 deleted successfully!
# Record b92a19b5da931f839d14c829c9aa379b deleted successfully!
# Record b9495dded80b1a6dc90031ab91e6e753 deleted successfully!
# Record b96642b22872bbe0f82a826dd1ca05b1 deleted successfully!
# Record b985c06f2666b4fccfaf78c7bd74e848 deleted successfully!
# Record b9aad07a0920d9390952e46d0b56d216 deleted successfully!
# Record b9c21e4ed477e7d8e434dcc8ff8268b7 deleted successfully!
# Record b9e68d6ff755e63206c16914e24ce10b deleted successfully!
# Record ba32fbe0f659a3a09c075f29cb3989c8 deleted successfully!
# Record ba5c97a394340ee4f19142d042f76846 deleted successfully!
# Record bb582d1a346a44b186ba9882e361f350 deleted successfully!
# Record bb9984245a6d7f543d00df1fb94d0249 deleted successfully!
# Record bba98db5d8bec1a295a0e739c4853331 deleted successfully!
# Record bbdead2c8fe690822ae3a7e23685d9f3 deleted successfully!
# Record bc87a9d4dda7609d33110964a687daff deleted successfully!
# Record bd4b53f527097370208ef3e58537eabd deleted successfully!
# Record bd9145adb5d38f551720e1b2b8eaf7fb deleted successfully!
# Record be9f8051782bcd27dd96c8006899a276 deleted successfully!
# Record bea6485a1266c0db103814d8fb62570d deleted successfully!
# Record beb656ff6bf702fdef0afd13d4bb8d17 deleted successfully!
# Record bf186853d0b4a5b4d640d774919ffd5e deleted successfully!
# Record bf47f53f8c110123192dea2998b0250c deleted successfully!
# Record bff7d6538b8d36edef313ab25e36ce11 deleted successfully!
# Record c04ba357cff3e57a7c290fb6415ca285 deleted successfully!
# Record c193624f1f3223e3d1258d76dd6ef627 deleted successfully!
# Record c19a70ef732c95a59de74cc6ee587e2b deleted successfully!
# Record c23552775416ad05b488d2d9427a45e3 deleted successfully!
# Record c2d61df8fa8a2d60cefcb63936edac55 deleted successfully!
# Record c2fa1387880268f9d7541745e881810f deleted successfully!
# Record c345212e3653573d7744b861073bbd85 deleted successfully!
# Record c377b58217872bdfd6dd8d161fc9d4fd deleted successfully!
# Record c3876546e8bd17089f8c46dfd5f73b9d deleted successfully!
# Record c3f3758b55c344630870885f238588eb deleted successfully!
# Record c44e009245136c2cbb4a3868b4d3d341 deleted successfully!
# Record c4877a599d9f0b6f1ff5fdef4e57215e deleted successfully!
# Record c49b987f2b4c252365d66638fbd03a82 deleted successfully!
# Record c4bd9a33f1a5c5c17c47cc533848c864 deleted successfully!
# Record c5007f75161725c9ce5550d5d0297e31 deleted successfully!
# Record c55e9cb62afeaca15e7afe8b65891c92 deleted successfully!
# Record c596a732478246fcbbd23cd2f98dedb5 deleted successfully!
# Record c5b5c7592e0a2c4f66140cb644d4d366 deleted successfully!
# Record c5cc53e59b73f7f3ca5c5ea136b6c085 deleted successfully!
# Record c5d82ca5bccf91f99bad36fdf7896fc9 deleted successfully!
# Record c65a9a8ef0b16c2856930090487027a7 deleted successfully!
# Record c698fe016b431ff30812e345d8ebc24f deleted successfully!
# Record c69b09c82d343d24e53478d8627a35a0 deleted successfully!
# Record c6a6980762fc0031412d02e4d56090aa deleted successfully!
# Record c6aa0482372d4eb1f5c0e5aadee09280 deleted successfully!
# Record c733f5a05e0fc6a1ce28f56d1ec0bafa deleted successfully!
# Record c795abfdf28df48ec62acb5bb457dd6e deleted successfully!
# Record c79bf4a97164efc5cd6ddadfe34613f7 deleted successfully!
# Record c7cedceb2682bb367b1250db96417246 deleted successfully!
# Record c8aed7495003ded67dc082e84e3d9f6a deleted successfully!
# Record c8ced1e738a8dfc0011b0e95f4bcc86d deleted successfully!
# Record c9127effb8b48f15761cb6f3317888e6 deleted successfully!
# Record c919cfdb429d8e19af68eb71ea5cd68f deleted successfully!
# Record c9f8f459e6af141207bd0fd2abe5de5a deleted successfully!
# Record c9ff0625fdaa09be9a22f0d132e70203 deleted successfully!
# Record caa07d1ef9c1180650e46e3972b77d5b deleted successfully!
# Record caaf8d9c43ab4fa5de35c0d24a0a00b0 deleted successfully!
# Record cacaa07a88b0360f3ba6f7a1feceb35d deleted successfully!
# Record cadbd818a72b9565052c009eacae8c15 deleted successfully!
# Record cb816ea62edcf890662d755dfa85198a deleted successfully!
# Record cbcd20456f9338d1f610973404ab12a7 deleted successfully!
# Record cbd751a041402348c229d1c2617581d9 deleted successfully!
# Record cbe2bb014af3e0297ebe0148abd0a19c deleted successfully!
# Record cbe9f208011e24e1bbb60d37017d7e57 deleted successfully!
# Record cc36418e8080e8ea4bab618239df0d99 deleted successfully!
# Record cce56a3c316f21492d1e3f3264281c42 deleted successfully!
# Record cd27e6efde8b0c246bfc89f448e99c56 deleted successfully!
# Record cd5c88c8afdbda94fadddde47ca19bf8 deleted successfully!
# Record cd90db2fbe398e95bb16732239b064ae deleted successfully!
# Record cdc2acedbe3cc44d578b7d314e2000c7 deleted successfully!
# Record cdde215c559f5c605df27840a7b5d937 deleted successfully!
# Record cdfcbeb83e14ffed80ebe2186cb0801a deleted successfully!
# Record cdffb4beff06dd54c3fa3e3a2d2a54b3 deleted successfully!
# Record ce29dc7e115fb050726b53843aebeab4 deleted successfully!
# Record ce33bd3cd487a8c2f338084aeb238116 deleted successfully!
# Record cf3d9df47a0e50d23ac431d91caa7573 deleted successfully!
# Record cfe4ad00555c430b8849fa0d3374c638 deleted successfully!
# Record d01da5f22fdd0248af817dfcd152dcdc deleted successfully!
# Record d05c47622435975d0e74a93c3af2b7eb deleted successfully!
# Record d085c30b8637cceb800cbfe1bc40523c deleted successfully!
# Record d09ce10ef2efe31accce015211eecbc5 deleted successfully!
# Record d0cecb90467caf17d8abc38eb64bfa30 deleted successfully!
# Record d1347cd8c242e8bf8ad2d39537e232b4 deleted successfully!
# Record d13dff122930c7d938fd25a105dd38b2 deleted successfully!
# Record d19d75ca0efe700302b25f8d689e2b20 deleted successfully!
# Record d1ab24ebfb370d8721a630d62ff9caa4 deleted successfully!
# Record d1e89f90a34bdd9e236a3eff572ebe53 deleted successfully!
# Record d205c7a6e4022aa4f3d13471d6625ad1 deleted successfully!
# Record d33b1ec50007bd3d69f25d42e07cf212 deleted successfully!
# Record d35ce432a87292658705cffe0382e64d deleted successfully!
# Record d36cea0f3642e492d4fdd8a3e2292f69 deleted successfully!
# Record d4d2bf47baf14b804ee2bb5457e0e919 deleted successfully!
# Record d4e33d5344dbf41202586acbdce627fc deleted successfully!
# Record d4f79260cca0140146a352618c6ba0d6 deleted successfully!
# Record d52e04d6340161f5b78047607172bada deleted successfully!
# Record d6bbd0caaaefdb40ded5376e47d85c54 deleted successfully!
# Record d6ce6b83a6da55a4acfdfe1dddfd9f5e deleted successfully!
# Record d6f422a97ddec300be3cd5e75fef743d deleted successfully!
# Record d750dc83b4d542adb8212ae1b04ce835 deleted successfully!
# Record d751dfe8ad93d6adbfa012bb0b2d5de8 deleted successfully!
# Record d75320bf63eef3df9b7118a9d79bfe25 deleted successfully!
# Record d79ceb088114977bf8e2637f85e0bb4d deleted successfully!
# Record d7f05e58ecbbef6546dd45a84917794b deleted successfully!
# Record d7fff230c0b400627c447b6fd096d869 deleted successfully!
# Record d82d0b54cf9f488958998e02180344ca deleted successfully!
# Record d86bcb7b0fe363c938cdb558f654ca21 deleted successfully!
# Record d8c1f0f34d8187ee8c4ca09211abf156 deleted successfully!
# Record d8e6717769c733aaf99cebb2b6b1ddc7 deleted successfully!
# Record d8f0e0f98675d8abf0dd4d9ab90f4e5f deleted successfully!
# Record d96232ecef6bb65a870d2d9d1919eee4 deleted successfully!
# Record d9b194b9bce3b97c350ec63640617fa2 deleted successfully!
# Record d9cad2c28bd9fcb0bb1af1a05d76368d deleted successfully!
# Record d9f7935fcaa3d8e01ad7e017e792f483 deleted successfully!
# Record dab938734b63a3b2f1c12de681db44fb deleted successfully!
# Record db60a18de37e417399c1a98beda6e511 deleted successfully!
# Record db9962b6626cb7cefc84edb6a2170de6 deleted successfully!
# Record dbbe55bd88af4c011749fdf0786f1c4b deleted successfully!
# Record dc2e8ea5bbe6d00c7fec76022f2b0ee1 deleted successfully!
# Record dcdf44d5e4713a27162bb00ddb597146 deleted successfully!
# Record dd5c7d860de29216cd0598866b0d2fb1 deleted successfully!
# Record ddb85e83a94fa70b86540a5cc02788eb deleted successfully!
# Record ddbbed7c304dcf85435cf5c53cf92cd4 deleted successfully!
# Record de9716a29976853d05a91fcde0ee93c9 deleted successfully!
# Record deba9344ac54431b1a55971ad085edab deleted successfully!
# Record dfd5f0ae6f908120c87b9117534c4c68 deleted successfully!
# Record dfdabe4843f4f573589323500f121244 deleted successfully!
# Record dfefa1f9cd4c637f5b011934ab9bd0bc deleted successfully!
# Record dff5f2cf40504cc0084e5f87612e3ad3 deleted successfully!
# Record e033270668b2e720a6078635eb4db145 deleted successfully!
# Record e04a7ba7ece527b9d93112323eda24df deleted successfully!
# Record e0d0e4f6cffd0c358fce022e1a6e89e7 deleted successfully!
# Record e124354dd3b491f2b3eb647595b6712d deleted successfully!
# Record e1f75d5dda1b03a394206a5938d632a3 deleted successfully!
# Record e1f82c3cf893729c397dab9f05e928b9 deleted successfully!
# Record e2942332099fe5cb1815eba844aed276 deleted successfully!
# Record e2e6a84c6d4eb0492df2168d31c9130e deleted successfully!
# Record e3063f4993fb0cbb9b09db92fc5cb5fd deleted successfully!
# Record e317664a6bbf3812bb81cfe888612472 deleted successfully!
# Record e33cb500d0791c273220dc88e531f926 deleted successfully!
# Record e36f3906a9ce35ed9a481861f4bcd7fc deleted successfully!
# Record e3c009ff8e5f52884cc1d4227fb3c928 deleted successfully!
# Record e449a5cff381941742ee161d2fe222eb deleted successfully!
# Record e468ecb1ae2f85e11570c706adc8d6d6 deleted successfully!
# Record e480e39e74dbabbaee34dfebd237c738 deleted successfully!
# Record e501ebbfa5631a8f11f25ce33cc8c96f deleted successfully!
# Record e55b37e865088e77638f3d3423daa1b2 deleted successfully!
# Record e634dd0f04fd5d885bfad3c65de8e814 deleted successfully!
# Record e6ac2a017839aaf85362384bc6ca232e deleted successfully!
# Record e6f375b3c3160f2255d0c9460838f602 deleted successfully!
# Record e6fb13b3f3a3fd84f1529bd913f8c778 deleted successfully!
# Record e7cbfcee0d9476f8607f2aa871b142d5 deleted successfully!
# Record e84823d904bc710c865febac78e4e7b5 deleted successfully!
# Record e8e22f7a06ca3532da40dd9c86211a85 deleted successfully!
# Record e8f3bf1bc4e022157e0b0b8a2b280c75 deleted successfully!
# Record e901386191fa679f997fd2875fd04f27 deleted successfully!
# Record e9a0b030a4a114df9178b8f8815afffa deleted successfully!
# Record e9c083d1c99e16ec509ce5e6223bcf40 deleted successfully!
# Record ea295eaaa4186e5944188d72a855159e deleted successfully!
# Record ea4a6b26e64167cd7b12d2bd1f6c5381 deleted successfully!
# Record eaa79e689169989b04b59cbaf9ce5c48 deleted successfully!
# Record eabbafd841e60fc603496445c48685ef deleted successfully!
# Record ec1091a523988b32a0ddbfa796eb24d2 deleted successfully!
# Record ecd109dc47580921207eb14ec0860089 deleted successfully!
# Record ed050af628b0b4d515523cd782cd931e deleted successfully!
# Record ee16f138e119d3b926cec9d71634405f deleted successfully!
# Record ee6ee5e71665bf7e2d783852484a8044 deleted successfully!
# Record ee777d1da7256a3be5a91263f7edc388 deleted successfully!
# Record eebb3ba8a9ee9521efa9eef2d030da04 deleted successfully!
# Record efb9be3659370389ae129e99459602c9 deleted successfully!
# Record f0a10a5e9104318cb4588696b78fa75c deleted successfully!
# Record f0c53fb2289e1ee09ae3310ec2576093 deleted successfully!
# Record f13096d4d99152692711f001d7e64bd1 deleted successfully!
# Record f13986681b8bb64834fcf6c924e2841f deleted successfully!
# Record f19048fd04c6f5bdd4f54a54ac2e8db1 deleted successfully!
# Record f1a085086c00db7c0295c4a41b9a6d0b deleted successfully!
# Record f1e809d6e0dd1e2da53fbe91c75ff93a deleted successfully!
# Record f2081f6534339b8c93ca5fafc092edf6 deleted successfully!
# Record f2aadf1586d9dca5a1abef1f09bfba90 deleted successfully!
# Record f2ebb12e920b85d1db5d4559aca8834f deleted successfully!
# Record f2f406374760aeb7579b147b41a4b671 deleted successfully!
# Record f33b1ebcb0068f8bee89e1c4cafb8091 deleted successfully!
# Record f399b5f4db9f826482701e36dd474a33 deleted successfully!
# Record f3e306b02eea80a2ffa3da638d46d8a7 deleted successfully!
# Record f402c1cbb5220cc73608d94d497c2ee3 deleted successfully!
# Record f4152618313ec3636b78633e1649c9c4 deleted successfully!
# Record f44b7bfbc9ca5672c318b926cb624512 deleted successfully!
# Record f494de46c039970f7b559f3c0b41c204 deleted successfully!
# Record f4cd9109ad18726182574800fd5af276 deleted successfully!
# Record f4cf2b2caf2096c44c30aa369c17a697 deleted successfully!
# Record f4e7ee1fc653811ab9cf0ebaa576f574 deleted successfully!
# Record f52ed65d45d2de1c252c3ec076e8db06 deleted successfully!
# Record f52f8c6cfbfa8df9d06979ecdd38e2bb deleted successfully!
# Record f53610213c0e35679453becabaab54c7 deleted successfully!
# Record f55ce8b0480e8cfafc8ba7df67640576 deleted successfully!
# Record f5f412911ba914337fa459f30e382aa7 deleted successfully!
# Record f62d242cab877cad223c4a31c90ae403 deleted successfully!
# Record f674d6ce098249e206194fc18ef1f967 deleted successfully!
# Record f675146257295dba4ea4499172cf7934 deleted successfully!
# Record f691980586c9e8fade02f6225ef5d4c9 deleted successfully!
# Record f6b94f1486fa25036f35112efdf44c5b deleted successfully!
# Record f6d18afc86bedb52bb3846b62f6a6db6 deleted successfully!
# Record f71b511e5ca36a5349cdab566c7f60f1 deleted successfully!
# Record f7632690b91fc5f9f18a1b86a2c667c0 deleted successfully!
# Record f8f6cb0f4246f80122adf10699caccd4 deleted successfully!
# Record f90fa62603eaa98fe603c9b611d6b415 deleted successfully!
# Record f9f597a920c932505b5863184e1a6af1 deleted successfully!
# Record fa0621bae516022bbf130da231efc24c deleted successfully!
# Record fa25db5ed86d17e75576e2b02217d8e6 deleted successfully!
# Record fabe98232ee69a7340f4e3391ea64121 deleted successfully!
# Record fac5db9c499ad2af0e50eb97889f6267 deleted successfully!
# Record facccfb9cd7935742e3314339813a03f deleted successfully!
# Record fb50918a6f169125164bb59a56639109 deleted successfully!
# Record fbc8ede86eb09eb8314e263b3b8c5b62 deleted successfully!
# Record fcb1ec69780ec3d5561bf72045305e50 deleted successfully!
# Record fd5940e63a50a3fbfb61c8fb8bab4c6e deleted successfully!
# Record fd8609904322f6aea7d3614e86099ad8 deleted successfully!
# Record fdccd494757b38a77a1394cbdd8fd7e3 deleted successfully!
# Record fdf179b8f086c4962dcb3823797dd765 deleted successfully!
# Record fdfd58621d7004775caf8c4679af5411 deleted successfully!
# Record fe56bd9ed92bc6b30ddbe6a1d9d11845 deleted successfully!
# Record fe927a38a28f1f864603ef7ccf2c9515 deleted successfully!
# Record ff59f3cbdfb56ba5e228539f14198bb1 deleted successfully!
# Record ff99ff9be9c19d92c4c6c7941f4740f7 deleted successfully!
# Record ffe5f70d5699c32a3d2dc9d77f2074ee deleted successfully!
