# %%
! pip3 install --upgrade --user --quiet google-cloud-aiplatform
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 58.4 MB/s eta 0:00:00
#   WARNING: The script tb-gcp-uploader is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import sys

if "google.colab" in sys.modules:
    import IPython

    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.

# %%
# Define project information
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# Initialize Vertex AI
import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %%
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

def similarity_assessment_model(query1,query2):

    generation_config = {
    "max_output_tokens": 8192,
    "temperature": 1,
    "top_p": 0.95,
    "response_mime_type":"application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel(
        "gemini-1.5-flash-001",
    )
    responses = model.generate_content(
        [ """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

文章1 :"""+query1+"\n 文章2 : "+query2],
        generation_config=generation_config,
        stream=False,
    )

    #for response in responses:
        #print(response.text, end="")
    return str(responses.candidates[0].content.parts[0].text)

#write code here.

#model1
## get 20data
## get top similar data
### evaluate similality.


#Confirmation of the model's authenticity
for i in range(1,10):
  print(similarity_assessment_model(" 今日は忙しく取り組めません。","☁️日次報告☁️今日は取り組めませんでした💦"))
  print(similarity_assessment_model(" 今日は忙しく取り組めません。"," 取り組みできませんでした。"))
# Out:
# {"similarity": "3", "comment": "文章の大まかな内容は類似している。文章1は「今日は忙しく取り組めません」と断定的に書かれているのに対し、文章2は「今日は取り組めませんでした」と過去形で書かれている。また、文章2では絵文字が使われているなど、文章表現が異なっている。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似している（どちらも仕事について言及している）が、細かい内容は異なり（文章1は現在形で、文章2は過去形で記述されている）、文章表現も異なっている。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なり、文章表現も異なっている。文章1は「今日は忙しく取り組めません」と客観的な表現であるのに対し、文章2は「☁️日次報告☁️今日は取り組めませんでした💦」と、絵文字や顔文字を用いた、個人的な感情が強く表れている表現となっている。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている。文章1は「今日は忙しく取り組めません」と断言しているのに対し、文章2は「取り組みできませんでした」と過去形で結果を述べているため、文章表現も異なっている。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は「今日は忙しく取り組めません」と断定的な表現である一方、文章2は「今日は取り組めませんでした」と過去形で表現されている。また、文章2は絵文字を使用しているため、文章表現が異なると判断した。"}
# {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容は異なり、文章表現も異なっている。文章1は「今日は」という時間に関する記述があるが、文章2にはない。また、文章1は「取り組めません」という否定形だが、文章2は「できませんでした」という過去形である。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現が異なっている。文章1は「今日は忙しく取り組めません」と、具体的な理由を示している一方、文章2は「今日は取り組めませんでした」と、理由が不明確である。また、文章表現においても、文章1は簡潔な表現であるのに対し、文章2は絵文字や顔文字を用いた、よりカジュアルな表現となっている。"}
# {"similarity":3,"comment":"文章1は未来のこと、文章2は過去のことを述べており、細かい内容が異なる。しかし、どちらも「取り組む」という単語が使われていることから、文章表現は類似している。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は「今日は忙しく取り組めません」と断定的な表現である一方、文章2は「今日は取り組めませんでした」と事実を述べている。また、文章2は絵文字や顔文字を使用しており、文章1とは表現が異なる。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は今日の状況を表しているのに対し、文章2は過去を振り返っている。"}
# {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なり、文章表現も異なっています。文章1では「忙しく」という単語が使われているのに対し、文章2では「日次報告」や絵文字が使われていることから、文章表現が異なることがわかります。"}
# {"similarity":3,"comment":"文章1は未来形で、文章2は過去形で、文章の内容は類似しているが、細かい内容が異なっている。文章表現は類似している。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は「今日は忙しく取り組めません」と断定的に書かれている一方、文章2は「今日は取り組めませんでした」と過去形で書かれている。また、文章2には絵文字や口語表現が含まれており、文章1よりもカジュアルな印象を受ける。"}
# {"similarity":3,"comment":"文章1は現在形の「取り組めません」であり、文章2は過去形の「取り組みできませんでした」であるため、細かい内容は異なります。しかし、文章の大まかな内容は「仕事ができない」という点で類似しています。また、文章表現も類似しています。そのため、類似度は3と判断しました。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現が異なっている。文章1は「今日は忙しく取り組めません」と、具体的な理由が示されている一方、文章2は「今日は取り組めませんでした」と、理由が不明確。また、文章2は絵文字や顔文字を使用しており、文章1とは表現が異なる。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっており、文章表現も異なっている。文章1は未来のことについて述べているが、文章2は過去のことについて述べている。"}
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は「今日は忙しく取り組めません」と断定的に述べている一方、文章2は「今日は取り組めませんでした」と過去形で表現している。また、文章2は絵文字を使用しているなど、文章表現が異なる。"}
# {"similarity": "3", "comment": "文章1は「今日は忙しく取り組めません」と未来の話、文章2は「取り組みできませんでした」と過去の話をしているので、細かい内容は異なります。しかし、文章表現はどちらも簡潔で、同じような文末表現（「ません」「ませんでした」）を用いているため、3としました。"}

# %%
#Confirmation of the model's authenticity
print(similarity_assessment_model(" 今日は忙しく取り組めません。","☁️日次報告☁️今日は取り組めませんでした💦"))
print(similarity_assessment_model(" 今日は忙しく取り組めません。"," 取り組みできませんでした。"))
print(similarity_assessment_model(" 今日は忙しく取り組めません。"," 関係ない文章"))
print(similarity_assessment_model(" 今日は忙しく取り組めません。", "今日はバタバタしていて取り組めませんでした💦"))
# Out:
# {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は単にできないことを伝えているのに対し、文章2は日次報告という文脈で、さらに絵文字や絵文字を用いた表現で、感情を含んでいる点が異なる。"}
# {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は現在形の断定で、文章2は過去形の否定形である。"}
# {"similarity":0,"comment":"文章1と文章2は全く異なる内容であり、単語も共通点が見当たらないため0と評価しました。"}
# {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現は類似している。文章1は未来形の表現で、文章2は過去形の表現になっている。また、文章2では絵文字が使われている。"}

# %%
# !pip install google-cloud-storage
from google.cloud import storage
import pandas as pd
# バケット名とファイル名を指定
bucket_name = 'not_confidencial_data_for_share'
file_name = 'output_with_categories_1107.jsonl'
local_file_path = 'output_with_categories_1107.jsonl'  # ローカルの保存先

# Storageクライアントを初期化
client = storage.Client()

# バケットとBlobオブジェクトを取得
bucket = client.get_bucket(bucket_name)
blob = bucket.blob(file_name)

# ファイルをローカルにダウンロード
blob.download_to_filename(local_file_path)
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.19.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (4.25.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.25.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2024.8.30)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.6.1)

# %%
# バケット名とファイル名を指定
bucket_name = 'not_confidencial_data_for_share'
file_name = 'qa_pairs_for_rag_1108.jsonl'
local_file_path = 'qa_pairs_for_rag_1108.jsonl'  # ローカルの保存先

# Storageクライアントを初期化
client = storage.Client()

# バケットとBlobオブジェクトを取得
bucket = client.get_bucket(bucket_name)
blob = bucket.blob(file_name)

# ファイルをローカルにダウンロード
blob.download_to_filename(local_file_path)

# %% [markdown]
# # **BERT and ScaNN (Model 1)**

# %%
# !pip install sentence-transformers scann numpy jsonlines
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Collecting scann
#   Downloading scann-1.3.4-cp310-cp310-manylinux_2_27_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.46.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: tensorflow~=2.17.0 in /usr/local/lib/python3.10/dist-packages (from scann) (2.17.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (24.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (1.67.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.17.0->scann) (0.37.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.17.0->scann) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow~=2.17.0->scann) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow~=2.17.0->scann) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow~=2.17.0->scann) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow~=2.17.0->scann) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow~=2.17.0->scann) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow~=2.17.0->scann) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow~=2.17.0->scann) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow~=2.17.0->scann) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow~=2.17.0->scann) (0.1.2)
# Downloading scann-1.3.4-cp310-cp310-manylinux_2_27_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 80.6 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: jsonlines, scann
# Successfully installed jsonlines-4.0.0 scann-1.3.4

# %% [markdown]
# With category

# %%
import jsonlines
import numpy as np
import random
from sentence_transformers import SentenceTransformer
import scann
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Step 1: Load your dataset (output_categories.jsonl)
with jsonlines.open('output_with_categories_1107.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer-category pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']} Category: {pair['category']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]
categories = [pair['category'] for pair in qa_pairs]

# Initialize model for SBERT
model_sbert = SentenceTransformer('all-MiniLM-L6-v2')

# Step 3: Encode the documents using SBERT
question_embeddings = model_sbert.encode(documents, convert_to_numpy=True)

# Step 4: Create ScaNN index for SBERT embeddings
scann_index = scann.scann_ops.builder(question_embeddings, 10, "dot_product").tree(num_leaves=min(1000, len(questions)), num_leaves_to_search=50).score_ah(2, anisotropic_quantization_threshold=0.2).reorder(50).build()

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 5: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Encode the query using SBERT
    query_embedding = model_sbert.encode([f"Question: {query}"], convert_to_numpy=True)

    # Search the ScaNN index
    neighbors, distances = scann_index.search_batched(query_embedding)

    # Return the most similar questions
    closest_questions = [questions[i] for i in neighbors[0][:top_k]]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Evaluate the system with 20 selected questions using SBERT and ScaNN
print("Evaluating using SBERT and ScaNN:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Evaluating using SBERT and ScaNN:
# query1: 訂正 【日次報告】7-1 課題提出完了,10/3　Week7-1、7-2の実践課題を提出しました,Week7  7-3の課題を提出しました,【日次報告】7-3 課題完了（プロンプト提出欄・保留中）,week7-1提出しました
# similarity_assessment_model(query1, 訂正 【日次報告】7-1 課題提出完了): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容で、文章表現も同一です。"}
# similarity_assessment_model(query1, 10/3　Week7-1、7-2の実践課題を提出しました): {"similarity": "3", "comment": "文章1は、日付と課題提出状況を簡潔に報告しているのに対し、文章2は、日付、週、課題番号を明記し、より詳細な報告となっている。大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっているため、3とした。"}
# similarity_assessment_model(query1, Week7  7-3の課題を提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容は異なり（日付や課題番号）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query1, 【日次報告】7-3 課題完了（プロンプト提出欄・保留中）): {"similarity": 3, "comment": "文章の大まかな内容は類似している（日次報告、課題に関する内容）が、細かい内容（提出日、課題の詳細）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query1, week7-1提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出に関する報告）が、細かい内容は異なり（文章1は日次報告であることを明記、文章2は週次報告であることを示唆）、文章表現も異なっている（文章1はフォーマル、文章2はカジュアル）ため、3と評価しました。"}
# query2: すみませんクレジットカードをもう一度試してもいいですか？💦,すみません…zoomに入れないです…,【クレジットカード】,ホワイトボードですね？わかりました！,フレームピクセルの指定や画像のピクセルの指定はございますが何でもいいのですか？
# similarity_assessment_model(query2, すみませんクレジットカードをもう一度試してもいいですか？💦): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, すみません…zoomに入れないです…): {"similarity": 0, "comment": "文章の内容、表現、単語全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query2, 【クレジットカード】): {"similarity": 1, "comment": "文章1はクレジットカード決済に関するお願いであり、文章2はクレジットカードという単語のみであり、内容は大きく異なる。しかし、文章表現は簡潔で、同じような雰囲気を感じられるため1点と評価した。"}
# similarity_assessment_model(query2, ホワイトボードですね？わかりました！): {"similarity":0,"comment":"文章1はクレジットカードに関する問い合わせ、文章2はホワイトボードに関する返答で、内容、表現、単語全てが異なります。"}
# similarity_assessment_model(query2, フレームピクセルの指定や画像のピクセルの指定はございますが何でもいいのですか？): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なります。"}
# query3: 谷津さんへ4-2 実践課題再提出しました！,谷津さま今日は3-3課題の修正と、3-5動画視聴をしました！,谷津さんへPC再起動したらできました！🥺✨ありがとうございます！！,谷津さま今日は3-5の実践課題の作業をしました！,谷津さん10/313-3の動画視聴をしました。figma提出課題の途中です。
# similarity_assessment_model(query3, 谷津さんへ4-2 実践課題再提出しました！): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query3, 谷津さま今日は3-3課題の修正と、3-5動画視聴をしました！): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題に関する報告）が、細かい内容（提出した課題、行った学習内容）が異なり、文章表現も異なるため3とした。"}
# similarity_assessment_model(query3, 谷津さんへPC再起動したらできました！🥺✨ありがとうございます！！): {"similarity": 0, "comment": "文章の内容と単語が大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query3, 谷津さま今日は3-5の実践課題の作業をしました！): {"similarity": 3, "comment": "文章の大まかな内容は類似している(課題提出に関する連絡)が、細かい内容(提出済みか作業中かの違い)が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query3, 谷津さん10/313-3の動画視聴をしました。figma提出課題の途中です。): {"similarity": "3", "comment": "文章の大まかな内容は類似している(課題の提出に関する連絡)、細かい内容は異なり(課題の種類、提出日などが異なる)、文章表現は異なっている(文末が異なる)ため3としました。"}
# query4: 今日取り組んだことweek7-2完了しました。明日は7-3を進めようと思います！,今日取り組んだことweek8-2完了しました。来週はweek9-1を進めて行きたいと思います！,【今日（昨日）取り組んだこと】3-3の動画視聴と課題を進めました。今日も同様に進めていきたいです。,【取り組んだこと】竹内さん昨日・クラウドワークスzoom面談今日・Photoshop・week4-2,今日は何も取り組めませんでした。
# similarity_assessment_model(query4, 今日取り組んだことweek7-2完了しました。明日は7-3を進めようと思います！): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query4, 今日取り組んだことweek8-2完了しました。来週はweek9-1を進めて行きたいと思います！): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっているため、3としました。weekの番号が異なり、明日と来週という表現も異なります。"}
# similarity_assessment_model(query4, 【今日（昨日）取り組んだこと】3-3の動画視聴と課題を進めました。今日も同様に進めていきたいです。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（今週の課題に取り組んでいる）が、細かい内容（取り組んだ課題番号、明日やることなど）が異なり、文章表現も異なっているため。"}
# similarity_assessment_model(query4, 【取り組んだこと】竹内さん昨日・クラウドワークスzoom面談今日・Photoshop・week4-2): {"similarity": "2", "comment": "文章1は今週のタスクの進捗について記述している一方、文章2は昨日と今日の業務内容を羅列しているため、内容的には大きく異なります。しかし、どちらも業務内容について記述しているという点で、単語の類似性が見られます。"}
# similarity_assessment_model(query4, 今日は何も取り組めませんでした。): {"similarity": 0, "comment": "文章1と文章2の内容は全く異なり、単語も異なります。"}
#
# query5: week2 2-1 課題を提出しました,week2-1-3も提出しました。,Week3-1の課題を提出しました。,week2-2の課題を提出しました,Week4-2,3の課題を提出しました。
# similarity_assessment_model(query5, week2 2-1 課題を提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1では、week2-3 2-4 3-1の課題を提出したことがわかるが、文章2ではweek2 2-1の課題を提出したことがわかる。文章表現においても、文章1は課題を提出したという事実を列挙するような書き方をしているのに対し、文章2はより簡潔な書き方をしている。"}
# similarity_assessment_model(query5, week2-1-3も提出しました。): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、文内で使われている単語が似通っている。文章1は3つの課題の提出を報告しているのに対し、文章2は1つの課題の提出を報告している。"}
# similarity_assessment_model(query5, Week3-1の課題を提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出した課題の週が異なる）、文章表現も異なっている（句読点の有無、数字の表記）ため3としました。"}
# similarity_assessment_model(query5, week2-2の課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出された課題の週が異なる）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query5, Week4-2,3の課題を提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっているため、3と判断しました。文章1では、week2-3 2-4 3-1の課題と複数課題が記載されているのに対し、文章2ではWeek4-2,3の課題と、1つの課題が記載されているため、細かい内容が異なります。また、文章表現においても、文章1では「課題を提出しました」と短く簡潔な表現であるのに対し、文章2では「課題を提出しました。」と句読点を使用し、より丁寧な表現となっています。"}
# query6: ホワイトボードですね？わかりました！,こんにちは！昨日成果をご報告するのを忘れていたので、今させていただきます。・動画視聴、課題提出・バナートレース途中まで,3-4提出しましたが、あれで良かったでしゃうか？上手くデータの共有出来ませんでして(汗),すみませんクレジットカードをもう一度試してもいいですか？💦,度々すみません💦8-2課題提出できました❢まとめての提出で恐縮ですが、よろしくお願いします❢
# similarity_assessment_model(query6, ホワイトボードですね？わかりました！): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なる。"}
# similarity_assessment_model(query6, こんにちは！昨日成果をご報告するのを忘れていたので、今させていただきます。・動画視聴、課題提出・バナートレース途中まで): {"similarity":0,"comment":"文章1はSlackの登録に関する問い合わせ、文章2は業務の進捗報告であり、内容や単語、文章表現も異なるため0点としました。"}
# similarity_assessment_model(query6, 3-4提出しましたが、あれで良かったでしゃうか？上手くデータの共有出来ませんでして(汗)): {"similarity": 0, "comment": "文章1はSlackの登録に関する問い合わせ、文章2はデータ共有に関する問い合わせであり、内容が大きく異なります。文章表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query6, すみませんクレジットカードをもう一度試してもいいですか？💦): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query6, 度々すみません💦8-2課題提出できました❢まとめての提出で恐縮ですが、よろしくお願いします❢): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現も単語も異なります。"}
# query7: また学習のほうですが、本日4-3まで完了しております。添削よろしくお願いいたします,ありがとうございます😊,あれ？すみません！今日の認識でした。本日は難しいですか？,こんにちは！よろしくお願いします！,ありがとうございます。改めて選択させていただきました。よろしくお願いします！
# similarity_assessment_model(query7, また学習のほうですが、本日4-3まで完了しております。添削よろしくお願いいたします): {"similarity": 5, "comment": "文章1と文章2は完全に同一の内容です。"}
# similarity_assessment_model(query7, ありがとうございます😊): {"similarity": 0, "comment": "文章1は学習の進捗について報告しており、文章2は感謝の言葉であり、内容が全く異なるため。"}
# similarity_assessment_model(query7, あれ？すみません！今日の認識でした。本日は難しいですか？): {"similarity": 0, "comment": "文章1は学習の進捗について報告しており、文章2は今日の予定に関する問い合わせです。内容や表現が大きく異なるため0としました。"}
# similarity_assessment_model(query7, こんにちは！よろしくお願いします！): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query7, ありがとうございます。改めて選択させていただきました。よろしくお願いします！): {"similarity": 0, "comment": "文章の内容が異なり、単語も異なるため、類似度は0です。"}
# query8: こんばんは。チャットGPTの有料版申し込みしようと思いますが、この画面で合ってますか？,この画面がでます,嶋内さんお忙しい中と思いますが、本日、午後から再度面接のお時間を頂戴することは難しいでしょうか？,すみませんお返事しておらず夕方17:30以降で空いてる日はございますか？,ログインしているのですが、パソコンからだとどうしてもできず、、インターネットがMicrosoftedgeというのは関係ありますでしょうか？
# similarity_assessment_model(query8, こんばんは。チャットGPTの有料版申し込みしようと思いますが、この画面で合ってますか？): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query8, この画面がでます): {"similarity": 2, "comment": "文章の内容は異なっていますが、チャットGPTの有料版申し込みに関する内容であることがわかります。また、文章1の「この画面で合ってますか？」と文章2の「この画面がでます」という表現が似ています。"}
# similarity_assessment_model(query8, 嶋内さんお忙しい中と思いますが、本日、午後から再度面接のお時間を頂戴することは難しいでしょうか？): {"similarity": 0, "comment": "文章1はチャットGPTに関する質問、文章2は面接に関する依頼であり、内容、単語、表現ともに異なるため0としました。"}
# similarity_assessment_model(query8, すみませんお返事しておらず夕方17:30以降で空いてる日はございますか？): {"similarity":0,"comment":"文章の内容、単語、表現がすべて異なるため類似度は0です。"}
# similarity_assessment_model(query8, ログインしているのですが、パソコンからだとどうしてもできず、、インターネットがMicrosoftedgeというのは関係ありますでしょうか？): {"similarity": 0, "comment": "文章1はチャットGPTの有料版申し込みに関する質問で、文章2はパソコンからのログインに関する質問で、内容は全く異なり、単語も類似していません。"}
# query9: 藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出,藤川様へ【10/9,12に取り組んだこと】・3-3 動画視聴、課題実施【本日取り組んだこと】・3-3 課題提出・2-3課題手直し、再提出,藤川さん本日取り組んだことです。・Week2-3 動画視聴、講義後テスト・4-1 任意課題バナー作成以上となります。,藤川さん3-1.3-2動画視聴と課題提出終わりました！3-3は課題が今途中です！,中川さん今日は1-3の課題を再提出しました！(昨日は、1-4、2-1、2-2の動画視聴と2-2の課題を提出しました！)
# similarity_assessment_model(query9, 藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query9, 藤川様へ【10/9,12に取り組んだこと】・3-3 動画視聴、課題実施【本日取り組んだこと】・3-3 課題提出・2-3課題手直し、再提出): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も一部異なるため3としました。\n文章1では、「3-3 実践課題手直し、再提出」「3-4 課題提出」と具体的な内容が記載されています。\n文章2では、「3-3 動画視聴、課題実施」「3-3 課題提出」「2-3課題手直し、再提出」と、具体的な内容が異なり、日付や課題番号も記載されています。\n文章表現は、箇条書きや「藤川様へ」「【本日取り組んだこと】」といった共通点があるものの、文章2では「10/9,12に取り組んだこと」など、文章1にはない表現も見られます。"}
# similarity_assessment_model(query9, 藤川さん本日取り組んだことです。・Week2-3 動画視聴、講義後テスト・4-1 任意課題バナー作成以上となります。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっており、文章表現も異なっている。文章1は具体的なタスク内容が記述されているのに対し、文章2は章立てのような記述になっている。また、文章表現も文章1は「～手直し」「～提出」など、具体的な行動を記述しているのに対し、文章2は「～視聴」「～作成」など、より抽象的な表現になっている。"}
# similarity_assessment_model(query9, 藤川さん3-1.3-2動画視聴と課題提出終わりました！3-3は課題が今途中です！): {"similarity": "3", "comment": "文章の大まかな内容は類似していますが、細かい内容が異なり、文章表現も異なっています。文章1は業務報告のような形式で、文章2は個人的な報告のような形式になっています。"}
# similarity_assessment_model(query9, 中川さん今日は1-3の課題を再提出しました！(昨日は、1-4、2-1、2-2の動画視聴と2-2の課題を提出しました！)): {"similarity": "2", "comment": "文章の大まかな内容は異なっているが、課題提出、再提出といった単語が共通で使用されている。"}
# query10: 8-1課題完了しました。,課題8-1.8-2を提出しました,8-3、8-4課題完了しました。,課題2-3,2-4完了しました。,2-4 課題提出しました！
# similarity_assessment_model(query10, 8-1課題完了しました。): {"similarity":4,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なっている。文章表現は類似している。"}
# similarity_assessment_model(query10, 課題8-1.8-2を提出しました): {"similarity": "4", "comment": "文章の大まかな内容は類似していますが、細かい内容が異なっています。文章1は8-2課題の完了を報告しているのに対し、文章2は8-1と8-2の両方の課題の提出を報告しています。文章表現は類似しています。"}
# similarity_assessment_model(query10, 8-3、8-4課題完了しました。): {"similarity": "4", "comment": "文章の大まかな内容は類似しており、課題の完了を報告している。細かい内容では、課題番号が異なっている。文章表現は類似している。"}
# similarity_assessment_model(query10, 課題2-3,2-4完了しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現が異なっている。文章1は「8-2課題」と課題番号が先頭にきているのに対し、文章2は「課題2-3,2-4」と課題番号が後にきている。また、文章1は「完了しました」と簡潔な表現であるのに対し、文章2は「完了しました」の後にカンマがあり、表現が異なっている。"}
# similarity_assessment_model(query10, 2-4 課題提出しました！): {"similarity": 4, "comment": "文章の大まかな内容は課題の提出に関するもので類似している。細かい内容は課題番号が異なり、文章表現も「完了しました」と「提出しました！」で異なるため、4とした。"}
# query11: 以前提出してエラーになっていた課題3-3を再提出いたしました。よろしくお願いします。,課題3-3を提出しました。よろしくお願いします。,2-3まで提出しました！よろしくお願いいたします。,課題3−3を提出しました。添削よろしくお願いいたします。,課題2-3を提出しました。よろしくお願いします。
# similarity_assessment_model(query11, 以前提出してエラーになっていた課題3-3を再提出いたしました。よろしくお願いします。): {"similarity": "4", "comment": "文章の大まかな内容は類似していますが、課題3-3の提出状況が異なっています。文章表現は類似しています。"}
# similarity_assessment_model(query11, 課題3-3を提出しました。よろしくお願いします。): {"similarity":5,"comment":"文章1と文章2は完全に一致しているため、類似度は5です。"}
# similarity_assessment_model(query11, 2-3まで提出しました！よろしくお願いいたします。): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、課題の提出を報告している。細かい内容は課題番号が異なり、文章表現も若干異なる。"}
# similarity_assessment_model(query11, 課題3−3を提出しました。添削よろしくお願いいたします。): {"similarity": "4", "comment": "文章の大まかな内容は類似しており、細かい内容が異なっていますが、文章表現は類似しています。文章1では単に「よろしくお願いします」とありますが、文章2では「添削よろしくお願いいたします」と添削を依頼している点が異なります。"}
# similarity_assessment_model(query11, 課題2-3を提出しました。よろしくお願いします。): {"similarity":4,"comment":"文章の大まかな内容は類似しているが、課題番号が異なっている。文章表現は類似している。"}
# query12: すみません！治りました！,久しぶりに集中してできました！第2章の課題提出できました,こんにちは。何度もすみません。canvaの使い方でお伺いしたいのですがLINEでも可能でしょうか？,こんばんは！本日の成果をご報告します。・オリジナルバナー制作,こちらこそお時間いただきありがとうございました🙇なるほど、、！adobe試したのですが全然うまくいきませんでした😭YouTube等活用して再トライしてみます！
# similarity_assessment_model(query12, すみません！治りました！): {"similarity":0,"comment":"文章1は感謝の言葉と共に再試行を表明しており、文章2は問題解決の報告であり、内容も表現も大きく異なります。"}
# similarity_assessment_model(query12, 久しぶりに集中してできました！第2章の課題提出できました): {"similarity":0,"comment":"文章1は感謝の気持ちを伝えている一方で、文章2は達成感を表現しています。内容も単語も全く異なるため類似度は0です。"}
# similarity_assessment_model(query12, こんにちは。何度もすみません。canvaの使い方でお伺いしたいのですがLINEでも可能でしょうか？): {"similarity": 0, "comment": "文章1は感謝の言葉、文章2は質問であり、内容は全く異なります。文章表現も大きく異なるため、類似度は0です。"}
#
# similarity_assessment_model(query12, こんばんは！本日の成果をご報告します。・オリジナルバナー制作): {"similarity": 0, "comment": "文章1は感謝の気持ちを伝えているのに対し、文章2は報告を行っているため、内容が異なります。また、文章表現も異なっています。"}
# similarity_assessment_model(query12, こちらこそお時間いただきありがとうございました🙇なるほど、、！adobe試したのですが全然うまくいきませんでした😭YouTube等活用して再トライしてみます！): {"similarity": "3", "comment": "文章の大まかな内容は類似している（感謝の気持ちを表し、問題解決のために試行錯誤する様子がわかる）。しかし、細かい内容は異なり（文章1は操作方法に関する内容、文章2はAdobeに関する内容）、文章表現も異なる（文章1は絵文字を多く使用し、文章2は絵文字を1つのみ使用している）ため、3と評価しました。"}
# query13: 課題2-3,2-4完了しました。,4-4課題まで提出しました。,1-4 実践課題④提出しました,2-4 課題提出しました！,4-2 実践課題提出しました。
# similarity_assessment_model(query13, 課題2-3,2-4完了しました。): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、課題番号の表記が異なり、文章表現も若干異なる。"}
# similarity_assessment_model(query13, 4-4課題まで提出しました。): {"similarity": 4, "comment": "文章の大まかな内容は類似している（課題の提出について）。細かい内容では、文章1は「3-4課題」と具体的な課題番号が示されているのに対し、文章2は「4-4課題」と、より抽象的な表現になっている。文章表現は、文章1が「完了しました」という簡潔な表現である一方、文章2は「提出しました」というより丁寧な表現であるなど、類似している。"}
# similarity_assessment_model(query13, 1-4 実践課題④提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の提出）が、細かい内容（課題番号、提出済みか完了済みか）が異なり、文章表現も異なるため3とした。"}
# similarity_assessment_model(query13, 2-4 課題提出しました！): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている。課題完了と課題提出は異なるが、2-4という数字が共通していることから、文章表現は類似していると言える。"}
# similarity_assessment_model(query13, 4-2 実践課題提出しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（課題番号、提出という言葉の有無）、文章表現も異なっている（句読点の有無）ため、3としました。"}
# query14: 島戸さんへ＜一日報告＞体調が悪くて休んでた分を取り返す為に今日長めに時間を取ったので、課題を進めることが出来ました！明日以降、2-3のバナー制作演習をすすめていきます2-2のバナーのデザイン制作の課題提出したのですが、間違えて2-3の制作演習のところに提出してしまったので、訂正してもらうことは可能でしょうか？？,井関様1-3の実践課題、オススメバナー初級をトレースして提出しました♪,谷津さんへ昨日は進めれなかったので、今日3-3の再提出、3-4の課題の提出まで終わりました💡明日明後日は結構時間があるので、進められると思います✨,井関さん今日は面談ありがとうございました✨不安だったことを聞けて、勉強をすることが楽しみになりました💕今日は1-1動画視聴をして課題を提出してみました！iPhoneでも課題はできますが、早くパソコンで課題を提出できるようにしたいので、明日パソコンを見に行って1-2からはパソコンから課題を提出したいと思います👀,【井関さん】「今日取り組んだこと」3-1から3-2まで受講しました。添削していただいた実践課題2つ(1-3と2-2)も修正して再提出しました。
# similarity_assessment_model(query14, 島戸さんへ＜一日報告＞体調が悪くて休んでた分を取り返す為に今日長めに時間を取ったので、課題を進めることが出来ました！明日以降、2-3のバナー制作演習をすすめていきます2-2のバナーのデザイン制作の課題提出したのですが、間違えて2-3の制作演習のところに提出してしまったので、訂正してもらうことは可能でしょうか？？): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
# similarity_assessment_model(query14, 井関様1-3の実践課題、オススメバナー初級をトレースして提出しました♪): {"similarity": 1, "comment": "文章1は課題の進捗報告と修正依頼、文章2は課題提出報告という内容で、内容は大きく異なります。しかし、課題提出に関する報告という点で、文章表現や単語が似ているため、1としました。"}
# similarity_assessment_model(query14, 谷津さんへ昨日は進めれなかったので、今日3-3の再提出、3-4の課題の提出まで終わりました💡明日明後日は結構時間があるので、進められると思います✨): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の進捗報告）。しかし、細かい内容は異なり、文章表現も異なる。文章1は具体的な課題名や提出先などを記述している一方、文章2は具体的な課題名のみ記述している。また、文章1は疑問文で締めくくられているが、文章2は肯定文で締めくくられている。"}
# similarity_assessment_model(query14, 井関さん今日は面談ありがとうございました✨不安だったことを聞けて、勉強をすることが楽しみになりました💕今日は1-1動画視聴をして課題を提出してみました！iPhoneでも課題はできますが、早くパソコンで課題を提出できるようにしたいので、明日パソコンを見に行って1-2からはパソコンから課題を提出したいと思います👀): {"similarity": "0", "comment": "文章1と文章2は、内容、単語、文章表現全てが異なります。そのため類似度は0です。"}
# similarity_assessment_model(query14, 【井関さん】「今日取り組んだこと」3-1から3-2まで受講しました。添削していただいた実践課題2つ(1-3と2-2)も修正して再提出しました。): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、文内で使われている単語（課題、提出など）が似通っている。"}
# query15: 嶋内様本日はありがとうございました！楽しみながら受講していきたいと思います。早速、目標シートを書きましたので、お送りします。また、イベントの件もありがとうございました！残り1枠だったfigmaの会、無事に予約できました✨今後とも、よろしくお願いいたします！,延長はしません。このまま自動退会という事でよろしくお願いいたします。,迅速なお返事及びご対応ありがとうございます。無事メール届きました！,ありがとうございます！よろしくお願いいたします😭,ありがとうございます！
# similarity_assessment_model(query15, 嶋内様本日はありがとうございました！楽しみながら受講していきたいと思います。早速、目標シートを書きましたので、お送りします。また、イベントの件もありがとうございました！残り1枠だったfigmaの会、無事に予約できました✨今後とも、よろしくお願いいたします！): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query15, 延長はしません。このまま自動退会という事でよろしくお願いいたします。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なります。"}
#
# similarity_assessment_model(query15, 迅速なお返事及びご対応ありがとうございます。無事メール届きました！): {"similarity": "1", "comment": "文章の内容は異なっていますが、文章の雰囲気が似ています。特に、感謝の気持ちを表す言葉遣いが似通っています。"}
# similarity_assessment_model(query15, ありがとうございます！よろしくお願いいたします😭): {"similarity": "1", "comment": "文章1はイベント参加の報告と今後の継続的なサポートへの感謝が込められていますが、文章2は感謝のみの短い言葉です。内容が大きく異なりますが、文章表現はどちらも丁寧な印象で、感謝の気持ちが表れているため、1としました。"}
# similarity_assessment_model(query15, ありがとうございます！): {"similarity": "0", "comment": "文章1はイベント参加の報告と今後の継続的なサポート依頼が含まれている一方、文章2は単に感謝の言葉のみであり、内容が大きく異なります。文章表現も大きく異なるため、類似度は0と判断しました。"}
# query16: お世話になっております。パソコンについて確認したいのですが、MacBookAirでも問題ないでしょうか。,お世話になっております！先ほど入金させていただきました！ご確認をよろしくお願いいたします🙇‍♀,お世話になっております。受講開始を楽しみにしています！よろしくお願いします🙇‍♀️,ご迷惑をおかけして申し訳ありませんでした😖💦再度予約させていただきました！当日もよろしくお願いいたします🙇🏻‍♀️,こんにちは、お世話になっております。【MOOGA Plus】視聴の招待メールが届いておらず、お手数ですがメール再送頂けますでしょうか？
# similarity_assessment_model(query16, お世話になっております。パソコンについて確認したいのですが、MacBookAirでも問題ないでしょうか。): {"similarity": 0, "comment": "文章1は受講に関する問い合わせ、文章2はパソコンに関する問い合わせであり、内容が全く異なります。また、文章表現や単語も大きく異なります。"}
# similarity_assessment_model(query16, お世話になっております！先ほど入金させていただきました！ご確認をよろしくお願いいたします🙇‍♀): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query16, お世話になっております。受講開始を楽しみにしています！よろしくお願いします🙇‍♀️): {"similarity": 0, "comment": "文章の内容は全く異なり、単語もほとんど共通していません。文章表現も異なります。"}
# similarity_assessment_model(query16, ご迷惑をおかけして申し訳ありませんでした😖💦再度予約させていただきました！当日もよろしくお願いいたします🙇🏻‍♀️): {"similarity": 1, "comment": "文章1は受講に関する確認メールの再送を依頼する内容、文章2は予約の再確認を伝える内容で、内容は異なります。しかし、文章表現に丁寧な言い回しや絵文字を使用している点で類似性が見られます。"}
# similarity_assessment_model(query16, こんにちは、お世話になっております。【MOOGA Plus】視聴の招待メールが届いておらず、お手数ですがメール再送頂けますでしょうか？): {"similarity":3,"comment":"文章1は受講に関するメールの削除について謝罪し再送を依頼しているのに対し、文章2は視聴招待メールが届いていない旨を伝え再送を依頼しています。文章の大まかな内容は類似していますが、細かい内容が異なっており、文章表現も異なっています。"}
# query17: 終了証ですが、何か履歴書などに書ける資格になるのでしょうか？,未提出となっていたAdobeFarawayの課題、4-3と4-4を提出しました。結局、仕事でも使いたかったので有料版へアップデートしました。,今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。,今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。,今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。
# similarity_assessment_model(query17, 終了証ですが、何か履歴書などに書ける資格になるのでしょうか？): {"similarity":0,"comment":"文章1はクラウドワークスの登録に関する悩みについて、文章2は終了証の履歴書への記載についてと、内容が全く異なります。また文章表現や単語も大きく異なっています。"}
# similarity_assessment_model(query17, 未提出となっていたAdobeFarawayの課題、4-3と4-4を提出しました。結局、仕事でも使いたかったので有料版へアップデートしました。): {"similarity": 0, "comment": "文章1はクラウドワークスの会員登録について、文章2はAdobeFarawayの課題提出についてであり、内容が全く異なります。また、文章表現や単語も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query17, 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
# similarity_assessment_model(query17, 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query17, 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
#
# query18: しまうちさん、こんばんわ！こちらこそ予定が合わずで申し訳ございませんでした！次回、29日の11時〜よろしくお願い致します☺️,誠に申し訳ありません。,申し訳ございません！！予約時間を17:30からと勘違いしておりました😭本当に申し訳ございません😭今メールにも気づきました…本当にご迷惑をおかけ致しました😭,ありがとうございます。こちらで簡単な質問をさせていただいても大丈夫でしょうか？,当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！
# similarity_assessment_model(query18, しまうちさん、こんばんわ！こちらこそ予定が合わずで申し訳ございませんでした！次回、29日の11時〜よろしくお願い致します☺️): {"similarity": "1", "comment": "文章1は謝罪の言葉のみで、文章2は謝罪と次回の予定についての言葉が含まれています。文章表現は似ている部分がありますが、内容は異なります。"}
# similarity_assessment_model(query18, 誠に申し訳ありません。): {"similarity": 4, "comment": "文章の大まかな内容は謝罪であるため類似している。細かい内容では、文章1は「何度も」と繰り返しているのに対し、文章2は「誠に」と丁寧な表現を用いている。文章表現はどちらも謝罪を表す言葉遣いであるため類似している。"}
# similarity_assessment_model(query18, 申し訳ございません！！予約時間を17:30からと勘違いしておりました😭本当に申し訳ございません😭今メールにも気づきました…本当にご迷惑をおかけ致しました😭): {"similarity": "1", "comment": "文章1は簡潔な謝罪文であり、文章2は予約時間の勘違いによる謝罪文である。文章の内容は異なるが、文章表現や謝罪の言葉遣い、絵文字の使用など、文章の雰囲気が似ているため1とした。"}
# similarity_assessment_model(query18, ありがとうございます。こちらで簡単な質問をさせていただいても大丈夫でしょうか？): {"similarity": "0", "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query18, 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！): {"similarity": "3", "comment": "文章1は謝罪のみだが、文章2は謝罪に加え、予約変更の連絡をしている。そのため、大まかな内容は類似している。しかし、細かい内容は異なり、文章表現も「申し訳ございません」と「申し訳ないです」で異なるため、3とした。"}
# query19: 井関様1-3の実践課題、オススメバナー初級をトレースして提出しました♪,今日は、スプレッドシートの目標設定の記入と実践課題1-3の動画視聴まで終わらせました！,井関さん今日は面談ありがとうございました✨不安だったことを聞けて、勉強をすることが楽しみになりました💕今日は1-1動画視聴をして課題を提出してみました！iPhoneでも課題はできますが、早くパソコンで課題を提出できるようにしたいので、明日パソコンを見に行って1-2からはパソコンから課題を提出したいと思います👀,井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！,以前提出してエラーになっていた課題3-3を再提出いたしました。よろしくお願いします。
# similarity_assessment_model(query19, 井関様1-3の実践課題、オススメバナー初級をトレースして提出しました♪): {"similarity": "1", "comment": "文章1は目標の記載に関するお願いと、土日の状況説明が含まれている。一方、文章2は課題提出の報告のみである。そのため、内容が大きく異なる。しかし、文章表現や単語は似通っているため、1とした。"}
# similarity_assessment_model(query19, 今日は、スプレッドシートの目標設定の記入と実践課題1-3の動画視聴まで終わらせました！): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっている。文章1はスプレッドシートへの目標記載の確認依頼と、課題の遅延に関する説明が含まれている一方、文章2は目標設定の完了と課題の進捗状況についての報告のみとなっている。文章表現は一部類似しているが、文章1は口語調で、文章2はより簡潔な表現となっている。"}
# similarity_assessment_model(query19, 井関さん今日は面談ありがとうございました✨不安だったことを聞けて、勉強をすることが楽しみになりました💕今日は1-1動画視聴をして課題を提出してみました！iPhoneでも課題はできますが、早くパソコンで課題を提出できるようにしたいので、明日パソコンを見に行って1-2からはパソコンから課題を提出したいと思います👀): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、文内で使われている単語(井関さん、課題、動画視聴など)が似通っているため2としました。"}
# similarity_assessment_model(query19, 井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！): {"similarity": "3", "comment": "文章1は、土日の状況説明と、課題提出に関する説明の両方を含んでいるのに対し、文章2は、1-2までの完了報告と、明日の予定のみを記述している。そのため、細かい内容が異なっている。文章表現は、どちらも簡潔で、ビジネス文書のような口調であるため、類似していると言える。"}
# similarity_assessment_model(query19, 以前提出してエラーになっていた課題3-3を再提出いたしました。よろしくお願いします。): {"similarity": "2", "comment": "文章1は目標の記載について、文章2は課題の再提出についての内容です。大まかな内容は異なりますが、スプレッドシート、課題、再提出といった単語が共通しています。"}
# query20: 10/3　Week7-1、7-2の実践課題を提出しました,10/5 Week7-3実践課題を提出しました,Week7  7-3の課題を提出しました,Week3-1の課題を提出しました。,week2-2の課題を提出しました
# similarity_assessment_model(query20, 10/3　Week7-1、7-2の実践課題を提出しました): {"similarity": 5, "comment": "文章の内容、細かい内容、表現全てが完全に一致しています。"}
#
# similarity_assessment_model(query20, 10/5 Week7-3実践課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出日、課題番号）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query20, Week7  7-3の課題を提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現が異なっている。文章1では日付と課題番号が明確に記載されているが、文章2では日付と課題番号が省略されている。また、文章1では「提出しました」という表現が使われているが、文章2では「提出しました」という表現が使われていない。"}
# similarity_assessment_model(query20, Week3-1の課題を提出しました。): {"similarity": "2", "comment": "文章1と文章2は、どちらも課題提出に関する内容ですが、具体的な課題番号が異なり、文章表現も異なります。そのため、単語が似ているという点から2と評価しました。"}
# similarity_assessment_model(query20, week2-2の課題を提出しました): {"similarity": 2, "comment": "文章1と文章2では、課題提出という共通点はあるものの、具体的な内容や日付が異なるため、大まかな内容は異なっていると判断しました。しかし、課題提出という単語や表現が共通しているため、2と評価しました。"}

# %% [markdown]
# Without category

# %%
import jsonlines
import numpy as np
import random
from sentence_transformers import SentenceTransformer
import scann
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Step 1: Load your dataset (qa_pairs_for_rag_1108.jsonl)
with jsonlines.open('qa_pairs_for_rag_1108.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]

# Initialize model for SBERT
model_sbert = SentenceTransformer('all-MiniLM-L6-v2')

# Step 3: Encode the documents using SBERT
question_embeddings = model_sbert.encode(documents, convert_to_numpy=True)

# Step 4: Create ScaNN index for SBERT embeddings
scann_index = scann.scann_ops.builder(question_embeddings, 10, "dot_product").tree(num_leaves=min(1000, len(questions)), num_leaves_to_search=50).score_ah(2, anisotropic_quantization_threshold=0.2).reorder(50).build()

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 5: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Encode the query using SBERT
    query_embedding = model_sbert.encode([f"Question: {query}"], convert_to_numpy=True)

    # Search the ScaNN index
    neighbors, distances = scann_index.search_batched(query_embedding)

    # Return the most similar questions
    closest_questions = [questions[i] for i in neighbors[0][:top_k]]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Evaluate the system with 20 selected questions using SBERT and ScaNN
print("Evaluating using SBERT and ScaNN:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# Evaluating using SBERT and ScaNN:
# query1: いつもお世話になっております。Week8-2スクリーンショットを提出致します。添削のほどよろしくお願いいたします😊,お世話になります。week3の③,④を提出しました,いつもお世話になっております。Week7実践課題提出致します。添削のほどよろしくお願いいたします😊,お世話になります。week5の③を提出しました。,藤川さんお世話になります。3-5 課題提出しました！よろしくお願いします！
# similarity_assessment_model(query1, いつもお世話になっております。Week8-2スクリーンショットを提出致します。添削のほどよろしくお願いいたします😊): {"similarity": 0, "comment": "文章1はルビーコーヒーのヒアリングに関する質問、文章2はスクショ提出に関する内容であり、全く異なる内容です。また、文章表現も大きく異なっています。"}
# similarity_assessment_model(query1, お世話になります。week3の③,④を提出しました): {"similarity": 0, "comment": "文章1はルビーコーヒーのヒアリングに関する問い合わせ、文章2は課題提出の報告であり、内容が全く異なる。文章表現も異なるため、類似度は0です。"}
#
# similarity_assessment_model(query1, いつもお世話になっております。Week7実践課題提出致します。添削のほどよろしくお願いいたします😊): {"similarity": 0, "comment": "文章1はルビーコーヒーのワークシートに関する質問、文章2はWeek7の実践課題提出に関する連絡であり、内容が全く異なります。また、文章表現や単語も大きく異なっています。"}
# similarity_assessment_model(query1, お世話になります。week5の③を提出しました。): {"similarity": 0, "comment": "文章1はルビーコーヒーのヒアリングに関する質問であり、文章2はweek5の課題提出に関する報告です。内容が全く異なり、単語や文章表現も共通点が見られないため、類似度は0と判断しました。"}
# similarity_assessment_model(query1, 藤川さんお世話になります。3-5 課題提出しました！よろしくお願いします！): {"similarity": 0, "comment": "文章の内容が大きく異なり、単語も異なります。"}
# query2: 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします,谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします,谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします,谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします,谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします
# similarity_assessment_model(query2, 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query2, 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします): {"similarity": 5, "comment": "文章1と文章2は完全に一致しています。"}
# similarity_assessment_model(query2, 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
#
# similarity_assessment_model(query2, 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# query3: こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m,こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m,こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m,こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m,こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m
# similarity_assessment_model(query3, こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query3, こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query3, こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
#
# similarity_assessment_model(query3, こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query3, こんばんは遅くにすみません💦4-1任意課題が、どこにあるかわからなくなってしまって🙇🏻‍♀️探しても探し方が悪いので見つからず、、💦お手隙の時に教えて頂けますと幸いですm(_ _)m): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# query4: 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・バナートレース初級編の桜まつりの画像をトレース完了いたしました!引き続き明日も中級編をトレースします🙂お疲れ様でした。,谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。,【取り組んだこと】竹内さん昨日・クラウドワークスzoom面談今日・Photoshop・week4-2,谷津さん10/313-3の動画視聴をしました。figma提出課題の途中です。,今日取り組んだことweek7-2完了しました。明日は7-3を進めようと思います！
# similarity_assessment_model(query4, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・バナートレース初級編の桜まつりの画像をトレース完了いたしました!引き続き明日も中級編をトレースします🙂お疲れ様でした。): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query4, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なっています。文章表現は似ていますが、文章1では絵を描くという文脈があり、文章2では実践課題提出という文脈があるため、細かい内容は異なっています。"}
# similarity_assessment_model(query4, 【取り組んだこと】竹内さん昨日・クラウドワークスzoom面談今日・Photoshop・week4-2): {"similarity": 2, "comment": "文章1は、具体的な作業内容と進捗状況が記載されているのに対し、文章2は簡潔なキーワードのみが記載されています。文章の内容は異なっていますが、文章2には「取り組んだこと」という文言が含まれているため、類似度を2としました。"}
# similarity_assessment_model(query4, 谷津さん10/313-3の動画視聴をしました。figma提出課題の途中です。): {"similarity": 2, "comment": "文章1はバナー作成について、文章2はfigma課題についての内容なので、文章の大まかな内容は異なります。しかし、文章1と文章2では「谷津さん」という名前や「〇〇の画像をトレース」と「動画視聴」という単語が使われていることから、文内で使われている単語が似通っていると言えるため、2と評価しました。"}
# similarity_assessment_model(query4, 今日取り組んだことweek7-2完了しました。明日は7-3を進めようと思います！): {"similarity": "3", "comment": "文章の大まかな内容は類似している(日々の取り組み報告)。しかし、細かい内容は異なり(文章1はバナートレースの報告、文章2はweek7-2の報告)、文章表現も異なっている(文章1は絵文字を使用、文章2は絵文字を使用していない)。"}
# query5: 【今日取り組んだこと】・1-1 動画視聴、課題提出・1-2 動画視聴、課題提出11/3は予定があり、出来ません。11/4も出来ない可能性ありです。11/5は頑張ります。,藤川様へ【10/9,12に取り組んだこと】・3-3 動画視聴、課題実施【本日取り組んだこと】・3-3 課題提出・2-3課題手直し、再提出,11/2～4の取り組み　1-1～1-3実践課題提出、2-1動画視聴しました,井関さん「今日取り組んだこと」1-3 実践課題実施提出1-4 動画視聴1-4 課題実施1-3 任意課題実施,10月15日取り組んだ内容・1-4の①②③のテキスト確認と実践課題を提出しました。・明日は時間が取れそうなので、課題の続きを確認、提出する予定です。ご確認をよろしくお願いいたします！
# similarity_assessment_model(query5, 【今日取り組んだこと】・1-1 動画視聴、課題提出・1-2 動画視聴、課題提出11/3は予定があり、出来ません。11/4も出来ない可能性ありです。11/5は頑張ります。): {"similarity":5,"comment":"文章1と文章2は完全に一致するため、類似度は5です。"}
# similarity_assessment_model(query5, 藤川様へ【10/9,12に取り組んだこと】・3-3 動画視聴、課題実施【本日取り組んだこと】・3-3 課題提出・2-3課題手直し、再提出): {"similarity": 2, "comment": "文章1は、日々のタスクの進捗状況と今後の予定について記述している。一方、文章2は、過去の取り組みと本日の取り組みについて記述している。文章の内容は異なるが、文中に『動画視聴』『課題』などの単語が共通して見られるため、類似度を2とした。"}
# similarity_assessment_model(query5, 11/2～4の取り組み　1-1～1-3実践課題提出、2-1動画視聴しました): {"similarity": "3", "comment": "文章1は日付ごとの具体的な予定と進捗状況が記述されているのに対し、文章2は期間と概要のみが記述されています。そのため、細かい内容が異なります。しかし、どちらも動画視聴と課題提出という共通の要素が含まれており、文章の大まかな内容は類似しています。文章表現は、文章1は箇条書きで日付ごとに記述しているのに対し、文章2は期間と概要をまとめて記述しているため、異なります。"}
# similarity_assessment_model(query5, 井関さん「今日取り組んだこと」1-3 実践課題実施提出1-4 動画視聴1-4 課題実施1-3 任意課題実施): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、文内で使われている単語が似通っているため、2としました。"}
# similarity_assessment_model(query5, 10月15日取り組んだ内容・1-4の①②③のテキスト確認と実践課題を提出しました。・明日は時間が取れそうなので、課題の続きを確認、提出する予定です。ご確認をよろしくお願いいたします！): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、日付、課題提出といった単語が似通っているため2としました。"}
# query6: 中川さん今日は3-3の課題を実施しました！初めて使うFigmaの操作にまだ慣れず時間がかかりそうなので、制作途中ですが中断して、続きはまた後日取り組みたいと思います。,藤川さん昨日はオリジナルバナーの制作を進めました。今日は課題進められなかったので、明日頑張ります。,中川さん今日は1-3の課題を再提出しました！(昨日は、1-4、2-1、2-2の動画視聴と2-2の課題を提出しました！),谷津さんへ昨日は進めれなかったので、今日3-3の再提出、3-4の課題の提出まで終わりました💡明日明後日は結構時間があるので、進められると思います✨,中川さん今日は、3-5の実践課題を途中まで実施しました！
# similarity_assessment_model(query6, 中川さん今日は3-3の課題を実施しました！初めて使うFigmaの操作にまだ慣れず時間がかかりそうなので、制作途中ですが中断して、続きはまた後日取り組みたいと思います。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query6, 藤川さん昨日はオリジナルバナーの制作を進めました。今日は課題進められなかったので、明日頑張ります。): {"similarity":3,"comment":"文章の大まかな内容は類似している（課題の進捗について）。細かい内容は異なり（文章1はFigmaを使った課題、文章2はオリジナルバナー作成）、文章表現も異なる。"}
# similarity_assessment_model(query6, 中川さん今日は1-3の課題を再提出しました！(昨日は、1-4、2-1、2-2の動画視聴と2-2の課題を提出しました！)): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現も異なります。文章1はFigmaを使った課題について、文章2は提出した課題や視聴した動画について記述しています。"}
# similarity_assessment_model(query6, 谷津さんへ昨日は進めれなかったので、今日3-3の再提出、3-4の課題の提出まで終わりました💡明日明後日は結構時間があるので、進められると思います✨): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1はFigmaの使い方に苦労している様子がわかるが、文章2は課題の提出状況を報告している。また、文章1は「制作途中ですが中断して」と具体的な状況が書かれているのに対し、文章2は「進められると思います」と抽象的な表現になっている。"}
# similarity_assessment_model(query6, 中川さん今日は、3-5の実践課題を途中まで実施しました！): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、課題番号や詳細な状況が異なっている。文章表現も、文章1は具体的な状況が記載されているのに対し、文章2は簡潔な報告となっているため、類似度は3とした。"}
# query7: １週目の課題４つを提出しました。,6週目と7週目の課題完了しています,実践課題1ー4①提出しました,2-４実践課題提出しました。,5-2 実践課題提出しました
# similarity_assessment_model(query7, １週目の課題４つを提出しました。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query7, 6週目と7週目の課題完了しています): {"similarity": "0", "comment": "文章の内容が異なり、文章表現も異なります。課題の提出状況が異なるため、類似度は低いと考えられます。"}
# similarity_assessment_model(query7, 実践課題1ー4①提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は課題の内容が具体的に書かれているが、文章2は課題の番号のみが記載されている。また、文章1は「提出しました」と丁寧な表現だが、文章2は「提出しました」と簡潔な表現である。"}
# similarity_assessment_model(query7, 2-４実践課題提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、課題の番号や具体的な内容は異なっている。文章表現も若干異なるため3とした。"}
# similarity_assessment_model(query7, 5-2 実践課題提出しました): {"similarity": 2, "comment": "文章1は課題の提出についての内容であり、文章2は実践課題の提出についての内容なので、大まかな内容は異なっています。しかし、文章内で使われている単語が似通っているため、2と評価しました。"}
# query8: ご連絡ありがとうございます。会社に勤めているので、自宅に帰ったら確認させていただきます。よろしくお願いいたします。,ありがとうございます。改めて選択させていただきました。よろしくお願いします！,①から⑤まで教えてください。よろしくお願いします,ご対応ありがとうございます！こちらこそよろしくお願いいたします！,打合せに入るため、また改めさせて下さい🙇‍♀️
# similarity_assessment_model(query8, ご連絡ありがとうございます。会社に勤めているので、自宅に帰ったら確認させていただきます。よろしくお願いいたします。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query8, ありがとうございます。改めて選択させていただきました。よろしくお願いします！): {"similarity": "0", "comment": "文章1は仕事の依頼に対する返信、文章2は商品の選択に対する返信であり、内容が大きく異なるため。また、文章表現も異なる。"}
# similarity_assessment_model(query8, ①から⑤まで教えてください。よろしくお願いします): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query8, ご対応ありがとうございます！こちらこそよろしくお願いいたします！): {"similarity": 1, "comment": "文章1は仕事に関する返信で、文章2は一般的な返信です。内容が異なる一方、文章表現や単語が似ている部分があるので1としました。"}
# similarity_assessment_model(query8, 打合せに入るため、また改めさせて下さい🙇‍♀️): {"similarity": "2", "comment": "文章の大まかな内容は異なっていますが、文内で使われている単語（「ご連絡」「確認」「よろしくお願いいたします」「改め」など）が似通っています。"}
#
# query9: 「2-1実践課題　完了しました。リンクの共有が度々エラーになってしまい、提出ができないです。（有料版にしたんですけど・・）,バナー制作編2-2の課題を間違えて2-3に提出してしまいました,3-2 ,3-3の課題が完了しましたので、ご確認よろしくお願いいたします。,度々すみません💦8-2課題提出できました❢まとめての提出で恐縮ですが、よろしくお願いします❢,4-4提出しました。画像の貼り付けはできたと思うのですが、プロンプトのコピーの仕方がわかりませんでした。画像の生成は、入れたプロンプトが必ずしもぜんぶ反映される訳ではないのが面白かったです。
# similarity_assessment_model(query9, 「2-1実践課題　完了しました。リンクの共有が度々エラーになってしまい、提出ができないです。（有料版にしたんですけど・・）): {"similarity": 2, "comment": "文章1はバナー制作について、文章2はリンク共有についての内容で、内容は異なります。しかし、文章1で『分からず教えて貰いたいです』と文章2で『提出ができないです』と、どちらも困っている状況を表す文章であるため、単語が似通っているという点で2と評価しました。"}
# similarity_assessment_model(query9, バナー制作編2-2の課題を間違えて2-3に提出してしまいました): {"similarity": 0, "comment": "文章1はバナー制作に関する質問で、文章2は課題提出に関する内容です。内容、単語、表現、雰囲気全てが異なります。"}
# similarity_assessment_model(query9, 3-2 ,3-3の課題が完了しましたので、ご確認よろしくお願いいたします。): {"similarity": 0, "comment": "文章1はバナー制作についての質問、文章2は課題提出の報告なので、内容が全く異なります。文章表現も異なります。"}
# similarity_assessment_model(query9, 度々すみません💦8-2課題提出できました❢まとめての提出で恐縮ですが、よろしくお願いします❢): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query9, 4-4提出しました。画像の貼り付けはできたと思うのですが、プロンプトのコピーの仕方がわかりませんでした。画像の生成は、入れたプロンプトが必ずしもぜんぶ反映される訳ではないのが面白かったです。): {"similarity": 2, "comment": "文章1はバナー作成に関する質問、文章2は画像生成に関する質問で、内容が異なります。しかし、どちらも「やり方が分からず教えてほしい」という共通点があり、文中で使われている単語も似通っているため、2と評価しました。"}
# query10: ご質問ありがとうございます◎添付いただいた画像は、もしかするとブラウザ版かもしれないと思いました😌💦画面の右上にある「デスクトップアプリを入手」からダウンロードしてみてください🙌ダウンロードができたら、講義動画を参考に取り組んでみてくださいね😊について、「デスクトップアプリを入手」を押しても動きがありません💦Macなのですが、どうしたら良いでしょうか💦,7-3ドライブ保存しましたが、出来ているでしょうか?,1-3課題の、吹き出しが見つからないのですがどうしたら良いでしょうか？,8-1.8-2提出しました。,質問です！Webページ制作の途中です。素材の背景が透過されず、黒くなってしまいます、、。どうすればいいのでしょうか、使ってるパソコンはMacです。
# similarity_assessment_model(query10, ご質問ありがとうございます◎添付いただいた画像は、もしかするとブラウザ版かもしれないと思いました😌💦画面の右上にある「デスクトップアプリを入手」からダウンロードしてみてください🙌ダウンロードができたら、講義動画を参考に取り組んでみてくださいね😊について、「デスクトップアプリを入手」を押しても動きがありません💦Macなのですが、どうしたら良いでしょうか💦): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query10, 7-3ドライブ保存しましたが、出来ているでしょうか?): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query10, 1-3課題の、吹き出しが見つからないのですがどうしたら良いでしょうか？): {"similarity": 2, "comment": "文章1は、デスクトップアプリに関する質問と回答が書かれており、文章2は、1-3課題の吹き出しが見つからないという質問です。そのため、内容的には異なります。しかし、文章1と文章2では、「～が見つからない」という表現や「どうしたら良いでしょうか」という表現が使われているため、単語が似通っています。"}
# similarity_assessment_model(query10, 8-1.8-2提出しました。): {"similarity": 0, "comment": "文章の内容が大きく異なり、単語も共通点が見当たらないため、類似度は0です。"}
# similarity_assessment_model(query10, 質問です！Webページ制作の途中です。素材の背景が透過されず、黒くなってしまいます、、。どうすればいいのでしょうか、使ってるパソコンはMacです。): {"similarity": 2, "comment": "文章1はアプリのダウンロードに関する質問、文章2はWebページ制作に関する質問で、内容は異なります。しかし、文章1の「デスクトップアプリを入手」と文章2の「Webページ制作」はどちらもアプリやソフトウェアに関する内容であるため、単語が似通っています。"}
# query11: 初回面談の時に口頭で予約して、スケジュール表では予約を入れておりませんでした。勘違いでしたらすみません🙇‍♀️,どうぞよろしくお願いいたします。,瀧口です。11時からと思っておりまして申し訳ございません。再調整飲み会登録をさせていただきます。,☀️日次報告☀️今日は課題5-3を取り組みました。どうぞよろしくお願いします。,☀️日次報告☀️今日は課題5-3を取り組みました。どうぞよろしくお願いします。
# similarity_assessment_model(query11, 初回面談の時に口頭で予約して、スケジュール表では予約を入れておりませんでした。勘違いでしたらすみません🙇‍♀️): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query11, どうぞよろしくお願いいたします。): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query11, 瀧口です。11時からと思っておりまして申し訳ございません。再調整飲み会登録をさせていただきます。): {"similarity":0,"comment":"文章の内容、文章表現、単語全てが異なっているため"}
# similarity_assessment_model(query11, ☀️日次報告☀️今日は課題5-3を取り組みました。どうぞよろしくお願いします。): {"similarity":0,"comment":"文章の内容、表現、単語全てが異なるため0と評価しました。"}
# similarity_assessment_model(query11, ☀️日次報告☀️今日は課題5-3を取り組みました。どうぞよろしくお願いします。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# query12: 【返金・解約】,【返金・解約】,【返金・解約】,【料金】,【料金】
# similarity_assessment_model(query12, 【返金・解約】): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なり、文章表現も異なっている。文章1は「返金」という単語のみだが、文章2は「返金」と「解約」という単語を使用しており、文章表現も異なる。"}
# similarity_assessment_model(query12, 【返金・解約】): {"similarity": 3, "comment": "文章の大まかな内容は類似している（返金に関する内容）が、細かい内容は異なり、文章表現も異なっている（文章1は「返金制度」、文章2は「返金・解約」）。"}
# similarity_assessment_model(query12, 【返金・解約】): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっているため3としました。文章1は返金のみを指しますが、文章2は返金と解約の両方を含むため、細かい内容が異なります。また、文章1は簡潔な表現ですが、文章2は「・」を用いて2つの項目を並列に記述しているため、文章表現も異なります。"}
# similarity_assessment_model(query12, 【料金】): {"similarity":0,"comment":"文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query12, 【料金】): {"similarity":0,"comment":"文章の内容が大きく異なり、文章表現や単語も異なるため、類似度は0です。"}
# query13: figma関連のイベントは午前中から14時までの間に行われることはありますか？参加したいのですがどの時間帯も16時以降で参加することができません…。,連絡ありがとうございます！確認して返事しました🙇‍♂️まだ動画作り始める前段階だったので、初回と次の動画を途中までみてる所でした勉強会までに再度確認して質問まとめたいと思います🙇‍♂️,ご対応頂きありがとうございます！メール確認できました！かしこまりました、次回以降は何かあればSlackにてメッセージいたします！よろしくお願いします🙇,ご回答ありがとうございます。サポート期間有効に使わせて頂きます。引き続きよろしくお願いします,ありがとうございます。では登園アドレスを【mamire22319@gmail.com】に変更して頂いて招待メールを送って頂きた頂きたいです。宜しくお願いします。
# similarity_assessment_model(query13, figma関連のイベントは午前中から14時までの間に行われることはありますか？参加したいのですがどの時間帯も16時以降で参加することができません…。): {"similarity": 3, "comment": "文章1はイベント開催に関する問い合わせへの返信であり、文章2はイベント開催時間に関する質問です。文章の大まかな内容は類似していますが、細かい内容は異なり、文章表現も異なります。"}
# similarity_assessment_model(query13, 連絡ありがとうございます！確認して返事しました🙇‍♂️まだ動画作り始める前段階だったので、初回と次の動画を途中までみてる所でした勉強会までに再度確認して質問まとめたいと思います🙇‍♂️): {"similarity": 1, "comment": "文章の内容は異なるが、文章表現や単語が一部似ているため、1としました。特に、謝罪を表す絵文字や感謝の言葉などが類似しています。"}
# similarity_assessment_model(query13, ご対応頂きありがとうございます！メール確認できました！かしこまりました、次回以降は何かあればSlackにてメッセージいたします！よろしくお願いします🙇): {"similarity": 0, "comment": "文章1はFigmaに関する勉強会についての返信で、文章2は連絡手段に関する返信です。内容や単語も大きく異なり、文章表現も異なるため類似度は0です。"}
# similarity_assessment_model(query13, ご回答ありがとうございます。サポート期間有効に使わせて頂きます。引き続きよろしくお願いします): {"similarity": 0, "comment": "文章1はFigmaに関する内容で、文章2はサポートに関する内容のため、内容が全く異なる。文章表現も異なっている。"}
#
# similarity_assessment_model(query13, ありがとうございます。では登園アドレスを【mamire22319@gmail.com】に変更して頂いて招待メールを送って頂きた頂きたいです。宜しくお願いします。): {"similarity": 0, "comment": "文章1はFigmaの勉強会に関する内容で、文章2はメールアドレスの変更に関する内容です。内容が全く異なるため類似度は0です。"}
# query14: 分かりました！対応ありがとうございます！,5分前からやってはいるんですけど💦,予約しました😊,ありがとうございます！,ありがとうございます
# similarity_assessment_model(query14, 分かりました！対応ありがとうございます！): {"similarity": 4, "comment": "文章の大まかな内容は同じだが、文章2は文章1よりも感情表現が強い。"}
# similarity_assessment_model(query14, 5分前からやってはいるんですけど💦): {"similarity":0,"comment":"文章1は感謝の言葉を述べていますが、文章2は状況説明をしています。内容、表現ともに全く異なるため0としました。"}
# similarity_assessment_model(query14, 予約しました😊): {"similarity":0,"comment":"文章の内容、表現、単語が全て異なるため"}
# similarity_assessment_model(query14, ありがとうございます！): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は丁寧な表現だが、文章2はよりカジュアルな表現である。"}
# similarity_assessment_model(query14, ありがとうございます): {"similarity": "3", "comment": "文章1は「分かりました」という返信を含んでいるため、文章2よりも丁寧な印象を受ける。文章の大まかな内容は類似しているが、細かい内容は異なり、文章表現も異なっているため3とした。"}
# query15: ログインしているのですが、パソコンからだとどうしてもできず、、インターネットがMicrosoftedgeというのは関係ありますでしょうか？,おはようございます。https://crowdworks.jp/public/jobs/11322985こちらの案件をコンペで参加しようと思うのですが、ロゴだと画像のサイズはいくつにしたらいいですか？,ログインは出来ました！,スクリーンショットで1度送っていたのですが、,どうぞよろしくお願いいたします。
# similarity_assessment_model(query15, ログインしているのですが、パソコンからだとどうしてもできず、、インターネットがMicrosoftedgeというのは関係ありますでしょうか？): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query15, おはようございます。https://crowdworks.jp/public/jobs/11322985こちらの案件をコンペで参加しようと思うのですが、ロゴだと画像のサイズはいくつにしたらいいですか？): {"similarity": 0, "comment": "文章1はパソコンでのログインに関する問題で、文章2はクラウドワークスの案件に関する質問です。文章の内容や単語、表現が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query15, ログインは出来ました！): {"similarity": 0, "comment": "文章1はログインに関する問題点、文章2はログインできたことを伝えているため、内容は全く異なります。また、文章表現や単語も大きく異なります。"}
#
# similarity_assessment_model(query15, スクリーンショットで1度送っていたのですが、): {"similarity": 0, "comment": "文章1はログインに関する問題、文章2はスクリーンショットに関する内容で、内容も表現も全く異なります。"}
# similarity_assessment_model(query15, どうぞよろしくお願いいたします。): {"similarity": 0, "comment": "文章1は、マイクロソフトエッジのブラウザを使用していることによるログインに関する問題について問い合わせている。一方、文章2はあいさつのみであり、内容が異なるため類似度は0です。"}
# query16: 予約しました😊,ありがとうございます！,どこから入ればよいでしょうか,ありがとうございます！これから入ります,嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！
# similarity_assessment_model(query16, 予約しました😊): {"similarity":0,"comment":"文章の内容、表現が全く異なるため"}
# similarity_assessment_model(query16, ありがとうございます！): {"similarity": 4, "comment": "文章の大まかな内容は同じですが、文章2は文章1に比べてより強い感情表現が含まれています。"}
# similarity_assessment_model(query16, どこから入ればよいでしょうか): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query16, ありがとうございます！これから入ります): {"similarity": "3", "comment": "文章の大まかな内容は類似している(感謝の意を表す)が、細かい内容が異なり(文章1は単独の感謝、文章2はこれから何かを行う旨を付加)、文章表現も異なっている(文章2は感嘆符を使用している)"}
# similarity_assessment_model(query16, 嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！): {"similarity": "3", "comment": "文章の大まかな内容は類似している（感謝の意を表している）。しかし、文章2は具体的な日時や相手への呼びかけが含まれているため、細かい内容は異なる。また、文章表現も「ありがとうございます」と「ありがとうございます！！」のように、丁寧さや表現方法が異なっている。"}
# query17: 藤川さん本日取り組んだことです。・Week2-3 動画視聴、講義後テスト・4-1 任意課題バナー作成以上となります。,藤川さん本日取り組んだことです。・Week2-3 課題提出・Week3-1 課題実践・Week4-2 動画視聴、講義後テスト以上となります。,藤川さん本日取り組んだことです。・Week2-3 課題実践・Week3-1 動画視聴、講義後テスト・Week4-1 動画視聴・Week4-1 Clip1 動画視聴、コメント提出以上となります。,藤川さん昨日送るの忘れてました🙇‍♀️昨日は用事があって時間がなかったため何も取り組んでません。本日取り組んだことです。・Week4-1 Clip8・Week4-1 講義後テスト、課題提出以上となります。,藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出
# similarity_assessment_model(query17, 藤川さん本日取り組んだことです。・Week2-3 動画視聴、講義後テスト・4-1 任意課題バナー作成以上となります。): {"similarity":5,"comment":"文章1と文章2は全く同じ内容です。"}
#
# similarity_assessment_model(query17, 藤川さん本日取り組んだことです。・Week2-3 課題提出・Week3-1 課題実践・Week4-2 動画視聴、講義後テスト以上となります。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている。Week2-3の課題が動画視聴と課題提出で異なり、Week4-1の任意課題バナー作成とWeek4-2の動画視聴、講義後テストも内容が異なる。文章表現は類似している。"}
# similarity_assessment_model(query17, 藤川さん本日取り組んだことです。・Week2-3 課題実践・Week3-1 動画視聴、講義後テスト・Week4-1 動画視聴・Week4-1 Clip1 動画視聴、コメント提出以上となります。): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なっており、文章表現も異なります。特にWeek4-1に関する記述が異なります。文章1では任意課題バナー作成とあるのに対し、文章2では動画視聴とClip1動画視聴、コメント提出となっています。"}
# similarity_assessment_model(query17, 藤川さん昨日送るの忘れてました🙇‍♀️昨日は用事があって時間がなかったため何も取り組んでません。本日取り組んだことです。・Week4-1 Clip8・Week4-1 講義後テスト、課題提出以上となります。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1ではWeek2-3とWeek4-1の動画視聴と講義後テスト、バナー作成について言及している一方、文章2ではWeek4-1のClip8と講義後テスト、課題提出について言及している。文章表現においては、文章1では「本日取り組んだこと」と記載しているのに対し、文章2では「昨日送るの忘れてました🙇‍♀️昨日は用事があって時間がなかったため何も取り組んでません。本日取り組んだことです。」と記載されている点も異なる。"}
# similarity_assessment_model(query17, 藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出): {"similarity": "3", "comment": "文章の大まかな内容は類似している（業務報告）が、細かい内容（具体的な業務内容）が異なり、文章表現も異なっているため。"}
# query18: 井関さんこちらこそよろしくお願いいたします(emoji)昨日MacBook Airを購入しました🌟欲しい色が店舗になく、家に届くのは金曜日になったので、来週末から本格的にやっていこうと思います💭今日は目標シートを記入しました！iPhoneでやったので、文字が切れているところがありますが…😅よろしくお願いします🙇,井関さん今日は面談ありがとうございました✨不安だったことを聞けて、勉強をすることが楽しみになりました💕今日は1-1動画視聴をして課題を提出してみました！iPhoneでも課題はできますが、早くパソコンで課題を提出できるようにしたいので、明日パソコンを見に行って1-2からはパソコンから課題を提出したいと思います👀,井関さん、本日はお時間いただきありがとうございました！すみません、Zoomのチャットで共有していただいたURLがわからなくなってしまいました。もし可能であれば、もう一度URLを教えていただいてもよろしいでしょうか？お手数おかけしますが、どうぞよろしくお願いいたします🙇‍♀️,井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！,藤川様昨夜は遅くまで遊び続ける娘を寝かしつけ、一緒に眠ってしまったので、何も勉強が進んでいませんでした(汗)LINEの報告も遅くなりすみません🥲本日はまた少しでもポートフォリオ作成の続きを行っていきたいです！よろしくお願いいたします。
# similarity_assessment_model(query18, 井関さんこちらこそよろしくお願いいたします(emoji)昨日MacBook Airを購入しました🌟欲しい色が店舗になく、家に届くのは金曜日になったので、来週末から本格的にやっていこうと思います💭今日は目標シートを記入しました！iPhoneでやったので、文字が切れているところがありますが…😅よろしくお願いします🙇): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章のため、類似度は5です。"}
# similarity_assessment_model(query18, 井関さん今日は面談ありがとうございました✨不安だったことを聞けて、勉強をすることが楽しみになりました💕今日は1-1動画視聴をして課題を提出してみました！iPhoneでも課題はできますが、早くパソコンで課題を提出できるようにしたいので、明日パソコンを見に行って1-2からはパソコンから課題を提出したいと思います👀): {"similarity": 3, "comment": "文章の大まかな内容は、どちらもオンライン学習を始めるにあたっての意気込みについて記述しているため類似している。しかし、文章1はMacBook Airを購入したことを述べている一方、文章2は1-1動画視聴や課題提出について述べているため、細かい内容は異なっている。また、文章表現も、文章1は絵文字を多く使用しているのに対し、文章2は絵文字の使用頻度が低いなど異なっている。そのため、類似度は3とした。"}
# similarity_assessment_model(query18, 井関さん、本日はお時間いただきありがとうございました！すみません、Zoomのチャットで共有していただいたURLがわからなくなってしまいました。もし可能であれば、もう一度URLを教えていただいてもよろしいでしょうか？お手数おかけしますが、どうぞよろしくお願いいたします🙇‍♀️): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query18, 井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！): {"similarity": 1, "comment": "文章1はMacBook Airを購入した喜びと今後の予定について書かれており、文章2は動画視聴と課題提出について書かれています。内容は大きく異なりますが、文章表現や文章の雰囲気は似ています。特に、文章1の最後にある「よろしくお願いします🙇」と文章2の「！」は、どちらも丁寧で親しみやすい印象を与えています。"}
# similarity_assessment_model(query18, 藤川様昨夜は遅くまで遊び続ける娘を寝かしつけ、一緒に眠ってしまったので、何も勉強が進んでいませんでした(汗)LINEの報告も遅くなりすみません🥲本日はまた少しでもポートフォリオ作成の続きを行っていきたいです！よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（どちらも仕事や学習の進捗について報告している）。しかし、細かい内容は異なり（文章1はMacBook Airを購入したという内容、文章2は娘を寝かしつけたという内容）、文章表現も異なる（文章1は絵文字を多く使用している、文章2は絵文字をあまり使用していない）。"}
# query19: 予約しました😊,ありがとうございます！,どこから入ればよいでしょうか,ありがとうございます！これから入ります,嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！
# similarity_assessment_model(query19, 予約しました😊): {"similarity":0,"comment":"文章1は感謝の言葉、文章2は予約完了の報告であり、内容、表現、単語全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query19, ありがとうございます！): {"similarity":5,"comment":"文章1と文章2は全く同じなので、類似度は5です。"}
# similarity_assessment_model(query19, どこから入ればよいでしょうか): {"similarity":0,"comment":"文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query19, ありがとうございます！これから入ります): {"similarity": "4", "comment": "文章の大まかな内容は同じですが、細かい内容が異なります。文章表現は同じです。"}
# similarity_assessment_model(query19, 嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！): {"similarity": "3", "comment": "文章の大まかな内容は類似している（感謝の意を伝えている）が、細かい内容は異なり（文章1は一般的な感謝、文章2は具体的な提案に対する感謝）、文章表現も異なっている（文章1は簡潔、文章2は丁寧で詳細）"}
# query20: １週目の課題４つを提出しました。,課題の提出が終わりました。連絡を失念していました💦,実践課題1ー4①提出しました,2-2の課題終了しました,1の実践課題の①と④を提出しました。よろしくお願いします！
# similarity_assessment_model(query20, １週目の課題４つを提出しました。): {"similarity":0,"comment":"文章1の内容が不明確で、文章2の内容との関連性が全くありません。そのため、類似度は0と評価しました。"}
# similarity_assessment_model(query20, 課題の提出が終わりました。連絡を失念していました💦): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query20, 実践課題1ー4①提出しました): {"similarity":0,"comment":"文章の内容が大きく異なり、文章表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query20, 2-2の課題終了しました): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なるため。"}
# similarity_assessment_model(query20, 1の実践課題の①と④を提出しました。よろしくお願いします！): {"similarity": 0, "comment": "文章1は文脈が不明で、文章2は課題提出に関する内容です。内容も文章表現も異なるため、類似度は0です。"}

# %% [markdown]
# # **T5 & FAISS (Model 2)**

# %%
# !pip install transformers
# !pip install faiss-gpu
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 22.8 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %% [markdown]
# With category

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import faiss
import jsonlines
import numpy as np
import random
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Step 1: Load your dataset (output_categories.jsonl)
with jsonlines.open('output_with_categories_1107.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer-category pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']} Category: {pair['category']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]
categories = [pair['category'] for pair in qa_pairs]

# Initialize tokenizer and model for T5
tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-base")

# Step 3: Function to generate embeddings using T5
def generate_embedding(text):
    input_ids = tokenizer.encode(text, return_tensors="pt")
    with torch.no_grad():
        output = model.encoder(input_ids)
    embeddings = output.last_hidden_state.mean(dim=1).squeeze().numpy()  # Average pooling
    return embeddings

# Step 4: Generate embeddings for each question
question_embeddings = [generate_embedding(doc) for doc in documents]

# Step 5: Initialize Faiss index
d = question_embeddings[0].shape[0]  # Dimensionality of embeddings
faiss_index = faiss.IndexFlatL2(d)
faiss_index.add(np.array(question_embeddings))

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 6: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Generate embedding for the query
    query_embedding = generate_embedding(f"Question: {query}")

    # Search Faiss index for nearest neighbors
    distances, indices = faiss_index.search(query_embedding.reshape(1, -1), top_k)

    # Return the most similar questions
    closest_questions = [questions[i] for i in indices[0]]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Evaluate the system with 20 selected questions using T5 and Faiss
print("Evaluating using T5 and Faiss:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Evaluating using T5 and Faiss:
# query1: ２-1実践課題を提出しました。宜しくお願いいたします。,4-4課題まで提出しました。,4-4提出しました。画像の貼り付けはできたと思うのですが、プロンプトのコピーの仕方がわかりませんでした。画像の生成は、入れたプロンプトが必ずしもぜんぶ反映される訳ではないのが面白かったです。,お疲れ様です。昨日はありがとうございました。実践課題6-4提出いたします。宜しくお願いします。,実践課題6-4を提出しました。ご確認よろしくお願い致します。
# similarity_assessment_model(query1, ２-1実践課題を提出しました。宜しくお願いいたします。): {"similarity": "0", "comment": "文章の内容が全く異なり、文章表現や単語も異なっているため。"}
# similarity_assessment_model(query1, 4-4課題まで提出しました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query1, 4-4提出しました。画像の貼り付けはできたと思うのですが、プロンプトのコピーの仕方がわかりませんでした。画像の生成は、入れたプロンプトが必ずしもぜんぶ反映される訳ではないのが面白かったです。): {"similarity": 0, "comment": "文章1はイベントのキャンセルに関する連絡、文章2は課題提出に関する報告で、内容が全く異なるため。"}
# similarity_assessment_model(query1, お疲れ様です。昨日はありがとうございました。実践課題6-4提出いたします。宜しくお願いします。): {"similarity":0,"comment":"文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query1, 実践課題6-4を提出しました。ご確認よろしくお願い致します。): {"similarity": 0, "comment": "文章の内容、表現、単語すべてが異なっています。"}
# query2: ナカガワ トオル 様気持ちを切り替え、今日からまた学習を始めました。Canvaを使用し、キャンペーンの広告作成の練習を行いました。初めての作成で、3時間以上かかってしまいましたが、なんとか自力で最後まで作成出来ました！少し自信がついたので、また頑張ります！,おはようございます。本日、10時からイベント参加の予約をしておりましたが、体調不良のためキャンセルさせて頂きたくご連絡させて頂きました。欠席連絡しようとしましたが、入力が間違っているとなってしまい、ご連絡出来ていません。,おはようございます。模擬案件は架空のものですよね？？メール後半部分のバナー素材の件に関して、Canva内の素材を使用していますがどのように返信したらいいでしょうか？,嶋内様本日はありがとうございました！楽しみながら受講していきたいと思います。早速、目標シートを書きましたので、お送りします。また、イベントの件もありがとうございました！残り1枠だったfigmaの会、無事に予約できました✨今後とも、よろしくお願いいたします！,ありがとうございます。確認できましたのでクラウドサインにて署名しました
# similarity_assessment_model(query2, ナカガワ トオル 様気持ちを切り替え、今日からまた学習を始めました。Canvaを使用し、キャンペーンの広告作成の練習を行いました。初めての作成で、3時間以上かかってしまいましたが、なんとか自力で最後まで作成出来ました！少し自信がついたので、また頑張ります！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, おはようございます。本日、10時からイベント参加の予約をしておりましたが、体調不良のためキャンセルさせて頂きたくご連絡させて頂きました。欠席連絡しようとしましたが、入力が間違っているとなってしまい、ご連絡出来ていません。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query2, おはようございます。模擬案件は架空のものですよね？？メール後半部分のバナー素材の件に関して、Canva内の素材を使用していますがどのように返信したらいいでしょうか？): {"similarity": "2", "comment": "文章1はCanvaを使って広告作成の練習をしたという内容で、文章2はCanva内の素材を使用しているという内容なので、文章の大まかな内容は異なります。しかし、Canvaという単語が使われているため、2と評価しました。"}
# similarity_assessment_model(query2, 嶋内様本日はありがとうございました！楽しみながら受講していきたいと思います。早速、目標シートを書きましたので、お送りします。また、イベントの件もありがとうございました！残り1枠だったfigmaの会、無事に予約できました✨今後とも、よろしくお願いいたします！): {"similarity": "0", "comment": "文章の内容、文章表現、単語が全て異なります。"}
# similarity_assessment_model(query2, ありがとうございます。確認できましたのでクラウドサインにて署名しました): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
# query3: 本日分を都合によりキャンセルしたかったのですが、土曜日に実行してできませんでした🙇‍♀️こちら当日キャンセルとなってしまいますが、可能でしょうか？申し訳ございません。,千賀さん風邪で数日休んでました😅またバナートレースなど、頑張ります！,「勉強会」はどのようなことをするのでしょうか？何人くらい一度に受講するのか、内容や難易度は？を知りたいです。,谷津さんへ今日はありがとうございました！今月の目標作成しました🙇‍♀️次回の面談までまた頑張ります！✨,ホワイトボードですね？わかりました！
# similarity_assessment_model(query3, 本日分を都合によりキャンセルしたかったのですが、土曜日に実行してできませんでした🙇‍♀️こちら当日キャンセルとなってしまいますが、可能でしょうか？申し訳ございません。): {"similarity": "0", "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query3, 千賀さん風邪で数日休んでました😅またバナートレースなど、頑張ります！): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query3, 「勉強会」はどのようなことをするのでしょうか？何人くらい一度に受講するのか、内容や難易度は？を知りたいです。): {"similarity": 0, "comment": "文章1はチャットアプリのメッセージが表示されない場合の案内文であり、文章2は勉強会に関する質問です。内容も単語も全く異なります。"}
# similarity_assessment_model(query3, 谷津さんへ今日はありがとうございました！今月の目標作成しました🙇‍♀️次回の面談までまた頑張ります！✨): {"similarity": 0, "comment": "文章の内容が全く異なり、単語も異なります。"}
# similarity_assessment_model(query3, ホワイトボードですね？わかりました！): {"similarity": 0, "comment": "文章1と文章2は、内容、単語、表現がすべて異なります。"}
# query4: 課題提出しました。よろしくお願いいたします🙇,☁️日次報告☁️今日は取り組めませんでした💦,本日も取り組みできませんでした。,子どもが体調を崩したりとなかなか思うように進まない週でした💦引き続き隙間時間を見つけてがんばりたいとおもいます,☁️日次報告☁️今日は取り組めませんでした💦
# similarity_assessment_model(query4, 課題提出しました。よろしくお願いいたします🙇): {"similarity": "0", "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query4, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なるため。"}
# similarity_assessment_model(query4, 本日も取り組みできませんでした。): {"similarity": "0", "comment": "文章の内容が異なり、単語も異なるため類似度は0です。"}
# similarity_assessment_model(query4, 子どもが体調を崩したりとなかなか思うように進まない週でした💦引き続き隙間時間を見つけてがんばりたいとおもいます): {"similarity": "0", "comment": "文章1はサポートに関する感謝と継続的な依頼、文章2は子供の体調不良による進捗の遅れと今後の意欲に関する内容であり、内容、文章表現、単語ともに類似点は見られません。"}
# similarity_assessment_model(query4, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 0, "comment": "文章1はサポートに対する感謝と継続的な依頼、文章2は日次報告で作業ができない旨を報告しているため、内容も表現も大きく異なります。"}
# query5: 続けて失礼します🙇‍♀️8-1実践課題も終了しましたので添削お願いいたします！,谷津さん遅くなってしまい申し訳ございません🙇‍♀️やり方が分からなくて戸惑ってました、、【取り組み報告】一昨日は仕事で1時間も出来なかったので昨日は2-2まで進めました！今日はその続きから始めます！,初回ガイダンスについて予約をしようと思います。が、1人の時間がほぼなく子供と一緒でも大丈夫でしょうか？,嶋内様こんばんは。遅くなりましたが今月の目標シートと進捗状況を報告させていただきます🙇‍♀️先週はバタバタしていた為、本日1-3の再提出と3-2まで進みました😊明日以降も出来る範囲で進めていきたいと思います。,早速の質問で恐れ入ります。10/1より受講開始なのですが、最初のは受講の仕方としましては、ラインにて様々情報が送られてきますでしょうか？また、いつ頃に情報が送られてくるかわかりましたら、お知らせいただけますと幸いです。よろしくお願いいたします。
# similarity_assessment_model(query5, 続けて失礼します🙇‍♀️8-1実践課題も終了しましたので添削お願いいたします！): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query5, 谷津さん遅くなってしまい申し訳ございません🙇‍♀️やり方が分からなくて戸惑ってました、、【取り組み報告】一昨日は仕事で1時間も出来なかったので昨日は2-2まで進めました！今日はその続きから始めます！): {"similarity": 2, "comment": "文章1は添削依頼、文章2は進捗報告という内容で大きく異なっています。しかし、どちらも丁寧な言葉遣いで、絵文字を使用しているという点で共通点が見られます。"}
# similarity_assessment_model(query5, 初回ガイダンスについて予約をしようと思います。が、1人の時間がほぼなく子供と一緒でも大丈夫でしょうか？): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現も異なります。"}
# similarity_assessment_model(query5, 嶋内様こんばんは。遅くなりましたが今月の目標シートと進捗状況を報告させていただきます🙇‍♀️先週はバタバタしていた為、本日1-3の再提出と3-2まで進みました😊明日以降も出来る範囲で進めていきたいと思います。): {"similarity": "3", "comment": "文章1は添削依頼、文章2は進捗報告という内容で、大まかな内容は異なります。しかし、どちらも丁寧な依頼/報告で、絵文字を使用している点など文章表現が似ています。"}
# similarity_assessment_model(query5, 早速の質問で恐れ入ります。10/1より受講開始なのですが、最初のは受講の仕方としましては、ラインにて様々情報が送られてきますでしょうか？また、いつ頃に情報が送られてくるかわかりましたら、お知らせいただけますと幸いです。よろしくお願いいたします。): {"similarity": "0", "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
# query6: こんばんは実践課題week3-3〜3-4提出いたしました。また、week4-2Adobe fire fly を使える状態にしましたご確認よろしくお願いします。,Week5-1.2の課題を提出しました。ご確認よろしくお願いします。,Week4-2とweek5-1~4が終了致しました。リンクをコピー致しましたので、ご確認の程宜しくお願い致します。,Week8-4の課題も提出しましたのでご確認下さい。,谷津さん11/43-3の提出課題をしました。
# similarity_assessment_model(query6, こんばんは実践課題week3-3〜3-4提出いたしました。また、week4-2Adobe fire fly を使える状態にしましたご確認よろしくお願いします。): {"similarity": 5, "comment": "文章1と文章2は完全に一致しています。"}
# similarity_assessment_model(query6, Week5-1.2の課題を提出しました。ご確認よろしくお願いします。): {"similarity": "3", "comment": "文章1は、week3,4の課題提出とAdobe fire flyの確認依頼、文章2はweek5の課題提出の依頼というように、大まかな内容は課題提出の依頼という点で類似しています。しかし、細かい内容(提出した課題、確認依頼の内容)が異なり、文章表現も異なるため3と評価しました。"}
# similarity_assessment_model(query6, Week4-2とweek5-1~4が終了致しました。リンクをコピー致しましたので、ご確認の程宜しくお願い致します。): {"similarity": "3", "comment": "文章1は、week3-3〜3-4の提出とweek4-2の環境構築について、文章2は、week4-2とweek5-1~4の終了について報告しています。そのため、大まかな内容は類似していますが、細かい内容が異なります。また、文章表現も異なっており、文章1は依頼形、文章2は報告形となっています。"}
# similarity_assessment_model(query6, Week8-4の課題も提出しましたのでご確認下さい。): {"similarity": "2", "comment": "文章1は課題提出とAdobe fire fly の確認依頼、文章2は課題提出のみの連絡というように、内容は異なる。しかし、どちらも課題提出に関する内容であり、文章表現も類似しているため、2とした。"}
#
# similarity_assessment_model(query6, 谷津さん11/43-3の提出課題をしました。): {"similarity": "1", "comment": "文章の内容は異なっているが、文章表現や単語も異なっているため1としました。"}
# query7: week8-1,2を提出しました。よろしくお願いいたします。,Week4-2,3の課題を提出しました。,Week3-1~4の課題が終わりました。リンクのコピーを致しましたので、ご確認の程、宜しくお願い致します。,Week4-2とweek5-1~4が終了致しました。リンクをコピー致しましたので、ご確認の程宜しくお願い致します。,week7-1〜7-3の課題を提出しました
# similarity_assessment_model(query7, week8-1,2を提出しました。よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（weekの番号）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query7, Week4-2,3の課題を提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出された課題のWeekと番号）が異なり、文章表現もわずかに異なる（「week」と「Week」の違いなど）。"}
# similarity_assessment_model(query7, Week3-1~4の課題が終わりました。リンクのコピーを致しましたので、ご確認の程、宜しくお願い致します。): {"similarity": "3", "comment": "文章の大まかな内容は類似している(課題の提出について)。しかし、細かい内容は異なり(提出した週、課題の数)、文章表現も異なっている(丁寧語の使い方が異なる)ため、3と評価しました。"}
# similarity_assessment_model(query7, Week4-2とweek5-1~4が終了致しました。リンクをコピー致しましたので、ご確認の程宜しくお願い致します。): {"similarity": "2", "comment": "文章1と文章2は、どちらも課題提出に関する内容ですが、具体的な課題番号や提出時期が異なります。また、文章表現も異なります。そのため、文章の大まかな内容は類似していますが、細かい内容や文章表現は異なります。単語レベルでは「課題」「提出」「終了」「リンク」など共通する単語がみられるため、2と評価しました。"}
# similarity_assessment_model(query7, week7-1〜7-3の課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出した課題の週や番号）が異なっており、文章表現も異なっているため3とした。"}
# query8: こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース,ホワイトボードですね？わかりました！,延長プランを申込ましたが、決済の手続きは別に連絡がくるのでしょうか？,ありがとうございます。面談との違いはどのようなところですか？,目標シートの記入をしようとしているのですがこれはパソコンからじゃないと記入できないやつですか？スマホでやろうとしても出来なさそうで、、
# similarity_assessment_model(query8, こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース): {"similarity": 3, "comment": "文章の大まかな内容は類似している（日々の成果報告）。細かい内容は異なり（具体的なタスクが異なる）、文章表現も異なっている（挨拶や報告の言葉遣い、文章の構成が異なる）。"}
#
# similarity_assessment_model(query8, ホワイトボードですね？わかりました！): {"similarity": 0, "comment": "文章1は業務報告の内容で、文章2は質問の内容であり、内容や文章表現、単語も全く異なっています。"}
# similarity_assessment_model(query8, 延長プランを申込ましたが、決済の手続きは別に連絡がくるのでしょうか？): {"similarity":0,"comment":"文章1は業務報告の内容で、文章2は問い合わせの内容です。文章の内容も表現も全く異なるため類似度は0です。"}
# similarity_assessment_model(query8, ありがとうございます。面談との違いはどのようなところですか？): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なるため、類似度は0です。"}
#
# similarity_assessment_model(query8, 目標シートの記入をしようとしているのですがこれはパソコンからじゃないと記入できないやつですか？スマホでやろうとしても出来なさそうで、、): {"similarity": "0", "comment": "文章1は業務報告、文章2は質問であり、内容や文章表現が全く異なるため。"}
# query9: ありがとうございます。4-4は文章で提出しました(emoji)また、5-1、5-2も提出しました。,こんばんはお世話になっております。2-3実践課題を提出いたしました。宜しくお願い致します(emoji),こんばんは(月)2-3の課題提出しました。すごく時間がかかってますが、出来ていくのは嬉しいです(emoji),お世話になっております。Week4-2(アカウント作成)、4-3(テキストから画像生成）の課題を提出しました,藤川さんこんばんは(月)1-3の3回目の再提出してます。コメントにも書いたんですが、見本と見比べることに意識がいっており画面を大きくしたら細かい作業もしやすいことに気付きました(emoji)
# similarity_assessment_model(query9, ありがとうございます。4-4は文章で提出しました(emoji)また、5-1、5-2も提出しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（提出した課題番号）が異なり、文章表現も異なる。"}
# similarity_assessment_model(query9, こんばんはお世話になっております。2-3実践課題を提出いたしました。宜しくお願い致します(emoji)): {"similarity":3,"comment":"文章の大まかな内容は類似している（提出報告）が、細かい内容（課題番号）が異なり、文章表現も若干異なるため3とした。"}
# similarity_assessment_model(query9, こんばんは(月)2-3の課題提出しました。すごく時間がかかってますが、出来ていくのは嬉しいです(emoji)): {"similarity": 3, "comment": "文章の大まかな内容は類似している(課題提出の報告)。しかし、細かい内容(提出した課題の番号や提出時期)は異なり、文章表現も異なっている。"}
# similarity_assessment_model(query9, お世話になっております。Week4-2(アカウント作成)、4-3(テキストから画像生成）の課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（提出した課題の内容）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query9, 藤川さんこんばんは(月)1-3の3回目の再提出してます。コメントにも書いたんですが、見本と見比べることに意識がいっており画面を大きくしたら細かい作業もしやすいことに気付きました(emoji)): {"similarity": 1, "comment": "文章1は課題提出の連絡、文章2は再提出の連絡と気づきを記載しているため、内容が異なります。しかし、文章表現や絵文字の使用、口語調である点は共通しています。"}
# query10: week7の実践課題プロンプトをワークシートへ入れました。添削お願いします。,week5の課題を提出しました。,week7-1提出しました,week1の課題を提出しました,week3-4の課題を提出しましたご確認よろしくお願いします
# similarity_assessment_model(query10, week7の実践課題プロンプトをワークシートへ入れました。添削お願いします。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query10, week5の課題を提出しました。): {"similarity": 2, "comment": "文章1は課題の提出を依頼しているのに対し、文章2は提出完了を報告しているので、内容は異なります。しかし、weekという単語や課題という言葉が使われているため、2と評価しました。"}
# similarity_assessment_model(query10, week7-1提出しました): {"similarity": "2", "comment": "文章1は課題の提出に関する依頼、文章2は提出完了の報告という内容で、大まかな内容は異なっています。しかし、week7という単語が共通しているため、文内で使われている単語が似通っています。"}
# similarity_assessment_model(query10, week1の課題を提出しました): {"similarity": "2", "comment": "文章の大まかな内容は異なっているが、文内で使われている単語が似通っているため、2としました。"}
# similarity_assessment_model(query10, week3-4の課題を提出しましたご確認よろしくお願いします): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出に関する内容）が、細かい内容（提出物の内容や提出時期）が異なっており、文章表現も異なっている。"}
# query11: ２-1実践課題を提出しました。宜しくお願いいたします。,11期生妻鹿です。今日は添削をしていただいた内容を参考にもう一度復習をしていました。なるほど、、、と思いながら再度課題に取り組んでいます。,4-2実践課題完了しました,4-4課題まで提出しました。,4-4提出しました。画像の貼り付けはできたと思うのですが、プロンプトのコピーの仕方がわかりませんでした。画像の生成は、入れたプロンプトが必ずしもぜんぶ反映される訳ではないのが面白かったです。
# similarity_assessment_model(query11, ２-1実践課題を提出しました。宜しくお願いいたします。): {"similarity": "0", "comment": "文章1は添削内容を参考に復習していることを記述しており、文章2は課題提出の報告のみであり、内容が全く異なります。また文章表現も大きく異なっています。"}
# similarity_assessment_model(query11, 11期生妻鹿です。今日は添削をしていただいた内容を参考にもう一度復習をしていました。なるほど、、、と思いながら再度課題に取り組んでいます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章なので、類似度は5です。"}
# similarity_assessment_model(query11, 4-2実践課題完了しました): {"similarity": "0", "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query11, 4-4課題まで提出しました。): {"similarity":0,"comment":"文章1は添削を受けた内容を復習している様子がわかる一方、文章2は課題提出を報告しているのみであり、内容が大きく異なる。文章表現も異なるため、類似度は0と判断した。"}
# similarity_assessment_model(query11, 4-4提出しました。画像の貼り付けはできたと思うのですが、プロンプトのコピーの仕方がわかりませんでした。画像の生成は、入れたプロンプトが必ずしもぜんぶ反映される訳ではないのが面白かったです。): {"similarity": 0, "comment": "文章1と文章2は、どちらも自分の活動について記述していますが、具体的な内容は全く異なります。文章1は添削内容の復習について、文章2は課題提出について記述しています。また、文章表現も単語も大きく異なります。"}
# query12: フレームピクセルの指定や画像のピクセルの指定はございますが何でもいいのですか？,２-1実践課題を提出しました。宜しくお願いいたします。,ありがとうございます。面談との違いはどのようなところですか？,すみません。やっぱり提出出来ていませんでした。もう一度提出のためのアドレスを７-3のところに入れていただきたいです。,4-3の課題が完了しましたのでご確認よろしくお願いいたします。
# similarity_assessment_model(query12, フレームピクセルの指定や画像のピクセルの指定はございますが何でもいいのですか？): {"similarity":0,"comment":"文章1と文章2は内容、表現、単語全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query12, ２-1実践課題を提出しました。宜しくお願いいたします。): {"similarity": "0", "comment": "文章の内容、表現、単語が全て異なるため類似度は0です。"}
# similarity_assessment_model(query12, ありがとうございます。面談との違いはどのようなところですか？): {"similarity":0,"comment":"文章1はキックボクシングの話題で、文章2は面談についての話題であり、内容が全く異なります。また、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query12, すみません。やっぱり提出出来ていませんでした。もう一度提出のためのアドレスを７-3のところに入れていただきたいです。): {"similarity":0,"comment":"文章1と文章2は内容、表現、単語全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query12, 4-3の課題が完了しましたのでご確認よろしくお願いいたします。): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なっているため0としました。"}
# query13: ホワイトボードですね？わかりました！,質問があるのですが、各種イベントや自習会は毎回同じ内容でしょうか？自習会は時間がある時は積極的に予約して行った方が良いのでしょうか？,ありがとうございます。面談との違いはどのようなところですか？,延長プランを申込ましたが、決済の手続きは別に連絡がくるのでしょうか？,「勉強会」はどのようなことをするのでしょうか？何人くらい一度に受講するのか、内容や難易度は？を知りたいです。
# similarity_assessment_model(query13, ホワイトボードですね？わかりました！): {"similarity": 0, "comment": "文章1は支払いに関する依頼、文章2は確認の返答であり、内容、表現、単語全てが異なるため0です。"}
# similarity_assessment_model(query13, 質問があるのですが、各種イベントや自習会は毎回同じ内容でしょうか？自習会は時間がある時は積極的に予約して行った方が良いのでしょうか？): {"similarity":0,"comment":"文章1は支払いに関する内容、文章2はイベントに関する内容で、全く異なる内容です。"}
# similarity_assessment_model(query13, ありがとうございます。面談との違いはどのようなところですか？): {"similarity": "0", "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query13, 延長プランを申込ましたが、決済の手続きは別に連絡がくるのでしょうか？): {"similarity":0,"comment":"文章の内容が異なっており、文章表現や単語も異なっているため、0と判断しました。"}
# similarity_assessment_model(query13, 「勉強会」はどのようなことをするのでしょうか？何人くらい一度に受講するのか、内容や難易度は？を知りたいです。): {"similarity": 0, "comment": "文章1は振込口座の問い合わせ、文章2は勉強会の内容に関する質問であり、内容、単語、文章表現全てが異なります。"}
# query14: お世話になります先程、明日の勉強会の件でお電話いただきましたが、申し込みした覚えがなく、明日は予定があって参加できません。勘違いしていたら申し訳ありません。,ホワイトボードですね？わかりました！,ありがとうございます。面談との違いはどのようなところですか？,質問があるのですが、各種イベントや自習会は毎回同じ内容でしょうか？自習会は時間がある時は積極的に予約して行った方が良いのでしょうか？,【動画】(受信失敗)
# similarity_assessment_model(query14, お世話になります先程、明日の勉強会の件でお電話いただきましたが、申し込みした覚えがなく、明日は予定があって参加できません。勘違いしていたら申し訳ありません。): {"similarity":0,"comment":"文章1は体調不良による休み連絡、文章2は勉強会への参加不可連絡であり、内容が全く異なる。単語も共通点は少ない。"}
# similarity_assessment_model(query14, ホワイトボードですね？わかりました！): {"similarity":0,"comment":"文章1と文章2は内容も表現も全く異なっています。"}
# similarity_assessment_model(query14, ありがとうございます。面談との違いはどのようなところですか？): {"similarity": 0, "comment": "文章1は体調不良による欠勤連絡で、文章2は面談に関する質問です。内容、単語、表現全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query14, 質問があるのですが、各種イベントや自習会は毎回同じ内容でしょうか？自習会は時間がある時は積極的に予約して行った方が良いのでしょうか？): {"similarity": 0, "comment": "文章1は体調不良による欠勤連絡、文章2はイベントや自習会に関する質問です。内容が全く異なるため類似度は0です。"}
# similarity_assessment_model(query14, 【動画】(受信失敗)): {"similarity": 0, "comment": "文章の内容が異なっており、文章表現も単語も異なっているため、類似度は0です。"}
#
# query15: Week8-4の課題も提出しましたのでご確認下さい。,お世話になります。Fireflyのアカウント登録完了しましたよろしくお願いいたします,谷津さま今日の取り組み今日は、体調がすぐれなく制作する事が出来ませんでした💦昨日は、Photoshopでのバナートレースと勉強会に参加をして、バナー訂正しました。,谷津さま今日の取り組み今日は、体調がすぐれなく制作する事が出来ませんでした💦昨日は、Photoshopでのバナートレースと勉強会に参加をして、バナー訂正しました。,お世話になります。week3の②を提出しました。
# similarity_assessment_model(query15, Week8-4の課題も提出しましたのでご確認下さい。): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query15, お世話になります。Fireflyのアカウント登録完了しましたよろしくお願いいたします): {"similarity": "5", "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query15, 谷津さま今日の取り組み今日は、体調がすぐれなく制作する事が出来ませんでした💦昨日は、Photoshopでのバナートレースと勉強会に参加をして、バナー訂正しました。): {"similarity":0,"comment":"文章1と文章2は内容、単語、文章表現が異なるため、類似度は0です。"}
# similarity_assessment_model(query15, 谷津さま今日の取り組み今日は、体調がすぐれなく制作する事が出来ませんでした💦昨日は、Photoshopでのバナートレースと勉強会に参加をして、バナー訂正しました。): {"similarity": 0, "comment": "文章1はアカウント登録完了の報告、文章2は業務報告であり、内容も表現も大きく異なるため。"}
# similarity_assessment_model(query15, お世話になります。week3の②を提出しました。): {"similarity": 0, "comment": "文章の内容が異なり、単語も異なるため0としました。"}
# query16: 株式会社アウローラ
# 改めて貴重なご意見ありがとうございます。HerTech運営事務局です。メンター宛にいただきました貴重なお声につきまして、面談の中で十分な回答ができておらず大変申し訳ございませんでした。いただいたお声はメンター含め運営内でもご要望として再度共有させていただきました。改めて再度のお伝えとなり前回からの回答と重複してしまいますが、他の受講生様との交流の場所は先日もお伝えさせていただきました通り、現時点ですぐにご提供できるものがなく大変申し訳ございません。代わりに勉強会は複数名の講師が担当しておりますし、実際に元受講生の方も講師として登壇しております。メンターの池田も元受講生ですので、実際に受講でどう取り組みしたか等、あくまでも池田個人の取り組み方になりますがお伝えができるかと思います。ただ、メンターは講師ではないため、面談の立ち位置としてはあくまでも受講の取り組み方やアドバイスを中心としております。そのため、生成AIの使い方等詳細につきましては、勉強会もしくはLINEでご質問いただけますと幸いです。またご質問いただきました「女性限定」であることは、HerTechを運営しているアウローラのミッションの性質上、提供するサービスについても女性に限定している背景となっております。何卒ご理解くださいませ。なお、最後の面談につきまして、吉崎様がご不要と感じる場合は実施なしでも問題ございません。ご不要の場合は、その旨ご連絡いただけると嬉しいです。いただいた添削とご質問に関しましては、後ほどご連絡させていただきますので今しばらくお待ちくださいませ。どうぞよろしくお願い致します。   ご連絡ありがとうございます！最後の面談については不要とかではなく目的を教えていただけたらと思います！お互い目的意識して臨めた方が効果的と思うからです。どうぞ宜しくお願い致します。,■HerTech受講への今の気持ち：全くの未経験で不安な気持ちもありますが、新しいことを学べるのを楽しみにしている気持ちもあります。途中で投げ出さず、最後までしっかり頑張りたいです！,■HerTech受講への今の気持ち：いよいよ受講開始でドキドキしてますが、数ヶ月後少しでもなりたい自分になれるように頑張ります！,■HerTech受講への今の気持ち：資料確認いたしました。新しい事を学べるのでワクワクしています！最初は仕事との関係でうまく時間が取れるか不安ですが、しっかりと学んでいきたいと思います！,■HerTech受講への今の気持ち：受講の流れを資料で確認をして､受講開始日まで楽しみな気持ちやWebデザイナーの基礎を早く身につけたいなという気持ちが深まりました！
# similarity_assessment_model(query16, 株式会社アウローラ
# 改めて貴重なご意見ありがとうございます。HerTech運営事務局です。メンター宛にいただきました貴重なお声につきまして、面談の中で十分な回答ができておらず大変申し訳ございませんでした。いただいたお声はメンター含め運営内でもご要望として再度共有させていただきました。改めて再度のお伝えとなり前回からの回答と重複してしまいますが、他の受講生様との交流の場所は先日もお伝えさせていただきました通り、現時点ですぐにご提供できるものがなく大変申し訳ございません。代わりに勉強会は複数名の講師が担当しておりますし、実際に元受講生の方も講師として登壇しております。メンターの池田も元受講生ですので、実際に受講でどう取り組みしたか等、あくまでも池田個人の取り組み方になりますがお伝えができるかと思います。ただ、メンターは講師ではないため、面談の立ち位置としてはあくまでも受講の取り組み方やアドバイスを中心としております。そのため、生成AIの使い方等詳細につきましては、勉強会もしくはLINEでご質問いただけますと幸いです。またご質問いただきました「女性限定」であることは、HerTechを運営しているアウローラのミッションの性質上、提供するサービスについても女性に限定している背景となっております。何卒ご理解くださいませ。なお、最後の面談につきまして、吉崎様がご不要と感じる場合は実施なしでも問題ございません。ご不要の場合は、その旨ご連絡いただけると嬉しいです。いただいた添削とご質問に関しましては、後ほどご連絡させていただきますので今しばらくお待ちくださいませ。どうぞよろしくお願い致します。   ご連絡ありがとうございます！最後の面談については不要とかではなく目的を教えていただけたらと思います！お互い目的意識して臨めた方が効果的と思うからです。どうぞ宜しくお願い致します。): {"similarity": "5", "comment": "文章の内容と表現が完全に一致しているため、類似度は5です。"}
# similarity_assessment_model(query16, ■HerTech受講への今の気持ち：全くの未経験で不安な気持ちもありますが、新しいことを学べるのを楽しみにしている気持ちもあります。途中で投げ出さず、最後までしっかり頑張りたいです！): {"similarity": "0", "comment": "文章1はHerTech運営事務局からの返信で、文章2は受講生からのメッセージです。内容が全く異なり、文章表現や単語も大きく異なります。"}
#
# similarity_assessment_model(query16, ■HerTech受講への今の気持ち：いよいよ受講開始でドキドキしてますが、数ヶ月後少しでもなりたい自分になれるように頑張ります！): {"similarity": "0", "comment": "文章1は運営事務局からの返信で、文章2は受講生からのメッセージです。内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query16, ■HerTech受講への今の気持ち：資料確認いたしました。新しい事を学べるのでワクワクしています！最初は仕事との関係でうまく時間が取れるか不安ですが、しっかりと学んでいきたいと思います！): {"similarity": 0, "comment": "文章1は受講後のアンケートへの返信のような内容で、文章2は受講前の期待感のような内容です。文章の内容、単語、表現全てが異なるため類似度は0です。"}
# similarity_assessment_model(query16, ■HerTech受講への今の気持ち：受講の流れを資料で確認をして､受講開始日まで楽しみな気持ちやWebデザイナーの基礎を早く身につけたいなという気持ちが深まりました！): {"similarity": 0, "comment": "文章1はサービスに関する問い合わせへの回答、文章2はサービス受講に対する期待の内容であり、内容が全く異なる。文章表現や単語も異なっているため0点とした。"}
# query17: 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします,10/31に初回面談の空きはありますか？,すみませんお返事しておらず夕方17:30以降で空いてる日はございますか？,10/11　Week8-3、8-4実践課題を提出しました,こんばんは、梅木です。11/5(火)8:50に予約しました。お願いします♬
# similarity_assessment_model(query17, 谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします): {"similarity": "3", "comment": "文章1は予約の連絡、文章2は予約の提案という内容で、大まかな内容は類似しています。細かい内容（日時や予約対象）が異なり、文章表現も異なります。そのため3としました。"}
# similarity_assessment_model(query17, 10/31に初回面談の空きはありますか？): {"similarity": 0, "comment": "文章1は予約に関する内容で、文章2は面談に関する内容です。内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query17, すみませんお返事しておらず夕方17:30以降で空いてる日はございますか？): {"similarity": 1, "comment": "文章1は予約の連絡、文章2は予約の問い合わせという内容で大きく異なります。しかし、文章表現や時間に関する単語が共通しているため、1点としました。"}
# similarity_assessment_model(query17, 10/11　Week8-3、8-4実践課題を提出しました): {"similarity": 0, "comment": "文章1は予約に関する内容、文章2は課題提出に関する内容であり、内容も文章表現も全く異なります。"}
# similarity_assessment_model(query17, こんばんは、梅木です。11/5(火)8:50に予約しました。お願いします♬): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、予約日時と曜日が異なっており、文章表現も異なっているため3とした。"}
# query18: Week2-3③提出しました。,Week5-3の課題を提出しました。ご確認よろしくお願いします。,Week5-3の課題を提出しました。,Week3-3の課題を提出しました。,Week5-1課題を提出しました。渡辺容子
# similarity_assessment_model(query18, Week2-3③提出しました。): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query18, Week5-3の課題を提出しました。ご確認よろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出週と提出物の番号）が異なり、文章表現も異なっているため3と評価しました。"}
# similarity_assessment_model(query18, Week5-3の課題を提出しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（Weekと提出番号）が異なり、文章表現はほぼ同じです。"}
# similarity_assessment_model(query18, Week3-3の課題を提出しました。): {"similarity": 4, "comment": "文章の大まかな内容は提出に関することで類似している。細かい内容では、文章1はWeek2-3③、文章2はWeek3-3と週数が異なる。文章表現は類似している。"}
# similarity_assessment_model(query18, Week5-1課題を提出しました。渡辺容子): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出時期、提出物）が異なり、文章表現も異なるため3とした。"}
# query19: 井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！,ありがとうございます。花びらの素材については、鉛筆マークで同じ色をえらぶことができず、デフォルトの色の中から選んだのですが、素材の色の変更方法はそれしかありませんか？見本バナーのコピーのやり方やってみます！ありがとうございます。,藤川さん今日は3-5実践課題再提出しました。土日はあまり課題進められませんでした。,平田さん昨日は初回面接のお時間を頂き、ありがとうございました。これから新しい学びを楽しみながら進められたらいいなと思っています。よろしくお願い致します。【今日取り組んだこと】・目標シートの記入をしました。・1-1、1-2、1-3まで動画視聴と課題の提出をしました。初めてCanvaを触ってみてとても苦戦しました...でも、頑張りました！今日は時間が取れたのでたくさん出来ましたが、継続できるようなペースを考えて取り組んでいきたいと思います。,お世話になります2-1の実践課題を提出しましたよろしくお願いします
# similarity_assessment_model(query19, 井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！): {"similarity": "0", "comment": "文章1はCanva演習に関する質問、文章2はCanva演習の進捗報告であり、内容が全く異なります。また、文章表現や単語も異なっています。"}
# similarity_assessment_model(query19, ありがとうございます。花びらの素材については、鉛筆マークで同じ色をえらぶことができず、デフォルトの色の中から選んだのですが、素材の色の変更方法はそれしかありませんか？見本バナーのコピーのやり方やってみます！ありがとうございます。): {"similarity": 0, "comment": "文章の内容が異なり、単語も大きく異なります。"}
# similarity_assessment_model(query19, 藤川さん今日は3-5実践課題再提出しました。土日はあまり課題進められませんでした。): {"similarity":0,"comment":"文章1はCanvaの課題に関する質問であり、文章2は課題提出に関する報告です。内容が異なるため、類似度は0です。"}
# similarity_assessment_model(query19, 平田さん昨日は初回面接のお時間を頂き、ありがとうございました。これから新しい学びを楽しみながら進められたらいいなと思っています。よろしくお願い致します。【今日取り組んだこと】・目標シートの記入をしました。・1-1、1-2、1-3まで動画視聴と課題の提出をしました。初めてCanvaを触ってみてとても苦戦しました...でも、頑張りました！今日は時間が取れたのでたくさん出来ましたが、継続できるようなペースを考えて取り組んでいきたいと思います。): {"similarity": 0, "comment": "文章1はCanvaの演習に関する質問で、文章2は研修の進捗報告です。内容、文章表現、単語も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query19, お世話になります2-1の実践課題を提出しましたよろしくお願いします): {"similarity":0,"comment":"文章1はCanva演習に関する質問で、文章2は課題提出の報告です。内容も文章表現も全く異なるため、類似度は0です。"}
# query20: すみません。やっぱり提出出来ていませんでした。もう一度提出のためのアドレスを７-3のところに入れていただきたいです。,フレームピクセルの指定や画像のピクセルの指定はございますが何でもいいのですか？,お世話になります3-3、3-4の課題を提出しました。よろしくお願いします,課題2-3を提出しました。よろしくお願いします。,お世話になります2-3の課題を提出しましたよろしくお願いします
# similarity_assessment_model(query20, すみません。やっぱり提出出来ていませんでした。もう一度提出のためのアドレスを７-3のところに入れていただきたいです。): {"similarity":0,"comment":"文章1は日常業務の報告、文章2は依頼の内容であり、内容が大きく異なります。また、文章表現も異なっています。"}
# similarity_assessment_model(query20, フレームピクセルの指定や画像のピクセルの指定はございますが何でもいいのですか？): {"similarity": 0, "comment": "文章1は日々の業務報告のような内容で、文章2はデザインに関する質問です。内容や表現が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query20, お世話になります3-3、3-4の課題を提出しました。よろしくお願いします): {"similarity": 2, "comment": "文章1は課題提出に加えて、バナー作成のための素材探しまで記述されています。文章2は課題提出のみで、内容は異なります。しかし、文章1では「課題提出」と「素材探し」という単語が使われており、文章2でも「課題提出」という単語が使われているため、単語レベルでは類似性が見られます。"}
# similarity_assessment_model(query20, 課題2-3を提出しました。よろしくお願いします。): {"similarity": "2", "comment": "文章1はタスクの進捗を具体的に記述しているのに対し、文章2は課題提出のみを伝えているため、内容が大きく異なります。ただし、どちらも課題に関する記述であり、単語の類似性が見られます。そのため、2と判断しました。"}
# similarity_assessment_model(query20, お世話になります2-3の課題を提出しましたよろしくお願いします): {"similarity": "1", "comment": "文章の内容は異なるが、文章表現や文章の雰囲気が似ている。文章1は具体的な行動が記述されており、文章2は依頼のような丁寧な口調である。"}

# %% [markdown]
# Without category

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import faiss
import jsonlines
import numpy as np
import random
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting


# Step 1: Load your dataset (qa_pairs_for_rag_1108.jsonl)
with jsonlines.open('qa_pairs_for_rag_1108.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]

# Initialize tokenizer and model for T5
tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-base")

# Step 3: Function to generate embeddings using T5
def generate_embedding(text):
    input_ids = tokenizer.encode(text, return_tensors="pt")
    with torch.no_grad():
        output = model.encoder(input_ids)
    embeddings = output.last_hidden_state.mean(dim=1).squeeze().numpy()  # Average pooling
    return embeddings

# Step 4: Generate embeddings for each question
question_embeddings = [generate_embedding(doc) for doc in documents]

# Step 5: Initialize Faiss index
d = question_embeddings[0].shape[0]  # Dimensionality of embeddings
faiss_index = faiss.IndexFlatL2(d)
faiss_index.add(np.array(question_embeddings))

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 6: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Generate embedding for the query
    query_embedding = generate_embedding(f"Question: {query}")

    # Search Faiss index for nearest neighbors
    distances, indices = faiss_index.search(query_embedding.reshape(1, -1), top_k)

    # Return the most similar questions
    closest_questions = [questions[i] for i in indices[0]]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Evaluate the system with 20 selected questions using T5 and Faiss
print("Evaluating using T5 and Faiss:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# Evaluating using T5 and Faiss:
# query1: 課題7-3を提出しました,こんにちは。7-3の課題を提出しましたのでよろしくお願いします。ただ、プロンプトのリンクの貼り付けをどこにしたらいいのか分からず、欄外に貼り付けました。よろしくお願いします。,実践課題7-3まで提出完了いたしました。ご確認よろしくお願い致します。,課題7-2提出しました,添削ありがとうございます。課題7-2を提出しました
# similarity_assessment_model(query1, 課題7-3を提出しました): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、文章1では「提出完了いたしました」と完了していることを明確に記述しているのに対し、文章2では「提出しました」と完了していることが明記されていない。文章表現は類似している。"}
# similarity_assessment_model(query1, こんにちは。7-3の課題を提出しましたのでよろしくお願いします。ただ、プロンプトのリンクの貼り付けをどこにしたらいいのか分からず、欄外に貼り付けました。よろしくお願いします。): {"similarity": "3", "comment": "文章1は課題提出完了の報告のみだが、文章2は課題提出に加えて、プロンプトのリンク貼り付けに関する質問が含まれている。そのため、細かい内容は異なる。しかし、文章表現はどちらも簡潔で、依頼や確認を丁寧に行っているため類似していると言える。"}
# similarity_assessment_model(query1, 実践課題7-3まで提出完了いたしました。ご確認よろしくお願い致します。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query1, 課題7-2提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似している(課題提出に関する連絡)が、細かい内容(提出した課題の番号)が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query1, 添削ありがとうございます。課題7-2を提出しました): {"similarity": "2", "comment": "文章1は課題提出の報告、文章2は添削に対する返答というように、文脈が異なります。しかし、課題番号や提出という単語が使われているため、2としました。"}
# query2: 今ワイヤーフレームの修正をおこなっているのですが、「なめらかな〜」「素の唇を〜」「唇に〜」の部分が操作解説動画通りのフォントや文字の大きさにしているのに見本よりも字が濃く･太く見えるのですが、私の勘違いなんでしょうか、、、？,ありがとうございます。対応します,課題提出しました。よろしくお願いいたします🙇,☁️日次報告☁️今日は取り組めませんでした💦,こんなメッセージが出ました。
# similarity_assessment_model(query2, 今ワイヤーフレームの修正をおこなっているのですが、「なめらかな〜」「素の唇を〜」「唇に〜」の部分が操作解説動画通りのフォントや文字の大きさにしているのに見本よりも字が濃く･太く見えるのですが、私の勘違いなんでしょうか、、、？): {"similarity": 0, "comment": "文章の内容が全く異なっており、文章表現や単語も異なっています。"}
# similarity_assessment_model(query2, ありがとうございます。対応します): {"similarity":0,"comment":"文章1は謝罪、文章2は依頼に対する回答であり、内容も表現も全く異なります。"}
# similarity_assessment_model(query2, 課題提出しました。よろしくお願いいたします🙇): {"similarity": 0, "comment": "文章1は謝罪、文章2は報告であり、内容が異なります。また、単語や文章表現も異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query2, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": "1", "comment": "文章の内容は異なるが、文章表現や文章の雰囲気が似ている。どちらも謝罪のニュアンスを含んでいる。"}
# similarity_assessment_model(query2, こんなメッセージが出ました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# query3: 竹内様✴︎課題の進捗状況について4-1,4-2動画を視聴しました。これからポートフォリオやresumeページを充実させていけるよう任意バナーなどの作成をしていきたいと思います。,前回4-2.とお伝えしたのは4-3の間違えでした。,お世話になります4-1、4-2終わりましたよろしくお願いします,おはようございます。遅くなり大変申し訳ございません。7-1～8-4を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林,お疲れ様です。実践課題8-1、8-2提出いたします。宜しくお願いします。
# similarity_assessment_model(query3, 竹内様✴︎課題の進捗状況について4-1,4-2動画を視聴しました。これからポートフォリオやresumeページを充実させていけるよう任意バナーなどの作成をしていきたいと思います。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query3, 前回4-2.とお伝えしたのは4-3の間違えでした。): {"similarity": 0, "comment": "文章1と文章2の内容は全く異なります。文章1は課題の進捗について報告しているのに対し、文章2は誤った情報の訂正を行っています。また、文章表現や単語も大きく異なっています。"}
#
# similarity_assessment_model(query3, お世話になります4-1、4-2終わりましたよろしくお願いします): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は課題の進捗状況を報告し、今後の計画を述べているのに対し、文章2は単に完了報告のみで、文章表現も簡潔で、丁寧さや計画性を感じられないため3とした。"}
# similarity_assessment_model(query3, おはようございます。遅くなり大変申し訳ございません。7-1～8-4を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林): {"similarity": 2, "comment": "文章1と文章2は、どちらも課題の進捗に関する報告という文脈では共通していますが、具体的な内容や表現が大きく異なります。文章1では、具体的な課題番号や今後の計画が示されている一方、文章2では提出した課題番号のみが記載されています。また、文章表現も、文章1は丁寧な表現で、文章2は簡潔な表現となっています。そのため、文章の大まかな内容は異なっているが、文内で使われている単語が似通っているという判断をしました。"}
# similarity_assessment_model(query3, お疲れ様です。実践課題8-1、8-2提出いたします。宜しくお願いします。): {"similarity": "2", "comment": "文章1は課題の進捗状況について記述していますが、文章2は課題提出に関する記述です。そのため、文章の大まかな内容は異なっています。しかし、文章1と文章2では「課題」「動画」「提出」といった単語が共通して使用されているため、2と評価しました。"}
# query4: 青木さん、おはようございます🌞早速ですが、下記に進捗状況をまとめております🙂‍↕️10/10(金)・2-3課題提出・任意課題のバナートレースのやり方を確認10/11(土)・バナートレースの取り組み開始以上となります。今週、帰省するためご連絡が遅くなるかもしれませんが、少しずつ進めてまいります!!✨どうぞよろしくお願いします🙇🏻‍♀️!!,「島戸さん宛」▼11/5(火)取り組みの報告　・3-5課題実施・バナートレース・10分読書昨日のトレースの別レイアウトパターンをしました😊10分読書は新しく「3色だけでセンスのいい色」を合間の時間で読んでいます！,青木さん、おはようございます🌞早速ですが、下記に進捗状況をまとめております!!10/12(日)休み10/13(月)・任意課題のバナートレース実施10/14(火)・2-3課題の再提出以上となります。少し進捗がゆっくりになっているので、調整しつつ進めます🙂‍↕️どこかで勉強会に参加できればと思っています…!!引き続きよろしくお願いいたします🙇🏻‍♀️✨,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 質問です。メンター面談2回まで終了しました。次回は、いつ頃予定（予約）すれば良いでしょうか？,10/5も予定があり参加が難しい状況です🙇🙇途中で一時的に抜けてしまっても大丈夫でしたら、明日10/2(水)10時〜12時で参加させていただきたいと思います🙇🙇
# similarity_assessment_model(query4, 青木さん、おはようございます🌞早速ですが、下記に進捗状況をまとめております🙂‍↕️10/10(金)・2-3課題提出・任意課題のバナートレースのやり方を確認10/11(土)・バナートレースの取り組み開始以上となります。今週、帰省するためご連絡が遅くなるかもしれませんが、少しずつ進めてまいります!!✨どうぞよろしくお願いします🙇🏻‍♀️!!): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query4, 「島戸さん宛」▼11/5(火)取り組みの報告　・3-5課題実施・バナートレース・10分読書昨日のトレースの別レイアウトパターンをしました😊10分読書は新しく「3色だけでセンスのいい色」を合間の時間で読んでいます！): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の進捗報告）。しかし、細かい内容は異なり、文章表現も異なっている。文章1では、日付、具体的な課題の内容、連絡が遅くなる旨が記載されている一方、文章2では、日付、課題の内容、読書の内容が記載されている。また、文章1では絵文字を多く使用しているのに対し、文章2では絵文字を1つのみ使用している。"}
# similarity_assessment_model(query4, 青木さん、おはようございます🌞早速ですが、下記に進捗状況をまとめております!!10/12(日)休み10/13(月)・任意課題のバナートレース実施10/14(火)・2-3課題の再提出以上となります。少し進捗がゆっくりになっているので、調整しつつ進めます🙂‍↕️どこかで勉強会に参加できればと思っています…!!引き続きよろしくお願いいたします🙇🏻‍♀️✨): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、課題提出やバナートレースの取り組みなど共通の話題が含まれている。しかし、具体的な日付や内容は異なっており、文章表現も一部異なっているため、4点とした。"}
# similarity_assessment_model(query4, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 質問です。メンター面談2回まで終了しました。次回は、いつ頃予定（予約）すれば良いでしょうか？): {"similarity":0,"comment":"文章1は進捗状況報告、文章2はメンター面談に関する質問であり、内容が全く異なります。また、文章表現も大きく異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query4, 10/5も予定があり参加が難しい状況です🙇🙇途中で一時的に抜けてしまっても大丈夫でしたら、明日10/2(水)10時〜12時で参加させていただきたいと思います🙇🙇): {"similarity": 0, "comment": "文章の内容や表現が大きく異なり、共通点が見当たらないためです。"}
# query5: ご連絡ありがとうございます。主人との都合がとれたので、11/4の14時からでも大丈夫でしょうか？,遅くなり申し訳ございません。4-4～5-2を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林,おはようございます。遅くなり大変申し訳ございません。7-1～8-4を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林,お世話になります4-1、4-2終わりましたよろしくお願いします,講師のかたがお時間を勘違いされていたので、結局18時30分からあらためて行うことになりました。念の為おしらせまで。
# similarity_assessment_model(query5, ご連絡ありがとうございます。主人との都合がとれたので、11/4の14時からでも大丈夫でしょうか？): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query5, 遅くなり申し訳ございません。4-4～5-2を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林): {"similarity":0,"comment":"文章1は予定に関する問い合わせ、文章2は提出物の報告と依頼です。内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query5, おはようございます。遅くなり大変申し訳ございません。7-1～8-4を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林): {"similarity":0,"comment":"文章1は予約に関する問い合わせ、文章2は仕事の提出に関する連絡であり、内容が全く異なります。また、文章表現や単語も異なっています。"}
# similarity_assessment_model(query5, お世話になります4-1、4-2終わりましたよろしくお願いします): {"similarity":0,"comment":"文章の内容、表現、単語が全て異なるため"}
# similarity_assessment_model(query5, 講師のかたがお時間を勘違いされていたので、結局18時30分からあらためて行うことになりました。念の為おしらせまで。): {"similarity":0,"comment":"文章1は予約に関する内容で、文章2は時間変更に関する内容のため、全く異なる内容です。"}
# query6: ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。,☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。,ご連絡失念しておりましたが、昨日「2-1実践課題」を提出いたしました。ご確認よろしくお願いいたします,課題2-1提出しました。,すみません、課題の提出を勘違いしていました。先程、課題2-1を提出しました。よろしくお願いします。
# similarity_assessment_model(query6, ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。): {"similarity": 0, "comment": "文章の内容が異なり、文末表現や絵文字など文章表現も大きく異なっています。"}
# similarity_assessment_model(query6, ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。): {"similarity": 0, "comment": "文章1は提出に関する連絡、文章2は進捗報告に関する連絡であり、内容が全く異なる。また文章表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query6, ご連絡失念しておりましたが、昨日「2-1実践課題」を提出いたしました。ご確認よろしくお願いいたします): {"similarity": "3", "comment": "文章1は提出物の報告、文章2は提出済みの報告という点で、大まかな内容は類似しています。しかし、細かい内容(提出物の内容、提出日時)が異なり、文章表現も異なります。そのため、類似度は3としました。"}
# similarity_assessment_model(query6, 課題2-1提出しました。): {"similarity": "1", "comment": "文章の内容は異なっているものの、文章表現や文末が似ており、課題提出に関する内容であることから、1と判断しました。"}
# similarity_assessment_model(query6, すみません、課題の提出を勘違いしていました。先程、課題2-1を提出しました。よろしくお願いします。): {"similarity": 2, "comment": "文章1は課題提出の報告、文章2は提出の遅延と謝罪という内容で異なっている。しかし、文章1の「藤岡様宛て」や「2-2課題」といった単語が、文章2の「課題」や「2-1」と似ているため、2と評価した。"}
# query7: 10/5 Week7-3実践課題を提出しました,Week7  7-3の課題を提出しました,9/25　Week6-1実践課題を提出しました,Week5-3の課題を提出しました。ご確認よろしくお願いします。,Week5-3の課題を提出しました。
# similarity_assessment_model(query7, 10/5 Week7-3実践課題を提出しました): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章のため、類似度は5です。"}
# similarity_assessment_model(query7, Week7  7-3の課題を提出しました): {"similarity": 4, "comment": "文章の大まかな内容は類似していますが、文章1の「10/5」と「Week7-3」の情報が文章2に含まれていません。文章表現は類似しています。"}
# similarity_assessment_model(query7, 9/25　Week6-1実践課題を提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出日、課題番号）が異なり、文章表現も異なっているため。"}
# similarity_assessment_model(query7, Week5-3の課題を提出しました。ご確認よろしくお願いします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（Weekの番号、提出物の内容）が異なり、文章表現も異なっている（文章1は短く、文章2は丁寧な表現）ため、3と評価しました。"}
# similarity_assessment_model(query7, Week5-3の課題を提出しました。): {"similarity":3,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なる。文章1は日付と課題番号が具体的に記載されている一方、文章2は日付と課題番号が曖昧である。また、文章1は「提出しました」と断定的に書かれているのに対し、文章2は「提出しました。」とより丁寧な表現である。"}
# query8: week7-1提出しました,Week5-1の課題を提出しました。,Week5-1課題を提出しました。渡辺容子,week 6-1の課題を提出しました。,Week3-1の課題を提出しました。
# similarity_assessment_model(query8, week7-1提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（提出に関する報告）が、細かい内容は異なり（提出物の番号が異なる）、文章表現はほぼ同じであるため3とした。"}
# similarity_assessment_model(query8, Week5-1の課題を提出しました。): {"similarity":4,"comment":"文章の大まかな内容は類似しているが、課題の提出時期が異なるため、細かい内容が異なっている。文章表現は類似している。"}
# similarity_assessment_model(query8, Week5-1課題を提出しました。渡辺容子): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（weekとweek、提出番号）、文章表現も異なっている（名前の有無）ため3とした。"}
# similarity_assessment_model(query8, week 6-1の課題を提出しました。): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が少し異なり、文章表現はほぼ類似しているため。"}
# similarity_assessment_model(query8, Week3-1の課題を提出しました。): {"similarity":3,"comment":"文章の大まかな内容は類似している（課題提出）が、細かい内容（提出週）が異なり、文章表現も異なっている（「week」と「Week」、「-1」の表記）ため3とした。"}
# query9: 2-2 実践課題2-３実践課題提出しました。議事録の作成については後日提出いたします。,ご連絡をすっかり忘れておりました。課題2-2から4-2まで提出終わりましたので、ご確認をお願いします。,課題3-4から4-3まで進めました。ご確認よろしくお願いいたします。,お世話になります4-1、4-2終わりましたよろしくお願いします,お世話になります3-3、3-4の課題を提出しました。よろしくお願いします
# similarity_assessment_model(query9, 2-2 実践課題2-３実践課題提出しました。議事録の作成については後日提出いたします。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
#
# similarity_assessment_model(query9, ご連絡をすっかり忘れておりました。課題2-2から4-2まで提出終わりましたので、ご確認をお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は課題2-3の提出について言及しているが、文章2は課題2-2から4-2までの提出について言及している。また、文章1は議事録の提出について言及しているが、文章2は確認依頼をしている。"}
# similarity_assessment_model(query9, 課題3-4から4-3まで進めました。ご確認よろしくお願いいたします。): {"similarity": "3", "comment": "文章1は課題提出に関する報告、文章2は進捗報告となっており、大まかな内容は類似している。細かい内容は異なり、文章表現も異なるため3とした。"}
# similarity_assessment_model(query9, お世話になります4-1、4-2終わりましたよろしくお願いします): {"similarity":0,"comment":"文章の内容が異なり、文章表現も単語も異なっています。"}
# similarity_assessment_model(query9, お世話になります3-3、3-4の課題を提出しました。よろしくお願いします): {"similarity": 2, "comment": "文章1は課題提出に関する内容で、具体的な課題番号も記載されています。文章2は課題提出の報告ですが、具体的な課題番号は記載されていません。そのため、文章の大まかな内容は異なっていますが、課題提出という共通点があり、文内で使われている単語が似通っています。"}
# query10: 谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！,谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！,ありがとうございます！,谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！,谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！
# similarity_assessment_model(query10, 谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！): {"similarity": 0, "comment": "文章1は感謝の言葉、文章2は仕事の報告であり、内容、文章表現、単語も全く異なっています。"}
# similarity_assessment_model(query10, 谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！): {"similarity": "0", "comment": "文章1は感謝の言葉、文章2は作業に関する報告であり、内容や表現が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query10, ありがとうございます！): {"similarity": "5", "comment": "文章1と文章2は全く同じ文章であるため、類似度は5です。"}
# similarity_assessment_model(query10, 谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！): {"similarity": "0", "comment": "文章1は感謝の言葉、文章2は仕事の報告で、内容や表現が全く異なります。"}
# similarity_assessment_model(query10, 谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！): {"similarity":0,"comment":"文章1は感謝の言葉、文章2は仕事の報告であり、内容が全く異なっています。また、文章表現も異なります。"}
# query11: 今ワイヤーフレームの修正をおこなっているのですが、「なめらかな〜」「素の唇を〜」「唇に〜」の部分が操作解説動画通りのフォントや文字の大きさにしているのに見本よりも字が濃く･太く見えるのですが、私の勘違いなんでしょうか、、、？,ありがとうございます。対応します,課題提出しました。よろしくお願いいたします🙇,☁️日次報告☁️今日は取り組めませんでした💦,こんなメッセージが出ました。
# similarity_assessment_model(query11, 今ワイヤーフレームの修正をおこなっているのですが、「なめらかな〜」「素の唇を〜」「唇に〜」の部分が操作解説動画通りのフォントや文字の大きさにしているのに見本よりも字が濃く･太く見えるのですが、私の勘違いなんでしょうか、、、？): {"similarity": 0, "comment": "文章1は申込書に関する内容で、文章2はワイヤーフレームの修正に関する内容であり、内容や単語、表現が大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query11, ありがとうございます。対応します): {"similarity": 0, "comment": "文章1は延長プランの申込書の提出に関する問い合わせであり、文章2はそれに対応する言葉です。内容も表現も全く異なります。"}
# similarity_assessment_model(query11, 課題提出しました。よろしくお願いいたします🙇): {"similarity": 2, "comment": "文章1は延長プランの申込書に関する内容で、文章2は課題提出に関する内容です。そのため、内容は異なります。しかし、文章1には「提出」という言葉が使われており、文章2にも「提出」という言葉が使われているため、単語が似通っていると言えるでしょう。"}
# similarity_assessment_model(query11, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity":0,"comment":"文章1は延長プランの申込書の提出に関する内容で、文章2は日次報告の内容であり、内容、文章表現、単語ともに共通点が見当たらないため、類似度は0です。"}
# similarity_assessment_model(query11, こんなメッセージが出ました。): {"similarity": 0, "comment": "文章1は延長プランの申込書に関する内容で、文章2はメッセージに関する内容で、内容が全く異なっています。文章表現も単語も異なっているため、類似度は0です。"}
# query12: 10月24日に取り組んだ内容・【2-2】実践課題の実施・提出ご確認を宜しくお願いいたします。,10月21日に取り組んだ内容・2-1の実践課題の実施と提出をしました。ご確認を宜しくお願いいたします。,10月20日取り組んだ内容・1-4の④の実践課題を提出しました。ご確認を宜しくお願いいたします。,ご連絡をすっかり忘れておりました。課題2-2から4-2まで提出終わりましたので、ご確認をお願いします。,遅くなり申し訳ございません。4-4～5-2を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林
# similarity_assessment_model(query12, 10月24日に取り組んだ内容・【2-2】実践課題の実施・提出ご確認を宜しくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は完全に同一の内容のため、類似度は5です。"}
# similarity_assessment_model(query12, 10月21日に取り組んだ内容・2-1の実践課題の実施と提出をしました。ご確認を宜しくお願いいたします。): {"similarity":4,"comment":"文章の大まかな内容は類似しているが、日付と課題番号が異なっており、文章表現は類似している。"}
# similarity_assessment_model(query12, 10月20日取り組んだ内容・1-4の④の実践課題を提出しました。ご確認を宜しくお願いいたします。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容(日付、課題番号)が異なっており、文章表現は類似しているため3としました。"}
# similarity_assessment_model(query12, ご連絡をすっかり忘れておりました。課題2-2から4-2まで提出終わりましたので、ご確認をお願いします。): {"similarity": "3", "comment": "文章1は課題提出の確認を求める内容、文章2は課題提出の報告内容であり、大まかな内容は類似している。しかし、文章1は日付や課題番号を明確に示しているのに対し、文章2は課題番号のみしか示されていない。また、文章表現も異なる。文章1は丁寧な表現で、文章2は簡潔な表現である。"}
# similarity_assessment_model(query12, 遅くなり申し訳ございません。4-4～5-2を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林): {"similarity": "3", "comment": "文章1は「提出ご確認を宜しくお願いいたします」と、文章2は「ご確認のほど、よろしくお願いいたします」と、文章表現が異なります。また、文章1は具体的な課題名と日付が記述されているのに対し、文章2は課題番号のみ記述されているため、細かい内容は異なります。しかし、どちらも課題提出に関する内容であり、大まかな内容は類似しているため、類似度は3と判断しました。"}
# query13: おはようございます☀昨日1-1と1-2をしました。,お世話になります4-1、4-2終わりましたよろしくお願いします,おはようございます。遅くなり大変申し訳ございません。7-1～8-4を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林,ご連絡をすっかり忘れておりました。課題2-2から4-2まで提出終わりましたので、ご確認をお願いします。,課題5-1から5-3を提出しました
# similarity_assessment_model(query13, おはようございます☀昨日1-1と1-2をしました。): {"similarity": "5", "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query13, お世話になります4-1、4-2終わりましたよろしくお願いします): {"similarity": 3, "comment": "文章の大まかな内容は類似している（試合の結果を報告している）が、細かい内容は異なり（具体的なスコアが異なる）、文章表現も異なっている（文章1は「おはようございます」と挨拶を含んでいるのに対し、文章2は「お世話になります」と「よろしくお願いします」と挨拶を含んでいる）ため、3とした。"}
# similarity_assessment_model(query13, おはようございます。遅くなり大変申し訳ございません。7-1～8-4を提出させていただきました。ご確認のほど、よろしくお願いいたします。村林): {"similarity": "1", "comment": "文章の内容は異なるが、挨拶と報告の文章という点で文章の雰囲気が似ている。"}
# similarity_assessment_model(query13, ご連絡をすっかり忘れておりました。課題2-2から4-2まで提出終わりましたので、ご確認をお願いします。): {"similarity": 0, "comment": "文章1と文章2は、内容、単語、文体全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query13, 課題5-1から5-3を提出しました): {"similarity": 2, "comment": "文章の内容は異なるが、番号とハイフンで区切られた表現が共通しているため2としました。"}
# query14: お世話になっております。STEP1、2共に回答完了いたしました。引き続きどうぞよろしくお願いいたします🙇🏻‍♀️,本日はありがとうございます。課題提出できてませんでしたので、1週間目の1から4課題提出しましたよろしくお願いします。,面談の予約入れました。ありがとうございます。8-1〜4の実践課題提出しました。月火曜日は出かけるため、一度に提出させて頂きました。申し訳ありません。🙇‍♀️生成AI特別演習の勉強会予約は済ませました。よろしくお願い致します🙇‍♀️,実践課題2ー1、2ー2を提出しました。宜しくお願いします。,Week1課題②、③、④提出しました。
# similarity_assessment_model(query14, お世話になっております。STEP1、2共に回答完了いたしました。引き続きどうぞよろしくお願いいたします🙇🏻‍♀️): {"similarity": 5, "comment": "文章の内容、表現、単語全てが同じです。"}
#
# similarity_assessment_model(query14, 本日はありがとうございます。課題提出できてませんでしたので、1週間目の1から4課題提出しましたよろしくお願いします。): {"similarity":3,"comment":"文章の大まかな内容は類似している（課題提出の報告）。しかし、細かい内容は異なり（文章1はSTEP1、2、文章2は1週間目の1から4）、文章表現も異なっている（文章1は丁寧な表現、文章2はカジュアルな表現）。"}
# similarity_assessment_model(query14, 面談の予約入れました。ありがとうございます。8-1〜4の実践課題提出しました。月火曜日は出かけるため、一度に提出させて頂きました。申し訳ありません。🙇‍♀️生成AI特別演習の勉強会予約は済ませました。よろしくお願い致します🙇‍♀️): {"similarity": "3", "comment": "文章1と文章2はどちらも感謝の気持ちと今後の依頼に対する意欲を表しており、大まかな内容は類似しています。しかし、文章1はSTEP1、2の回答完了を報告している一方、文章2は面談予約と課題提出、勉強会予約の報告を行っており、細かい内容は異なります。また、文章表現も「回答完了いたしました」や「引き続きどうぞよろしくお願いいたします」といった丁寧な表現が文章1に見られる一方、文章2では「申し訳ありません」や「よろしくお願い致します」といった謝罪や依頼の表現が多く、表現方法が異なります。そのため、類似度は3と評価しました。"}
# similarity_assessment_model(query14, 実践課題2ー1、2ー2を提出しました。宜しくお願いします。): {"similarity":3,"comment":"文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（課題番号、丁寧な言葉遣い）が異なっており、文章表現も異なっている（絵文字の有無、敬語の使い分け）ため3とした。"}
# similarity_assessment_model(query14, Week1課題②、③、④提出しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）。しかし、細かい内容は異なり（文章1はSTEP1,2、文章2はWeek1課題②、③、④）、文章表現も異なっている（文章1は丁寧な表現、文章2は簡潔な表現）ため、3と評価しました。"}
#
# query15: カリキュラムのことで質問なのですが、数日前に課題を提出して添削中となっているのですが、これは添削されるのを待っていればいいでしょうか？また、2-3の課題は提出して添削中なのですが、新たに任意課題も作成しましたがもう追加でアップロードできないので提出しなくてよいでしょうか？(今日の勉強会で添削してもらったので、、),「島戸さん宛」▼11/5(火)取り組みの報告　・3-5課題実施・バナートレース・10分読書昨日のトレースの別レイアウトパターンをしました😊10分読書は新しく「3色だけでセンスのいい色」を合間の時間で読んでいます！,ワイヤーフレーム作成している時に素材をコピーしようとしたら背景が黒くなってしまうのですが、背景透明にするにはどうすれば良いでしょうか？？,メンター面談の予約を11/3の日曜日にさせて頂いているのですが、都合が悪くなってしまいました。前日の土曜日に変更させていただくことは難しいでしょうか？予約変更のリンクより変更しようとしたところ、ただいま予約受付は停止中です。と出て変更ができませんでした。どうぞよろしくお願いいたします。,竹内様、1105取り組み報告・勉強会参加・3ｰ3３回目直し提出いつの間にかついている字の周り？の枠線の存在や、正しい中心線の見抜き方などを勉強会では教えていただきました。おかげで、なんとか３回目の直しを提出することができました。Resume 4ｰ1はやり直しになったので、他の方々のものも参考にしながら、明日以降訂正していきたいと思います。どうぞよろしくお願いいたします。
# similarity_assessment_model(query15, カリキュラムのことで質問なのですが、数日前に課題を提出して添削中となっているのですが、これは添削されるのを待っていればいいでしょうか？また、2-3の課題は提出して添削中なのですが、新たに任意課題も作成しましたがもう追加でアップロードできないので提出しなくてよいでしょうか？(今日の勉強会で添削してもらったので、、)): {"similarity": 0, "comment": "文章1はCanvaの操作に関する質問で、文章2はカリキュラムに関する質問なので、内容が大きく異なります。また、文章表現も異なるため、類似度は0と評価しました。"}
# similarity_assessment_model(query15, 「島戸さん宛」▼11/5(火)取り組みの報告　・3-5課題実施・バナートレース・10分読書昨日のトレースの別レイアウトパターンをしました😊10分読書は新しく「3色だけでセンスのいい色」を合間の時間で読んでいます！): {"similarity": 0, "comment": "文章1はCanvaの操作に関する質問で、文章2はCanvaを使った取り組みの報告です。文章の内容、単語、表現が大きく異なります。"}
# similarity_assessment_model(query15, ワイヤーフレーム作成している時に素材をコピーしようとしたら背景が黒くなってしまうのですが、背景透明にするにはどうすれば良いでしょうか？？): {"similarity": 0, "comment": "文章1はCanvaの機能に関する質問で、文章2はワイヤーフレーム作成に関する質問です。内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query15, メンター面談の予約を11/3の日曜日にさせて頂いているのですが、都合が悪くなってしまいました。前日の土曜日に変更させていただくことは難しいでしょうか？予約変更のリンクより変更しようとしたところ、ただいま予約受付は停止中です。と出て変更ができませんでした。どうぞよろしくお願いいたします。): {"similarity": 0, "comment": "文章1はCanvaの機能についての質問、文章2は予約変更に関する問い合わせであり、内容が全く異なります。また、単語も大きく異なっており、文章表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query15, 竹内様、1105取り組み報告・勉強会参加・3ｰ3３回目直し提出いつの間にかついている字の周り？の枠線の存在や、正しい中心線の見抜き方などを勉強会では教えていただきました。おかげで、なんとか３回目の直しを提出することができました。Resume 4ｰ1はやり直しになったので、他の方々のものも参考にしながら、明日以降訂正していきたいと思います。どうぞよろしくお願いいたします。): {"similarity": 0, "comment": "文章1はCanvaのデザインに関する質問で、文章2はResumeの修正に関する報告です。内容が全く異なり、文章表現や単語も異なります。"}
# query16: ご連絡ありがとうございました。プロンプトの共有ができるようになりましたので6-1実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。,また、6-1も提出しました。よろしくお願いします。,課題6-1を提出しました。ご確認よろしくお願いします。,実践課題6-1を提出しました。よろしくお願い致します。,おはようございます。8-1まで課題終えてます。ご確認をお願いします。
# similarity_assessment_model(query16, ご連絡ありがとうございました。プロンプトの共有ができるようになりましたので6-1実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章のため、類似度は5です。"}
# similarity_assessment_model(query16, また、6-1も提出しました。よろしくお願いします。): {"similarity": "3", "comment": "文章1ではプロンプトの提出を報告し、添削を依頼しています。文章2では提出を報告しているのみで、添削依頼はありません。大まかな内容は類似していますが、細かい内容が異なり、文章表現も異なります。"}
# similarity_assessment_model(query16, 課題6-1を提出しました。ご確認よろしくお願いします。): {"similarity": "3", "comment": "文章1ではプロンプトの共有について言及していますが、文章2では課題提出についてのみ言及しています。そのため、細かい内容は異なります。文章表現はどちらも簡潔で類似しています。"}
# similarity_assessment_model(query16, 実践課題6-1を提出しました。よろしくお願い致します。): {"similarity": "3", "comment": "文章1はプロンプトの共有について言及しており、文章2は提出について言及しているため、細かい内容は異なります。しかし、どちらも実践課題6-1に関する内容であるため、大まかな内容は類似しています。文章表現も異なるため、3と評価しました。"}
# similarity_assessment_model(query16, おはようございます。8-1まで課題終えてます。ご確認をお願いします。): {"similarity": "0", "comment": "文章の内容、表現、単語全てが異なっています。"}
# query17: すみません！治りました！,藤川様先ほど、質問のご連絡をさせていただいたのですが続けて本日の勉強成果をお伝えします！本日は課題の再提出とワイヤーフレーム課題の提出をしました！,井関さん宛動画視聴を始めてみました！目標設定したのでこれから頑張ります！,ホワイトボードですね？わかりました！,こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース
# similarity_assessment_model(query17, すみません！治りました！): {"similarity": 0, "comment": "文章の内容が全く異なり、単語も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query17, 藤川様先ほど、質問のご連絡をさせていただいたのですが続けて本日の勉強成果をお伝えします！本日は課題の再提出とワイヤーフレーム課題の提出をしました！): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
#
# similarity_assessment_model(query17, 井関さん宛動画視聴を始めてみました！目標設定したのでこれから頑張ります！): {"similarity": 0, "comment": "文章1は仕事の報告、文章2は個人の学習に関する内容であり、内容や表現が大きく異なります。"}
# similarity_assessment_model(query17, ホワイトボードですね？わかりました！): {"similarity":0,"comment":"文章1は勉強に関する内容で、文章2はホワイトボードに関する内容で、全く関係がありません。文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query17, こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1は報告というより連絡に近い印象で、文章2は報告という印象。また、文章1では「課題の再提出」「ワイヤーフレーム課題」と具体的に記述しているが、文章2では「ワイヤーフレーム完成」「バナートレース」と簡潔に記述している。"}
# query18: 実際には、こちらの環境の問題で一部課題ができていません💦そこも含めて またお話させていただければと思います…URLありがとうございます！直近ではありますが、10月18日9:00~の枠を取らせていただきました。よろしくお願いします。,有料の編集プラン最初からツールキットが揃った月額7,780円の方がよいでしょうか…皆さんどうされてますか？参考に教えて下さい🙇,こんにちは！明日のミーティングなのですが、18時からだと思っていました🥲18時まで予定が入っているため、30分ずらすといったことは可能でしょうか？すみません🙇‍♀️,1⃣で再度手続きしたのですが、エラーが出てしまいました。別のカードで手続きしようと考えているので、御手数ですがもう一度URL送っていただくことは可能でしょうか。何度もすみません。よろしくお願いします,入金の際にエラーになってしまったため、もう一度URLの送信お願いします。
# similarity_assessment_model(query18, 実際には、こちらの環境の問題で一部課題ができていません💦そこも含めて またお話させていただければと思います…URLありがとうございます！直近ではありますが、10月18日9:00~の枠を取らせていただきました。よろしくお願いします。): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query18, 有料の編集プラン最初からツールキットが揃った月額7,780円の方がよいでしょうか…皆さんどうされてますか？参考に教えて下さい🙇): {"similarity": 0, "comment": "文章1は、課題に関する問い合わせと、会議の予約に関する内容です。文章2は、有料編集プランの質問です。内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query18, こんにちは！明日のミーティングなのですが、18時からだと思っていました🥲18時まで予定が入っているため、30分ずらすといったことは可能でしょうか？すみません🙇‍♀️): {"similarity": 0, "comment": "文章1は、課題に関する連絡とミーティングの時間の報告、文章2はミーティング時間の変更依頼です。内容が異なるため、類似度は0です。"}
# similarity_assessment_model(query18, 1⃣で再度手続きしたのですが、エラーが出てしまいました。別のカードで手続きしようと考えているので、御手数ですがもう一度URL送っていただくことは可能でしょうか。何度もすみません。よろしくお願いします): {"similarity": 0, "comment": "文章の内容、表現、単語が大きく異なるため類似度は0です。文章1は、課題発生の報告とスケジュール調整の依頼をしています。文章2は、手続きにおけるエラー報告とURL再送の依頼をしています。"}
# similarity_assessment_model(query18, 入金の際にエラーになってしまったため、もう一度URLの送信お願いします。): {"similarity": "0", "comment": "文章1は、課題ができていないことを説明し、今後の対応について記述しています。文章2は、入金エラーについてのみ記述しています。内容が大きく異なるため、類似度は0です。"}
# query19: 今ワイヤーフレームの修正をおこなっているのですが、「なめらかな〜」「素の唇を〜」「唇に〜」の部分が操作解説動画通りのフォントや文字の大きさにしているのに見本よりも字が濃く･太く見えるのですが、私の勘違いなんでしょうか、、、？,ありがとうございます。対応します,課題提出しました。よろしくお願いいたします🙇,☁️日次報告☁️今日は取り組めませんでした💦,こんなメッセージが出ました。
# similarity_assessment_model(query19, 今ワイヤーフレームの修正をおこなっているのですが、「なめらかな〜」「素の唇を〜」「唇に〜」の部分が操作解説動画通りのフォントや文字の大きさにしているのに見本よりも字が濃く･太く見えるのですが、私の勘違いなんでしょうか、、、？): {"similarity": 0, "comment": "文章1と文章2は内容、表現、単語の全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query19, ありがとうございます。対応します): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
#
# similarity_assessment_model(query19, 課題提出しました。よろしくお願いいたします🙇): {"similarity": 0, "comment": "文章1は謝罪文、文章2は提出報告文で、内容も表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query19, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 0, "comment": "文章1は謝罪文であり、文章2は報告書であり、内容も表現も大きく異なります。"}
# similarity_assessment_model(query19, こんなメッセージが出ました。): {"similarity":0,"comment":"文章の内容が全く異なり、単語や表現も共通点が見当たらないため。"}
# query20: すみません！治りました！,藤川様先ほど、質問のご連絡をさせていただいたのですが続けて本日の勉強成果をお伝えします！本日は課題の再提出とワイヤーフレーム課題の提出をしました！,井関さん宛動画視聴を始めてみました！目標設定したのでこれから頑張ります！,ホワイトボードですね？わかりました！,こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース
# similarity_assessment_model(query20, すみません！治りました！): {"similarity": 0, "comment": "文章1は受講申し込みに関する内容で、文章2は体調に関する内容で全く関係がありません。また、文章表現も異なります。"}
# similarity_assessment_model(query20, 藤川様先ほど、質問のご連絡をさせていただいたのですが続けて本日の勉強成果をお伝えします！本日は課題の再提出とワイヤーフレーム課題の提出をしました！): {"similarity": "0", "comment": "文章1は、感謝の言葉と受講申し込みに関する内容。文章2は、質問と課題提出に関する内容。内容、単語、表現全てが異なっているため、類似度は0です。"}
# similarity_assessment_model(query20, 井関さん宛動画視聴を始めてみました！目標設定したのでこれから頑張ります！): {"similarity": "0", "comment": "文章の内容が全く異なり、使われている単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query20, ホワイトボードですね？わかりました！): {"similarity": 0, "comment": "文章1は受講の申し込みに関する内容、文章2はホワイトボードに関する内容で、内容も文章表現も全く異なります。"}
# similarity_assessment_model(query20, こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース): {"similarity": 0, "comment": "文章1は感謝の気持ちを伝えて、受講申し込みをしたい旨を伝えています。一方、文章2は業務の報告で、内容が全く異なります。文章表現も異なります。"}

# %% [markdown]
# # **TF-IDF + Annoy (Model 3)**

# %%
# !pip install scikit-learn annoy jsonlines --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for annoy (setup.py) ... done

# %% [markdown]
# With category

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from annoy import AnnoyIndex
import jsonlines
import numpy as np
import random
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Step 1: Load your dataset (output_categories.jsonl)
with jsonlines.open('output_with_categories_1107.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer-category pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']} Category: {pair['category']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]
categories = [pair['category'] for pair in qa_pairs]

# Step 3: Initialize the TF-IDF Vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Convert the documents to TF-IDF vectors
tfidf_matrix = vectorizer.fit_transform(documents).toarray()  # Convert to numpy array

# Step 4: Initialize the ANNoy index
dim = tfidf_matrix.shape[1]  # Dimensionality of the vectors (number of features)
annoy_index = AnnoyIndex(dim, 'angular')  # 'angular' is cosine similarity equivalent

# Step 5: Add the TF-IDF vectors to the ANNoy index
for i, vec in enumerate(tfidf_matrix):
    annoy_index.add_item(i, vec)

# Build the index (this step can take a while depending on the number of documents)
annoy_index.build(10)  # 10 trees is a good trade-off for speed and accuracy

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 6: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Convert the query to a TF-IDF vector
    query_tfidf = vectorizer.transform([f"Question: {query}"]).toarray()

    # Get the nearest neighbors from ANNoy
    nearest_neighbors = annoy_index.get_nns_by_vector(query_tfidf[0], top_k, include_distances=False)

    # Return the most similar questions
    closest_questions = [questions[i] for i in nearest_neighbors]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Evaluate the system with 20 selected questions using TF-IDF and ANNoy
print("Evaluating using TF-IDF and ANNoy:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# Evaluating using TF-IDF and ANNoy:
# query1: こんにちは。何度もすみません。canvaの使い方でお伺いしたいのですがLINEでも可能でしょうか？,何度もすみません。ドコモメールで再度登録してみたらできました🙇💦,1⃣で再度手続きしたのですが、エラーが出てしまいました。別のカードで手続きしようと考えているので、御手数ですがもう一度URL送っていただくことは可能でしょうか。何度もすみません。よろしくお願いします,こんにちは！よろしくお願いします！,こんにちは！事前の説明でプレミアムプロのアプリを使用するとのことだったんですけど購入しておいた方がいいですか？？
# similarity_assessment_model(query1, こんにちは。何度もすみません。canvaの使い方でお伺いしたいのですがLINEでも可能でしょうか？): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
#
# similarity_assessment_model(query1, 何度もすみません。ドコモメールで再度登録してみたらできました🙇💦): {"similarity": 0, "comment": "文章1はcanvaの使い方に関する質問で、文章2はドコモメールの登録に関する内容であり、内容が全く異なります。また、文章表現も大きく異なっています。"}
# similarity_assessment_model(query1, 1⃣で再度手続きしたのですが、エラーが出てしまいました。別のカードで手続きしようと考えているので、御手数ですがもう一度URL送っていただくことは可能でしょうか。何度もすみません。よろしくお願いします): {"similarity": "3", "comment": "文章1はcanvaの使い方について質問しているが、文章2は手続きに関するエラーについて質問しているため、大まかな内容は異なっている。しかし、どちらも丁寧な表現で、何度もすみませんという言葉が使われているため、文章表現は類似している。"}
# similarity_assessment_model(query1, こんにちは！よろしくお願いします！): {"similarity": 0, "comment": "文章1はcanvaの使い方について質問しているが、文章2は挨拶のみであり、内容が異なる。また、文章表現も異なる。"}
# similarity_assessment_model(query1, こんにちは！事前の説明でプレミアムプロのアプリを使用するとのことだったんですけど購入しておいた方がいいですか？？): {"similarity":0,"comment":"文章の内容、表現、単語が全て異なります。"}
# query2: お世話になっております。Week5-1の課題を提出しました,Week5-1の課題を提出しました。,week 5-1の課題を提出しました。,week5-3 課題を提出しました,4-4、5-1の課題を提出しました。よろしくお願いいたします。
# similarity_assessment_model(query2, お世話になっております。Week5-1の課題を提出しました): {"similarity": 4, "comment": "文章の大まかな内容は同じですが、文章2は丁寧な表現が使われています。"}
# similarity_assessment_model(query2, Week5-1の課題を提出しました。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章であるため、類似度は5です。"}
# similarity_assessment_model(query2, week 5-1の課題を提出しました。): {"similarity": 4, "comment": "文章の大まかな内容は同じで、課題提出という内容である。細かい内容では、Weekとweekの表記ゆれがあるものの、内容はほぼ同じである。文章表現はほぼ同じである。"}
# similarity_assessment_model(query2, week5-3 課題を提出しました): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり（課題番号が異なる）、文章表現は類似している。"}
# similarity_assessment_model(query2, 4-4、5-1の課題を提出しました。よろしくお願いいたします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出した課題の番号）が異なっており、文章表現も異なっているため、3と評価しました。"}
# query3: あと、質問なのですが全てのイベント参加の時はZoomの名前はニックネームにした方が良いのでしょうか？,あと、2-3の添削もしてもらったので明日はそれから始めます！,夜中にすみません、質問です🙇‍♀️1番予約出来るところで11/18にバナートレース自習のイベントを予約してみました。慣れたいので、自分に余裕がある場合、続けてイベントに参加しても大丈夫でしょうか？？あんまり日にちが近いと意味が無いなどありますか？？あと、任意課題で作ったバナーを添削して頂きたい時は、勉強会の予約は、どれぐらい日にちを開けて予約すればいいでしょうか？？提出できるのが、午前中とかだったら、次の日の午後とかがいいでしょうか？？,【その他】,week1の課題を提出しました
# similarity_assessment_model(query3, あと、質問なのですが全てのイベント参加の時はZoomの名前はニックネームにした方が良いのでしょうか？): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query3, あと、2-3の添削もしてもらったので明日はそれから始めます！): {"similarity": 0, "comment": "文章1はイベント参加時のZoomの名前について質問しており、文章2は添削を受けて明日から始めることを伝えています。内容や表現が大きく異なるため類似度は0です。"}
# similarity_assessment_model(query3, 夜中にすみません、質問です🙇‍♀️1番予約出来るところで11/18にバナートレース自習のイベントを予約してみました。慣れたいので、自分に余裕がある場合、続けてイベントに参加しても大丈夫でしょうか？？あんまり日にちが近いと意味が無いなどありますか？？あと、任意課題で作ったバナーを添削して頂きたい時は、勉強会の予約は、どれぐらい日にちを開けて予約すればいいでしょうか？？提出できるのが、午前中とかだったら、次の日の午後とかがいいでしょうか？？): {"similarity": 2, "comment": "文章1はZoomのニックネームに関する質問、文章2はイベント参加に関する質問です。文章の内容は異なりますが、イベント参加、質問という単語が共通して使われているため、2としました。"}
# similarity_assessment_model(query3, 【その他】): {"similarity":0,"comment":"文章1はイベント参加時のZoomのニックネームに関する質問で、文章2は「その他」というタイトルのみであり、内容が全く異なるため0です。"}
# similarity_assessment_model(query3, week1の課題を提出しました): {"similarity": 0, "comment": "文章1と文章2は全く異なる内容であり、文章表現も単語も異なります。"}
# query4: ご連絡ありがとうございます。会社に勤めているので、自宅に帰ったら確認させていただきます。よろしくお願いいたします。,課題を提出しました。よろしくお願いいたします,課題提出しました。よろしくお願いいたします🙇,5-3、6-2、6-3、6-4課題完了いたしました。よろしくお願いいたします。,4-4、5-1の課題を提出しました。よろしくお願いいたします。
# similarity_assessment_model(query4, ご連絡ありがとうございます。会社に勤めているので、自宅に帰ったら確認させていただきます。よろしくお願いいたします。): {"similarity": "2", "comment": "文章の内容は大きく異なるが、文末に「よろしくお願いいたします」が使われているため、単語が似通っていると言える。"}
# similarity_assessment_model(query4, 課題を提出しました。よろしくお願いいたします): {"similarity":4,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現は類似しているため。"}
# similarity_assessment_model(query4, 課題提出しました。よろしくお願いいたします🙇): {"similarity": "4", "comment": "文章1と文章2はどちらも依頼やお願いをしていることがわかります。文章表現も似ていますが、文章2では「課題提出しました」という具体的な内容が含まれているため、細かい内容が異なります。"}
# similarity_assessment_model(query4, 5-3、6-2、6-3、6-4課題完了いたしました。よろしくお願いいたします。): {"similarity": 1, "comment": "文章1は単に挨拶であり、文章2は課題完了の報告です。内容は大きく異なりますが、文章表現が似ているため、1としました。"}
# similarity_assessment_model(query4, 4-4、5-1の課題を提出しました。よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現は異なる。文章1では単に依頼をしているが、文章2では具体的な課題提出を報告している。文章表現も、文章1は簡潔なお願いだが、文章2は課題番号を明記している点が異なる。"}
# query5: どうでしょ？,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました,week6-3, 6-4 課題提出しました。
# similarity_assessment_model(query5, どうでしょ？): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query5, 【その他】): {"similarity": 0, "comment": "文章1と文章2は内容、表現、単語がすべて異なっているため、類似度は0です。"}
# similarity_assessment_model(query5, week1の課題を提出しました): {"similarity": 0, "comment": "文章の内容が全く異なっており、単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query5, Week8  8-4の課題を提出しました): {"similarity":0,"comment":"文章の内容が異なり、単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query5, week6-3, 6-4 課題提出しました。): {"similarity": 0, "comment": "文章1と文章2は内容も表現も全く異なるため、類似度は0です。"}
# query6: 谷津さん、こんばんわ。遅くに失礼いたします。▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・昨日ゆっくり休みましたので本日1-3の動画視聴完了、実践もおおまかなところまで完了しました。明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します。引き続き、宜しくお願いします🙂,谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・バナートレース初級編の桜まつりの画像をトレース完了いたしました!引き続き明日も中級編をトレースします🙂お疲れ様でした。,谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。,谷津さん▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-2　動画視聴と課題は別日に提出積みですので、1-3　動画視聴し、途中まで実践に取り組んでいます。しかし、動画と実際の私のcanvaアカウントの表示が異なるため、調べながら取り組んでいるため時間を要しています。。。スケジュールの 11月7日提出できるよう取り組みます。,ありがとうございます。引き続き、宜しくお願いします。
# similarity_assessment_model(query6, 谷津さん、こんばんわ。遅くに失礼いたします。▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・昨日ゆっくり休みましたので本日1-3の動画視聴完了、実践もおおまかなところまで完了しました。明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します。引き続き、宜しくお願いします🙂): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query6, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・バナートレース初級編の桜まつりの画像をトレース完了いたしました!引き続き明日も中級編をトレースします🙂お疲れ様でした。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なり、文章表現も異なっている。文章1では動画視聴と実践について触れている一方、文章2ではバナートレースについて触れている。また、文章表現も、文章1では丁寧な表現が多く、文章2ではよりカジュアルな表現が多い。"}
# similarity_assessment_model(query6, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容は異なっています。文章表現は若干異なります。"}
# similarity_assessment_model(query6, 谷津さん▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-2　動画視聴と課題は別日に提出積みですので、1-3　動画視聴し、途中まで実践に取り組んでいます。しかし、動画と実際の私のcanvaアカウントの表示が異なるため、調べながら取り組んでいるため時間を要しています。。。スケジュールの 11月7日提出できるよう取り組みます。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1では、動画視聴完了、実践完了と具体的な内容が記載されている一方で、文章2では、動画視聴と課題提出が別日であること、canvaアカウントとの差異による時間のかかりなどが記載されている。また、文章表現も、文章1は丁寧な表現、文章2は簡潔な表現となっている。"}
# similarity_assessment_model(query6, ありがとうございます。引き続き、宜しくお願いします。): {"similarity": 1, "comment": "文章1の内容は、業務の進捗報告であり、文章2は感謝の言葉と依頼のみであるため、内容的には大きく異なります。しかし、文章表現や単語の選び方においては、丁寧な口調で、絵文字を使用している点などが似ているため、1と評価しました。"}
# query7: 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。,今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。,今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。,【その他】,week1の課題を提出しました
# similarity_assessment_model(query7, 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章であるため、類似度は5です。"}
#
# similarity_assessment_model(query7, 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
#
# similarity_assessment_model(query7, 今4-2のクラウドワークスの会員登録をして、プロフィールの記載をしようと思ったのですが自己PRが何を書けばいいかわかりません。特に美大を出てる訳でもないので、経歴とかなんて書けばいいか、業務内容……何も無い状態だと何を書けばいいか分からなくなってしまいます。): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
#
# similarity_assessment_model(query7, 【その他】): {"similarity":0,"comment":"文章1はクラウドワークスの自己PRについて悩んでいる内容で、文章2は単に「その他」という単語のみであり、内容が全く一致しません。そのため類似度は0です。"}
# similarity_assessment_model(query7, week1の課題を提出しました): {"similarity": 0, "comment": "文章1はクラウドワークスのプロフィール作成に関する悩みを述べていますが、文章2はweek1の課題提出についてのみ触れており、内容が全く異なります。文章表現や単語も異なるため、類似度は0です。"}
# query8: カリキュラム4-1のREZUMEに掲載するデザインは今の段階で何を載せればいいですか？,こんにちは、カリキュラム4-1について、教えてください。任意課題でバナーを作成し、それをポートフォリオとして掲載しようと考えています。RESUMEのworksにこれのみ、登録すれば良いのでしょうか。,いつもお世話になっております。カリキュラム4-1について質問です🙇‍♀️②でResumeにポートフォリオとなるデザインを掲載するとありますが、デザインは自分で作成したバナーとかで良いのでしょうか？作成したバナーは勉強会で見ていただけたりしますでしょうか？,【その他】,week1の課題を提出しました
# similarity_assessment_model(query8, カリキュラム4-1のREZUMEに掲載するデザインは今の段階で何を載せればいいですか？): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query8, こんにちは、カリキュラム4-1について、教えてください。任意課題でバナーを作成し、それをポートフォリオとして掲載しようと考えています。RESUMEのworksにこれのみ、登録すれば良いのでしょうか。): {"similarity": 3, "comment": "文章1と文章2は、どちらもカリキュラム4-1についての質問であるという点で、大まかな内容は類似しています。しかし、文章1は具体的にREZUMEに掲載するデザインについて質問しているのに対し、文章2はバナー作成の任意課題について質問しており、細かい内容は異なります。また、文章表現も「掲載するデザイン」と「ポートフォリオとして掲載」のように異なる表現が使われています。そのため、類似度は3と判断しました。"}
# similarity_assessment_model(query8, いつもお世話になっております。カリキュラム4-1について質問です🙇‍♀️②でResumeにポートフォリオとなるデザインを掲載するとありますが、デザインは自分で作成したバナーとかで良いのでしょうか？作成したバナーは勉強会で見ていただけたりしますでしょうか？): {"similarity": 4, "comment": "文章1と文章2は、カリキュラム4-1のREZUMEに載せるデザインに関する質問という点で内容は類似しています。文章2では、具体的な質問として「デザインは自分で作成したバナーとかで良いのでしょうか？」「作成したバナーは勉強会で見ていただけたりしますでしょうか？」という点が挙げられており、文章1ではそれらに触れていません。しかし、文章表現は類似しており、特に「カリキュラム4-1」や「REZUME」といった単語が共通していることから、4と評価しました。"}
# similarity_assessment_model(query8, 【その他】): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なっているため、類似度は0です。"}
# similarity_assessment_model(query8, week1の課題を提出しました): {"similarity": 0, "comment": "文章の内容が全く異なっており、文章表現や単語も異なります。"}
# query9: http://chatgpt.com/share/66fbf71e-9370-8013-87bb-c8b49dabd3b5,2-2提出しますhttps://chatgpt.com/share/67162370-76fc-8013-9fab-fb6e4b8b9a7c,大西知里
# https://chatgpt.com/share/670f2b64-1684-8013-bca2-52a4900846ba   1-4-③,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 明日の勉強会はこのプロンプトについて教えていただきたいと思っています。よろしくお願いいたしました。https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f,week8は終わりました
# similarity_assessment_model(query9, http://chatgpt.com/share/66fbf71e-9370-8013-87bb-c8b49dabd3b5): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
# similarity_assessment_model(query9, 2-2提出しますhttps://chatgpt.com/share/67162370-76fc-8013-9fab-fb6e4b8b9a7c): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現も異なっている。文章1では、登場人物の行動や状況が詳しく描写されている一方、文章2では、登場人物の心情や考えが中心に描写されている。また、文章表現においても、文章1では、比喩や擬人化などの表現が用いられている一方で、文章2では、より簡潔な表現が用いられている。"}
# similarity_assessment_model(query9, 大西知里
# https://chatgpt.com/share/670f2b64-1684-8013-bca2-52a4900846ba   1-4-③): {"similarity": 3, "comment": "文章1と文章2はどちらも大西知里選手の話題について触れていますが、文章1は彼女の過去の活躍について言及している一方、文章2は現在について触れています。細かい内容に違いが見られる一方で、文章表現はどちらも簡潔で事実を伝えるスタイルであるため、3と評価しました。"}
# similarity_assessment_model(query9, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 明日の勉強会はこのプロンプトについて教えていただきたいと思っています。よろしくお願いいたしました。https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f): {"similarity": 0, "comment": "文章1はプロンプトの例で、文章2は明日の勉強会で質問したい内容についてです。内容は全く異なり、文章表現も異なります。"}
# similarity_assessment_model(query9, week8は終わりました): {"similarity": 0, "comment": "文章1は「週8の働き方」に関する内容で、文章2は「週8が終わった」という内容で、全く異なる内容です。文章表現も単語も全く異なっています。"}
# query10: 5-1、5-2、5-3、6-1課題提出しました。,2-1課題提出しました,6-1課題提出しました。現在、自身の業務がひっ迫中なので課題に取組む時間が取れない状況ですが隙間時間に少しずつ進めていきます。AI特別演習もスタートしたいのですがとても出来そうにないので、受講期間延長などで取り組みたいと考えています。,【その他】,week1の課題を提出しました
# similarity_assessment_model(query10, 5-1、5-2、5-3、6-1課題提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっているため3と評価しました。文章1では課題提出した課題が1つのみであるのに対し、文章2では複数の課題が提出されている点が異なります。また、文章1では課題番号が省略されているのに対し、文章2では課題番号が明記されている点も異なります。"}
# similarity_assessment_model(query10, 2-1課題提出しました): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query10, 6-1課題提出しました。現在、自身の業務がひっ迫中なので課題に取組む時間が取れない状況ですが隙間時間に少しずつ進めていきます。AI特別演習もスタートしたいのですがとても出来そうにないので、受講期間延長などで取り組みたいと考えています。): {"similarity": 1, "comment": "文章1は課題提出の報告のみであり、文章2は課題提出の報告に加え、今後の課題への取り組み方について言及しています。文章表現は類似していますが、内容は大きく異なります。"}
# similarity_assessment_model(query10, 【その他】): {"similarity": 0, "comment": "文章の内容が異なっており、文章表現や単語も異なっているため。"}
# similarity_assessment_model(query10, week1の課題を提出しました): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており（文章1は提出した課題の番号が記載されているが、文章2は提出した課題がweek1の課題であることが記載されている）、文章表現は類似している。"}
# query11: すみませんすぐ入ります,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました,week6-3, 6-4 課題提出しました。
# similarity_assessment_model(query11, すみませんすぐ入ります): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
#
# similarity_assessment_model(query11, 【その他】): {"similarity":0,"comment":"文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query11, week1の課題を提出しました): {"similarity":0,"comment":"文章の内容、表現、単語全てが異なるため、類似度は0です。"}
#
# similarity_assessment_model(query11, Week8  8-4の課題を提出しました): {"similarity": 0, "comment": "文章の内容が全く異なっており、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query11, week6-3, 6-4 課題提出しました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# query12: 谷津さん▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-2　動画視聴と課題は別日に提出積みですので、1-3　動画視聴し、途中まで実践に取り組んでいます。しかし、動画と実際の私のcanvaアカウントの表示が異なるため、調べながら取り組んでいるため時間を要しています。。。スケジュールの 11月7日提出できるよう取り組みます。,谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・バナートレース初級編の桜まつりの画像をトレース完了いたしました!引き続き明日も中級編をトレースします🙂お疲れ様でした。,谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。,谷津さん、こんばんわ。遅くに失礼いたします。▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・昨日ゆっくり休みましたので本日1-3の動画視聴完了、実践もおおまかなところまで完了しました。明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します。引き続き、宜しくお願いします🙂,こちらこそありがとうございました！確認メールの件、承知しました。勉強会使わせていただきます(にっこり)
# similarity_assessment_model(query12, 谷津さん▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-2　動画視聴と課題は別日に提出積みですので、1-3　動画視聴し、途中まで実践に取り組んでいます。しかし、動画と実際の私のcanvaアカウントの表示が異なるため、調べながら取り組んでいるため時間を要しています。。。スケジュールの 11月7日提出できるよう取り組みます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query12, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・バナートレース初級編の桜まつりの画像をトレース完了いたしました!引き続き明日も中級編をトレースします🙂お疲れ様でした。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（日々の取り組み報告）が、細かい内容は異なり（文章1は動画視聴と課題提出、文章2はバナートレース）、文章表現も異なっているため3としました。"}
# similarity_assessment_model(query12, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。): {"similarity": "3", "comment": "文章1と文章2は、どちらも谷津さんへの日々の取り組み報告という共通点がある。文章1は課題に取り組んでいる途中であることを報告しており、文章2は課題を提出したことを報告している。そのため、大まかな内容は類似していると言える。しかし、細かい内容は異なっており、文章表現も異なっている。文章1は課題に取り組む過程の詳細が書かれているのに対し、文章2は課題提出完了を簡潔に報告している。また、文章1は「〜ため時間を要しています」など、個人的な状況や感情が表現されているのに対し、文章2は客観的な報告のみが行われている。これらのことから、文章1と文章2は類似度3と判断した。"}
# similarity_assessment_model(query12, 谷津さん、こんばんわ。遅くに失礼いたします。▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・昨日ゆっくり休みましたので本日1-3の動画視聴完了、実践もおおまかなところまで完了しました。明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します。引き続き、宜しくお願いします🙂): {"similarity": "4", "comment": "文章の大まかな内容は類似しており、日々の取り組み報告という文脈は共通している。細かい内容としては、文章1では課題提出が11月7日であることが明記されているのに対し、文章2では明記されていない。また、文章表現も類似しているが、文章1では「動画と実際の私のcanvaアカウントの表示が異なるため、調べながら取り組んでいるため時間を要しています」という具体的な記述がある一方、文章2では「明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します」という記述があり、表現が異なる。そのため、類似度は4とした。"}
# similarity_assessment_model(query12, こちらこそありがとうございました！確認メールの件、承知しました。勉強会使わせていただきます(にっこり)): {"similarity": 0, "comment": "文章1は業務報告、文章2は個人的なやり取りであり、内容・表現ともに全く異なるため"}
# query13: week3の残りの課題も提出しました。,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました,week6-3, 6-4 課題提出しました。
# similarity_assessment_model(query13, week3の残りの課題も提出しました。): {"similarity":5,"comment":"文章1と文章2は完全に同一であるため、類似度は5です。"}
# similarity_assessment_model(query13, 【その他】): {"similarity": 0, "comment": "文章1は課題提出に関する内容で、文章2は「その他」という短い言葉のみです。内容や文章表現、単語も全く異なっています。"}
# similarity_assessment_model(query13, week1の課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出した週）が異なっており、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query13, Week8  8-4の課題を提出しました): {"similarity": "2", "comment": "文章1と文章2は、どちらも課題提出に関する内容ですが、具体的な内容が異なります。また、文章表現も異なるため、2と評価しました。"}
# similarity_assessment_model(query13, week6-3, 6-4 課題提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なる。文章1は「week3の残りの課題」と漠然とした表現であるのに対し、文章2は「week6-3, 6-4」と具体的な課題番号が挙げられている。また、文章1は「提出しました」と過去形で書かれているのに対し、文章2は「課題提出しました」と課題という名詞を明示的に使用している。"}
# query14: 6-2、6-4についてですが1つの原稿に繋げる作業は自分でコピペして1つに繋げるという事でよろしいでしょうか？chat GPTに1つにつなげて欲しいとお願いしたら、お願いの仕方が悪かったのか、省略した形で繋げてくれました。,ありがとうございました。Chat GPTのプロンプトを共有する時に出るエラーです。week6以降、全然共有できていない状況です。よろしくお願いします。,添削ありがとうございます。Chat GPTのリンクですが、エラーメッセージが出て、全く共有できないでいます。来週火曜日まで講義が詰まっているので、水曜日以降になりますが、提出させていただきます。宜しくお願い致します。,ありがとうございます！確認させていただきます！もう一つ確認なのですが、現在WEBデザイン編week2-3をやっているのですが三人のペルソナはカフェのターゲットにそった3名で完全オリジナルで自分で考えてワークシートに記載するということでよろしいですか？よろしくお願いいたします。,- 実践課題に取り組んだら、プロンプトをワークシートに記載してHerTech公式アカウントに提出してください🙌    - プロンプトの提出方法は、[こちらの記事](https://note.com/rorosuke/n/n150d2737c451)を参考にして、Chat GPTとの会話のURLをワークシートに記載してください。とありますが、ワークシートとは何でしょうか？どこにありますか？
# similarity_assessment_model(query14, 6-2、6-4についてですが1つの原稿に繋げる作業は自分でコピペして1つに繋げるという事でよろしいでしょうか？chat GPTに1つにつなげて欲しいとお願いしたら、お願いの仕方が悪かったのか、省略した形で繋げてくれました。): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
#
# similarity_assessment_model(query14, ありがとうございました。Chat GPTのプロンプトを共有する時に出るエラーです。week6以降、全然共有できていない状況です。よろしくお願いします。): {"similarity": 0, "comment": "文章1は、原稿の結合について質問しており、文章2はChatGPTのプロンプト共有に関する問題を報告しています。内容が全く異なり、文章表現も異なります。"}
# similarity_assessment_model(query14, 添削ありがとうございます。Chat GPTのリンクですが、エラーメッセージが出て、全く共有できないでいます。来週火曜日まで講義が詰まっているので、水曜日以降になりますが、提出させていただきます。宜しくお願い致します。): {"similarity": 0, "comment": "文章1は原稿の繋ぎ合わせについて質問しており、文章2はChatGPTのリンク共有について言及しています。内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query14, ありがとうございます！確認させていただきます！もう一つ確認なのですが、現在WEBデザイン編week2-3をやっているのですが三人のペルソナはカフェのターゲットにそった3名で完全オリジナルで自分で考えてワークシートに記載するということでよろしいですか？よろしくお願いいたします。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query14, - 実践課題に取り組んだら、プロンプトをワークシートに記載してHerTech公式アカウントに提出してください🙌    - プロンプトの提出方法は、[こちらの記事](https://note.com/rorosuke/n/n150d2737c451)を参考にして、Chat GPTとの会話のURLをワークシートに記載してください。とありますが、ワークシートとは何でしょうか？どこにありますか？): {"similarity": 0, "comment": "文章1はChatGPTで文章を繋げる作業について質問をしています。文章2は実践課題提出に関する質問をしています。文章の内容が異なっており、文章表現も異なります。"}
# query15: 3-1の実践課題をスプシに記載しました！（添削課題となっていない場合には報告不要ですか？）,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました,week6-3, 6-4 課題提出しました。
# similarity_assessment_model(query15, 3-1の実践課題をスプシに記載しました！（添削課題となっていない場合には報告不要ですか？）): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query15, 【その他】): {"similarity": 0, "comment": "文章の内容が全く異なっており、単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query15, week1の課題を提出しました): {"similarity": "3", "comment": "文章1は課題提出に関する具体的な内容が書かれており、文章2は一般的な課題提出の報告であるため、大まかな内容は類似していると言える。しかし、文章1では課題の種類や提出先などが明確に示されている一方、文章2では課題の種類や提出先などが不明確であるため、細かい内容は異なる。また、文章表現も異なる。"}
# similarity_assessment_model(query15, Week8  8-4の課題を提出しました): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、文内で使われている単語が似通っているため2としました。"}
#
# similarity_assessment_model(query15, week6-3, 6-4 課題提出しました。): {"similarity": 2, "comment": "文章1は実践課題の内容に関する質問を含んでいますが、文章2は単に課題提出を報告しています。文章の内容は異なりますが、課題提出に関する単語が使われているため、2と評価しました。"}
# query16: 谷津さん10/313-3の動画視聴をしました。figma提出課題の途中です。,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました,week6-3, 6-4 課題提出しました。
# similarity_assessment_model(query16, 谷津さん10/313-3の動画視聴をしました。figma提出課題の途中です。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query16, 【その他】): {"similarity": 0, "comment": "文章1はfigmaに関する内容で、文章2は内容が不明です。内容も表現も全く異なるため、類似度は0です。"}
# similarity_assessment_model(query16, week1の課題を提出しました): {"similarity": 2, "comment": "文章1はfigma提出課題に関する内容、文章2はweek1の課題提出に関する内容で、内容は異なります。しかし、どちらも課題に関する内容であり、単語も類似しているため2としました。"}
# similarity_assessment_model(query16, Week8  8-4の課題を提出しました): {"similarity": 2, "comment": "文章1はfigmaの課題について言及しているのに対し、文章2はWeek8の課題について言及しており、内容が異なります。しかし、どちらも課題提出に関する内容であるため、単語が似通っています。"}
#
# similarity_assessment_model(query16, week6-3, 6-4 課題提出しました。): {"similarity": 2, "comment": "文章1はfigmaの課題に関する動画視聴の報告と課題の進捗状況に関する記述、文章2は課題提出の報告となっています。文章の内容は異なりますが、課題に関する単語が含まれているため、2と評価しました。"}
# query17: 権限をリンクを知っている人にしています。,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました,week6-3, 6-4 課題提出しました。
# similarity_assessment_model(query17, 権限をリンクを知っている人にしています。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章であるため、類似度は5です。"}
# similarity_assessment_model(query17, 【その他】): {"similarity":0,"comment":"文章1と文章2は内容、表現、単語が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query17, week1の課題を提出しました): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なります。"}
# similarity_assessment_model(query17, Week8  8-4の課題を提出しました): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query17, week6-3, 6-4 課題提出しました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# query18: ありがとうございます。改めて選択させていただきました。よろしくお願いします！,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ありがとうございます！よろしくお願いします。,目標シートお送りします。よろしくお願いします。,すみません、ありがとうございます🙇‍♀️,11月の目標です。よろしくお願いします。
# similarity_assessment_model(query18, ありがとうございます。改めて選択させていただきました。よろしくお願いします！): {"similarity":5,"comment":"文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query18, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ありがとうございます！よろしくお願いします。): {"similarity": 1, "comment": "文章の内容は大きく異なり、感謝の言葉と依頼の言葉が含まれている点で類似している。しかし、文章表現や単語は異なる。"}
# similarity_assessment_model(query18, 目標シートお送りします。よろしくお願いします。): {"similarity": "2", "comment": "文章1は感謝の言葉とお願いが含まれているのに対し、文章2はファイルの送信とお願いのみが含まれているため、内容が異なります。しかし、どちらも依頼・お願いを目的とした文章であり、文末に「よろしくお願いします」が使われていることから、単語や文章表現が似通っているため2としました。"}
# similarity_assessment_model(query18, すみません、ありがとうございます🙇‍♀️): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なります。"}
#
# similarity_assessment_model(query18, 11月の目標です。よろしくお願いします。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
#
# query19: 谷津さんへ＋New Workを開いて、『カバー写真を登録』と『画像を挿入』をクリックしても何も反応がないです💦,谷津さんへRESUMEアプリでハーテックの課題で作成したものを掲載したいのですが、画像の貼り付け方が分かりません😭どうしたらいいですか？,【その他】,week1の課題を提出しました,Week8  8-4の課題を提出しました
# similarity_assessment_model(query19, 谷津さんへ＋New Workを開いて、『カバー写真を登録』と『画像を挿入』をクリックしても何も反応がないです💦): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query19, 谷津さんへRESUMEアプリでハーテックの課題で作成したものを掲載したいのですが、画像の貼り付け方が分かりません😭どうしたらいいですか？): {"similarity": 4, "comment": "文章1と文章2は、谷津さんへ宛てた画像アップロードに関する問い合わせという点で内容が類似しています。細かい内容としては、文章1は『カバー写真を登録』と『画像を挿入』という具体的な操作について言及している一方、文章2は「画像の貼り付け方」と抽象的に表現しています。文章表現はどちらもカジュアルな口調で、絵文字を使用している点で類似しています。そのため、類似度は4と評価しました。"}
# similarity_assessment_model(query19, 【その他】): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query19, week1の課題を提出しました): {"similarity":0,"comment":"文章1は、New Workの機能に関する質問で、文章2は課題提出の報告です。内容、表現、単語ともに全く異なるため、類似度は0です。"}
# similarity_assessment_model(query19, Week8  8-4の課題を提出しました): {"similarity": 0, "comment": "文章1は画像に関する問題を報告しており、文章2は課題提出の報告です。内容や単語、文章表現が全く異なるため0としました。"}
# query20: こんばんは。今日は遅くなりましたが2-3の課題を再提出しました。作っている時には気付かなかった誤字脱字がありましたので今後気を付けようと思います💦Canvaを使ってのトレースも見よう見まねですが練習しているところです。,中川さん今日は1-3の課題を再提出しました！(昨日は、1-4、2-1、2-2の動画視聴と2-2の課題を提出しました！),こんばんは！本日の成果をご報告します。・オリジナルバナー制作,こんばんは、お疲れ様です。実践課題8-3、8-4提出いたします。宜しくお願いします。,こんばんは、予約いれました。
# similarity_assessment_model(query20, こんばんは。今日は遅くなりましたが2-3の課題を再提出しました。作っている時には気付かなかった誤字脱字がありましたので今後気を付けようと思います💦Canvaを使ってのトレースも見よう見まねですが練習しているところです。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query20, 中川さん今日は1-3の課題を再提出しました！(昨日は、1-4、2-1、2-2の動画視聴と2-2の課題を提出しました！)): {"similarity": 2, "comment": "文章1は、Canvaを使ったトレースの練習について言及しており、文章2は動画視聴と課題提出について言及しているため、内容が異なります。しかし、文章1は「課題を再提出しました」という文言を使用しており、文章2も「課題を再提出しました」という文言を使用しているため、文内で使われている単語が似通っています。"}
# similarity_assessment_model(query20, こんばんは！本日の成果をご報告します。・オリジナルバナー制作): {"similarity": "1", "comment": "文章1は、課題の再提出とCanvaを使ったトレースの練習について報告している。一方、文章2はオリジナルバナー制作の報告のみであり、内容が大きく異なる。しかし、文章表現や単語は似通っているため、1点と評価しました。"}
# similarity_assessment_model(query20, こんばんは、お疲れ様です。実践課題8-3、8-4提出いたします。宜しくお願いします。): {"similarity": "3", "comment": "文章1はCanvaを使ったトレースの練習について言及しており、文章2は実践課題の提出についてのみ触れているため、細かい内容は異なります。しかし、どちらも課題提出に関する内容であり、文章表現も類似していることから、3と評価しました。"}
# similarity_assessment_model(query20, こんばんは、予約いれました。): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なります。"}

# %% [markdown]
# Without category

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from annoy import AnnoyIndex
import jsonlines
import numpy as np
import random
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Step 1: Load your dataset (qa_pairs_for_rag_1108.jsonl)
with jsonlines.open('qa_pairs_for_rag_1108.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]

# Step 3: Initialize the TF-IDF Vectorizer
vectorizer = TfidfVectorizer(stop_words='english')

# Convert the documents to TF-IDF vectors
tfidf_matrix = vectorizer.fit_transform(documents).toarray()  # Convert to numpy array

# Step 4: Initialize the ANNoy index
dim = tfidf_matrix.shape[1]  # Dimensionality of the vectors (number of features)
annoy_index = AnnoyIndex(dim, 'angular')  # 'angular' is cosine similarity equivalent

# Step 5: Add the TF-IDF vectors to the ANNoy index
for i, vec in enumerate(tfidf_matrix):
    annoy_index.add_item(i, vec)

# Build the index (this step can take a while depending on the number of documents)
annoy_index.build(10)  # 10 trees is a good trade-off for speed and accuracy

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 6: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Convert the query to a TF-IDF vector
    query_tfidf = vectorizer.transform([f"Question: {query}"]).toarray()

    # Get the nearest neighbors from ANNoy
    nearest_neighbors = annoy_index.get_nns_by_vector(query_tfidf[0], top_k, include_distances=False)

    # Return the most similar questions
    closest_questions = [questions[i] for i in nearest_neighbors]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Evaluate the system with 20 selected questions using TF-IDF and ANNoy
print("Evaluating using TF-IDF and ANNoy:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# Evaluating using TF-IDF and ANNoy:
# query1: 杉本さん先日はお時間頂きありがとうございましたあれからまた余裕が持てず、そのままになってしまいました。頂いた情報を活用出来るよう、何とか無駄にしないよう頑張りたい、、、お世話かけますが、宜しくお願い致します。,課題提出の報告w6-4 7-1終了致しました。宜しくお願い致します。,課題提出の報告w6-1終了致しました。宜しくお願い致します。,課題提出の報告w6-2終了致しました。宜しくお願い致します。,課題提出の報告w5-1終了致しました。宜しくお願い致します。
# similarity_assessment_model(query1, 杉本さん先日はお時間頂きありがとうございましたあれからまた余裕が持てず、そのままになってしまいました。頂いた情報を活用出来るよう、何とか無駄にしないよう頑張りたい、、、お世話かけますが、宜しくお願い致します。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query1, 課題提出の報告w6-4 7-1終了致しました。宜しくお願い致します。): {"similarity": 0, "comment": "文章1は感謝の気持ちを伝える内容で、文章2は報告の内容です。内容、文章表現、単語全てが異なるため0としました。"}
# similarity_assessment_model(query1, 課題提出の報告w6-1終了致しました。宜しくお願い致します。): {"similarity": 0, "comment": "文章1は、感謝の気持ちを表明し、今後の活動に対する意欲を示す内容です。文章2は、業務報告の簡潔な内容です。内容、表現、単語のいずれも類似性がありません。"}
# similarity_assessment_model(query1, 課題提出の報告w6-2終了致しました。宜しくお願い致します。): {"similarity": 0, "comment": "文章1は、杉本さんへの感謝と今後の意気込みを述べています。文章2は、課題提出の報告のみで、内容は全く違います。文章表現も、文章1は丁寧な口調で、文章2は簡潔な口調です。"}
# similarity_assessment_model(query1, 課題提出の報告w5-1終了致しました。宜しくお願い致します。): {"similarity": 0, "comment": "文章1は、感謝の気持ちを表明し、今後の協力関係を期待する内容。一方、文章2は、業務報告の簡潔な内容。内容は全く異なり、文章表現も異なる。"}
# query2: 島戸さんへ＜一日報告＞今日は体調が悪くて課題がすすめられなかったです。目標シートは入力しました！,島戸さんへ＜一日報告＞今日は1-1と1-2の動画視聴をしました！Canvaも登録しました！はじめようとしたところでPCの設定に手こずって時間をくってしまい、予定の1-2の課題提出までいきませんでしたので、明日1-2の課題提出に向けて作業をすすめるのと、スケジュールリスト入力を行いたいと思います！,島戸さんへ＜一日報告＞体調が悪くて休んでた分を取り返す為に今日長めに時間を取ったので、課題を進めることが出来ました！明日以降、2-3のバナー制作演習をすすめていきます2-2のバナーのデザイン制作の課題提出したのですが、間違えて2-3の制作演習のところに提出してしまったので、訂正してもらうことは可能でしょうか？？,ありがとうございます！,4-4 実践課題提出しました。
# similarity_assessment_model(query2, 島戸さんへ＜一日報告＞今日は体調が悪くて課題がすすめられなかったです。目標シートは入力しました！): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, 島戸さんへ＜一日報告＞今日は1-1と1-2の動画視聴をしました！Canvaも登録しました！はじめようとしたところでPCの設定に手こずって時間をくってしまい、予定の1-2の課題提出までいきませんでしたので、明日1-2の課題提出に向けて作業をすすめるのと、スケジュールリスト入力を行いたいと思います！): {"similarity": 3, "comment": "文章の大まかな内容は類似している（日々の進捗報告）が、細かい内容は異なっており（文章1は体調不良、文章2は動画視聴）、文章表現も異なっている。"}
# similarity_assessment_model(query2, 島戸さんへ＜一日報告＞体調が悪くて休んでた分を取り返す為に今日長めに時間を取ったので、課題を進めることが出来ました！明日以降、2-3のバナー制作演習をすすめていきます2-2のバナーのデザイン制作の課題提出したのですが、間違えて2-3の制作演習のところに提出してしまったので、訂正してもらうことは可能でしょうか？？): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なっています。文章1は体調が悪く課題が進められなかったという報告のみですが、文章2は体調が悪かった分を取り返すために課題を進めたという内容になっています。文章表現も、文章1は簡潔な報告文ですが、文章2は詳細な報告と質問が含まれているため、異なります。"}
# similarity_assessment_model(query2, ありがとうございます！): {"similarity": 0, "comment": "文章1は業務報告の内容で、文章2は感謝の言葉です。内容も文章表現も全く異なるため、類似度は0です。"}
# similarity_assessment_model(query2, 4-4 実践課題提出しました。): {"similarity": 0, "comment": "文章1は体調不良による課題の遅延報告、文章2は課題提出の報告であり、内容が異なります。また、文章表現や単語も大きく異なります。"}
# query3: 井関さん、こんにちは！2-1、2-2の動画視聴と課題提出が終わりました！,井関さん、こんにちは！3-3実践課題の提出終わりました！,井関さん、こんにちは！1-2、1-3、1-4の動画視聴と課題提出終わりました！,井関さん、こんばんは！2-3実践課題、3-1、3-2の動画視聴と実践課題の提出終わりました！,【井関さん】「今日取り組んだこと」3-1から3-2まで受講しました。添削していただいた実践課題2つ(1-3と2-2)も修正して再提出しました。
# similarity_assessment_model(query3, 井関さん、こんにちは！2-1、2-2の動画視聴と課題提出が終わりました！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query3, 井関さん、こんにちは！3-3実践課題の提出終わりました！): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容は異なり（動画視聴の有無、課題番号）、文章表現も異なっているため3としました。"}
# similarity_assessment_model(query3, 井関さん、こんにちは！1-2、1-3、1-4の動画視聴と課題提出終わりました！): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容（動画の番号）が異なっている。文章表現は類似している。"}
# similarity_assessment_model(query3, 井関さん、こんばんは！2-3実践課題、3-1、3-2の動画視聴と実践課題の提出終わりました！): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、動画視聴と課題提出という共通の行為が含まれています。しかし、具体的な内容は異なっており、文章表現も若干異なります。そのため、類似度は4としました。"}
# similarity_assessment_model(query3, 【井関さん】「今日取り組んだこと」3-1から3-2まで受講しました。添削していただいた実践課題2つ(1-3と2-2)も修正して再提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なる。文章1では動画視聴と課題提出が完了したことを報告しているのに対し、文章2では受講した内容と課題の修正について報告している。また、文章表現も「こんにちは！」や「終わりました！」など、文章1の方がカジュアルな表現になっているのに対し、文章2はよりフォーマルな表現になっている。"}
# query4: このURLから入り直してみます！,ありがとうございます！,4-4 実践課題提出しました。,4-2 実践課題提出しました。,5-2 実践課題提出しました
# similarity_assessment_model(query4, このURLから入り直してみます！): {"similarity":5,"comment":"文章1と文章2は完全に一致するため、類似度は5です。"}
# similarity_assessment_model(query4, ありがとうございます！): {"similarity":0,"comment":"文章の内容が異なり、文章表現も単語も異なります。"}
# similarity_assessment_model(query4, 4-4 実践課題提出しました。): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query4, 4-2 実践課題提出しました。): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現も異なっています。"}
# similarity_assessment_model(query4, 5-2 実践課題提出しました): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なるため"}
# query5: 谷津さま体調崩しており、学習ができていませんでした…今日はFigmaと仲良くなろう会に参加しました！,ありがとうございます！,4-4 実践課題提出しました。,4-2 実践課題提出しました。,5-2 実践課題提出しました
# similarity_assessment_model(query5, 谷津さま体調崩しており、学習ができていませんでした…今日はFigmaと仲良くなろう会に参加しました！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query5, ありがとうございます！): {"similarity": 0, "comment": "文章1の内容は体調不良とFigmaに関するものであり、文章2は感謝の言葉のみで内容が全く異なります。文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query5, 4-4 実践課題提出しました。): {"similarity":0,"comment":"文章1の内容は体調不良とFigmaの学習について、文章2の内容は課題提出についてと、全く異なる内容です。また文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query5, 4-2 実践課題提出しました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query5, 5-2 実践課題提出しました): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっているため0と評価しました。"}
# query6: 【日次報告】取り組みなし,☁️日次報告☁️今日は取り組めませんでした💦,☁️日次報告☁️今日は取り組めませんでした💦,☂️日次報告☂️今日は課題4-4を取り組みました。よろしくお願いします。,☂️日次報告☂️今日は課題4-4を取り組みました。よろしくお願いします。
# similarity_assessment_model(query6, 【日次報告】取り組みなし): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query6, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": "3", "comment": "文章の大まかな内容は類似している（日次報告の内容について記述している）が、細かい内容は異なっており（文章1は取り組みなし、文章2は取り組めなかった）、文章表現も異なっている（文章1は簡潔、文章2は絵文字を使用している）"}
# similarity_assessment_model(query6, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": "3", "comment": "文章の大まかな内容は類似している（日次報告の内容を伝えている）が、細かい内容が異なり（文章1は取り組みなし、文章2は取り組めなかった）、文章表現も異なっている（文章1は簡潔、文章2は絵文字を使用している）ため3とした。"}
# similarity_assessment_model(query6, ☂️日次報告☂️今日は課題4-4を取り組みました。よろしくお願いします。): {"similarity": 1, "comment": "文章の内容は異なっていますが、文章表現や文章の雰囲気が似ています。文章1は簡潔で事務的な報告書のような文章で、文章2はより親しみやすく、感情的な表現を含んでいます。"}
# similarity_assessment_model(query6, ☂️日次報告☂️今日は課題4-4を取り組みました。よろしくお願いします。): {"similarity": "1", "comment": "文章1は報告内容がなく、文章2は課題に取り組んだことを報告しているため、内容が異なります。しかし、文章表現や単語（「日次報告」など）が似ているため、1と評価しました。"}
# query7: 青木さんお疲れ様です。2-3課題再提出1-3任意課題実施3-3実践課題実施以上です。明日バナートレースの勉強会を行います。,青木さんお疲れ様です。3-3再提出課題実施バナートレースの勉強会行いました。,青木さんお疲れ様です。本日は任意課題バナートレース初心者をやりました。始めての勉強会も参加しました。イベントはなかなか予約が取れないです､､。,青木さんお疲れ様です。本日はありがとうございました。進捗状況は3-2 Figmaの使い方まで終わりました。再提出の1-3は細かいところは月曜の勉強会で聞きます。2-3も再提出でしたのでこちらも明日以降にやります。,ありがとうございます！
# similarity_assessment_model(query7, 青木さんお疲れ様です。2-3課題再提出1-3任意課題実施3-3実践課題実施以上です。明日バナートレースの勉強会を行います。): {"similarity": "5", "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query7, 青木さんお疲れ様です。3-3再提出課題実施バナートレースの勉強会行いました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現が異なっている。文章1では2-3課題、1-3任意課題、3-3実践課題の再提出や実施について触れられている一方、文章2では3-3再提出課題の実施のみが記述されている。また、文章表現においても、文章1は課題の提出や実施について詳細に記述しているのに対し、文章2は簡潔な表現となっている。"}
# similarity_assessment_model(query7, 青木さんお疲れ様です。本日は任意課題バナートレース初心者をやりました。始めての勉強会も参加しました。イベントはなかなか予約が取れないです､､。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現が異なっている。文章1は課題の報告、文章2は勉強会の報告という違いがある。また、文章表現も形式的な文章1と、個人的な感想を含んだ文章2で異なっている。"}
# similarity_assessment_model(query7, 青木さんお疲れ様です。本日はありがとうございました。進捗状況は3-2 Figmaの使い方まで終わりました。再提出の1-3は細かいところは月曜の勉強会で聞きます。2-3も再提出でしたのでこちらも明日以降にやります。): {"similarity": "3", "comment": "文章1は課題の報告、文章2は進捗状況の報告というように、大まかな内容は類似しているものの、内容は異なっています。文章表現は「お疲れ様です」「課題」「再提出」など共通している単語が多く見られますが、文章全体としては異なります。"}
# similarity_assessment_model(query7, ありがとうございます！): {"similarity": 0, "comment": "文章1は業務連絡の内容で、文章2はそれに返信する言葉なので、内容が大きく異なります。また、文章表現も全く異なっています。"}
# query8: 申し訳ございません！失念してしまいました！家族で外に出ており、後少し家着くのですが、時間の変更は可能でしょうか？,申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦,申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦,申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦,申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦
# similarity_assessment_model(query8, 申し訳ございません！失念してしまいました！家族で外に出ており、後少し家着くのですが、時間の変更は可能でしょうか？): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query8, 申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は丁寧な表現で具体的な状況説明があり、文章2は絵文字を用いたカジュアルな表現で具体的な状況説明がない。"}
# similarity_assessment_model(query8, 申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦): {"similarity": 3, "comment": "文章の大まかな内容は類似している（どちらも謝罪と時間の変更を依頼している）。細かい内容は異なり（文章1は具体的な状況説明があり、文章2は具体的な状況説明がない）、文章表現も異なっている（文章1は丁寧な口調、文章2はカジュアルな口調）。"}
# similarity_assessment_model(query8, 申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦): {"similarity": 3, "comment": "文章の大まかな内容は類似している（時間に遅れる旨を謝罪している）。細かい内容は異なる（文章1は家族で外出中であることを説明しているが、文章2は休みの間違いを説明している）。文章表現も異なる（文章1は丁寧な表現だが、文章2は絵文字を用いたカジュアルな表現である）"}
# similarity_assessment_model(query8, 申し訳ございません🙇‍♀️休み間違えてました💦10/9はいかがでしょうか💦): {"similarity": 3, "comment": "文章の大まかな内容は類似している（どちらも予定変更を伝える内容）。細かい内容は異なり（文章1は家族で外出中、文章2は休みを間違えた）、文章表現も異なる（文章1は丁寧な表現、文章2は絵文字を用いたカジュアルな表現）。"}
# query9: 3-2 ,3-3の課題が完了しましたので、ご確認よろしくお願いいたします。,1-4の②③課題完了しましたので、ご確認よろしくお願いいたします。,実践課題6-3を提出しました。ご確認よろしくお願いいたします。,1-4の④、2-1課題完了しましたので、ご確認よろしくお願いいたします。,まとめてのご報告となりすみません、、、2-2.3.4、3-1の課題が完了しましたので、ご確認よろしくお願いいたします。
# similarity_assessment_model(query9, 3-2 ,3-3の課題が完了しましたので、ご確認よろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query9, 1-4の②③課題完了しましたので、ご確認よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、課題番号が異なっており、文章表現も若干異なる。"}
# similarity_assessment_model(query9, 実践課題6-3を提出しました。ご確認よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（課題番号）が異なり、文章表現も少し異なっているため3とした。"}
# similarity_assessment_model(query9, 1-4の④、2-1課題完了しましたので、ご確認よろしくお願いいたします。): {"similarity": 4, "comment": "文章の大まかな内容は類似していますが、課題番号が異なっています。文章表現は類似しています。"}
# similarity_assessment_model(query9, まとめてのご報告となりすみません、、、2-2.3.4、3-1の課題が完了しましたので、ご確認よろしくお願いいたします。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1では3-2,3-3の課題が完了しているが、文章2では2-2.3.4、3-1の課題が完了している。また、文章表現も「まとめてのご報告となりすみません、、、」という表現が文章2にのみ含まれている。"}
# query10: 井関さんへ😊今日1-3までの動画をみました！1-3実践課題提出しました！明日は1-4終わらせようと思ってます。,嶋内様先日は面談ありがとうございました🙇‍♀️遅くなりましたが目標シートを送らせていただきます。今日は1-3実践課題の提出まで終わりました。明日は1-4の動画視聴を行います。,青木さん、こんばんは！今日は1-2の課題提出をして、動画は1-4まで視聴しました。連休でなかなか進みませんが、少しずつ頑張ります。明日は1-3の課題に挑戦しようと思います😊,ありがとうございます！,4-4 実践課題提出しました。
# similarity_assessment_model(query10, 井関さんへ😊今日1-3までの動画をみました！1-3実践課題提出しました！明日は1-4終わらせようと思ってます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query10, 嶋内様先日は面談ありがとうございました🙇‍♀️遅くなりましたが目標シートを送らせていただきます。今日は1-3実践課題の提出まで終わりました。明日は1-4の動画視聴を行います。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（動画視聴・課題提出に関する内容）が、細かい内容（具体的な動画番号や提出内容）が異なっており、文章表現も異なっているため3と評価しました。"}
# similarity_assessment_model(query10, 青木さん、こんばんは！今日は1-2の課題提出をして、動画は1-4まで視聴しました。連休でなかなか進みませんが、少しずつ頑張ります。明日は1-3の課題に挑戦しようと思います😊): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。動画視聴の進捗や課題提出の状況、明日の予定が異なる。また、文章表現も「～ました」「～と思ってます」など、言葉遣いが異なる。"}
# similarity_assessment_model(query10, ありがとうございます！): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。文章1は動画視聴と課題提出に関する報告であり、文章2は単なる感謝の言葉です。"}
# similarity_assessment_model(query10, 4-4 実践課題提出しました。): {"similarity": 0, "comment": "文章1は動画視聴と課題提出についての内容で、文章2は課題提出のみの内容です。文章の内容や文章表現が異なるため、類似度は0です。"}
#
# query11: 課題7-1を提出しました,課題7-1を提出しました,課題7-3を提出しました,課題7-3を提出しました,課題7-2提出しました
# similarity_assessment_model(query11, 課題7-1を提出しました): {"similarity": 5, "comment": "文章1と文章2は完全に同一であるため、類似度は5です。"}
# similarity_assessment_model(query11, 課題7-1を提出しました): {"similarity":5,"comment":"文章1と文章2は全く同じ文章なので、類似度は5です。"}
# similarity_assessment_model(query11, 課題7-3を提出しました): {"similarity":3,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現は似ている。課題番号が異なる。"}
# similarity_assessment_model(query11, 課題7-3を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（課題番号）が異なっており、文章表現はほぼ同じであるため3とした。"}
# similarity_assessment_model(query11, 課題7-2提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している(課題の提出)が、細かい内容(課題番号)が異なっており、文章表現は類似している(簡潔な表現)ため、3と評価しました。"}
# query12: 青木さん宛目標シートを入力しましたので共有させていただきます。ご確認よろしくお願いいたします。,1-4の②③課題完了しましたので、ご確認よろしくお願いいたします。,3-2 ,3-3の課題が完了しましたので、ご確認よろしくお願いいたします。,実践課題6-3を提出しました。ご確認よろしくお願いいたします。,1-4の④、2-1課題完了しましたので、ご確認よろしくお願いいたします。
# similarity_assessment_model(query12, 青木さん宛目標シートを入力しましたので共有させていただきます。ご確認よろしくお願いいたします。): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query12, 1-4の②③課題完了しましたので、ご確認よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（共有・確認を依頼している）が、細かい内容は異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query12, 3-2 ,3-3の課題が完了しましたので、ご確認よろしくお願いいたします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（報告、確認依頼）。細かい内容は異なり（文章1は目標シート、文章2は課題）、文章表現も異なる。"}
# similarity_assessment_model(query12, 実践課題6-3を提出しました。ご確認よろしくお願いいたします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（報告・確認依頼）が、細かい内容（具体的な内容）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query12, 1-4の④、2-1課題完了しましたので、ご確認よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっており、文章表現も異なっている。どちらも報告や確認を依頼している文章である。"}
# query13: また、初回ガイダンスは日曜日も行っていますでしょうか？,ご回答、ありがとうございます！また、個数について察しが悪く失礼しました！いわれてみればそうですよね＾＾；また、「最低な内容とは言えない内容」と書いていたのですが「最適な内容」の間違いでした。失礼しました。こちら、もう少しいろいろ試してみて旅行会社の日程表のような具体的な内容が出てくるよう試してみたいと思います。また、本日のタスクを完了しておりますので添削、お願いします。ちなみに課題以外にyahooの謝罪文を添削してみたのですが、修正点がありました。あえてわかりづらくしているのかもしれませんが、面白いですね。,また、6-1も提出しました。よろしくお願いします。,つなぎ方間違ってますか？,6-4.7-3の提出しております。
# similarity_assessment_model(query13, また、初回ガイダンスは日曜日も行っていますでしょうか？): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
#
# similarity_assessment_model(query13, ご回答、ありがとうございます！また、個数について察しが悪く失礼しました！いわれてみればそうですよね＾＾；また、「最低な内容とは言えない内容」と書いていたのですが「最適な内容」の間違いでした。失礼しました。こちら、もう少しいろいろ試してみて旅行会社の日程表のような具体的な内容が出てくるよう試してみたいと思います。また、本日のタスクを完了しておりますので添削、お願いします。ちなみに課題以外にyahooの謝罪文を添削してみたのですが、修正点がありました。あえてわかりづらくしているのかもしれませんが、面白いですね。): {"similarity": 0, "comment": "文章1は初回ガイダンスの開催曜日について質問しているのに対し、文章2は過去のやり取りを振り返りつつ、今後の進め方や添削依頼、そして追加で取り組んだ課題について記述しています。文章の内容や単語、表現、雰囲気全てが大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query13, また、6-1も提出しました。よろしくお願いします。): {"similarity":0,"comment":"文章の内容が全く異なり、単語も類似していないため。"}
# similarity_assessment_model(query13, つなぎ方間違ってますか？): {"similarity": 0, "comment": "文章の内容、表現、単語全てが異なります。"}
# similarity_assessment_model(query13, 6-4.7-3の提出しております。): {"similarity":0,"comment":"文章1は問い合わせ、文章2は報告であり、内容も表現も大きく異なります。"}
# query14: 【画像】(受信失敗),【動画】(受信失敗),ワイヤーフレーム作成している時に素材をコピーしようとしたら背景が黒くなってしまうのですが、背景透明にするにはどうすれば良いでしょうか？？,かしこまりました！その前に、現在の取り組み課題の事で質問なのですが3-4の動画でPinterestからダウンロードしたものをfigmaに貼り付ける方法の説明がなかったのですがどうして貼り付けるのですか？,ありがとうございます！
# similarity_assessment_model(query14, 【画像】(受信失敗)): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query14, 【動画】(受信失敗)): {"similarity": 2, "comment": "文章の内容は異なるが、どちらも受信失敗という単語が含まれており、文章表現も似ているため2としました。"}
# similarity_assessment_model(query14, ワイヤーフレーム作成している時に素材をコピーしようとしたら背景が黒くなってしまうのですが、背景透明にするにはどうすれば良いでしょうか？？): {"similarity": 0, "comment": "文章1は画像に関するエラーメッセージであり、文章2はデザインに関する質問です。内容、表現、単語のいずれも類似していません。"}
# similarity_assessment_model(query14, かしこまりました！その前に、現在の取り組み課題の事で質問なのですが3-4の動画でPinterestからダウンロードしたものをfigmaに貼り付ける方法の説明がなかったのですがどうして貼り付けるのですか？): {"similarity": 0, "comment": "文章1は画像に関する情報のみで、文章2はPinterestからfigmaへの画像貼り付けに関する質問です。文章内容が全く異なっており、類似点は見当たりません。"}
# similarity_assessment_model(query14, ありがとうございます！): {"similarity": 0, "comment": "文章の内容、単語、表現が全く異なります。"}
# query15: 完了なってました！,ありがとうございます！,4-4 実践課題提出しました。,4-2 実践課題提出しました。,5-2 実践課題提出しました
# similarity_assessment_model(query15, 完了なってました！): {"similarity":5,"comment":"文章1と文章2は同一の内容であり、文章表現も全く同じです。"}
# similarity_assessment_model(query15, ありがとうございます！): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query15, 4-4 実践課題提出しました。): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、\"完了\"と\"提出\"という単語が似通っているため、2としました。"}
# similarity_assessment_model(query15, 4-2 実践課題提出しました。): {"similarity":2,"comment":"文章の内容は異なるが、文章内で使われている単語（提出、完了）が似ている。"}
# similarity_assessment_model(query15, 5-2 実践課題提出しました): {"similarity": 1, "comment": "文章の内容は異なるが、簡潔な表現で報告をしているという点で、文章の雰囲気が似ているため1点としました。"}
# query16: https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton,https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton,https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton,https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton,https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton
# similarity_assessment_model(query16, https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton): {"similarity": "5", "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query16, https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton): {"similarity": 5, "comment": "文章1と文章2は同一の文章のため、類似度は5です。"}
# similarity_assessment_model(query16, https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton): {"similarity": "5", "comment": "文章1と文章2は同一の文章であるため、類似度は5です。"}
# similarity_assessment_model(query16, https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton): {"similarity": 5, "comment": "文章1と文章2は同一のURLリンクであり、同一の内容です。"}
# similarity_assessment_model(query16, https://www.canva.com/design/DAGRrRKYYhw/toWcQYQyvR9xdI5Wpq5Q8Q/edit?utm_content=DAGRrRKYYhw&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章なので、類似度は5です。"}
# query17: こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース,こんばんは！本日の成果をご報告します。・オリジナルバナー制作,こんばんは！本日の成果をご報告します。・動画視聴、課題提出・バナートレース完成,島戸さんお世話になっております、榎本です。▼今日の取り組み・2-1、2-2　受講・2-2 課題提出,藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出
# similarity_assessment_model(query17, こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
#
# similarity_assessment_model(query17, こんばんは！本日の成果をご報告します。・オリジナルバナー制作): {"similarity":3,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なっており、文章表現は類似している。どちらも成果報告という点で共通しているが、具体的な内容は異なっている。文章表現はどちらも簡潔で、同じような口語調であるため類似していると言える。"}
# similarity_assessment_model(query17, こんばんは！本日の成果をご報告します。・動画視聴、課題提出・バナートレース完成): {"similarity": 4, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なります。ワイヤーフレームと動画視聴が異なる点、バナートレースが完成しているかどうかの違いがあります。文章表現は類似しています。"}
# similarity_assessment_model(query17, 島戸さんお世話になっております、榎本です。▼今日の取り組み・2-1、2-2　受講・2-2 課題提出): {"similarity":2,"comment":"文章の内容は大きく異なるが、文内で使われている単語が似通っているため、2と評価しました。"}
# similarity_assessment_model(query17, 藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出): {"similarity": "3", "comment": "文章の大まかな内容は類似している（業務の進捗報告）。細かい内容は異なり、文章表現も異なる。"}
# query18: 11期生　妻鹿です。先ほどに引き続き、以下課題を行いました。３Week　3-1ChatGPTで翻訳をしてみようと行いました。結果、2week　２－から２－４、3week３－１まで完了しました～。チェックのほどよろしくお願いいたします。,お疲れ様です！5-1.2week-実践課題を提出しました。よろしくお願いします(よろしく),ありがとうございます！,4-4 実践課題提出しました。,4-2 実践課題提出しました。
# similarity_assessment_model(query18, 11期生　妻鹿です。先ほどに引き続き、以下課題を行いました。３Week　3-1ChatGPTで翻訳をしてみようと行いました。結果、2week　２－から２－４、3week３－１まで完了しました～。チェックのほどよろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query18, お疲れ様です！5-1.2week-実践課題を提出しました。よろしくお願いします(よろしく)): {"similarity": 1, "comment": "文章1は、ChatGPTを用いた翻訳の課題に関する報告で、3週間分の課題進捗が記述されている。文章2は、2週間目の実践課題提出の報告である。内容は異なるが、文章表現や文章の雰囲気が似ているため、1と評価しました。"}
# similarity_assessment_model(query18, ありがとうございます！): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なっているため"}
# similarity_assessment_model(query18, 4-4 実践課題提出しました。): {"similarity": 0, "comment": "文章1はChatGPTを用いた課題の進捗報告であり、文章2は実践課題の提出報告です。内容が大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query18, 4-2 実践課題提出しました。): {"similarity": 0, "comment": "文章1は、11期生の妻鹿さんがChatGPTを使った翻訳の課題に取り組んだことを報告しており、具体的な進捗状況が記載されています。一方、文章2は、4-2の実践課題を提出した旨のみが記載されており、内容が全く異なります。文章表現や単語も異なるため、類似度は0と判断しました。"}
# query19: 6-1実践課題提出しました。,5-1実践課題提出しました,ありがとうございます！,4-4 実践課題提出しました。,4-2 実践課題提出しました。
# similarity_assessment_model(query19, 6-1実践課題提出しました。): {"similarity":5,"comment":"文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query19, 5-1実践課題提出しました): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、提出された課題番号が異なる。文章表現は類似している。"}
# similarity_assessment_model(query19, ありがとうございます！): {"similarity": 0, "comment": "文章の内容がまったく異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query19, 4-4 実践課題提出しました。): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている。提出された課題の番号が異なるため、細かい内容が異なる。文章表現は類似している。"}
# similarity_assessment_model(query19, 4-2 実践課題提出しました。): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、提出した課題の番号が異なるため、細かい内容が違っている。文章表現は類似している。"}
# query20: お世話になっております。諸々忙しく、来週半ばまで予定が立ちません。来週になりましたら、ご連絡させて頂きます。申し訳ございません。,お世話になっております。Week3-4の課題を提出しました,お世話になっております。Week2-4の課題を提出しました,お世話になっております。Week4-4の課題を提出しました,お世話になっております。Week3-2の課題を提出しました
# similarity_assessment_model(query20, お世話になっております。諸々忙しく、来週半ばまで予定が立ちません。来週になりましたら、ご連絡させて頂きます。申し訳ございません。): {"similarity": "5", "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query20, お世話になっております。Week3-4の課題を提出しました): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query20, お世話になっております。Week2-4の課題を提出しました): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっているため"}
# similarity_assessment_model(query20, お世話になっております。Week4-4の課題を提出しました): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query20, お世話になっております。Week3-2の課題を提出しました): {"similarity": 0, "comment": "文章の内容が全く異なっており、文章表現や単語も異なっています。"}

# %% [markdown]
# # **Universal Sentence Encoder + HNSW (Model 4)**

# %%
# !pip install tensorflow tensorflow-hub hnswlib numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Collecting hnswlib
#   Downloading hnswlib-0.8.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (2.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp310-cp310-linux_x86_64.whl size=2360795 sha256=e4a99f6c37a3cae067c4b91c2af8aafcc87806fef58aeec2d8b7f6cf9ada67d6
#   Stored in directory: /root/.cache/pip/wheels/af/a9/3e/3e5d59ee41664eb31a4e6de67d1846f86d16d93c45f277c4e7
# Successfully built hnswlib
# Installing collected packages: hnswlib
# Successfully installed hnswlib-0.8.0

# %% [markdown]
# With category

# %%
import jsonlines
import numpy as np
import random
import tensorflow as tf
import tensorflow_hub as hub
import hnswlib
import json
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting
import time

# Step 1: Load your dataset (output_categories.jsonl)
with jsonlines.open('output_with_categories_1107.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer-category pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']} Category: {pair['category']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]
categories = [pair['category'] for pair in qa_pairs]

# Load Universal Sentence Encoder model from TensorFlow Hub
use_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Step 3: Encode the documents using USE
question_embeddings = use_model(documents).numpy()

# Step 4: Create HNSW index
dim = question_embeddings.shape[1]
p = hnswlib.Index(space='cosine', dim=dim)
p.init_index(max_elements=len(questions), ef_construction=200, M=16)
p.add_items(question_embeddings)
p.set_ef(50)  # ef should be set to a value between 10 and 100 for best performance

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 5: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Encode the query using USE
    query_embedding = use_model([f"Question: {query}"]).numpy()

    # Search the HNSW index
    labels, distances = p.knn_query(query_embedding, k=top_k)

    # Return the most similar questions
    closest_questions = [questions[i] for i in labels[0]]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。

        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return responses.candidates[0].content.parts[0].text

# Evaluate the system with 20 selected questions using USE and HNSW
print("Evaluating using USE and HNSW:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    print(f"Query {idx}: {question}")
    print("Most similar data (top 5):")
    for i, similar_question in enumerate(similar_questions, start=1):
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
    print()
# Out:
# Evaluating using USE and HNSW:
# Query 1: week1-1,2の課題を提出しました。
# Most similar data (top 5):
# similarity_assessment_model(query1, 完了出来ました、遅くなりすみません、よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は課題提出の報告、文章2は完了報告と謝罪となっており、内容が異なります。文章表現も異なるため、類似度は0と判断しました。"}
#
# similarity_assessment_model(query1, 6-4.7-3の提出しております。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の提出に関する内容）が、細かい内容（課題番号）が異なり、文章表現も異なっているため3と評価しました。"}
# similarity_assessment_model(query1, こんにちは。本日9時〜面談ということでzoomで待機しておりましたが「ホストによってミーティングが開始されるのを待機しています」のまま繋がりません。日程を再調整したいのですが、10月以降のスケジュールはいつ頃選択できるでしょうか？): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query1, 内田さん⬛︎今日の取り組みweek3-1,2,3提出フィードバックの勉強会:予約済⬛︎これから月末までCanvaバナートレース　する以上です(flower)): {"similarity": 0, "comment": "文章1は課題提出に関する簡潔な報告であり、文章2は多岐にわたる業務内容と予定を記述しており、内容や表現が大きく異なるため、類似度は0です。"}
#
# similarity_assessment_model(query1, 前回4-2.とお伝えしたのは4-3の間違えでした。): {"similarity": 0, "comment": "文章1と文章2は内容も表現も全く異なります。"}
#
# Query 2: お世話になります先程提出いたしました。よろしくお願いします
# Most similar data (top 5):
# similarity_assessment_model(query2, お世話になります先程提出いたしました。よろしくお願いします): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 口座名明記していなかった為再度失礼します。ヤマダナツミです。よろしくお願いします。): {"similarity":0,"comment":"文章1と文章2は内容が全く異なり、文章表現や単語も異なります。"}
#
# similarity_assessment_model(query2, 今日は何も取り組めませんでした。): {"similarity":0,"comment":"文章の内容、表現、単語が全く異なります。"}
# similarity_assessment_model(query2, ありがとうございます。): {"similarity":0,"comment":"文章1は依頼や報告、文章2はお礼の言葉であり、内容も文章表現も異なる。"}
#
# similarity_assessment_model(query2, かしこまりました！それまでにパソコンは用意して良いですか？パソコン購入の注意点は入会時に渡された資料を見ればいいですね？): {"similarity":0,"comment":"文章1は依頼の完了を伝える内容、文章2は確認と指示を伝える内容で、内容、文章表現、単語も全く異なるため0としました。"}
#
# Query 3: 入力内容を確認してくださいと表示がされます。
# Most similar data (top 5):
# similarity_assessment_model(query3, スクリーンショットができませんでした。すみません。): {"similarity":0,"comment":"文章1は入力確認に関するエラーメッセージ、文章2はスクリーンショットに関するエラーメッセージであり、内容が大きく異なります。単語も共通点は少ないため、類似度は0と判断しました。"}
# similarity_assessment_model(query3, 竹中先生今日は面談をありがとうございました。目標を立ててアップしましたので、ご確認をお願いします。スケジュールを立ててくださり、受講進度の目安が分かりやすいです。頑張ります。): {"similarity":0,"comment":"文章の内容、単語、文章表現すべてが大きく異なっているため、類似度は0です。"}
# similarity_assessment_model(query3, 嶋内さんこんにちは。先日はありがとうございました。バタバタしてしまって遅くなりましたが、目標シート送ります。): {"similarity": 0, "comment": "文章の内容が大きく異なり、単語も異なるため0としました。"}
# similarity_assessment_model(query3, 藤川さんこんばんは(月)1-3の3回目の再提出してます。コメントにも書いたんですが、見本と見比べることに意識がいっており画面を大きくしたら細かい作業もしやすいことに気付きました(emoji)): {"similarity": 0, "comment": "文章1と文章2は、内容、単語、文章表現全てが異なるため類似度は0です。"}
# similarity_assessment_model(query3, 課題7-3を提出しました): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なるため、類似度は0です。"}
#
# Query 4: 昨日はありがとうございました！今日から旅行に行くので受講を始めるのと目標シート等も24日に送る予定です！よろしくお願いします！
# Most similar data (top 5):
# similarity_assessment_model(query4, 立て続けに申し訳ありません。実践課題について質問させてください。2-1のコメントを提出したのですが、エラーになって書き直したところ、なぜか2-2にも2-1と同じ内容のコメントが提出されてしまいました💦2-2の課題では、画像を提出しましょう！となっていたのですが、画像を提出できないまますでに完了となってしまいました…このままでも問題ないのでしょうか？🙇‍♂️): {"similarity": 0, "comment": "文章1と文章2は内容、文章表現、単語がすべて異なるため、類似度は0です。"}
# similarity_assessment_model(query4, ありがとうございます): {"similarity": "0", "comment": "文章の内容が異なり、文章表現も異なるため0です。"}
# similarity_assessment_model(query4, 坂尻です6-4実践課題をワークシートに入力しました添削をよろしくお願いします。): {"similarity":0,"comment":"文章1は旅行に関する内容で、文章2は課題提出に関する内容であり、内容が全く異なります。また、文章表現や単語も大きく異なっています。"}
# similarity_assessment_model(query4, お疲れ様です！4-4week-実践課題を提出しました。よろしくお願いします(よろしく)): {"similarity": 0, "comment": "文章の内容、単語、表現が全く異なるため類似度は0です。"}
# similarity_assessment_model(query4, 10/3　Week7-1、7-2の実践課題を提出しました): {"similarity": 0, "comment": "文章1は感謝の言葉と今後の予定についての連絡、文章2は課題提出の報告であり、内容、表現ともに全く異なるため"}
#
# Query 5: 課題6-2.6-3を提出しました
# Most similar data (top 5):
# similarity_assessment_model(query5, 課題6-2.6-3を提出しました): {"similarity":5,"comment":"文章の内容、表現、単語全てが一致しているため、類似度は5です。"}
# similarity_assessment_model(query5, お世話になります。Slackですが招待いただいたmailが携帯宛でしてPCの方に転送したのですが、上手く読み取れない部分があり登録が出来ません。ayano.jinno@gmail.comの方に再度送信していただけませんか？よろしくお願いします。): {"similarity": 0, "comment": "文章1は課題提出に関するものであり、文章2はSlackへの招待に関するものです。内容も文章表現も全く異なっています。"}
#
# similarity_assessment_model(query5, こんにちは！先日はありがとうございました。ご連絡が遅くなってしまい申し訳ありません。受講の申し込みをさせていただきたいです！): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query5, URLが開けません): {"similarity": 0, "comment": "文章1は課題提出に関する内容で、文章2はURLに関する内容であり、内容、単語、文章表現全てにおいて類似点が見当たらないため、0と評価しました。"}
# similarity_assessment_model(query5, ありがとうございます。): {"similarity":0,"comment":"文章1は課題提出に関する内容で、文章2は感謝の言葉です。内容も文章表現も全く異なるため、類似度は0です。"}
#
# Query 6: お世話になっております。パソコンについて確認したいのですが、MacBookAirでも問題ないでしょうか。
# Most similar data (top 5):
# similarity_assessment_model(query6, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 質問です。メンター面談2回まで終了しました。次回は、いつ頃予定（予約）すれば良いでしょうか？): {"similarity": 0, "comment": "文章1と文章2は、内容、文章表現、単語全てが異なります。"}
# similarity_assessment_model(query6, 嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！): {"similarity": 0, "comment": "文章1はパソコンに関する問い合わせで、文章2はスケジュールに関する返信です。内容も表現も全く異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query6, お世話になっております。パソコンについて確認したいのですが、MacBookAirでも問題ないでしょうか。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章であるため、類似度は5です。"}
# similarity_assessment_model(query6, 申し訳ありません。いろいろしていただいたのに。): {"similarity":0,"comment":"文章1はパソコンについての質問、文章2は謝罪の言葉であり、内容も文章表現も全く異なるため、類似度は0です。"}
# similarity_assessment_model(query6, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 口座名明記していなかった為再度失礼します。ヤマダナツミです。よろしくお願いします。): {"similarity": 0, "comment": "文章1はパソコンに関する問い合わせ、文章2は口座名と名前の連絡で、内容が全く異なるため。文章表現も異なる。"}
#
# Query 7: 10/5も予定があり参加が難しい状況です🙇🙇途中で一時的に抜けてしまっても大丈夫でしたら、明日10/2(水)10時〜12時で参加させていただきたいと思います🙇🙇
# Most similar data (top 5):
# similarity_assessment_model(query7, お世話になります。week3の③,④を提出しました): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query7, すみません。「が」はタイプミスです🙏💦): {"similarity": 0, "comment": "文章1はイベントへの参加に関する内容で、文章2は誤字に関する謝罪です。内容も文章表現も全く異なっています。"}
# similarity_assessment_model(query7, 8-4まで課題の提出ができました。添削をお願いします。): {"similarity": "0", "comment": "文章1は会議への参加に関する内容、文章2は課題提出に関する内容であり、内容が全く異なる。また、文章表現も異なっているため、類似度は0です。"}
# similarity_assessment_model(query7, week7-3.8-1.8-2の課題を提出しました。): {"similarity": 0, "comment": "文章1は会議への参加に関する内容で、文章2は課題提出に関する内容のため、全く異なる内容です。文章表現や単語も異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query7, お振込でなくカード登録でした。ご確認ください。): {"similarity": 0, "comment": "文章1はイベントへの参加に関する内容で、文章2は支払い方法に関する内容です。内容も文章表現も全く異なっています。"}
#
# Query 8: 入金の仕方はクレジット選んだのですが、案内のページはこれからきますか？
# Most similar data (top 5):
# similarity_assessment_model(query8, いつもお世話になっております。Week8-2スクリーンショットを提出致します。添削のほどよろしくお願いいたします😊): {"similarity": 0, "comment": "文章1は支払い方法に関する問い合わせ、文章2は提出物に関する連絡で、内容が全く異なる。また、文章表現や単語も異なる。"}
# similarity_assessment_model(query8, お疲れ様です！4-4week-実践課題を提出しました。よろしくお願いします(よろしく)): {"similarity":0,"comment":"文章1はクレジットカード決済に関する問い合わせ、文章2は提出物の報告であり、内容、表現、単語全てにおいて類似点が見当たらないため0点としました。"}
# similarity_assessment_model(query8, お振込でなくカード登録でした。ご確認ください。): {"similarity": "2", "comment": "文章1は入金方法について質問しているのに対し、文章2はカード登録について言及しているため、内容は異なります。しかし、クレジットカードとカード登録という単語が共通しているため、2としました。"}
# similarity_assessment_model(query8, わかりました✨ありがとうございます！🙇‍♀️※返信不要です！): {"similarity":0,"comment":"文章1はクレジットカードでの入金に関する問い合わせ、文章2は感謝の返信であり、内容が全く異なる。文章表現や単語も異なるため類似度は0です。"}
# similarity_assessment_model(query8, 3-4提出しましたが、あれで良かったでしゃうか？上手くデータの共有出来ませんでして(汗)): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なります。"}
#
# Query 9: 谷津さま今日は3-3が添削中で3-5の課題には切れなかったので、3-1〜3-5の動画視聴をしました！
# Most similar data (top 5):
# similarity_assessment_model(query9, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 0, "comment": "文章1は添削作業の報告で、文章2は作業できなかった旨の報告です。内容も表現も全く異なります。"}
# similarity_assessment_model(query9, 谷津さん、お疲れ様です！当日で大変申し訳無いのですが、急遽仕事が長引いてしまい、面談に間に合いそうにありません(汗)面談をリスケしてもらうことは可能ですか😖？？): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も大きく異なります。"}
# similarity_assessment_model(query9, 坂尻です6-4実践課題をワークシートに入力しました添削をよろしくお願いします。): {"similarity": 2, "comment": "文章1と文章2は、どちらも添削依頼に関する内容です。しかし、具体的な内容が異なります。文章1は3-3の添削依頼、3-1～3-5の動画視聴に関する内容である一方、文章2は6-4実践課題のワークシート入力に関する内容です。文章表現も、文章1は「添削中で」「切れなかったので」など、進行状況を説明する表現が使われているのに対し、文章2は「入力しました」「よろしくお願いします」など、依頼を簡潔に伝える表現が使われています。そのため、文章の大まかな内容は類似しているものの、細かい内容や文章表現は大きく異なります。"}
# similarity_assessment_model(query9, ２-1実践課題を提出しました。宜しくお願いいたします。): {"similarity":0,"comment":"文章1は添削と動画視聴の内容、文章2は課題提出の内容で、内容も表現も全く異なるため0としました。"}
# similarity_assessment_model(query9, 添削が早くて驚きます。ありがとうございます‼️): {"similarity": 0, "comment": "文章1は添削中の課題の報告と動画視聴の報告、文章2は添削に対する感謝の言葉と驚きの表現であり、内容も文章表現も全く異なるため"}
#
# Query 10: 有難うございました。こちらこそ宜しくお願いします。
# Most similar data (top 5):
# similarity_assessment_model(query10, お世話になります。予約が入ってなかったとのこと、安心しました。留守電の内容は、明日(8日)午前10時からの説明会参加の確認の連絡でしたよろしくお願いします): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query10, 内田さん⬛︎今日の取り組みweek3-1,2,3提出フィードバックの勉強会:予約済⬛︎これから月末までCanvaバナートレース　する以上です(flower)): {"similarity": 0, "comment": "文章1は感謝の言葉、文章2は仕事の報告のような内容で、全く異なるため。"}
# similarity_assessment_model(query10, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity":0,"comment":"文章1は丁寧な表現で感謝の言葉を述べていますが、文章2は報告の形式で、内容も異なります。文章表現も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query10, ありがとうございます): {"similarity": "2", "comment": "文章1と文章2はどちらも感謝の気持ちを伝える内容だが、文章1は丁寧な表現で、文章2は簡潔な表現である。文章表現は異なるが、感謝の気持ちを伝える単語「有難う」と「ありがとう」が使われているため、2とした。"}
# similarity_assessment_model(query10, わかりました✨ありがとうございます！🙇‍♀️※返信不要です！): {"similarity": "1", "comment": "文章の内容は異なっているが、文章表現や文章の雰囲気が似ている。文章1は丁寧な表現で、文章2はカジュアルな表現である。"}
#
# Query 11: week6-2提出しました。
# Most similar data (top 5):
# similarity_assessment_model(query11, こんばんは！本日の成果をご報告します。・ワイヤーフレーム完成→課題提出・バナートレース): {"similarity": "3", "comment": "文章1は課題提出の報告、文章2は日々の成果報告という内容で、大まかな内容は類似している。しかし、文章1は具体的な課題名がなく、文章2はワイヤーフレームとバナートレースという具体的な内容が記述されているため、細かい内容は異なる。また、文章表現も「提出しました」と「ご報告します」のように異なる。"}
# similarity_assessment_model(query11, 今日は忙しく取り組めません。): {"similarity":0,"comment":"文章1は提出に関する内容、文章2は作業の遅延に関する内容で、全く異なる内容です。また、文章表現や単語も大きく異なっています。"}
# similarity_assessment_model(query11, 前回4-2.とお伝えしたのは4-3の間違えでした。): {"similarity":0,"comment":"文章1は課題提出に関する内容、文章2は誤り訂正に関する内容で、内容も表現も全く異なるため0としました。"}
# similarity_assessment_model(query11, 課題3-3を提出しました。よろしくお願いします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出物の番号が違う）、文章表現も異なっている（文章2には「よろしくお願いします」が含まれている）ため、3とした。"}
# similarity_assessment_model(query11, week6-2提出しました。): {"similarity":5,"comment":"文章の内容、表現が完全に一致しているため"}
#
# Query 12: 谷津さん、こんばんわ。遅くに失礼いたします。▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・昨日ゆっくり休みましたので本日1-3の動画視聴完了、実践もおおまかなところまで完了しました。明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します。引き続き、宜しくお願いします🙂
# Most similar data (top 5):
# similarity_assessment_model(query12, お世話になります。week3の③,④を提出しました): {"similarity": 0, "comment": "文章1は日々の取り組みについて詳細に報告しているのに対し、文章2は提出報告のみであり、内容が大きく異なります。また、文章表現も異なっています。"}
# similarity_assessment_model(query12, 坂尻です6-4実践課題をワークシートに入力しました添削をよろしくお願いします。): {"similarity": 2, "comment": "文章1は日々の取り組み報告についての内容で、文章2は特定の実践課題についての報告です。大まかな内容は異なっていますが、文内で使われている単語（取り組み、報告、実践課題など）が似通っているため、2としました。"}
# similarity_assessment_model(query12, 7-3実践課題ワークシートに記入しました。添削のほどよろしくお願いします。): {"similarity": 2, "comment": "文章1では動画視聴や実践について言及されていますが、文章2ではワークシート記入のみで内容が異なります。しかし、文章1の「実践課題」と文章2の「実践課題ワークシート」という単語が共通しているため、2としました。"}
# similarity_assessment_model(query12, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 口座名明記していなかった為再度失礼します。ヤマダナツミです。よろしくお願いします。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現も異なっています。"}
# similarity_assessment_model(query12, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 1, "comment": "文章の内容は全く異なるが、文章表現や単語が似ている部分があるため、1点としました。"}
#
# Query 13: 明日、面談の予約をしているのですが、今夜から、かなりの高熱が出てしまったため、キャンセルをお願いできますでしょうか？
# Most similar data (top 5):
# similarity_assessment_model(query13, 10/3　Week7-1、7-2の実践課題を提出しました): {"similarity": 0, "comment": "文章の内容、表現が大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query13, 藤川さんこんばんは(月)1-3の3回目の再提出してます。コメントにも書いたんですが、見本と見比べることに意識がいっており画面を大きくしたら細かい作業もしやすいことに気付きました(emoji)): {"similarity": 0, "comment": "文章1は面談のキャンセルに関するお願いで、文章2は仕事の再提出に関する報告です。内容や文章表現、単語も全く異なります。"}
# similarity_assessment_model(query13, 7-3実践課題ワークシートに記入しました。添削のほどよろしくお願いします。): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なります。"}
# similarity_assessment_model(query13, かしこまりました！それまでにパソコンは用意して良いですか？パソコン購入の注意点は入会時に渡された資料を見ればいいですね？): {"similarity":0,"comment":"文章1は面談のキャンセル依頼、文章2は入会に関する確認のやり取りで、内容も文章表現も全く異なっています。"}
# similarity_assessment_model(query13, ぜひ受講させていただきたいです！よろしくお願いいたします。): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なります。"}
#
# Query 14: こちらこそどうぞよろしくお願いいたします
# Most similar data (top 5):
# similarity_assessment_model(query14, 【取り組んだこと】土〜火・week4-2〜5-3・勉強会): {"similarity":0,"comment":"文章1は挨拶文、文章2は業務報告のような内容であり、内容も表現も全く異なるため0としました。"}
# similarity_assessment_model(query14, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 0, "comment": "文章の内容が異なっており、文章表現や単語も異なっているため0としました。"}
# similarity_assessment_model(query14, 大変申し訳ございません。失念しておりました。): {"similarity":0,"comment":"文章1と文章2は、文末の表現が似ているものの、内容や文脈が全く異なるため、類似度は0です。"}
#
# similarity_assessment_model(query14, week8-1,2を提出しました。よろしくお願いいたします。): {"similarity":2,"comment":"文章1は一般的な挨拶で、文章2は提出物の報告と依頼を兼ねています。内容としては全く異なるため、0に近いですが、文章2に「よろしくお願いいたします」という単語が含まれているため、2としました。"}
# similarity_assessment_model(query14, 解決しました。回答不要です。): {"similarity": 0, "comment": "文章1は挨拶、文章2は問題解決の報告であり、内容、単語、文章表現が全く異なるため"}
#
# Query 15: week2-1.2-2課題を提出しました
# Most similar data (top 5):
# similarity_assessment_model(query15, 上田さん(emoji)面接の案内ありがとうございます(emoji)明日、よろしくお願いいたします(emoji)): {"similarity": 0, "comment": "文章1は課題提出に関する内容、文章2は面接に関する内容で、内容が全く異なります。文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query15, 川本さん宛てこんばんは⭐️カラーピッカーのご確認ありがとうございました。私も再度確認しましたが出てきませんでした。進捗状況は、息子が体調を崩していたのでなかなか進めず、動画をちょこちょこ見て進めています。現在1-3の課題を再提出しようと取り組んでいるところです。1-4の動画視聴は完了しています。よろしくお願いいたします。嶋﨑): {"similarity": 2, "comment": "文章1は課題提出に関する簡潔な報告、文章2は具体的な状況説明と今後の予定に関する連絡となっており、内容は異なります。しかし、どちらも課題に関する内容であり、「提出」「課題」などの単語が共通しているため、2と評価しました。"}
# similarity_assessment_model(query15, お世話になります。week3の③,④を提出しました): {"similarity": "1", "comment": "文章の内容は異なりますが、文章表現が簡潔で、単語も似通っているため、1としました。"}
# similarity_assessment_model(query15, week2-1.2-2課題を提出しました): {"similarity":5,"comment":"文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query15, ありがとうございます。あと10月24日の9時からセルフマネジメント講座の予約を入れたのですが、担当者に予め耳が不自由なことをお伝え頂けると助かります。（複人数だと字幕を読み取るのに時間かかるため、もし呼びかけがあった場合すぐ対応出来ないかもしれないです）ご不便をおかけしますが、よろしくお願いいたします。): {"similarity": 0, "comment": "文章1と文章2は内容が全く異なり、単語も共通点が見当たらないため、類似度は0と判断しました。"}
#
# Query 16: 谷津さんへ昨日送り忘れてしまってすみません！昨日3-5の課題を提出し、今日再提出をしました！今日は昼の仕事が忙しかったので、早めに休んで明日また次に進めて行きます！🙇‍♀️
# Most similar data (top 5):
# similarity_assessment_model(query16, わかりました✨ありがとうございます！🙇‍♀️※返信不要です！): {"similarity": 0, "comment": "文章1は課題の提出に関する内容で、文章2は返信不要の旨を伝えているため、内容が全く異なります。また、文章表現も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query16, いつもお世話になっております。Week8-3,4を提出致します。添削よろしくお願いいたします😊): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出に関する連絡）。細かい内容は異なり、文章1は具体的な内容（課題番号、提出日、今後の予定）が含まれているのに対し、文章2は簡潔な報告のみ。文章表現も異なり、文章1はカジュアルな表現、文章2は丁寧な表現。"}
# similarity_assessment_model(query16, 本日figmaのイベントに参加しました。行う内容が違うのであればまた参加しようと思うのですがfigmaのイベントは1種類だけでしょうか？): {"similarity": 0, "comment": "文章の内容、単語、表現すべて異なるため"}
# similarity_assessment_model(query16, 課題　3-1,3-2を行いました): {"similarity": 2, "comment": "文章1は課題提出に関する連絡、文章2は課題の完了報告なので、内容は大きく異なります。しかし、どちらも課題に関する内容で、数字や「課題」という単語が使われているため、2としました。"}
# similarity_assessment_model(query16, お疲れ様です！4-4week-実践課題を提出しました。よろしくお願いします(よろしく)): {"similarity": "2", "comment": "文章1は課題提出に関する内容で、文章2は課題提出を報告しているという点で、大まかな内容は類似しています。しかし、文章1は具体的な課題番号や提出日時が記載されている一方、文章2は具体的な情報が不足しているため、細かい内容は異なります。また、文章表現も異なるため、2と評価しました。"}
#
# Query 17: ありがとうございます！追加でこのまま質問ですが、こちらのおすすめバナーを練習後、ポートフォリオ作成に向けてオリジナルバナー制作に取り掛かる、で良いでしょうか？
# Most similar data (top 5):
# similarity_assessment_model(query17, ご対応ありがとうございます！こちらこそよろしくお願いいたします！): {"similarity": "0", "comment": "文章1はポートフォリオ制作についての質問ですが、文章2は感謝の言葉のみであり、内容が全く異なります。文章表現も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query17, ぜひ受講させていただきたいです！よろしくお願いいたします。): {"similarity":0,"comment":"文章1は、受講後の具体的な行動について質問しており、文章2は受講の意向を示しているため、内容が大きく異なります。また、文章表現も大きく異なります。"}
# similarity_assessment_model(query17, SLACKにGoogleアカウントでログインできません。（一度Yahooのメールアドレスにてログインしてしまいました。）最初にGoogleのアカウントを登録しているのであればそのアカウントを変更したいのですが可能でしょうか？): {"similarity":0,"comment":"文章の内容、表現、単語が全て異なります。"}
# similarity_assessment_model(query17, すみません、課題の提出を勘違いしていました。先程、課題2-1を提出しました。よろしくお願いします。): {"similarity": 0, "comment": "文章1と文章2は内容、単語、文体全て異なります。"}
# similarity_assessment_model(query17, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章の内容、単語、表現がすべて異なるため"}
#
# Query 18: 課題7-2提出しました
# Most similar data (top 5):
# similarity_assessment_model(query18, いつもお世話になっております。Week8-2スクリーンショットを提出致します。添削のほどよろしくお願いいたします😊): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（課題番号、表現）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query18, こんにちは！楽しくプログラムを進めています☺️面談楽しみにしています！よろしくお願いします！): {"similarity": 0, "comment": "文章1は課題提出に関するものであり、文章2は挨拶と面談に関するものです。内容、表現、単語全てが異なるため0としました。"}
# similarity_assessment_model(query18, 10月24日に取り組んだ内容・【2-2】実践課題の実施・提出ご確認を宜しくお願いいたします。): {"similarity": "1", "comment": "文章1は課題提出の報告、文章2は課題に取り組んだ内容の報告と提出確認依頼なので、内容は異なります。しかし、文章表現や文末の「〜いたします」という丁寧な表現が類似しているため、1と評価しました。"}
# similarity_assessment_model(query18, 課題7-2提出しました): {"similarity": 5, "comment": "文章の内容、表現、単語全てが同一であるため、類似度は5です。"}
# similarity_assessment_model(query18, 3-4提出しましたが、あれで良かったでしゃうか？上手くデータの共有出来ませんでして(汗)): {"similarity": "2", "comment": "文章1は課題提出の報告のみで、文章2は提出内容に関する質問と不安が含まれています。そのため、大まかな内容は異なりますが、文章内に「提出」「データ」などの共通の単語が含まれているため、2としました。"}
#
#
# Query 19: 藤川さんお世話になります！3-5 、4-1 再提出終わりました。よろしくお願いします！
# Most similar data (top 5):
# similarity_assessment_model(query19, 藤川さんお世話になります！3-5 、4-1 再提出終わりました。よろしくお願いします！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query19, 4-2完了しました。): {"similarity": 2, "comment": "文章1と文章2は、どちらも提出に関する内容ですが、具体的な提出物や提出先が異なっています。また、文章表現も異なります。そのため、単語が似通っているという点で2と評価しました。"}
# similarity_assessment_model(query19, 4-4 提出しました。添削をお願いします): {"similarity":3,"comment":"文章の大まかな内容は類似している（提出に関する連絡）。細かい内容は異なり（提出物の内容や提出先）、文章表現も異なっている（文章1は丁寧な表現、文章2は簡潔な表現）ため、3と判断しました。"}
# similarity_assessment_model(query19, week6-1提出しました。): {"similarity": "1", "comment": "文章の内容は違いますが、提出に関する連絡という文脈と短い文章という点で雰囲気が似ています。"}
# similarity_assessment_model(query19, 4-2 実践課題提出しました。): {"similarity":2,"comment":"文章1は再提出の報告、文章2は課題提出の報告となっており、内容は異なります。しかし、どちらも提出に関する内容で、単語も似通っているため、2としました。"}
#
# Query 20: わかりました。一応、カラーピッカーについてはこのサイト見てみたのですが、よくわからなくて…もう一度やってみます。それでもわからなかったら勉強会を予約して聞いた方が良いでしょうか？
# Most similar data (top 5):
# similarity_assessment_model(query20, 本日figmaのイベントに参加しました。行う内容が違うのであればまた参加しようと思うのですがfigmaのイベントは1種類だけでしょうか？): {"similarity":0,"comment":"文章1と文章2は内容、文章表現、単語全て異なっているため、類似度は0です。"}
# similarity_assessment_model(query20, week2-2の課題を提出しましたご確認よろしくお願いします): {"similarity": 0, "comment": "文章1はカラーピッカーに関する質問と勉強会予約に関する問い合わせ、文章2は課題提出の報告となっており、内容が全く異なる。また、文章表現も異なっているため類似度は0です。"}
# similarity_assessment_model(query20, 前回4-2.とお伝えしたのは4-3の間違えでした。): {"similarity":0,"comment":"文章1と文章2は内容、単語、文章表現全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query20, お世話になります。week3の③,④を提出しました): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なるため、類似度は0です。"}
# similarity_assessment_model(query20, 一昨日は1-3の再提出分を進めました。昨日はお休みしました。): {"similarity":0,"comment":"文章1はカラーピッカーについて質問をしていますが、文章2は仕事の進捗について報告をしています。内容は全く異なります。また、使われている単語も異なるため、類似度は0です。"}

# %% [markdown]
# Without category

# %%
import jsonlines
import numpy as np
import random
import tensorflow as tf
import tensorflow_hub as hub
import hnswlib
import json
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting
import time

# Step 1: Load your dataset (qa_pairs_for_rag_1108.jsonl)
with jsonlines.open('qa_pairs_for_rag_1108.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]

# Load Universal Sentence Encoder model from TensorFlow Hub
use_model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Step 3: Encode the documents using USE
question_embeddings = use_model(documents).numpy()

# Step 4: Create HNSW index
dim = question_embeddings.shape[1]
p = hnswlib.Index(space='cosine', dim=dim)
p.init_index(max_elements=len(questions), ef_construction=200, M=16)
p.add_items(question_embeddings)
p.set_ef(50)  # ef should be set to a value between 10 and 100 for best performance

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Step 5: Function to retrieve the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    # Encode the query using USE
    query_embedding = use_model([f"Question: {query}"]).numpy()

    # Search the HNSW index
    labels, distances = p.knn_query(query_embedding, k=top_k)

    # Return the most similar questions
    closest_questions = [questions[i] for i in labels[0]]
    return closest_questions

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。

        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return responses.candidates[0].content.parts[0].text

# Evaluate the system with 20 selected questions using USE and HNSW
print("Evaluating using USE and HNSW:")
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    print(f"Query {idx}: {question}")
    print("Most similar data (top 5):")
    for i, similar_question in enumerate(similar_questions, start=1):
        similarity_score = similarity_assessment_model(question, similar_question)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
    print()
# Out:
# Evaluating using USE and HNSW:
# Query 1: 【その他】
# Most similar data (top 5):
# similarity_assessment_model(query1, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1と文章2の内容は全く異なるため、類似度は0です。"}
# similarity_assessment_model(query1, 6-4.7-3の提出しております。): {"similarity": 0, "comment": "文章1は、具体的な内容が不明です。文章2は、数字の羅列であり、文章として成立していません。そのため、内容や表現の類似性を評価することができません。"}
# similarity_assessment_model(query1, 11期生妻鹿です。２Week　２－３～２－４の課題をしました。日本語CatGTPが、先ほどラインしたように、今日から、「ようこそ！このGPTはサブスクライバー専用です。アカウントを確認していますので、少々お待ちください。初めての方は、サインアップの流れを案内します。」というメッセージが表示されます。そのため、日本語版ではないCatGTPにて課題をしました。日本語CatGTPだけ、無料期間があるのかどうかの、情報をお持ちでしたらご教示いただければさわいです。よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は、文章2の内容と全く異なるため、類似度は0です。文章1は、日本語版CatGTPの利用について触れており、文章2は、11期生の妻鹿さんが課題をしたことを報告しています。文章1は、日本語版CatGTPの無料期間について質問をしていますが、文章2は、日本語版CatGTPがサブスクライバー専用であることを説明しています。文章の内容が全く異なっており、文章表現や単語も異なっているため、類似度は0です。"}
# similarity_assessment_model(query1, 課題2-3,2-4完了しました。): {"similarity":0,"comment":"文章1と文章2の内容は全く異なり、文章表現や単語も異なるため0と評価しました。"}
# similarity_assessment_model(query1, 課題　3-1,3-2を行いました): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なります。"}
#
# Query 2: ID見つかりました！大変失礼いたしました🙇‍♀️
# Most similar data (top 5):
# similarity_assessment_model(query2, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1と文章2は内容、文章表現、単語ともに全く異なるため、類似度は0です。"}
# similarity_assessment_model(query2, ID見つかりました！大変失礼いたしました🙇‍♀️): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, 11期生妻鹿です。２Week　２－３～２－４の課題をしました。日本語CatGTPが、先ほどラインしたように、今日から、「ようこそ！このGPTはサブスクライバー専用です。アカウントを確認していますので、少々お待ちください。初めての方は、サインアップの流れを案内します。」というメッセージが表示されます。そのため、日本語版ではないCatGTPにて課題をしました。日本語CatGTPだけ、無料期間があるのかどうかの、情報をお持ちでしたらご教示いただければさわいです。よろしくお願いいたします。): {"similarity": 0, "comment": "文章1はIDが見つかったという内容で、文章2は日本語版CatGTPの課題に関する内容です。文章の内容が全く異なっており、文章表現や単語も異なっています。"}
# similarity_assessment_model(query2, お世話になっております。パソコンについて確認したいのですが、MacBookAirでも問題ないでしょうか。): {"similarity":0,"comment":"文章の内容も表現も全く異なるため、類似度は0です。"}
# similarity_assessment_model(query2, 6-4.7-3の提出しております。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現も異なるため、類似度は0です。"}
#
#
# Query 3: ☁️日次報告☁️今日は取り組めませんでした💦
# Most similar data (top 5):
# similarity_assessment_model(query3, こんなメッセージが出ました。): {"similarity":0,"comment":"文章1と文章2は全く異なる内容であり、文章表現や単語も異なります。"}
# similarity_assessment_model(query3, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章1は、報告に関する内容で、文章2はパソコン購入に関する内容であり、内容が全く異なります。また、文章表現も大きく異なります。"}
# similarity_assessment_model(query3, 6-4.7-3の提出しております。): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なっているため"}
# similarity_assessment_model(query3, 11期生妻鹿です。２Week　２－３～２－４の課題をしました。日本語CatGTPが、先ほどラインしたように、今日から、「ようこそ！このGPTはサブスクライバー専用です。アカウントを確認していますので、少々お待ちください。初めての方は、サインアップの流れを案内します。」というメッセージが表示されます。そのため、日本語版ではないCatGTPにて課題をしました。日本語CatGTPだけ、無料期間があるのかどうかの、情報をお持ちでしたらご教示いただければさわいです。よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は、日次報告の簡潔な内容で、文章2は、具体的な課題遂行と、CatGPTの利用に関する質問という異なる内容です。文章表現や単語も大きく異なります。"}
# similarity_assessment_model(query3, ☁️日次報告☁️今日は取り組めませんでした💦): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
#
# Query 4: 島戸さん宛
# Most similar data (top 5):
# similarity_assessment_model(query4, 島戸さん宛): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容であり、文章表現も全く同じであるため、類似度は5です。"}
# similarity_assessment_model(query4, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章1は宛名のみで、文章2はパソコンの到着遅延に関する内容です。内容が異なるため、類似度は0です。"}
# similarity_assessment_model(query4, 6-4.7-3の提出しております。): {"similarity": 0, "comment": "文章1は宛名のみ、文章2は提出書類についての記述であるため、内容が全く異なる。文章表現も単語も異なっている。"}
# similarity_assessment_model(query4, 10月24日に取り組んだ内容・【2-2】実践課題の実施・提出ご確認を宜しくお願いいたします。): {"similarity": 0, "comment": "文章1は宛名のみで、文章2は具体的な内容と依頼が含まれているため、内容が大きく異なります。文章表現も単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query4, こんなメッセージが出ました。): {"similarity":0,"comment":"文章1と文章2は、文末が「。」で終わっているという点以外、共通点が見当たらないため。"}
#
# Query 5: 8-3と8-4提出致しました。よろしくお願いします
# Most similar data (top 5):
# similarity_assessment_model(query5, 失礼しました。15分からでしたので、間に合うかもしれません。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query5, 8-3と8-4提出致しました。よろしくお願いします): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query5, 課題2-3,2-4完了しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（提出物の報告）が、細かい内容（提出物の番号）が異なり、文章表現も異なるため3とした。"}
# similarity_assessment_model(query5, こんなメッセージが出ました。): {"similarity":0,"comment":"文章の内容や表現、単語が全く異なります。"}
# similarity_assessment_model(query5, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章の内容、表現、単語が全て異なるため、類似度は0です。"}
#
# Query 6: 谷津さんへPC再起動したらできました！🥺✨ありがとうございます！！
# Most similar data (top 5):
# similarity_assessment_model(query6, こんなメッセージが出ました。): {"similarity":0,"comment":"文章1はPCのトラブルシューティングに関する感謝のメッセージ、文章2はトラブル発生の報告であり、内容、表現とも全く異なる。"}
# similarity_assessment_model(query6, かしこまりました！それまでにパソコンは用意して良いですか？パソコン購入の注意点は入会時に渡された資料を見ればいいですね？): {"similarity":0,"comment":"文章1はPCのトラブルに関する感謝のメッセージ、文章2はパソコン購入に関する案内であり、内容が異なるため。"}
# similarity_assessment_model(query6, 失礼しました。15分からでしたので、間に合うかもしれません。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query6, こんにちは。7-3の課題を提出しましたのでよろしくお願いします。ただ、プロンプトのリンクの貼り付けをどこにしたらいいのか分からず、欄外に貼り付けました。よろしくお願いします。): {"similarity": 0, "comment": "文章1はPCのトラブルシューティングに関する内容で感謝の気持ちを伝えています。一方、文章2は課題提出に関する連絡で、プロンプトのリンク貼り付けに関する質問をしています。文章の内容、表現、単語全てが異なるため類似度は0です。"}
# similarity_assessment_model(query6, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1はPCのトラブルに関する感謝の言葉、文章2はPC購入に関する連絡で、内容も文体も全く異なるため"}
#
# Query 7: 谷津さんへ昨日は進めれなかったので、今日3-3の再提出、3-4の課題の提出まで終わりました💡明日明後日は結構時間があるので、進められると思います✨
# Most similar data (top 5):
# similarity_assessment_model(query7, 島戸さんお疲れ様です。本日は貴重なお時間ありがとうございました！お話していて、自分の中でまだふわふわしてる部分があるなぁと感じたので、もうちょっと目標を明確にして少しずつですが、自分のペースで頑張りたいと思います。本日はWEBデザイン基礎編1-2まで行い、10月までの目標シートを作成しました。別途添付しますので、ご確認ください。): {"similarity": 0, "comment": "文章1は仕事の進捗報告、文章2は仕事に対する感想と目標設定に関する内容であり、内容が大きく異なります。文章表現や単語も異なっているため、類似度は0です。"}
# similarity_assessment_model(query7, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章1は仕事に関する内容で、文章2はパソコンの購入に関する内容で、全く異なる内容です。また、文章表現も単語も異なります。"}
# similarity_assessment_model(query7, 10月24日に取り組んだ内容・【2-2】実践課題の実施・提出ご確認を宜しくお願いいたします。): {"similarity": 0, "comment": "文章1は、進捗状況を報告しており、文章2は提出確認を依頼しているため、内容が全く異なります。文章表現や単語も異なるため、類似度は0としました。"}
#
# similarity_assessment_model(query7, 課題8-1.8-2を提出しました): {"similarity": 0, "comment": "文章1は、具体的な課題の進捗状況と今後の予定について記述していますが、文章2は課題の提出を報告しているのみで、内容が大きく異なります。また、文章表現や単語も異なっています。"}
# similarity_assessment_model(query7, こんにちは、カリキュラム4-1について、教えてください。任意課題でバナーを作成し、それをポートフォリオとして掲載しようと考えています。RESUMEのworksにこれのみ、登録すれば良いのでしょうか。): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も大きく異なります。"}
#
# Query 8: 内田様夜分に失礼致します。明日の面談ですが、子供の学校行事のため変更していただきたいです。10/25以降の平日15時までの時間でしたらいつでも構いません。よろしくお願いいたします。
# Most similar data (top 5):
# similarity_assessment_model(query8, 内田様夜分に失礼致します。明日の面談ですが、子供の学校行事のため変更していただきたいです。10/25以降の平日15時までの時間でしたらいつでも構いません。よろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は完全に一致するため、類似度は5です。"}
#
# similarity_assessment_model(query8, ChatGPTChatGPT): {"similarity": 0, "comment": "文章1は相手に依頼をする内容の文章で、文章2は文字列のみなので内容が全く異なり、文章表現も単語も異なります。"}
#
# similarity_assessment_model(query8, 風邪をこじらせて、1週間ほど寝込んでいました…今日から再開します💦課題6-3、6-4、7-1を提出しました): {"similarity": 0, "comment": "文章1は面談の変更依頼、文章2は体調不良からの復旧報告と課題提出報告であり、内容が全く異なる。また、単語も共通点が少ないため類似度は0です。"}
# similarity_assessment_model(query8, 本日も取り組みできませんでした。): {"similarity": 0, "comment": "文章の内容、文章表現、単語全てが異なるため"}
# similarity_assessment_model(query8, 嶋内さん🌱こんにちは！前回の面談でお聞きしたランサーズで案件を見ていたのですが、私もできたらコンペのがいいなと思っていたのですがあまり件数がなく、プロジェクトの方で2つ気になる案件を見つけました。ポートフォリオ掲載OKで実績なくても大丈夫とのことでやってみたいなと思ったのですが、もしやれることになったとしても勉強会やチャットを使いながらと思っていますが、お仕事ですし中途半端な状態で手をつけるのも良くないと思っているので悩んでいます。今、ハーテックの模擬案件に手をつけようかと思っててまだ進めていないのでそちらをしてから案件に手を付けるほうがいいのかをご助言頂きたいです！気になった案件のURLを添付するので確認していただけると助かります🙇‍♀️https://www.lancers.jp/work/detail/5124461?ref=mypagehttps://www.lancers.jp/work/detail/5121825?ref=mypage): {"similarity": 0, "comment": "文章の内容は全く異なり、単語も類似している部分が見当たらないため0としました。"}
#
# Query 9: ありがとうございます
# Most similar data (top 5):
# similarity_assessment_model(query9, どこから入ればよいでしょうか): {"similarity":0,"comment":"文章の内容、単語、表現が全て異なるため"}
# similarity_assessment_model(query9, ありがとうございます): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query9, ありがとうございます！): {"similarity": 4, "comment": "文章の大まかな内容は同じだが、文章表現が少し異なるため、4と評価した。"}
# similarity_assessment_model(query9, ありがとうございます): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query9, ありがとうございます。): {"similarity": "4", "comment": "文章の大まかな内容は同じだが、文章2の方が丁寧な表現になっている。"}
#
# Query 10: なんとか形にはなりましたが、まだまだです·····！でも昨日の絶望感は無くなりました！今度の金曜日に勉強会を予約したので、自分ではどうにもならない所を確認したいと思います！
# Most similar data (top 5):
# similarity_assessment_model(query10, 失礼しました。15分からでしたので、間に合うかもしれません。): {"similarity": 0, "comment": "文章1は勉強会に関する内容で、文章2は時間に関する内容なので、内容が全く異なります。また、文章表現や単語も大きく異なっています。"}
# similarity_assessment_model(query10, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章1は勉強会に関する内容で、文章2はパソコンの到着待ちに関する内容のため、内容が全く異なる。また、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query10, 課題8-1.8-2を提出しました): {"similarity":0,"comment":"文章の内容が全く異なる。文章1は学習の進捗に関する記述だが、文章2は課題提出に関する記述である。文章表現や単語も異なるため、類似度は低い。"}
# similarity_assessment_model(query10, 添削ありがとうございます(emoji)続けてWeek1-4実践課題②③④を提出しましたご確認よろしくお願いします): {"similarity": 0, "comment": "文章1は自身の学習進捗と今後の予定について記述していますが、文章2は課題提出の報告のみであり、内容が大きく異なります。文章表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query10, 今日は忙しく取り組めません。): {"similarity": 0, "comment": "文章の内容が大きく異なり、文末表現や単語も全く異なるため、類似度は0です。"}
#
# Query 11: week 5-1の課題を提出しました。
# Most similar data (top 5):
# similarity_assessment_model(query11, 7-3実践課題ワークシートに記入しました。添削のほどよろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出に関する内容）が、細かい内容（提出物の内容や提出先）が異なり、文章表現も異なるため、3としました。"}
# similarity_assessment_model(query11, おはようございます。承知いたしました。13:30以降は融通が効きますので、ご都合をお知らせください。よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は課題提出に関する内容、文章2はスケジュールの調整に関する内容で、内容、文章表現、単語全てが異なっています。"}
# similarity_assessment_model(query11, こんばんはお世話になっております。2-3実践課題を提出いたしました。宜しくお願い致します(emoji)): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出時期や課題番号）、文章表現も異なる。"}
# similarity_assessment_model(query11, 立て続けに申し訳ありません。実践課題について質問させてください。2-1のコメントを提出したのですが、エラーになって書き直したところ、なぜか2-2にも2-1と同じ内容のコメントが提出されてしまいました💦2-2の課題では、画像を提出しましょう！となっていたのですが、画像を提出できないまますでに完了となってしまいました…このままでも問題ないのでしょうか？🙇‍♂️): {"similarity": 0, "comment": "文章1と文章2は、内容、文章表現、単語全てが異なるため、類似度は0です。"}
#
# similarity_assessment_model(query11, 1-3の課題が再提出になってたので2回目として再提出してて、その添削コメントには今回で完了と書いてありますが、また3回目を提出という表示が出ていますこれは放っておいて大丈夫ですか？): {"similarity": 0, "comment": "文章1と文章2の内容は全く異なります。文章1は課題提出に関する報告であり、文章2は課題の再提出に関する質問です。また、文章表現や単語も大きく異なります。"}
#
# Query 12: 谷津さまご連絡が遅くなり申し訳ございません。子供が急に体調が悪くなってしまい、参加出来ませんでした。また、日を改めさせて頂きます。
# Most similar data (top 5):
# similarity_assessment_model(query12, 谷津さまご連絡が遅くなり申し訳ございません。子供が急に体調が悪くなってしまい、参加出来ませんでした。また、日を改めさせて頂きます。): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
#
# similarity_assessment_model(query12, 谷津さまご連絡が遅くなり申し訳ございません。子供が急に体調が悪くなってしまい、参加出来ませんでした。また、日を改めさせて頂きます。): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容であり、文章表現も全く同じです。"}
# similarity_assessment_model(query12, 谷津さまご連絡が遅くなり申し訳ございません。子供が急に体調が悪くなってしまい、参加出来ませんでした。また、日を改めさせて頂きます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query12, 谷津さまご連絡が遅くなり申し訳ございません。子供が急に体調が悪くなってしまい、参加出来ませんでした。また、日を改めさせて頂きます。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query12, 谷津さまご連絡が遅くなり申し訳ございません。子供が急に体調が悪くなってしまい、参加出来ませんでした。また、日を改めさせて頂きます。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
#
# Query 13: 11期生妻鹿です。昨日は、学習できずでしたが、今日は進めています。2-1 【実践課題】ChatGPTでメール作成をしてみようの、実践課題ができました。よろしくお願いいたします。
# Most similar data (top 5):
# similarity_assessment_model(query13, 11期生妻鹿です。昨日は、学習できずでしたが、今日は進めています。2-1 【実践課題】ChatGPTでメール作成をしてみようの、実践課題ができました。よろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query13, ご連絡ありがとうございます。31日は時間か合いそうなので、また改めて予約しますなかなか進まないのですが、できるだけ取り組み頑張ります(頑張る)): {"similarity": 0, "comment": "文章1は学習に関する報告で、文章2は仕事の依頼や進捗に関する内容であり、内容や単語、文体も異なるため、類似度は0です。"}
# similarity_assessment_model(query13, おはようございます。承知いたしました。13:30以降は融通が効きますので、ご都合をお知らせください。よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は学習に関する内容で、文章2は仕事の予定に関する内容であり、全く異なるため類似度は0です。"}
# similarity_assessment_model(query13, 10月24日に取り組んだ内容・【2-2】実践課題の実施・提出ご確認を宜しくお願いいたします。): {"similarity":1,"comment":"文章1はChatGPTを用いたメール作成についての報告、文章2は実践課題の実施報告。内容が異なるが、文章表現や単語は似通っている。"}
# similarity_assessment_model(query13, 1-3の課題が再提出になってたので2回目として再提出してて、その添削コメントには今回で完了と書いてありますが、また3回目を提出という表示が出ていますこれは放っておいて大丈夫ですか？): {"similarity": 0, "comment": "文章1と文章2の内容は全く異なり、単語も異なるため、類似度は0です。"}
#
#
# Query 14: Week8  8-4の課題を提出しました
# Most similar data (top 5):
# similarity_assessment_model(query14, Week8  8-4の課題を提出しました): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query14, 課題提出しました): {"similarity": 3, "comment": "文章1は課題提出の詳細がわかるが、文章2は詳細が不明。そのため、細かい内容は異なる。しかし、文章表現は類似しているため3とした。"}
# similarity_assessment_model(query14, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1は課題提出に関するもので、文章2はパソコン購入に関するものであり、内容も表現も全く異なるため"}
# similarity_assessment_model(query14, 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も大きく異なります。"}
# similarity_assessment_model(query14, 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！): {"similarity": 0, "comment": "文章1は課題提出に関するもので、文章2は予約に関するものです。内容、表現、単語全てが異なるため、類似度は0です。"}
#
# Query 15: 藤川様へ【本日取り組んだこと】・3-3 実践課題手直し、再提出・3-4 課題提出
# Most similar data (top 5):
# similarity_assessment_model(query15, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ご連絡遅くなってしまいましたが、2回目の面談は希望しません。よろしくお願いします。): {"similarity": 0, "comment": "文章1は業務報告書の内容で、文章2は個人的な連絡です。内容、文章表現、単語全てが異なります。"}
# similarity_assessment_model(query15, ご丁寧にありがとうございます。何かエラーがでるのかと不安になっていたので問題なければ大丈夫です！必要があれば転送して受講させていただくので、変更はなしでお願いします。明日からよろしくお願いいたします🙇): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query15, こんにちは！昨日成果をご報告するのを忘れていたので、今させていただきます。・動画視聴、課題提出・バナートレース途中まで): {"similarity": 1, "comment": "文章の内容は異なり、藤川様への報告と、成果報告という文脈の違いが大きい。しかし、箇条書き形式で具体的な内容を羅列している点は共通しているため、1点としました。"}
# similarity_assessment_model(query15, ブラウザで送信する事ができました。遅くなってしまいすみません。ご確認をお願いします。): {"similarity":0,"comment":"文章1は業務報告の内容で、文章2は単に送信完了を報告する内容であり、内容、単語、文章表現共に類似点が見当たらないため。"}
# similarity_assessment_model(query15, ご対応ありがとうございます！こちらこそよろしくお願いいたします！): {"similarity": 0, "comment": "文章1は業務報告の内容で、文章2は挨拶の言葉であり、内容も文章表現も全く異なるため、類似度は0です。"}
#
# Query 16: ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。
# Most similar data (top 5):
# similarity_assessment_model(query16, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1は日報に関する内容、文章2はパソコン購入に関する内容で、内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query16, ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。): {"similarity":5,"comment":"文章1と文章2は全く同じ内容です。"}
# similarity_assessment_model(query16, ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
#
# similarity_assessment_model(query16, ありがとうございます): {"similarity":0,"comment":"文章1は日報の内容、文章2は感謝の言葉と全く異なるため類似度は0です。"}
# similarity_assessment_model(query16, こんばんは、予約いれました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっています。"}
#
# Query 17: 青木さん、おはようございます🌞早速ですが、下記に進捗状況をまとめております🙂‍↕️10/10(金)・2-3課題提出・任意課題のバナートレースのやり方を確認10/11(土)・バナートレースの取り組み開始以上となります。今週、帰省するためご連絡が遅くなるかもしれませんが、少しずつ進めてまいります!!✨どうぞよろしくお願いします🙇🏻‍♀️!!
# Most similar data (top 5):
# similarity_assessment_model(query17, 谷津さん11/43-3の提出課題をしました。): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query17, 失礼しました。15分からでしたので、間に合うかもしれません。): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なっています。"}
#
# similarity_assessment_model(query17, 6-4.7-3の提出しております。): {"similarity": 0, "comment": "文章1は進捗状況の報告で、文章2は単に提出した課題番号を記載しているため、内容が全く異なります。また、文章表現も大きく異なり、単語も共通しているものがほとんどないため、類似度は0と判断しました。"}
# similarity_assessment_model(query17, ありがとうございます): {"similarity": 0, "comment": "文章1は仕事の進捗状況を報告する内容で、文章2は単に感謝の言葉を述べているため、内容が全く異なる。また、文章表現や単語も大きく異なる。"}
# similarity_assessment_model(query17, 青木さん、おはようございます🌞早速ですが、下記に進捗状況をまとめております🙂‍↕️10/10(金)・2-3課題提出・任意課題のバナートレースのやり方を確認10/11(土)・バナートレースの取り組み開始以上となります。今週、帰省するためご連絡が遅くなるかもしれませんが、少しずつ進めてまいります!!✨どうぞよろしくお願いします🙇🏻‍♀️!!): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
#
# Query 18: 谷津さんへ今日はありがとうございました！今月の目標作成しました🙇‍♀️次回の面談までまた頑張ります！✨
# Most similar data (top 5):
# similarity_assessment_model(query18, こんなメッセージが出ました。): {"similarity": 0, "comment": "文章1は感謝と目標達成に向けた意気込みを伝えるメッセージで、文章2はエラーメッセージの内容を示唆しています。内容、文章表現、単語ともに大きく異なっているため、類似度は0と判断しました。"}
# similarity_assessment_model(query18, 谷津さんへ今日はありがとうございました！今月の目標作成しました🙇‍♀️次回の面談までまた頑張ります！✨): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query18, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity":0,"comment":"文章の内容、表現、単語全てが異なっています。"}
# similarity_assessment_model(query18, 課題8-1.8-2を提出しました): {"similarity": 0, "comment": "文章1は感謝の気持ちを伝えた上で、今後の目標設定への意欲を示す内容。一方、文章2は課題提出の報告のみで、内容が大きく異なる。また、文章表現も異なっている。"}
# similarity_assessment_model(query18, 添削ありがとうございます(emoji)続けてWeek1-4実践課題②③④を提出しましたご確認よろしくお願いします): {"similarity": "3", "comment": "文章の大まかな内容は類似している（感謝の言葉と報告）が、細かい内容は異なり（文章1は目標作成の報告、文章2は課題提出の報告）、文章表現も異なっている（文章1は絵文字が1つ、文章2は絵文字が2つ）ため、3と判断しました。"}
#
# Query 19: お忙しい所、ご返信ありがとうございます😭✨✨非表示アイコンのクリック、確認致しました！！そちらで試してみます☺️また、操作方法のサイトまで、ありがとうございます🙏確認させていただきます❣️今後とも、宜しくお願い致します🙂‍↕️
# Most similar data (top 5):
# similarity_assessment_model(query19, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1は感謝の気持ちを伝える内容で、文章2はパソコンの到着を待つ旨を伝える内容です。内容、単語、文章表現全てが異なるため0としました。"}
# similarity_assessment_model(query19, お忙しい所、ご返信ありがとうございます😭✨✨非表示アイコンのクリック、確認致しました！！そちらで試してみます☺️また、操作方法のサイトまで、ありがとうございます🙏確認させていただきます❣️今後とも、宜しくお願い致します🙂‍↕️): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query19, 失礼しました。15分からでしたので、間に合うかもしれません。): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現も異なります。"}
# similarity_assessment_model(query19, こんなメッセージが出ました。): {"similarity":0,"comment":"文章1は感謝の気持ちを込めた返信、文章2はエラーメッセージの内容。内容も文章表現も全く異なる。"}
# similarity_assessment_model(query19, 1-4実践課題②を提出しました): {"similarity":0,"comment":"文章の内容や単語が全く異なるため、類似度は0です。"}
#
# Query 20: 8-2を始めましたがvrewを開く事ができません💦
# Most similar data (top 5):
# similarity_assessment_model(query20, こんにちは！パソコンを購入したのですが到着が遅れており、まだ手元にきておりません。Slackはパソコンから参加したいので、少しお待ち下さい。よろしくお願いします。): {"similarity": 0, "comment": "文章1と文章2は全く異なる内容であり、文章表現も異なります。"}
# similarity_assessment_model(query20, Week3-3の課題を提出しました。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query20, ご確認ありがとうございます！2-1、間違えて提出していたのですね！申し訳ございません！再度提出致します！よろしくお願い申し上げます。): {"similarity":0,"comment":"文章1と文章2は内容、単語、文章表現全てが異なるため類似度は0です。"}
# similarity_assessment_model(query20, ブラウザで送信する事ができました。遅くなってしまいすみません。ご確認をお願いします。): {"similarity":0,"comment":"文章1と文章2は、内容、単語、文章表現において全く異なるため、類似度は0です。"}
# similarity_assessment_model(query20, こんばんは、予約いれました。): {"similarity": 0, "comment": "文章の内容、表現、単語全てが異なっています。"}

# %% [markdown]
# # **Word2Vec Implementation (Model 5)**

# %%
# !pip install nltk
# !pip install gensim
# !pip install janome
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)
# Collecting janome
#   Downloading Janome-0.5.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Downloading Janome-0.5.0-py2.py3-none-any.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 80.1 MB/s eta 0:00:00
# Installing collected packages: janome
# Successfully installed janome-0.5.0

# %% [markdown]
# With category

# %%
import jsonlines
import numpy as np
import random
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from janome.tokenizer import Tokenizer  # For Japanese tokenization
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Initialize Janome tokenizer for Japanese
tokenizer = Tokenizer()

# Function to tokenize Japanese text
def tokenize_japanese(text):
    return [token.surface for token in tokenizer.tokenize(text)]

# Step 1: Load your dataset (output_categories.jsonl)
with jsonlines.open('output_with_categories_1107.jsonl') as reader:
    qa_pairs = [obj for obj in reader]

# Step 2: Prepare the question-answer-category pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']} Category: {pair['category']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]
categories = [pair['category'] for pair in qa_pairs]

# Tokenize data using Janome for Japanese text
tokenized_data = []
for item in qa_pairs:
    question_tokens = tokenize_japanese(item['question'])
    answer_tokens = tokenize_japanese(item['answer'])
    category_tokens = tokenize_japanese(item['category'])
    # Flatten question, answer, and category into the same list for Word2Vec training
    tokenized_data.append(question_tokens + answer_tokens + category_tokens)

# Train Word2Vec model
model = Word2Vec(sentences=tokenized_data, vector_size=100, window=5, min_count=1, workers=4)

# Create a vectorized representation of questions without averaging word vectors
def get_combined_vector(tokens):
    vectors = [model.wv[token] for token in tokens if token in model.wv]
    if vectors:
        return np.vstack(vectors)  # Stack vectors vertically
    else:
        return None

question_vectors = []
for item in qa_pairs:
    question_tokens = tokenize_japanese(item['question'])
    question_vec = get_combined_vector(question_tokens)
    question_vectors.append(question_vec)

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Function to find the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    query_tokens = tokenize_japanese(query)
    query_vec = get_combined_vector(query_tokens)

    if query_vec is not None:
        valid_vectors = [(i, vec) for i, vec in enumerate(question_vectors) if vec is not None]
        similarities = []
        for i, vec in valid_vectors:
            similarity = cosine_similarity(query_vec, vec).mean()  # Calculate similarity between stacked vectors
            similarities.append((i, similarity))
        similarities = sorted(similarities, key=lambda x: x[1], reverse=True)
        most_similar_indices = [i for i, _ in similarities[:top_k]]
        closest_questions = [questions[i] for i in most_similar_indices]
        return closest_questions
    else:
        return []

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)


# Evaluate the system with 20 selected questions using Word2Vec
print("Evaluating using Word2Vec:")
similarity_scores = []
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        score_value = float(json.loads(similarity_score)['similarity'])
        similarity_scores.append(score_value)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# Evaluating using Word2Vec:
# query1: ありがとうございます。,ありがとうございます。,ありがとうございます,ありがとうございます,ありがとうございます
# similarity_assessment_model(query1, ありがとうございます。): {"similarity":0,"comment":"文章1は課題提出の謝罪と休日の連絡、面談予約の連絡をしている。文章2は単に感謝の言葉であり、内容が全く異なる。"}
# similarity_assessment_model(query1, ありがとうございます。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なっているため、類似度は0です。"}
#
# similarity_assessment_model(query1, ありがとうございます): {"similarity": 0, "comment": "文章1は休日の連絡と面談予約に関する内容、文章2は単に感謝の言葉であり、内容が全く異なる。単語も共通点が見当たらないため、類似度は0です。"}
# similarity_assessment_model(query1, ありがとうございます): {"similarity":0,"comment":"文章の内容が全く異なり、単語や文章表現も異なります。"}
# similarity_assessment_model(query1, ありがとうございます): {"similarity": 0, "comment": "文章1は休日の連絡と面談予約に関する内容ですが、文章2は単に感謝の言葉のみで内容が全く異なります。文章表現や単語も異なっています。"}
# query2: すみません解決しました,解決したので返信不要です,おはようございます。今記入し、締結完了メールも届きました。お手数おかけしました。ありがとうございます。,解決しました。回答不要です。,お手数をおかけしますがご確認お願いします。
# similarity_assessment_model(query2, すみません解決しました): {"similarity": 0, "comment": "文章1は動画制作に関する質問と確認を依頼する内容で、文章2は解決報告のみの内容であり、内容、単語、表現全てが異なります。"}
# similarity_assessment_model(query2, 解決したので返信不要です): {"similarity": 0, "comment": "文章1は動画作成に関する質問や確認事項があり、文章2は問題解決の報告であり、内容が全く異なります。また、文章表現や単語も大きく異なります。"}
# similarity_assessment_model(query2, おはようございます。今記入し、締結完了メールも届きました。お手数おかけしました。ありがとうございます。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現も異なります。"}
# similarity_assessment_model(query2, 解決しました。回答不要です。): {"similarity":0,"comment":"文章1は動画に関する質問について確認・質問をしたい旨を伝えていますが、文章2は問題が解決した旨を伝えており、内容が全く異なります。また、文章表現や単語も異なります。"}
# similarity_assessment_model(query2, お手数をおかけしますがご確認お願いします。): {"similarity":0,"comment":"文章1は動画作成に関する内容で、文章2は一般的な確認依頼のため、内容が全く異なります。文章表現も異なります。"}
# query3: 解決しました。回答不要です。,解決したので返信不要です,いえいえ。ありがとうございます。,誠に有難うございますm(__)mはげみます！！！,了解です。有難うございます。
# similarity_assessment_model(query3, 解決しました。回答不要です。): {"similarity": 0, "comment": "文章1は受講準備に関する問い合わせ、文章2は問題解決の報告であり、内容が全く異なるため"}
# similarity_assessment_model(query3, 解決したので返信不要です): {"similarity": 0, "comment": "文章1は受講準備に関する問い合わせで、文章2は返信不要の連絡です。内容が全く異なるため類似度は0です。"}
# similarity_assessment_model(query3, いえいえ。ありがとうございます。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっています。"}
# similarity_assessment_model(query3, 誠に有難うございますm(__)mはげみます！！！): {"similarity": 0, "comment": "文章の内容が全く異なり、単語も共通点が見当たらないため"}
# similarity_assessment_model(query3, 了解です。有難うございます。): {"similarity": 0, "comment": "文章1は受講準備に関する問い合わせであり、文章2は簡潔な返答であり、内容も表現も全く一致しません。"}
# query4: 課題提出しました,承知しました,承知しました,届きました。ありがとうございました。,了解しました
# similarity_assessment_model(query4, 課題提出しました): {"similarity": "3", "comment": "文章1は課題提出の報告と確認依頼をしているのに対し、文章2は単に提出したことを伝えているため、細かい内容は異なります。しかし、文章表現はどちらも簡潔で、課題提出に関する内容であるという点で類似性が見られます。"}
# similarity_assessment_model(query4, 承知しました): {"similarity": 0, "comment": "文章1は課題提出完了の連絡で、文章2は承知したという短い返信です。内容が全く異なります。"}
# similarity_assessment_model(query4, 承知しました): {"similarity": 0, "comment": "文章1は課題の提出完了を連絡しており、文章2は承知したとだけ伝えているため、内容が全く異なります。また、文章表現も異なります。"}
# similarity_assessment_model(query4, 届きました。ありがとうございました。): {"similarity": 1, "comment": "文章1は課題提出の報告で、文章2は受け取ったことを伝えているため、内容としては大きく異なります。しかし、どちらも簡潔な文章表現で、丁寧な言葉遣いが共通しているため、1としました。"}
# similarity_assessment_model(query4, 了解しました): {"similarity": 0, "comment": "文章1は課題提出の報告で、文章2は単に了解の返信であり、内容が全く異なります。また、文章表現も大きく異なります。"}
# query5: 今日はピンタレスト登録、バナーデザインのピックアップまでしました,すみません解決しました,日記にみたいに書いてしまい、すいません💦,ワークシート3の項目1～4まで提出しました。英語の翻訳のところがパソコンのチャットGTPではできなかったので、スマホを使い作成してリンクを共有しました,chatGPT講座の御指導ありがとうございました。新しい知識を身に付けることができとても勉強になりました。今回学んだ知識を仕事、生活で活かしていけるよう頑張ります。
# similarity_assessment_model(query5, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity":0,"comment":"文章の内容、文章表現、単語がすべて異なるため、類似度は0です。"}
# similarity_assessment_model(query5, すみません解決しました): {"similarity": 0, "comment": "文章1は、ワークシートの提出に関する内容で、文章2は、問題が解決したことを示す内容のため、内容が全く異なります。また、文章表現も単語も異なるため、類似度は0です。"}
#
# similarity_assessment_model(query5, 日記にみたいに書いてしまい、すいません💦): {"similarity": 0, "comment": "文章1はワークシートの提出に関する内容で、文章2は日記についての内容であり、内容、表現、単語ともに全く異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query5, ワークシート3の項目1～4まで提出しました。英語の翻訳のところがパソコンのチャットGTPではできなかったので、スマホを使い作成してリンクを共有しました): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容で、文章表現も同じです。"}
# similarity_assessment_model(query5, chatGPT講座の御指導ありがとうございました。新しい知識を身に付けることができとても勉強になりました。今回学んだ知識を仕事、生活で活かしていけるよう頑張ります。): {"similarity":0,"comment":"文章1は提出物の報告であり、文章2は講座の感想です。内容や表現が異なるため類似度は0です。"}
# query6: どうぞよろしくお願いいたします。,ありがとうございます♪,よろしくお願いいたします。,よろしくお願いいたします。,ありがとうございます。よろしくお願いいたします。
# similarity_assessment_model(query6, どうぞよろしくお願いいたします。): {"similarity":0,"comment":"文章1は課題提出に関する挨拶文であり、文章2は一般的な挨拶文であるため、内容、表現、単語ともに大きく異なります。"}
# similarity_assessment_model(query6, ありがとうございます♪): {"similarity": 0, "comment": "文章1は課題提出に関する連絡で、文章2は感謝の言葉です。内容、単語、文章表現が全く異なるため類似度は0です。"}
#
# similarity_assessment_model(query6, よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は課題提出に関する挨拶文で、文章2は単なる挨拶文です。内容も表現も全く異なります。"}
# similarity_assessment_model(query6, よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は課題提出の挨拶文であり、文章2は一般的な挨拶文です。内容、単語、文章表現が異なるため、類似度は0です。"}
# similarity_assessment_model(query6, ありがとうございます。よろしくお願いいたします。): {"similarity": "0", "comment": "文章1は課題提出に関する連絡であり、文章2は一般的な挨拶と依頼の言葉です。内容、単語、文章表現全てが異なります。"}
# query7: 5-1実践課題提出しました,2-2課題提出しました,4-2実践課題完了しました,5-2まで提出,実践課題1ー4①提出しました
# similarity_assessment_model(query7, 5-1実践課題提出しました): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現は類似している。提出時期が異なるため、細かい内容は異なる。しかし、文章表現はどちらも簡潔で類似している。"}
# similarity_assessment_model(query7, 2-2課題提出しました): {"similarity":4,"comment":"文章の大まかな内容は類似している（提出に関する内容）。細かい内容は異なっている（文章1は提出完了、文章2は提出のみ）。文章表現は類似している（簡潔な表現）"}
# similarity_assessment_model(query7, 4-2実践課題完了しました): {"similarity": 4, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なります。文章1には提出まで完了したという記述があり、文章2には完了したという記述のみです。しかし、文章表現は類似しています。"}
# similarity_assessment_model(query7, 5-2まで提出): {"similarity": 2, "comment": "文章1は提出物が完了したことを伝えているのに対し、文章2は提出物の範囲を示しているため、内容は異なります。しかし、提出に関する単語が共通しているため、2としました。"}
# similarity_assessment_model(query7, 実践課題1ー4①提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は「提出まで完了しました」と締めくくっているのに対し、文章2は「提出しました」と簡潔に締めくくっている。また、文章1では「実践課題」と「提出」が明確に分離されているのに対し、文章2では「実践課題1ー4①」と「提出」がハイフンで繋げられている。"}
# query8: ありがとうございます！！,ありがとうございます！,ありがとうございます！,ありがとうございます！,ありがとうございます！
# similarity_assessment_model(query8, ありがとうございます！！): {"similarity": 0, "comment": "文章1は日次報告の内容、文章2は感謝の言葉であり、内容も表現も全く異なります。"}
#
# similarity_assessment_model(query8, ありがとうございます！): {"similarity":0,"comment":"文章1は日報の内容で、文章2は単なる感謝の言葉です。内容も文章表現も全く異なります。"}
# similarity_assessment_model(query8, ありがとうございます！): {"similarity": 0, "comment": "文章の内容が全く異なり、単語も異なっています。"}
#
# similarity_assessment_model(query8, ありがとうございます！): {"similarity": 0, "comment": "文章1は日報の内容を記載しており、文章2は挨拶のみです。内容、表現、単語ともに類似点がありません。"}
# similarity_assessment_model(query8, ありがとうございます！): {"similarity": 0, "comment": "文章1は日次報告の内容、文章2は感謝の言葉であり、内容も表現も全く異なるため0としました。"}
# query9: 課題提出しました,2-４実践課題提出しました。,2-2課題提出しました,6-1実践課題提出しました。,5-1実践課題提出しました
# similarity_assessment_model(query9, 課題提出しました): {"similarity": "3", "comment": "文章1は提出の報告に加えて、相手へのあいさつと依頼が含まれている。文章2は提出の報告のみで、あいさつや依頼が含まれていない。そのため、文章の大まかな内容は類似しているが、細かい内容は異なっている。文章表現はどちらも簡潔で、類似していると言える。"}
# similarity_assessment_model(query9, 2-４実践課題提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似している(課題提出)が、細かい内容は異なり(期間や表現)、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query9, 2-2課題提出しました): {"similarity": "2", "comment": "文章1は4週間の実践課題の提出について、文章2は2-2の課題提出についてと、内容が異なります。しかし、どちらも課題提出についての内容であるため、単語が似通っています。"}
# similarity_assessment_model(query9, 6-1実践課題提出しました。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（週数、課題番号）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query9, 5-1実践課題提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している(提出物について)が、細かい内容(提出物の具体的な内容)が異なっており、文章表現も異なっている(文章1は丁寧な表現、文章2は簡潔な表現)ため3とした。"}
# query10: 今日はピンタレスト登録、バナーデザインのピックアップまでしました,Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。,すみません解決しました,青木さんワイヤーフレームの書き方まで終わりました。,こんばんは！本日の成果をご報告します。・オリジナルバナー制作
# similarity_assessment_model(query10, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity": "0", "comment": "文章1はCanvaのトレースに関する内容で、文章2はピンタレストの登録とバナーデザインに関する内容なので、内容は全く異なります。また、文章表現や単語も異なるため、類似度は0です。"}
#
# similarity_assessment_model(query10, Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。): {"similarity": 2, "comment": "文章1はCanvaトレースの任意課題、文章2はWeek5の実戦課題と、内容は異なります。しかし、どちらも課題提出に関する内容であり、単語も一部共通しているため、2と評価しました。"}
# similarity_assessment_model(query10, すみません解決しました): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query10, 青木さんワイヤーフレームの書き方まで終わりました。): {"similarity":0,"comment":"文章1はCanvaトレースの任意課題について、文章2はワイヤーフレームについて記述しており、内容が全く異なります。また、単語も共通点がほとんどありません。"}
# similarity_assessment_model(query10, こんばんは！本日の成果をご報告します。・オリジナルバナー制作): {"similarity": "0", "comment": "文章1はCanvaトレースの任意課題についての報告、文章2はオリジナルバナー制作の報告であり、内容も表現も大きく異なります。"}
# query11: ありがとうございます！！,ありがとうございます！,ありがとうございます！,ありがとうございます！,ありがとうございます！
# similarity_assessment_model(query11, ありがとうございます！！): {"similarity": "4", "comment": "文章の大まかな内容は同じですが、文章表現が異なります。文章2では「！」が二つ使われているため、文章1よりも強い感情表現となっています。"}
# similarity_assessment_model(query11, ありがとうございます！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query11, ありがとうございます！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query11, ありがとうございます！): {"similarity":5,"comment":"文章1と文章2は全く同じ文章なので、類似度は5です。"}
# similarity_assessment_model(query11, ありがとうございます！): {"similarity":5,"comment":"文章1と文章2は全く同じ文章のため、類似度は5です。"}
# query12: 解決したので返信不要です,解決しました。回答不要です。,今週もまとめての対応となり誠に恐れ入ります💦,ありがとうございます。対応します,お手数をおかけしますがご確認お願いします。
# similarity_assessment_model(query12, 解決したので返信不要です): {"similarity": 0, "comment": "文章の内容、表現、単語ともに異なるため"}
#
# similarity_assessment_model(query12, 解決しました。回答不要です。): {"similarity":0,"comment":"文章1はイベントへの参加に関する返答で、文章2は問題解決に関する返答であり、内容や表現が全く異なるため類似度は0です。"}
# similarity_assessment_model(query12, 今週もまとめての対応となり誠に恐れ入ります💦): {"similarity": 0, "comment": "文章1はイベントへの参加に関する内容で、文章2は業務に関する内容のため、内容が全く異なります。また、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query12, ありがとうございます。対応します): {"similarity": 0, "comment": "文章1はイベントへの参加に関する断りの返信で、文章2は依頼に対する承諾の返信です。内容、単語、表現が全く異なります。"}
# similarity_assessment_model(query12, お手数をおかけしますがご確認お願いします。): {"similarity": 0, "comment": "文章の内容、表現、単語が全て異なるため、類似度は0です。"}
# query13: 5-2まで提出,井関さん「今日取り組んだこと」2-1 動画視聴2-1 課題提出2-2動画視聴2-2 実践課題実施2-2 実践課題提出,井関さん「今日取り組んだこと」1-3 実践課題実施提出1-4 動画視聴1-4 課題実施1-3 任意課題実施,week6-1,6-2 課題を提出しました,3-1 実践課題3-2 実践課題提出しました。
# similarity_assessment_model(query13, 5-2まで提出): {"similarity": 1, "comment": "文章の内容は大きく異なり、文章表現も異なります。しかし、文章1の「2-1」「2-2」のような番号を用いた書き方は、文章2の「5-2」と類似しているため、1としました。"}
# similarity_assessment_model(query13, 井関さん「今日取り組んだこと」2-1 動画視聴2-1 課題提出2-2動画視聴2-2 実践課題実施2-2 実践課題提出): {"similarity": 5, "comment": "文章1と文章2は、内容、表現ともに全く同じです。"}
# similarity_assessment_model(query13, 井関さん「今日取り組んだこと」1-3 実践課題実施提出1-4 動画視聴1-4 課題実施1-3 任意課題実施): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、動画視聴や課題提出などの単語が共通している。"}
# similarity_assessment_model(query13, week6-1,6-2 課題を提出しました): {"similarity": "1", "comment": "文章1は具体的な内容が書かれており、文章2は抽象的な内容である。文章表現はどちらも簡潔で類似している。そのため、文章の内容は異なっているが、文章表現や文章の雰囲気が似ているため、1とした。"}
# similarity_assessment_model(query13, 3-1 実践課題3-2 実践課題提出しました。): {"similarity": "1", "comment": "文章1の内容は、具体的な作業内容と時間軸が示されているのに対し、文章2は漠然とした内容で、時間軸も示されていません。文章表現は、文章1は箇条書きで、文章2は文章形式なので異なっています。しかし、文章2は「実践課題」という言葉を用いているため、文章1と文内で使われている単語が似通っていると考えられます。"}
# query14: この画面がでます,スマホのアドレスで登録していて、パソコンの方で進めたいのですが。,コピーを作成するのですが、上手くコピーされないようです🥲,Slackは登録し直せたのですが、MoogaPlusの招待メールが届かないです💦,延長は、しなくてもこのまま終われそうではあります。
# similarity_assessment_model(query14, この画面がでます): {"similarity":0,"comment":"文章1はオリジナルバナー制作に関する質問であり、文章2は画面に関する記述であり、内容が全く異なるため0としました。"}
# similarity_assessment_model(query14, スマホのアドレスで登録していて、パソコンの方で進めたいのですが。): {"similarity": 0, "comment": "文章1はオリジナルバナー制作に関する質問、文章2はアカウントに関する質問で、内容が全く異なります。また、文章表現や単語も大きく異なります。"}
#
# similarity_assessment_model(query14, コピーを作成するのですが、上手くコピーされないようです🥲): {"similarity": 0, "comment": "文章1はオリジナルバナー制作に関する質問、文章2はコピー作成に関する質問であり、内容が全く異なるため"}
# similarity_assessment_model(query14, Slackは登録し直せたのですが、MoogaPlusの招待メールが届かないです💦): {"similarity":0,"comment":"文章1はオリジナルバナー制作に関する質問、文章2はSlackとMoogaPlusに関する問い合わせであり、内容が全く異なります。文章表現も異なっています。"}
# similarity_assessment_model(query14, 延長は、しなくてもこのまま終われそうではあります。): {"similarity":0,"comment":"文章1は、オリジナルバナー制作に関する質問で、画像の使用について問い合わせています。文章2は、延長の必要性について言及しており、内容が全く異なります。文章表現や単語も異なるため、類似度は0です。"}
# query15: どうでしょ？,どこから入ればよいでしょうか,Gammaの無料の400クレジットとはどういう意味ですか？,Slackの○○期生の、○○に入る数字は何になるんでしょうか,終了証ですが、何か履歴書などに書ける資格になるのでしょうか？
# similarity_assessment_model(query15, どうでしょ？): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なります。文章1は質問文、文章2は返答文であり、内容や表現に共通点が見当たりません。"}
# similarity_assessment_model(query15, どこから入ればよいでしょうか): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっており、文章表現が異なっている。文章1はガイダンスの開始方法について質問しているのに対し、文章2は具体的な内容への質問であり、より抽象的な表現となっている。"}
# similarity_assessment_model(query15, Gammaの無料の400クレジットとはどういう意味ですか？): {"similarity": 0, "comment": "文章1はガイダンスに関する質問、文章2はクレジットに関する質問であり、内容が全く異なります。文章表現も単語も異なっています。"}
# similarity_assessment_model(query15, Slackの○○期生の、○○に入る数字は何になるんでしょうか): {"similarity":2,"comment":"文章の内容は異なっているが、どちらも質問文であり、文章内で使われている単語(例：初回、数字)が似ているため"}
# similarity_assessment_model(query15, 終了証ですが、何か履歴書などに書ける資格になるのでしょうか？): {"similarity":0,"comment":"文章1はガイダンスに関する質問、文章2は終了証に関する質問であり、内容が異なるため。また、文章表現や単語も異なる。"}
# query16: すみませんありました💦,昨日も作業できませんでした…,すみません解決しました,わかりました,解決したので返信不要です
# similarity_assessment_model(query16, すみませんありました💦): {"similarity": 0, "comment": "文章1は残業で疲れて課題が進められなかったという内容で、文章2は謝罪のみの内容です。内容、単語、文章表現全てが異なるため0としました。"}
# similarity_assessment_model(query16, 昨日も作業できませんでした…): {"similarity": 3, "comment": "文章1は残業で疲れたという具体的な理由が書かれているのに対し、文章2は理由が不明瞭です。しかし、どちらも作業できなかったという内容は共通しています。文章表現は異なるため3としました。"}
# similarity_assessment_model(query16, すみません解決しました): {"similarity": 0, "comment": "文章の内容、表現、単語全てが異なるため"}
# similarity_assessment_model(query16, わかりました): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query16, 解決したので返信不要です): {"similarity":0,"comment":"文章1は残業で疲れて課題が進められなかったという内容で、文章2は問題が解決したという内容で、どちらも内容は異なります。また文章表現も大きく異なります。"}
# query17: 解決しました。回答不要です。,解決したので返信不要です,届きました。ありがとうございました。,ご回答、添削ありがとうございました。,承知いたしました。ご対応ありがとうございます。
# similarity_assessment_model(query17, 解決しました。回答不要です。): {"similarity":0,"comment":"文章1はイベント参加のキャンセルについて、文章2は解決報告についての内容であり、内容が全く異なっています。また、文章表現や単語も異なっています。"}
# similarity_assessment_model(query17, 解決したので返信不要です): {"similarity": 0, "comment": "文章1はイベントのキャンセルに関する連絡で、文章2は問題解決の報告です。内容が全く異なるため類似度は0です。"}
# similarity_assessment_model(query17, 届きました。ありがとうございました。): {"similarity":0,"comment":"文章の内容、表現、単語が全く異なっています。"}
# similarity_assessment_model(query17, ご回答、添削ありがとうございました。): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query17, 承知いたしました。ご対応ありがとうございます。): {"similarity": 0, "comment": "文章1はイベントのキャンセルを伝える内容で、文章2は承諾と感謝を伝える内容のため、全く異なる内容です。単語もほとんど共通していません。"}
# query18: 5-2まで提出,井関さん「今日取り組んだこと」2-1 動画視聴2-1 課題提出2-2動画視聴2-2 実践課題実施2-2 実践課題提出,week6-1,6-2 課題を提出しました,week6-3, 6-4 課題提出しました。,https://www.figma.com/design/MvKCnSA1Z9qembmWX7M5Gk/%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3%E3%82%AB%E3%83%B3%E3%83%97%E3%80%80%E5%8F%82%E8%80%83%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3?node-id=4-34&t=l5oBrJBREGF1ynrT-1
# similarity_assessment_model(query18, 5-2まで提出): {"similarity": 2, "comment": "文章1は具体的な課題提出に関する記述だが、文章2は課題提出に関する漠然とした記述のため、内容としては大きく異なる。ただし、文内で使われている単語（提出）が似通っていることから、2と評価した。"}
# similarity_assessment_model(query18, 井関さん「今日取り組んだこと」2-1 動画視聴2-1 課題提出2-2動画視聴2-2 実践課題実施2-2 実践課題提出): {"similarity": 2, "comment": "文章1は、課題提出に関する報告で、日付と課題の範囲を記載している。文章2は、一日の業務内容を箇条書きで記述しており、日付や具体的な課題名は記載されていない。文章の内容は異なるが、課題提出という単語が使われているため、2と評価した。"}
# similarity_assessment_model(query18, week6-1,6-2 課題を提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似していますが、細かい内容が異なり、文章表現も異なっています。文章1では9/28にWeek6-2～6-4の実践課題を提出したことがわかりますが、文章2ではweek6-1,6-2の課題を提出したことがわかります。また、文章1では日付と課題番号が明確に示されているのに対し、文章2では日付が省略され、課題番号のみが示されています。文章表現も、文章1では「提出しました」と丁寧な表現が使われているのに対し、文章2では「課題を提出しました」と簡潔な表現が使われています。"}
# similarity_assessment_model(query18, week6-3, 6-4 課題提出しました。): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、課題提出であることがわかる。細かい内容では、文章1はWeek6-2〜6-4のすべての課題提出であるのに対し、文章2はWeek6-3,6-4の2つの課題提出である点が異なる。文章表現は類似している。"}
# similarity_assessment_model(query18, https://www.figma.com/design/MvKCnSA1Z9qembmWX7M5Gk/%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3%E3%82%AB%E3%83%B3%E3%83%97%E3%80%80%E5%8F%82%E8%80%83%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3?node-id=4-34&t=l5oBrJBREGF1ynrT-1): {"similarity": 2, "comment": "文章1は課題提出に関する内容で、文章2はFigmaのデザインに関するURLです。内容が大きく異なるため、0に近い数値としました。しかし、文章2のURLがデザインに関する内容であることから、文章1の課題提出もデザインに関する課題である可能性があり、単語が似通っていることから2としました。"}
# query19: 今日はピンタレスト登録、バナーデザインのピックアップまでしました,Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。,４-４提出しました,ワークシート3の項目1～4まで提出しました。英語の翻訳のところがパソコンのチャットGTPではできなかったので、スマホを使い作成してリンクを共有しました,4-4実践課題のプロンプトをワークシートに入力しました。添削のほど、よろしくお願いします。
# similarity_assessment_model(query19, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity": "3", "comment": "文章1は課題の進捗状況についての報告で、バナー作成について触れています。文章2はピンタレスト登録とバナーデザインのピックアップについて記述しており、文章1の内容とは異なります。しかし、どちらもバナーデザインという共通点があり、文章1の内容の一部を文章2が含んでいることから3と評価しました。"}
# similarity_assessment_model(query19, Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。): {"similarity": 2, "comment": "文章1は課題の進捗状況についての報告、文章2は課題の提出に関する内容であり、内容は異なる。しかし、どちらも課題に関する内容であり、文中に「課題」「ポートフォリオ」などの共通の単語が含まれているため、2と評価した。"}
# similarity_assessment_model(query19, ４-４提出しました): {"similarity": 1, "comment": "文章の内容は大きく異なりますが、文章表現や単語が少し似ています。文章1は課題の進捗状況について報告しているのに対し、文章2は単に提出したことを伝えています。しかし、どちらも課題に関する内容であり、文章表現には「～を視聴しました」「～を作成していきたいと思います」「提出しました」など、共通する単語や表現が見られます。"}
# similarity_assessment_model(query19, ワークシート3の項目1～4まで提出しました。英語の翻訳のところがパソコンのチャットGTPではできなかったので、スマホを使い作成してリンクを共有しました): {"similarity": "0", "comment": "文章1は、ポートフォリオやレジュメページ作成について述べており、課題の進捗状況に関する内容です。一方、文章2はワークシート提出に関する内容であり、文章1の内容とは全く異なります。文章表現や単語も異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query19, 4-4実践課題のプロンプトをワークシートに入力しました。添削のほど、よろしくお願いします。): {"similarity": "2", "comment": "文章1はポートフォリオやレジュメについて言及しており、文章2は実践課題について言及しているため、大まかな内容は異なります。しかし、文中に「課題」「動画」「作成」などの単語が共通して見られるため、2と評価しました。"}
# query20: すみません解決しました,課題提出しました,了解しました,Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。,大変失礼しました。承知しました。
# similarity_assessment_model(query20, すみません解決しました): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query20, 課題提出しました): {"similarity": 2, "comment": "文章1はAdobeFarawayの課題の提出について詳細に記述している一方、文章2は課題提出のみを簡潔に記述しており、内容が大きく異なります。しかし、どちらも課題提出に関する内容であるため、文内で使われている単語が似通っています。"}
# similarity_assessment_model(query20, 了解しました): {"similarity": 0, "comment": "文章1はAdobe Farawayの課題提出についての内容で、文章2は了解の返答のみで内容が全く異なります。そのため類似度は0です。"}
# similarity_assessment_model(query20, Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。): {"similarity": 0, "comment": "文章1はAdobeのソフトに関する内容、文章2は課題に関する内容で全く異なります。文章表現も単語も異なるため類似度は0と判断しました。"}
# similarity_assessment_model(query20, 大変失礼しました。承知しました。): {"similarity": 0, "comment": "文章1はAdobe Farawayの課題提出に関する内容で、文章2は謝罪と承諾の内容です。内容、単語、文章表現全てが異なるため、類似度は0です。"}

# %% [markdown]
# Without category

# %%
import jsonlines
import numpy as np
import random
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity
from janome.tokenizer import Tokenizer  # For Japanese tokenization
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting

# Initialize Janome tokenizer for Japanese
tokenizer = Tokenizer()

# Function to tokenize Japanese text
def tokenize_japanese(text):
    return [token.surface for token in tokenizer.tokenize(text)]

# Step 1: Load your dataset (output_categories.jsonl)
with jsonlines.open('qa_pairs_for_rag_1108.jsonl') as reader:
    qa_pairs = [obj for obj in reader]


# Step 2: Prepare the question-answer pairs as documents
documents = [f"Question: {pair['question']} Answer: {pair['answer']}" for pair in qa_pairs]
questions = [pair['question'] for pair in qa_pairs]
answers = [pair['answer'] for pair in qa_pairs]

# Tokenize data using Janome for Japanese text
tokenized_data = []
for item in qa_pairs:
    question_tokens = tokenize_japanese(item['question'])
    answer_tokens = tokenize_japanese(item['answer'])
    # Flatten question, answer, and category into the same list for Word2Vec training
    tokenized_data.append(question_tokens + answer_tokens )

# Train Word2Vec model
model = Word2Vec(sentences=tokenized_data, vector_size=100, window=5, min_count=1, workers=4)

# Create a vectorized representation of questions without averaging word vectors
def get_combined_vector(tokens):
    vectors = [model.wv[token] for token in tokens if token in model.wv]
    if vectors:
        return np.vstack(vectors)  # Stack vectors vertically
    else:
        return None

question_vectors = []
for item in qa_pairs:
    question_tokens = tokenize_japanese(item['question'])
    question_vec = get_combined_vector(question_tokens)
    question_vectors.append(question_vec)

# Select 20 random questions for evaluation
evaluation_indices = random.sample(range(len(questions)), 20)
evaluation_questions = [questions[i] for i in evaluation_indices]

# Function to find the 5 most similar questions based on query
def find_similar_questions(query, top_k=5):
    query_tokens = tokenize_japanese(query)
    query_vec = get_combined_vector(query_tokens)

    if query_vec is not None:
        valid_vectors = [(i, vec) for i, vec in enumerate(question_vectors) if vec is not None]
        similarities = []
        for i, vec in valid_vectors:
            similarity = cosine_similarity(query_vec, vec).mean()  # Calculate similarity between stacked vectors
            similarities.append((i, similarity))
        similarities = sorted(similarities, key=lambda x: x[1], reverse=True)
        most_similar_indices = [i for i, _ in similarities[:top_k]]
        closest_questions = [questions[i] for i in most_similar_indices]
        return closest_questions
    else:
        return []

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。\n\n
        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)


# Evaluate the system with 20 selected questions using Word2Vec
print("Evaluating using Word2Vec:")
similarity_scores = []
for idx, question in enumerate(evaluation_questions, start=1):
    similar_questions = find_similar_questions(question)
    similar_str = ','.join(similar_questions)
    print(f"query{idx}: {similar_str}")

    # Perform similarity assessment for each pair
    for similar_question in similar_questions:
        similarity_score = similarity_assessment_model(question, similar_question)
        score_value = float(json.loads(similarity_score)['similarity'])
        similarity_scores.append(score_value)
        print(f"similarity_assessment_model(query{idx}, {similar_question}): {similarity_score}")
# Out:
# Evaluating using Word2Vec:
# query1: ありがとうございます！！,ありがとうございます！,ありがとうございます！,ありがとうございます！,ありがとうございます！
# similarity_assessment_model(query1, ありがとうございます！！): {"similarity": 1, "comment": "文章1は目標シート提出の報告であり、文章2は感謝の言葉です。内容は異なりますが、短い文章で、丁寧な口調という点で雰囲気が似ています。"}
# similarity_assessment_model(query1, ありがとうございます！): {"similarity":1,"comment":"文章の内容は異なっていますが、文章表現や文章の雰囲気が似ているため、1としました。"}
# similarity_assessment_model(query1, ありがとうございます！): {"similarity": 0, "comment": "文章1は目標シート提出の報告、文章2は感謝の言葉であり、内容が全く異なります。文章表現も異なるため、類似度は0です。"}
# similarity_assessment_model(query1, ありがとうございます！): {"similarity":2,"comment":"文章1は目標シート提出の報告、文章2は感謝の言葉なので内容は異なる。しかし、文末に「！」が使われていることや、短い文章であることから、文の雰囲気が似ているため2とした。"}
# similarity_assessment_model(query1, ありがとうございます！): {"similarity": "1", "comment": "文章の内容は全く異なりますが、文章表現や単語が似ているため、1としました。"}
# query2: 課題提出しました,2-2課題提出しました,2-1課題提出しました,4-2実践課題完了しました,5-1実践課題提出しました
# similarity_assessment_model(query2, 課題提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の提出について）が、細かい内容は異なり（課題番号の記載の有無）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query2, 2-2課題提出しました): {"similarity":3,"comment":"文章の大まかな内容は類似している（課題提出について）が、細かい内容（課題番号）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query2, 2-1課題提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出について）が、細かい内容は異なり（課題番号が異なる）、文章表現も異なっている（「課題6-1を提出しました」と「2-1課題提出しました」の表現の違い）ため、3と評価しました。"}
# similarity_assessment_model(query2, 4-2実践課題完了しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している(課題の提出について)が、課題番号が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query2, 5-1実践課題提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の提出について）が、細かい内容（課題番号）が異なり、文章表現も異なっているため3とした。"}
# query3: 承知しました,承知しました,今日はピンタレスト登録、バナーデザインのピックアップまでしました,すみません解決しました,承知しました！
# similarity_assessment_model(query3, 承知しました): {"similarity": 0, "comment": "文章1は面談日の変更と今日の取り組みについて説明していますが、文章2は承知した旨のみを伝えているため、内容が大きく異なります。また、文章表現や単語も大きく異なるため、類似度は0と判断しました。"}
#
# similarity_assessment_model(query3, 承知しました): {"similarity": 0, "comment": "文章1は面談日の変更とCanva自習会の内容について言及している一方、文章2は承知した旨のみを伝えているため、内容が全く異なっています。また、文章表現も大きく異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query3, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity": "3", "comment": "文章1ではCanvaを使ったバナー制作について言及されていますが、文章2ではピンタレストの登録とバナーデザインのピックアップについて言及されています。文章の大まかな内容は類似していますが、細かい内容は異なり、文章表現も異なります。"}
# similarity_assessment_model(query3, すみません解決しました): {"similarity": 0, "comment": "文章1は面談に関する内容で、Canvaを使ったバナー制作について記述されています。文章2は問題解決の報告であり、内容が全く異なります。文章表現も異なっているため、類似度は0と判断しました。"}
# similarity_assessment_model(query3, 承知しました！): {"similarity": 0, "comment": "文章1の内容は面談の日程変更とCanvaの練習についてですが、文章2は承諾の返答のみで内容が大きく異なります。単語も共通点がなく、文章表現も異なるため、類似度は0です。"}
#
# query4: 5-2まで提出,2-1week2実践課題1つ目アップいたしました。,実践課題1ー4①提出しました,課題　3-1,3-2を行いました,井関さん「今日取り組んだこと」2-1 動画視聴2-1 課題提出2-2動画視聴2-2 実践課題実施2-2 実践課題提出
# similarity_assessment_model(query4, 5-2まで提出): {"similarity": 0, "comment": "文章1は、具体的な課題や授業内容が記載されており、詳細な作業内容がわかります。文章2は、簡潔に「5-2まで提出」と記載されており、具体的な内容が不明です。文章の内容、文章表現、単語全てが異なるため、類似度は0です。"}
# similarity_assessment_model(query4, 2-1week2実践課題1つ目アップいたしました。): {"similarity": "0", "comment": "文章1は業務報告の内容で、文章2は進捗報告の内容です。文章の内容、文章表現、単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query4, 実践課題1ー4①提出しました): {"similarity":0,"comment":"文章1は、複数の課題に取り組んだことを報告している内容ですが、文章2は、1つの課題の提出報告のみであり、内容が大きく異なります。また、文章表現も大きく異なっています。"}
# similarity_assessment_model(query4, 課題　3-1,3-2を行いました): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっており、文章表現も異なっている。文章1では具体的な課題の提出や視聴内容、テストの実施などが記述されているのに対し、文章2では課題番号のみが記載されている。また、文章1は丁寧な口調で書かれているのに対し、文章2は簡潔な口調で書かれている。"}
#
# similarity_assessment_model(query4, 井関さん「今日取り組んだこと」2-1 動画視聴2-1 課題提出2-2動画視聴2-2 実践課題実施2-2 実践課題提出): {"similarity": 2, "comment": "文章1は、業務報告のような形式で、具体的な内容が記述されています。一方、文章2は、簡潔な箇条書き形式で、具体的な内容が省略されています。そのため、大まかな内容は似ているものの、細かい内容は異なっています。また、文章表現も異なっています。しかし、文中に「課題提出」「動画視聴」「実践課題」などの共通する単語が含まれているため、類似度を2と評価しました。"}
# query5: ありがとうございます！！,ありがとうございます！,ありがとうございます！,ありがとうございます！,ありがとうございます！
# similarity_assessment_model(query5, ありがとうございます！！): {"similarity":4,"comment":"文章1は「できました！」と完了の報告があり、文章2は「ありがとうございます」と感謝の言葉のみ。文章の大まかな内容は類似しているが、細かい内容は異なる。文章表現は、どちらも短い言葉で、感謝の気持ちを伝えているため、類似している。"}
# similarity_assessment_model(query5, ありがとうございます！): {"similarity": "4", "comment": "文章の大まかな内容は同じ感謝の気持ちを表している。細かい内容では文章1は「できました」という完了の報告が含まれている。文章表現は類似しており、どちらも短く簡潔な表現である。"}
# similarity_assessment_model(query5, ありがとうございます！): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現は類似している。文章1は「できました！」という完了の報告が含まれているが、文章2にはない。しかし、どちらも感謝の気持ちを伝えているため、類似度は4とした。"}
# similarity_assessment_model(query5, ありがとうございます！): {"similarity": "4", "comment": "文章の大まかな内容は同じですが、文章1は「できました」という表現が追加されており、細かい内容が異なります。文章表現は類似しています。"}
# similarity_assessment_model(query5, ありがとうございます！): {"similarity": "4", "comment": "文章の大まかな内容は類似している。感謝の気持ちを伝えている。細かい内容では、文章1は「できました！」という達成感も含まれているが、文章2は「ありがとうございます！」のみ。文章表現は類似している。"}
# query6: この画面がでます,解決したので返信不要です,この白い枠はサイズを設定することは出来ますでしょうか？自分で調整しても見本通りのサイズになかなか調整できなかったのですが…,スマホのアドレスで登録していて、パソコンの方で進めたいのですが。,サインもしたのですが、、出来なかったら教えてください！
# similarity_assessment_model(query6, この画面がでます): {"similarity": 0, "comment": "文章の内容が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query6, 解決したので返信不要です): {"similarity": 0, "comment": "文章1は、画像素材の文字化けとバナーの色変更に関する質問、文章2は返信不要の報告で、内容が全く異なり、文章表現も類似性が見られないためです。"}
# similarity_assessment_model(query6, この白い枠はサイズを設定することは出来ますでしょうか？自分で調整しても見本通りのサイズになかなか調整できなかったのですが…): {"similarity": 0, "comment": "文章1はデザインに関する質問で、トンマナやバナーについて言及しています。一方、文章2は白い枠のサイズ調整について質問しています。内容が全く異なっており、単語も類似しているものがほとんどありません。"}
#
# similarity_assessment_model(query6, スマホのアドレスで登録していて、パソコンの方で進めたいのですが。): {"similarity": 0, "comment": "文章1はバナー作成におけるカラー変更の相談、文章2はアカウントに関する質問で、内容が全く異なります。また、文章表現や単語も大きく異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query6, サインもしたのですが、、出来なかったら教えてください！): {"similarity": 0, "comment": "文章の内容が大きく異なり、単語や文章表現も異なるため"}
# query7: 課題提出しました,すみません解決しました,了解しました,承知しました,承知しました
# similarity_assessment_model(query7, 課題提出しました): {"similarity": 1, "comment": "文章1は課題提出について具体的な内容が書かれており、文章表現も丁寧です。文章2は簡潔な報告のみで、具体的な内容や表現がありません。文章表現の雰囲気は似ていますが、内容は大きく異なります。"}
# similarity_assessment_model(query7, すみません解決しました): {"similarity": 0, "comment": "文章1は課題提出に関する内容で、文章2は問題解決に関する内容であり、内容や表現に共通点が見当たらないため0としました。"}
# similarity_assessment_model(query7, 了解しました): {"similarity": 0, "comment": "文章1は実践課題の提出に関する報告であり、文章2は単なる了解の返答です。内容も表現も全く異なります。"}
# similarity_assessment_model(query7, 承知しました): {"similarity": 0, "comment": "文章1は提出に関する報告と感想、文章2は承知したという短い返信であり、内容も文章表現も大きく異なります。"}
# similarity_assessment_model(query7, 承知しました): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なっているため、類似度は0と判断しました。"}
# query8: 課題提出しました,2-４実践課題提出しました。,実践課題1ー4①提出しました,6-1実践課題提出しました。,2-2課題提出しました
# similarity_assessment_model(query8, 課題提出しました): {"similarity": 2, "comment": "文章1は課題提出の案内、文章2は提出完了の報告という内容で異なる。しかし、課題という単語が使われているため、2と評価しました。"}
# similarity_assessment_model(query8, 2-４実践課題提出しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容(期間、提出物)が異なり、文章表現も異なります。"}
# similarity_assessment_model(query8, 実践課題1ー4①提出しました): {"similarity": 2, "comment": "文章1は添削課題の提出に関する連絡で、文章2は課題提出の報告です。内容が異なるため、0に近いが、課題という言葉が使われていることから2としました。"}
# similarity_assessment_model(query8, 6-1実践課題提出しました。): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、文内で使われている単語が似通っている。文章1は課題のアップロードについて、文章2は提出について記述している。"}
# similarity_assessment_model(query8, 2-2課題提出しました): {"similarity": "2", "comment": "文章1は課題提出の案内と添削依頼、文章2は課題提出の報告なので、内容が異なります。しかし、課題提出という単語が共通しているので、2としました。"}
# query9: 解決したので返信不要です,すみませんすぐ入ります,閲覧権限の変更の仕方がわからず,この画面がでます,Slackの○○期生の、○○に入る数字は何になるんでしょうか
# similarity_assessment_model(query9, 解決したので返信不要です): {"similarity": 0, "comment": "文章1は領収書の発行について問い合わせているが、文章2は問題が解決した旨を伝えているため、内容が全く異なっている。また、文章表現も全く異なるため、類似度は0です。"}
# similarity_assessment_model(query9, すみませんすぐ入ります): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query9, 閲覧権限の変更の仕方がわからず): {"similarity": 0, "comment": "文章1は請求書に関する問い合わせ、文章2は閲覧権限に関する問い合わせで、内容が全く異なるため。"}
# similarity_assessment_model(query9, この画面がでます): {"similarity": 0, "comment": "文章1は請求書の発行に関する問い合わせ、文章2は画面に関する記述であり、内容が全く異なるため類似度は0です。"}
# similarity_assessment_model(query9, Slackの○○期生の、○○に入る数字は何になるんでしょうか): {"similarity": 0, "comment": "文章1は領収書に関する問い合わせ、文章2はSlackの期生番号に関する問い合わせで、内容が全く異なるため。"}
# query10: 青木さんワイヤーフレームの書き方まで終わりました。,今日はピンタレスト登録、バナーデザインのピックアップまでしました,すみませんすぐ入ります,すみません解決しました,【生成AIコースの料金】
# similarity_assessment_model(query10, 青木さんワイヤーフレームの書き方まで終わりました。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なり、文章表現も異なる。文章1ではFigmaを使って作成したことを明記しているが、文章2ではツールが不明。また、文章1では「頑張ります」という表現が含まれているが、文章2では含まれていない。"}
# similarity_assessment_model(query10, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity": 2, "comment": "文章の大まかな内容は異なっている（文章1はワイヤーフレーム作成、文章2はピンタレスト登録とバナーデザイン）が、文内で使われている単語（『デザイン』など）が似通っているため、2としました。"}
# similarity_assessment_model(query10, すみませんすぐ入ります): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query10, すみません解決しました): {"similarity": 0, "comment": "文章の内容が大きく異なり、単語も異なっています。"}
# similarity_assessment_model(query10, 【生成AIコースの料金】): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なるため、類似度は0です。"}
# query11: 課題提出しました,了解しました,承知しました,承知しました,すみません解決しました
# similarity_assessment_model(query11, 課題提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（提出物の内容や提出時期など）が異なっており、文章表現も異なっているため3としました。"}
# similarity_assessment_model(query11, 了解しました): {"similarity": 0, "comment": "文章1は課題提出の報告で、文章2は了解の返事なので、内容が全く異なっています。文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query11, 承知しました): {"similarity": 0, "comment": "文章1は課題提出の報告と依頼、文章2は承知したという短い返答で、内容が全く異なります。また、文章表現も大きく異なります。"}
# similarity_assessment_model(query11, 承知しました): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なっています。文章1は課題提出の報告、文章2は承諾の返信です。"}
# similarity_assessment_model(query11, すみません解決しました): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なっているため0としました。"}
# query12: 解決したので返信不要です,サインもしたのですが、、出来なかったら教えてください！,解決しました。回答不要です。,この画面がでます,お手数をおかけしますがご確認お願いします。
# similarity_assessment_model(query12, 解決したので返信不要です): {"similarity": 0, "comment": "文章1はルビーコーヒーのヒアリングに関する質問、文章2は解決した旨の報告であり、内容が全く異なるため。"}
# similarity_assessment_model(query12, サインもしたのですが、、出来なかったら教えてください！): {"similarity": 0, "comment": "文章1はルビーコーヒーのヒアリングに関する質問で、文章2はサインに関する質問で、内容が全く異なる。文章表現も異なっているため、類似度は0です。"}
# similarity_assessment_model(query12, 解決しました。回答不要です。): {"similarity": 0, "comment": "文章1はルビーコーヒーのヒアリングに関する質問であり、文章2は解決した旨の報告です。内容、文章表現、単語全てが異なります。"}
# similarity_assessment_model(query12, この画面がでます): {"similarity": 0, "comment": "文章1はコーヒーのヒアリングに関する問い合わせですが、文章2は画面表示に関する内容のため、内容が全く異なります。文章表現も大きく異なっています。"}
# similarity_assessment_model(query12, お手数をおかけしますがご確認お願いします。): {"similarity":0,"comment":"文章1はルビーコーヒーのヒアリングに関する質問で、文章2は単なる依頼文であり、内容が大きく異なります。また、文章表現や単語も異なるため、類似度は0です。"}
# query13: この画面がでます,閲覧権限の変更の仕方がわからず,この白い枠はサイズを設定することは出来ますでしょうか？自分で調整しても見本通りのサイズになかなか調整できなかったのですが…,島戸さんへ今日はイベント参加、バナーの言語化に取り組みました。イベントでタイムマネジメントについて学び、Googleカレンダーを初めて使いました。今まで頭の中でやっていた時間管理をPCや携帯で意外と簡単に入力や変更ができて、なんだか頭の中がスッキリした感覚です笑,スマホのアドレスで登録していて、パソコンの方で進めたいのですが。
# similarity_assessment_model(query13, この画面がでます): {"similarity": 0, "comment": "文章1はfigmaでの操作に関する質問で、文章2は説明文の一部であるため、内容が全く異なります。また、文章表現も異なります。"}
# similarity_assessment_model(query13, 閲覧権限の変更の仕方がわからず): {"similarity":0,"comment":"文章1は動画のように文字をコピーする方法を尋ねています。一方、文章2は閲覧権限の変更方法を尋ねています。両者は全く異なる内容です。"}
# similarity_assessment_model(query13, この白い枠はサイズを設定することは出来ますでしょうか？自分で調整しても見本通りのサイズになかなか調整できなかったのですが…): {"similarity": 0, "comment": "文章1はFigmaでの操作に関する質問、文章2はサイズ調整に関する質問であり、内容が全く異なるため。"}
# similarity_assessment_model(query13, 島戸さんへ今日はイベント参加、バナーの言語化に取り組みました。イベントでタイムマネジメントについて学び、Googleカレンダーを初めて使いました。今まで頭の中でやっていた時間管理をPCや携帯で意外と簡単に入力や変更ができて、なんだか頭の中がスッキリした感覚です笑): {"similarity":0,"comment":"文章1はFigmaに関する質問、文章2はイベント参加に関する報告であり、内容が全く異なる。文章表現や単語も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query13, スマホのアドレスで登録していて、パソコンの方で進めたいのですが。): {"similarity":0,"comment":"文章1はFigmaでの操作に関する質問、文章2はアカウントに関する質問で、内容が全く異なる。文章表現も異なる。"}
# query14: 解決したので返信不要です,すみません解決しました,今日はピンタレスト登録、バナーデザインのピックアップまでしました,解決しました。回答不要です。,サインもしたのですが、、出来なかったら教えてください！
# similarity_assessment_model(query14, 解決したので返信不要です): {"similarity":0,"comment":"文章1は、リンクが作れなかった旨を伝えているのに対し、文章2は問題が解決したことを伝えているため、内容が全く異なります。また、文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query14, すみません解決しました): {"similarity": 0, "comment": "文章1はリンク作成に関する問題を報告し、LINEでの送信を伝えています。文章2は問題が解決したことを伝えています。内容、単語、表現が全く異なるため、類似度は0です。"}
# similarity_assessment_model(query14, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity":0,"comment":"文章の内容が全く異なっており、文章表現や単語も異なっているため、類似度は0です。"}
# similarity_assessment_model(query14, 解決しました。回答不要です。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query14, サインもしたのですが、、出来なかったら教えてください！): {"similarity":0,"comment":"文章の内容、単語、表現全てが異なるため類似度は0です。"}
# query15: 解決したので返信不要です,すみません解決しました,今日はピンタレスト登録、バナーデザインのピックアップまでしました,おはようございます。かしこまりました。おっしゃる通りに復習をかねてFigma操作を慣れる練習をいたします。,おはようございます。今記入し、締結完了メールも届きました。お手数おかけしました。ありがとうございます。
# similarity_assessment_model(query15, 解決したので返信不要です): {"similarity": 0, "comment": "文章1はコンペに関する内容で、文章2は解決した旨を伝えている内容で、共通点は見当たりません。"}
#
# similarity_assessment_model(query15, すみません解決しました): {"similarity": 0, "comment": "文章1はコンペ式の応募について記述していますが、文章2は解決したことを伝えています。内容や文章表現に共通点が見られないため、類似度は0と判断しました。"}
# similarity_assessment_model(query15, 今日はピンタレスト登録、バナーデザインのピックアップまでしました): {"similarity":0,"comment":"文章1はコンペに関する内容、文章2はSNSに関する内容で、内容は全く異なる。文章表現も異なっている。"}
# similarity_assessment_model(query15, おはようございます。かしこまりました。おっしゃる通りに復習をかねてFigma操作を慣れる練習をいたします。): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なります。"}
#
# similarity_assessment_model(query15, おはようございます。今記入し、締結完了メールも届きました。お手数おかけしました。ありがとうございます。): {"similarity": "0", "comment": "文章1はコンペに関する内容で、文章2は契約に関する内容です。内容が全く異なっており、文章表現や単語も異なるため類似度は0です。"}
# query16: 課題提出しました,week7の実践課題プロンプトをワークシートへ入れました。添削お願いします。,承知しました,承知しました,Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。
# similarity_assessment_model(query16, 課題提出しました): {"similarity": "1", "comment": "文章1は日々の進捗報告のような内容で、文章2は課題提出の報告のみです。内容としては大きく異なりますが、文章表現や雰囲気が似ているため、1としました。"}
# similarity_assessment_model(query16, week7の実践課題プロンプトをワークシートへ入れました。添削お願いします。): {"similarity": 2, "comment": "文章1は成果報告、文章2は添削依頼という内容で異なります。しかし、どちらも「課題」や「提出」といった単語が使われているため、2としました。"}
# similarity_assessment_model(query16, 承知しました): {"similarity": 0, "comment": "文章の内容が大きく異なり、単語も共通点が見当たらないため0としました。"}
# similarity_assessment_model(query16, 承知しました): {"similarity": 0, "comment": "文章1は日々の進捗報告の内容、文章2は短い承諾の返信であり、内容も文章表現も大きく異なります。"}
# similarity_assessment_model(query16, Week5の実戦課題のプロンプトをワークシートに入力しました。添削のほど宜しくお願いします。): {"similarity": 0, "comment": "文章1は業務報告の内容で、文章2は課題提出に関する内容のため、内容が異なります。文章表現も異なるため、類似度は0です。"}
# query17: ありがとうございます！！,ありがとうございます！,ありがとうございます！,ありがとうございます！,ありがとうございます！
# similarity_assessment_model(query17, ありがとうございます！！): {"similarity": 3, "comment": "文章の大まかな内容は類似している(感謝の意を表している)が、細かい内容は異なり(文章1はお願いも込めている)、文章表現も異なっている(文章1は絵文字を使用している)。"}
# similarity_assessment_model(query17, ありがとうございます！): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、文章1には絵文字が含まれており、文章2には含まれていない。文章表現は類似している。"}
# similarity_assessment_model(query17, ありがとうございます！): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1は感謝の気持ちと依頼の気持ちを表すために絵文字を使用している一方で、文章2は感謝の気持ちのみを表している。"}
# similarity_assessment_model(query17, ありがとうございます！): {"similarity": "3", "comment": "文章の大まかな内容は類似している（感謝の意を表している）が、細かい内容は異なり（文章1には「よろしくお願いいたします」という文言がある）、文章表現も異なっている（文章1には絵文字が使われている）。"}
# similarity_assessment_model(query17, ありがとうございます！): {"similarity": "4", "comment": "文章の大まかな内容は同じお礼の言葉ですが、文章1には「よろしくお願いいたします」という追加の言葉があり、感情を表す絵文字が使われているため、細かい内容が異なります。文章表現は類似しています。"}
# query18: 実践課題1ー4①提出しました,2-４実践課題提出しました。,2-2課題提出しました,5-1実践課題提出しました,5-2まで提出
# similarity_assessment_model(query18, 実践課題1ー4①提出しました): {"similarity": "3", "comment": "文章1は「2-3 再提出の修正3-3.3-4の課題提出」と具体的な内容が示されているのに対し、文章2は「実践課題1ー4①」と抽象的な表現で、具体的な内容は不明です。文章表現はどちらも簡潔で、類似していると言えるでしょう。"}
# similarity_assessment_model(query18, 2-４実践課題提出しました。): {"similarity": 2, "comment": "文章1は「再提出の修正」という単語が含まれており、文章2には「実践課題」という単語が含まれており、文章の内容は異なります。しかし、どちらも課題提出に関する内容であり、文内で使われている単語が似通っていることから2と評価しました。"}
#
# similarity_assessment_model(query18, 2-2課題提出しました): {"similarity": 2, "comment": "文章1は課題提出の報告で、文章2は課題提出の報告のみで、文章の内容が異なります。しかし、文章内で使われている単語が似通っているため、2としました。"}
# similarity_assessment_model(query18, 5-1実践課題提出しました): {"similarity": "2", "comment": "文章1は提出物の内容に関する連絡で、文章2は提出したことを報告しているという内容なので、大まかな内容は異なります。しかし、どちらも課題提出に関する内容であるため、文内で使われている単語が似通っています。"}
# similarity_assessment_model(query18, 5-2まで提出): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現や単語も異なるため、類似度は0と判断しました。"}
# query19: 課題提出しました,承知いたしました。,承知しました,承知しました,課題を提出しました。よろしくお願いいたします
# similarity_assessment_model(query19, 課題提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっており、文章表現は異なっている。文章1は「２-1実践課題」という具体的な課題名を含んでいるのに対し、文章2は課題名を含んでいない。また、文章1は「宜しくお願いいたします」という丁寧な表現が含まれているのに対し、文章2は簡潔な表現となっている。"}
# similarity_assessment_model(query19, 承知いたしました。): {"similarity": 0, "comment": "文章の内容が異なり、文章表現も異なります。文章1は課題提出の報告であり、文章2は承諾の返答です。"}
# similarity_assessment_model(query19, 承知しました): {"similarity": 0, "comment": "文章1は課題提出の報告で、文章2は承知の返答と、内容が全く異なるため。"}
# similarity_assessment_model(query19, 承知しました): {"similarity":0,"comment":"文章の内容が異なり、文章表現も単語も異なっています。"}
# similarity_assessment_model(query19, 課題を提出しました。よろしくお願いいたします): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、文章1では課題の内容が具体的に書かれており、文章2では省略されている。文章表現は類似している。"}
# query20: 延長プランを申込させて頂きました。,承知しました,承知しました,承知致しました。確認してまたご連絡させていただきます。,ご回答、添削ありがとうございました。
# similarity_assessment_model(query20, 延長プランを申込させて頂きました。): {"similarity": "5", "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query20, 承知しました): {"similarity": 0, "comment": "文章の内容が全く異なり、文章表現や単語も異なります。"}
# similarity_assessment_model(query20, 承知しました): {"similarity":0,"comment":"文章の内容が異なり、単語も異なるため類似度は0です。"}
# similarity_assessment_model(query20, 承知致しました。確認してまたご連絡させていただきます。): {"similarity": "3", "comment": "文章1は延長プランの申込、文章2は確認後連絡という内容で、大まかな内容は類似している。しかし、細かい内容が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query20, ご回答、添削ありがとうございました。): {"similarity":0,"comment":"文章の内容が全く異なり、文章表現や単語も異なります。"}

# %% [markdown]
# # **Agent Builder**

# %%
# !pip install google-cloud-discoveryengine
# Out:
# Collecting google-cloud-discoveryengine
#   Downloading google_cloud_discoveryengine-0.13.4-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.19.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (4.25.5)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2024.8.30)
# Downloading google_cloud_discoveryengine-0.13.4-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 26.4 MB/s eta 0:00:00
# Installing collected packages: google-cloud-discoveryengine
# Successfully installed google-cloud-discoveryengine-0.13.4

# %%
from typing import List

from google.api_core.client_options import ClientOptions
from google.cloud import discoveryengine_v1 as discoveryengine

# TODO(developer): Uncomment these variables before running the sample.
# project_id = "YOUR_PROJECT_ID"
# location = "YOUR_LOCATION"          # Values: "global", "us", "eu"
# engine_id = "YOUR_APP_ID"
# search_query = "YOUR_SEARCH_QUERY"


def search_sample(
    project_id: str,
    location: str,
    engine_id: str,
    search_query: str,
) -> List[discoveryengine.SearchResponse]:
    #  For more information, refer to:
    # https://cloud.google.com/generative-ai-app-builder/docs/locations#specify_a_multi-region_for_your_data_store
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )

    # Create a client
    client = discoveryengine.SearchServiceClient(client_options=client_options)

    # The full resource name of the search app serving config
    serving_config = f"projects/{project_id}/locations/{location}/collections/default_collection/engines/{engine_id}/servingConfigs/default_config"

    # Optional - only supported for unstructured data: Configuration options for search.
    # Refer to the `ContentSearchSpec` reference for all supported fields:
    # https://cloud.google.com/python/docs/reference/discoveryengine/latest/google.cloud.discoveryengine_v1.types.SearchRequest.ContentSearchSpec
    content_search_spec = discoveryengine.SearchRequest.ContentSearchSpec(
        # For information about snippets, refer to:
        # https://cloud.google.com/generative-ai-app-builder/docs/snippets
        snippet_spec=discoveryengine.SearchRequest.ContentSearchSpec.SnippetSpec(
            return_snippet=True
        ),
        # For information about search summaries, refer to:
        # https://cloud.google.com/generative-ai-app-builder/docs/get-search-summaries
        summary_spec=discoveryengine.SearchRequest.ContentSearchSpec.SummarySpec(
            summary_result_count=5,
            include_citations=True,
            ignore_adversarial_query=True,
            ignore_non_summary_seeking_query=True,
            model_prompt_spec=discoveryengine.SearchRequest.ContentSearchSpec.SummarySpec.ModelPromptSpec(
                preamble="YOUR_CUSTOM_PROMPT"
            ),
            model_spec=discoveryengine.SearchRequest.ContentSearchSpec.SummarySpec.ModelSpec(
                version="stable",
            ),
        ),
    )

    # Refer to the `SearchRequest` reference for all supported fields:
    # https://cloud.google.com/python/docs/reference/discoveryengine/latest/google.cloud.discoveryengine_v1.types.SearchRequest
    request = discoveryengine.SearchRequest(
        serving_config=serving_config,
        query=search_query,
        page_size=10,
        content_search_spec=content_search_spec,
        query_expansion_spec=discoveryengine.SearchRequest.QueryExpansionSpec(
            condition=discoveryengine.SearchRequest.QueryExpansionSpec.Condition.AUTO,
        ),
        spell_correction_spec=discoveryengine.SearchRequest.SpellCorrectionSpec(
            mode=discoveryengine.SearchRequest.SpellCorrectionSpec.Mode.AUTO
        ),
    )

    response = client.search(request)
    #print(response)

    return response

# %% [markdown]
# With category

# %%
print(search_sample(
project_id = "monobrain-development",
location = "global",                    # Values: "global", "us", "eu"
engine_id = "sample-category_1732854393042",
search_query = "今日は取り組めませんでした"
))
type(search_sample(
project_id = "monobrain-development",
location = "global",                    # Values: "global", "us", "eu"
engine_id = "sample-category_1732854393042",
search_query = "今日は取り組めませんでした"
))
# Out:
# SearchPager<results {
#   id: "e36874abcb88c00019bbf57dc8a4ae00"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "今日は何も取り組めませんでした。"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_433"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "今日は取り組めず、連絡。\n"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告いただきありがとうございます♪"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/e36874abcb88c00019bbf57dc8a4ae00"
#     id: "e36874abcb88c00019bbf57dc8a4ae00"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "7e0390da41090783733bfa101510b0f0"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_588"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "[病院のために今日は取り組めませんでした。明日から再開します。] (17文字)\n目的: 制作物が作れなかったことの連絡と再開時期の報告\n"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご連絡ありがとうございます◎今日はゆっくりお子さんとの時間にあててくださいね😌"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/7e0390da41090783733bfa101510b0f0"
#     id: "7e0390da41090783733bfa101510b0f0"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "c72af80c21313c66b3acaf73b59d9b2f"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "☁️日次報告☁️今日は取り組めませんでした💦"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_021"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "今日はオンライン授業に参加できませんでした。"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告ありがとうございます✨無理なく進めていきましょう☺"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/c72af80c21313c66b3acaf73b59d9b2f"
#     id: "c72af80c21313c66b3acaf73b59d9b2f"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "38901678e0c12d8edfb1f8de054973d5"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "こんばんは、今日も体調が良くなく、進められませんでした·····明日は午後お休みなので、課題をやってみようと思います！"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_1221"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "体調不良で課題が進められなかった。明日は午後休みなので課題に取り組む予定。"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "体調復活されたらまた進めてくださいね💪本日もご無理なく💦"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/38901678e0c12d8edfb1f8de054973d5"
#     id: "38901678e0c12d8edfb1f8de054973d5"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "57369d0204541707a7e06f7efe0cf5ce"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "藤川さん今日は3-5実践課題再提出しました。土日はあまり課題進められませんでした。"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_1061"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "時間外に課題を提出したことを報告。土日はあまり進められなかった。"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告ありがとうございます！お取り組みお疲れ様でした！進められないときもありますよね😊お取り組みできる日に対応するで無理なくメリハリつけていただければ大丈夫です💪引き続きご自身の良いペースで進めていきましょうね＾＾"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/57369d0204541707a7e06f7efe0cf5ce"
#     id: "57369d0204541707a7e06f7efe0cf5ce"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "4b15f40d8cdca1abedda163416b5ce5f"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "谷津さま体調崩しており、学習ができていませんでした…今日はFigmaと仲良くなろう会に参加しました！"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_1331"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "体調不良のため、学習ができていませんでした。今日はFigmaと仲良くなろう会に参加しました。\n"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "お取り組みお疲れ様でした！体調不良の方、すごく増えております💦一気に寒くなってきましたので、どうぞ暖かくされて体調第一にお過ごしくださいね☺️"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/4b15f40d8cdca1abedda163416b5ce5f"
#     id: "4b15f40d8cdca1abedda163416b5ce5f"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "40af71a2fde532f272be65712a8c6b56"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "☁️日次報告☁️今日は取り組めませんでした💦"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_001"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "未完了の報告。"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告ありがとうございます✨無理なく進めていきましょう☺"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/40af71a2fde532f272be65712a8c6b56"
#     id: "40af71a2fde532f272be65712a8c6b56"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "f22d8ef04e3fcde53f1aa27dacbf906e"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "谷津さま今日の取り組み今日は、病院だった為に制作出来ませんでした。明日からまた取り組みます！"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_267"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "病院のため、今日の制作はできませんでした。明日から再開します。 \n\n**目的:** 制作の進捗状況報告 \n"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご連絡ありがとうございます◎今日はゆっくりお子さんとの時間にあててくださいね😌"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/f22d8ef04e3fcde53f1aa27dacbf906e"
#     id: "f22d8ef04e3fcde53f1aa27dacbf906e"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "2c2de9460d290275197a9f78456e9f10"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "谷津さんお久しぶりです1週間程体調を崩してしまい、あまり進められませんでした。取り組みもご報告できておらず、すみませんでした。本日からまた頑張っていきます！取り組んだこと10/4・2-2 動画視聴10/5・2-2 実践課題実施10/6・2-2 実践課題提出・2-3 動画視聴10/8・勉強会・2-3 実践課題実施、提出10/14・2-3 実践課題実施、再提出・3-1 動画視聴、実践課題提出・3-2 動画視聴、実践課題提出・3-3 動画視聴、実践課題実施"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_1341"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "健康不良のため10/4-10/8は学習進捗が遅れ、10/14に学習を再開し、2-3と3-1, 3-2, 3-3の内容を学習したことを報告しています。\n"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告ありがとうございます！体調不良の中でも、コツコツ進めてくださり素晴らしいです🥲体調第一で、引き続きご自身の良いペースで無理はしすぎず進めていきましょう😊お取り組みお疲れ様でした👏✨"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/2c2de9460d290275197a9f78456e9f10"
#     id: "2c2de9460d290275197a9f78456e9f10"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# results {
#   id: "56358b1f5f740645e4ecb88e80188ee1"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "今日は残業で疲れてしまったので課題進められませんでした(emoji)"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_1207"
#         }
#       }
#       fields {
#         key: "category"
#         value {
#           string_value: "残業で疲れて、課題が進められませんでした。"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告ありがとうございます！残業お疲れ様でした＞＜またお取り組みできる日に対応するで無理なくメリハリつけていただければ大丈夫ですので、体調第一で引き続きご自身の良いペースで進めていきましょうね＾＾"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/56358b1f5f740645e4ecb88e80188ee1"
#     id: "56358b1f5f740645e4ecb88e80188ee1"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# total_size: 1193
# attribution_token: "9gHw9QoMCOaCyroGEPa78p0DEiQ2NzUxYWQwNy0wMDAwLTJlMGYtOWE0Yi0xNGMxNGVmNGU2YmMiB0dFTkVSSUMqtAGq-LMttJKuMJzd2DDn7Ygt0ea1L5jWty3HxrEwwfi8MJCktDDC8J4V1LKdFaOAlyK3t4wt6IKxLZD3sjDk7Ygt5t3EMJSSxTCt-LMt64KxLZneqC_p3cQwxPzLMMT4vDCDspoi-fazLcTGsTCb1rctjaS0MK7Eii3bj5oio4mzLc7mtS-3kq4wjpHJMI6-nRWrxIot3o-aIpbeqC_B_Mswmd3YMPz2sy2AspoixcvzF6CJsy0wAQ"
# next_page_token: "MmY2UGNmVGNxMGNx0iY0EWOtYGMlJTLwADMw0iNwQWYxUzN2QiGDMdvCHMEGob2rbOCMIBMxIgC"
# summary {
#   summary_text: "It sounds like you were unable to work on something today. [1, 3] It\'s okay to take breaks and prioritize your well-being. [2, 4] You can resume your work when you\'re able. [2, 4]  It\'s important to find a balance and work at your own pace. [5]  Keep up the good work! [3] \n"
#   summary_with_metadata {
#     summary: "It sounds like you were unable to work on something today. It\'s okay to take breaks and prioritize your well-being. You can resume your work when you\'re able.  It\'s important to find a balance and work at your own pace.  Keep up the good work! \n"
#     citation_metadata {
#       citations {
#         end_index: 58
#         sources {
#         }
#         sources {
#           reference_index: 2
#         }
#       }
#       citations {
#         start_index: 59
#         end_index: 115
#         sources {
#           reference_index: 1
#         }
#         sources {
#           reference_index: 3
#         }
#       }
#       citations {
#         start_index: 116
#         end_index: 158
#         sources {
#           reference_index: 1
#         }
#         sources {
#           reference_index: 3
#         }
#       }
#       citations {
#         start_index: 160
#         end_index: 219
#         sources {
#           reference_index: 4
#         }
#       }
#       citations {
#         start_index: 221
#         end_index: 243
#         sources {
#           reference_index: 2
#         }
#       }
#     }
#     references {
#       document: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/e36874abcb88c00019bbf57dc8a4ae00"
#     }
#     references {
#       document: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/7e0390da41090783733bfa101510b0f0"
#     }
#     references {
#       document: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/c72af80c21313c66b3acaf73b59d9b2f"
#     }
#     references {
#       document: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/38901678e0c12d8edfb1f8de054973d5"
#     }
#     references {
#       document: "projects/954273464710/locations/global/collections/default_collection/dataStores/category_1732854489356/branches/0/documents/57369d0204541707a7e06f7efe0cf5ce"
#     }
#   }
# }
# query_expansion_info {
# }
# >
# google.cloud.discoveryengine_v1.services.search_service.pagers.SearchPager

# %%
# Transform the response into desired format
def transform_search_response(response: SearchPager) -> list:
    similar_chats = []
    for result in response.results:
        data = dict(result.document.struct_data)
        chat = {
            'id': data.get('id', ''),
            'question': data.get('question', ''),
            'answer': data.get('answer', ''),
            'category': data.get('category', ''),
        }
        similar_chats.append(chat)
    return similar_chats

# Fetch data from multiple pages
def fetch_all_data(project_id, location, engine_id, num_pages=5, page_size=20):
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )

    client = discoveryengine.SearchServiceClient(client_options=client_options)
    serving_config = f"projects/{project_id}/locations/{location}/collections/default_collection/engines/{engine_id}/servingConfigs/default_config"

    all_data = []
    for page in range(num_pages):
        request = discoveryengine.SearchRequest(
            serving_config=serving_config,
            query="",  # Broad query to fetch data
            page_size=page_size,
            offset=page * page_size
        )
        response = client.search(request)
        all_data.extend(transform_search_response(response))

    return all_data

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。

        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Step 1: Fetch data from multiple pages
all_data = fetch_all_data(
    project_id="monobrain-development",
    location="global",
    engine_id="sample-category_1732854393042",
    num_pages=5,
    page_size=20
)

# Step 2: Randomly select 20 entries for evaluation
evaluation_data = random.sample(all_data, min(20, len(all_data)))

# Step 3: Evaluate each query and find 5 similar questions
print("Evaluating using Agent Builder:")
for idx, data in enumerate(evaluation_data, start=1):
    query = data['question']

    # Query the engine for similar questions
    similar_response = search_sample(
        project_id="monobrain-development",
        location="global",
        engine_id="sample-category_1732854393042",
        search_query=query
    )

    # Transform the response to extract similar chats
    similar_chats = transform_search_response(similar_response)[:5]

    # Display the results
    similar_questions = ','.join([chat['question'] for chat in similar_chats])
    print(f"query{idx}: {similar_questions}")
    for i, chat in enumerate(similar_chats, start=1):
        similarity_score = similarity_assessment_model(query, chat['question'])
        print(f"similarity_assessment_model(query{idx}, {chat['question']}): {similarity_score}")
    print()
# Out:
# Evaluating using Agent Builder:
# query1: 初回ガイダンスについて予約をしようと思います。が、1人の時間がほぼなく子供と一緒でも大丈夫でしょうか？,質問があるのですが、各種イベントや自習会は毎回同じ内容でしょうか？自習会は時間がある時は積極的に予約して行った方が良いのでしょうか？,実際には、こちらの環境の問題で一部課題ができていません💦そこも含めて またお話させていただければと思います…URLありがとうございます！直近ではありますが、10月18日9:00~の枠を取らせていただきました。よろしくお願いします。,嶋内様初めまして。ご連絡ありがとうございます！2土曜の、11時からでお願いしてもよろしいでしょうか？こちらの都合で申し訳ございません。どうぞよろしくお願いいたします。,こんにちは！14時からの予約だったと思うのですが大丈夫でしょうか？🥲
# similarity_assessment_model(query1, 初回ガイダンスについて予約をしようと思います。が、1人の時間がほぼなく子供と一緒でも大丈夫でしょうか？): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query1, 質問があるのですが、各種イベントや自習会は毎回同じ内容でしょうか？自習会は時間がある時は積極的に予約して行った方が良いのでしょうか？): {"similarity": "2", "comment": "文章1は初回ガイダンスについて予約に関する質問、文章2はイベントや自習会に関する質問で、内容が異なります。ただし、どちらも予約に関する質問であるため、単語が似通っています。"}
# similarity_assessment_model(query1, 実際には、こちらの環境の問題で一部課題ができていません💦そこも含めて またお話させていただければと思います…URLありがとうございます！直近ではありますが、10月18日9:00~の枠を取らせていただきました。よろしくお願いします。): {"similarity": "0", "comment": "文章1は予約に関する問い合わせで、文章2は課題に関する返信と予約に関する連絡です。内容が大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query1, 嶋内様初めまして。ご連絡ありがとうございます！2土曜の、11時からでお願いしてもよろしいでしょうか？こちらの都合で申し訳ございません。どうぞよろしくお願いいたします。): {"similarity": 0, "comment": "文章1は初回ガイダンスの予約に関する問い合わせ、文章2は予約日時に関する提案と依頼で、内容が全く異なります。文章表現も異なります。"}
#
# similarity_assessment_model(query1, こんにちは！14時からの予約だったと思うのですが大丈夫でしょうか？🥲): {"similarity": "0", "comment": "文章1は初回ガイダンスの予約に関する問い合わせで、文章2は予約時間の確認に関する問い合わせです。内容が大きく異なるため、類似度は0です。"}
#
# query2: 課題3−3を提出しました。添削よろしくお願いいたします。,5-3課題提出しました。何度か試しましたが、コピペしやすいフォーマットにはなりませんでした💦添削をお願いします,いつもお世話になっております。昨日、誤って省略してしまいましたが、Week6-3と4実践課題提出致します。添削のほどよろしくお願いいたします😊,課題3-3を提出しました。よろしくお願いします。,6-4 課題提出しました。添削よろしくお願いします。
# similarity_assessment_model(query2, 課題3−3を提出しました。添削よろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query2, 5-3課題提出しました。何度か試しましたが、コピペしやすいフォーマットにはなりませんでした💦添削をお願いします): {"similarity": 4, "comment": "文章の大まかな内容は類似している(課題提出について)。細かい内容では、課題番号の表記が異なり、文章2ではコピペに関する記述がある。文章表現は類似している。"}
# similarity_assessment_model(query2, いつもお世話になっております。昨日、誤って省略してしまいましたが、Week6-3と4実践課題提出致します。添削のほどよろしくお願いいたします😊): {"similarity": "3", "comment": "文章1は課題提出の報告、文章2は誤って省略した課題の提出報告と謝罪が加わっているため、細かい内容が異なります。文章表現はどちらも丁寧な依頼文で類似しています。"}
# similarity_assessment_model(query2, 課題3-3を提出しました。よろしくお願いします。): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている(文章1は添削を依頼しているが、文章2は依頼の内容が不明確)。文章表現は類似している。"}
# similarity_assessment_model(query2, 6-4 課題提出しました。添削よろしくお願いします。): {"similarity":4,"comment":"文章の大まかな内容は類似している。細かい内容(課題番号)が異なっているが、文章表現は類似している。"}
#
# query3: 「勉強会」はどのようなことをするのでしょうか？何人くらい一度に受講するのか、内容や難易度は？を知りたいです。,ご連絡ありがとうございます。勉強会についてお伺いします。延長を申し込まない場合、勉強会も11/1まで、となりますか？,なんとか形にはなりましたが、まだまだです·····！でも昨日の絶望感は無くなりました！今度の金曜日に勉強会を予約したので、自分ではどうにもならない所を確認したいと思います！,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 明日の勉強会はこのプロンプトについて教えていただきたいと思っています。よろしくお願いいたしました。https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f,内田さんご無沙汰しております💦家庭内、つぎつぎと臥せっておりました💦やっと再開できました！week2-2、2-3を提出、フィードバックいただきました。week3-1本日中提出が目標です！一つ、確認させていただきたいのですが、さきほどの勉強会のZoomをすぐに閉じてしまっちゃって、先生がどなたか分かりません💦確認する方法はありますでしょうか？？
# similarity_assessment_model(query3, 「勉強会」はどのようなことをするのでしょうか？何人くらい一度に受講するのか、内容や難易度は？を知りたいです。): {"similarity": 5, "comment": "文章1と文章2は全く同じ内容です。"}
# similarity_assessment_model(query3, ご連絡ありがとうございます。勉強会についてお伺いします。延長を申し込まない場合、勉強会も11/1まで、となりますか？): {"similarity":0,"comment":"文章1は勉強会の概要について質問しているのに対し、文章2は勉強会に関する問い合わせではなく、延長に関する問い合わせであるため、内容が全く異なる。文章表現や単語も異なるため、類似度は0です。"}
# similarity_assessment_model(query3, なんとか形にはなりましたが、まだまだです·····！でも昨日の絶望感は無くなりました！今度の金曜日に勉強会を予約したので、自分ではどうにもならない所を確認したいと思います！): {"similarity": 1, "comment": "文章1は「勉強会」に関する質問であり、文章2は「勉強会」に参加する旨の記述であり、内容が大きく異なります。しかし、文章表現や文章の雰囲気は似ています。そのため、1と評価しました。"}
# similarity_assessment_model(query3, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 明日の勉強会はこのプロンプトについて教えていただきたいと思っています。よろしくお願いいたしました。https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f): {"similarity": 0, "comment": "文章1は「勉強会」に関する質問であり、文章2は具体的な内容の質問と明日の勉強会への期待を表明する内容であり、全く異なる内容です。文章表現や単語も異なっているため類似度は0と判断しました。"}
# similarity_assessment_model(query3, 内田さんご無沙汰しております💦家庭内、つぎつぎと臥せっておりました💦やっと再開できました！week2-2、2-3を提出、フィードバックいただきました。week3-1本日中提出が目標です！一つ、確認させていただきたいのですが、さきほどの勉強会のZoomをすぐに閉じてしまっちゃって、先生がどなたか分かりません💦確認する方法はありますでしょうか？？): {"similarity": 0, "comment": "文章1は勉強会の内容に関する質問で、文章2は勉強会の参加者に関する質問です。文章の内容や単語も大きく異なります。"}
#
#
# query4: 6週目と7週目の課題完了しています,Week7  7-3の課題を提出しました,week7の実践課題プロンプトをワークシートへ入れました。添削お願いします。,week6-3の課題を提出しました。,１週目の課題４つを提出しました。
# similarity_assessment_model(query4, 6週目と7週目の課題完了しています): {"similarity":5,"comment":"文章1と文章2は完全に同一のため、類似度は5です。"}
# similarity_assessment_model(query4, Week7  7-3の課題を提出しました): {"similarity":3,"comment":"文章1では6週目と7週目の課題完了と記載されているのに対し、文章2ではWeek7 7-3の課題提出と記載されているため、細かい内容が異なります。文章表現も、「完了しています」「提出しました」と異なるため、3としました。"}
# similarity_assessment_model(query4, week7の実践課題プロンプトをワークシートへ入れました。添削お願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の提出について）。しかし、細かい内容は異なり（文章1は「6週目と7週目の課題完了しています」と複数週の課題完了を報告しているのに対し、文章2は「week7の実践課題プロンプト」と特定の週と課題を指定している）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query4, week6-3の課題を提出しました。): {"similarity": "3", "comment": "文章1は課題完了を報告しているのに対し、文章2は課題提出を報告しており、細かい内容が異なる。文章表現はどちらも簡潔で類似している。"}
# similarity_assessment_model(query4, １週目の課題４つを提出しました。): {"similarity": 0, "comment": "文章の内容、文章表現、単語もすべて異なるため、類似度は0です。"}
#
# query5: ご連絡ありがとうございます。会社に勤めているので、自宅に帰ったら確認させていただきます。よろしくお願いいたします。,お手数をおかけしてしまい、大変申し訳ありません。迅速なご対応ありがとうございます！！💦引き続き、どうぞよろしくお願い致します🙇‍♀️,承知致しました。確認してまたご連絡させていただきます。,いつもお世話になります。連絡が遅くなってしまい申し訳ありません。今回、面談はスキップさせていただきます。よろしくお願いいたします。,有難うございました。こちらこそ宜しくお願いします。
# similarity_assessment_model(query5, ご連絡ありがとうございます。会社に勤めているので、自宅に帰ったら確認させていただきます。よろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query5, お手数をおかけしてしまい、大変申し訳ありません。迅速なご対応ありがとうございます！！💦引き続き、どうぞよろしくお願い致します🙇‍♀️): {"similarity": 1, "comment": "文章1は相手に何かしらの依頼に対する返答で、文章2は相手に何かしらの依頼をした後に相手が対応してくれたことに対する感謝の言葉です。文章の内容は大きく異なりますが、文章表現は丁寧で、感謝の言葉が含まれている点は共通しています。"}
# similarity_assessment_model(query5, 承知致しました。確認してまたご連絡させていただきます。): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容は異なっており、文章表現も異なっています。文章1は会社に勤めていることを伝えていますが、文章2ではその情報は含まれていません。また、文章1は「確認させていただきます」と丁寧な表現ですが、文章2は「確認してご連絡させていただきます」とより簡潔な表現となっています。"}
# similarity_assessment_model(query5, いつもお世話になります。連絡が遅くなってしまい申し訳ありません。今回、面談はスキップさせていただきます。よろしくお願いいたします。): {"similarity": "0", "comment": "文章の内容が全く異なるため、類似度は0です。"}
#
# similarity_assessment_model(query5, 有難うございました。こちらこそ宜しくお願いします。): {"similarity": 0, "comment": "文章1は仕事に関する返信で、文章2は一般的な返信であるため、内容が全く違います。また、文章表現も異なります。"}
#
# query6: おはようございます実践課題week4-3提出いたしました。ちゃんとできているか不明ですが🥹提出方法間違っていたらまたご指導ください。よろしくお願いします。,松丸です。Week3-1の実践課題を提出しました。よろしくお願いします。,こんばんはお世話になっております。2-3実践課題を提出いたしました。宜しくお願い致します(emoji),おはようございます。お疲れ様です。実践課題6-3提出いたします。宜しくお願いします。,week2-3の課題を提出しましたご確認よろしくお願いします
# similarity_assessment_model(query6, おはようございます実践課題week4-3提出いたしました。ちゃんとできているか不明ですが🥹提出方法間違っていたらまたご指導ください。よろしくお願いします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query6, 松丸です。Week3-1の実践課題を提出しました。よろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似していますが、細かい内容が異なっており、文章表現も異なっています。文章1は提出内容に対する不安を表明していますが、文章2は特にそのような内容は含まれていません。また、文章1は「おはようございます」や「🥹」など、文章2にはない表現が含まれています。"}
#
# similarity_assessment_model(query6, こんばんはお世話になっております。2-3実践課題を提出いたしました。宜しくお願い致します(emoji)): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容は異なり（提出物の内容や曜日が異なる）、文章表現も異なっている（絵文字の使用、敬語の使い方が異なる）ため3とした。"}
# similarity_assessment_model(query6, おはようございます。お疲れ様です。実践課題6-3提出いたします。宜しくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（課題の番号、提出時期、不安の表明）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query6, week2-3の課題を提出しましたご確認よろしくお願いします): {"similarity": "3", "comment": "文章1は課題提出の報告と不明点に関する質問、文章2は単なる提出報告となっており、細かい内容が異なります。文章表現はどちらも簡潔で類似しています。"}
#
# query7: こんにちは！昨日成果をご報告するのを忘れていたので、今させていただきます。・動画視聴、課題提出・バナートレース途中まで,こんにちは！昨日成果をご報告するのを忘れてしまったので、ご報告します！・動画視聴、課題提出・オリジナルバナーの素材集め,こんばんは！本日の成果をご報告します。・動画視聴、課題提出・バナートレース完成,青木さんお疲れ様です。本日は任意課題バナートレース初心者をやりました。始めての勉強会も参加しました。イベントはなかなか予約が取れないです､､。,こんばんは！しばらく進捗報告できておらず、申し訳ありません🙇🏻‍♀️💦仕事でバタバタしておりました…😵‍💫バナートレース練習3つできました！30日の勉強会でフィードバックしてもらいます☺️✨あと何個か練習してみて、4-1と4-2の任意課題にも取り組んでみます💪🏻
# similarity_assessment_model(query7, こんにちは！昨日成果をご報告するのを忘れていたので、今させていただきます。・動画視聴、課題提出・バナートレース途中まで): {"similarity":5,"comment":"文章1と文章2は全く同じ内容なので、類似度は5です。"}
#
# similarity_assessment_model(query7, こんにちは！昨日成果をご報告するのを忘れてしまったので、ご報告します！・動画視聴、課題提出・オリジナルバナーの素材集め): {"similarity":4,"comment":"文章の大まかな内容は同じですが、細かい内容が異なります。動画視聴、課題提出は共通していますが、文章1ではバナートレース途中まで、文章2ではオリジナルバナーの素材集めと、具体的な作業内容が違います。文章表現はほぼ同じです。"}
# similarity_assessment_model(query7, こんばんは！本日の成果をご報告します。・動画視聴、課題提出・バナートレース完成): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、動画視聴と課題提出は共通している。バナートレースの進捗が異なるため、細かい内容が異なっている。文章表現は類似している。"}
# similarity_assessment_model(query7, 青木さんお疲れ様です。本日は任意課題バナートレース初心者をやりました。始めての勉強会も参加しました。イベントはなかなか予約が取れないです､､。): {"similarity": "1", "comment": "文章1は、報告内容を簡潔に記述したものであり、文章2は、個人の感想や状況を記述したものです。内容面では異なるものの、文章表現や文末の省略など、雰囲気は似ています。"}
# similarity_assessment_model(query7, こんばんは！しばらく進捗報告できておらず、申し訳ありません🙇🏻‍♀️💦仕事でバタバタしておりました…😵‍💫バナートレース練習3つできました！30日の勉強会でフィードバックしてもらいます☺️✨あと何個か練習してみて、4-1と4-2の任意課題にも取り組んでみます💪🏻): {"similarity": 3, "comment": "文章の大まかな内容は類似している（進捗報告）。細かい内容は異なり（文章1は具体的な内容、文章2は練習できた内容）、文章表現も異なる（文章1は簡潔、文章2は絵文字や顔文字を使用）"}
#
# query8: Week5-1課題を提出しました。渡辺容子,お世話になっております。Week5-1の課題を提出しました,Week5-1の課題を提出しました。,おはようございます実践課題week5-1を提出しました,week5-2 課題を提出しました
# similarity_assessment_model(query8, Week5-1課題を提出しました。渡辺容子): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query8, お世話になっております。Week5-1の課題を提出しました): {"similarity": "4", "comment": "文章の大まかな内容は類似している（課題提出の報告）。細かい内容は異なる（文章1には提出した課題名が記載されているが、文章2には記載されていない）。文章表現は類似している（丁寧な表現、敬語の使用）"}
# similarity_assessment_model(query8, Week5-1の課題を提出しました。): {"similarity": "4", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり（文章1には提出者の名前が含まれている）、文章表現は類似している。"}
# similarity_assessment_model(query8, おはようございます実践課題week5-1を提出しました): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容は異なり（文章1は課題名、文章2は曜日と課題名）、文章表現も異なる。"}
#
# similarity_assessment_model(query8, week5-2 課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なります。文章1には提出者の名前が含まれているのに対し、文章2には含まれていません。また、文章1では課題番号がハイフンで区切られているのに対し、文章2ではスペースで区切られています。"}
#
#
# query9: お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇‍♀️,week2-3の課題を提出しましたご確認よろしくお願いします,こんにちは実践課題week2-1の【※添削対象】を前回から追加で提出しております。また、実践課題week2-3も提出いたしました。ご確認よろしくお願いします。,課題2-3を提出しました。よろしくお願いします。,こんにちは実践課題week2-4～3-2提出いたしました。ご確認よろしくお願いします。
# similarity_assessment_model(query9, お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇‍♀️): {"similarity":5,"comment":"文章の内容、表現、単語、絵文字まで完全に一致しているので、類似度は5です。"}
#
# similarity_assessment_model(query9, week2-3の課題を提出しましたご確認よろしくお願いします): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1ではweek2-2とweek2-3の提出を報告しているのに対し、文章2ではweek2-3のみの提出を報告している。また、文章表現も、文章1では丁寧な表現で「お世話になっております」「よろしくお願いします」と用いられている一方、文章2では「ご確認よろしくお願いします」と簡潔な表現となっている。"}
# similarity_assessment_model(query9, こんにちは実践課題week2-1の【※添削対象】を前回から追加で提出しております。また、実践課題week2-3も提出いたしました。ご確認よろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容は異なっている。文章表現も一部異なるため3とした。"}
# similarity_assessment_model(query9, 課題2-3を提出しました。よろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（week2-2, week2-3 vs 課題2-3）、文章表現も異なっている（絵文字の使用、丁寧語の程度）ため3としました。"}
# similarity_assessment_model(query9, こんにちは実践課題week2-4～3-2提出いたしました。ご確認よろしくお願いします。): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、提出物の報告であることがわかる。細かい内容では、提出物の範囲が異なり、文章表現も若干異なる。"}
#
# query10: 昨日、お支払いしたのですが…,お世話になっております。失礼致しました。大石紗織里で昨日、支払いいたしました。お手数おかけしますが、確認していただけますと幸いです。,延長プランを申込ましたが、決済の手続きは別に連絡がくるのでしょうか？,【お支払いについて】,支払いは完了しました
# similarity_assessment_model(query10, 昨日、お支払いしたのですが…): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query10, お世話になっております。失礼致しました。大石紗織里で昨日、支払いいたしました。お手数おかけしますが、確認していただけますと幸いです。): {"similarity": "3", "comment": "文章1は簡潔な依頼文である一方、文章2は丁寧な表現で、依頼内容に加えて自己紹介と謝罪が含まれている。そのため、文章の大まかな内容は類似しているものの、細かい内容は異なっている。また、文章表現も異なる。"}
# similarity_assessment_model(query10, 延長プランを申込ましたが、決済の手続きは別に連絡がくるのでしょうか？): {"similarity": 3, "comment": "文章1は支払い完了を伝える内容、文章2は決済手続きに関する問い合わせです。大まかな内容は「支払いに関する問い合わせ」という点で類似していますが、具体的な内容は異なります。文章表現はどちらも簡潔で、類似性が見られます。"}
# similarity_assessment_model(query10, 【お支払いについて】): {"similarity":0,"comment":"文章の内容が異なり、文章表現や単語も異なっているため"}
#
# similarity_assessment_model(query10, 支払いは完了しました): {"similarity":4,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なっている。文章表現は類似している。"}
#
# query11: 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！,当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！,当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！,私の記憶違いでしょうか？明日の15：30〜だと思っていました。,失礼しました。15分からでしたので、間に合うかもしれません。
# similarity_assessment_model(query11, 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query11, 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！): {"similarity": 5, "comment": "文章1と文章2は完全に同一の内容です。"}
# similarity_assessment_model(query11, 当日のご連絡申し訳ないです……間に合いそうにないので明日の16：30から予約させていただきました……！): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query11, 私の記憶違いでしょうか？明日の15：30〜だと思っていました。): {"similarity": 2, "comment": "文章1は予約変更の連絡、文章2は予約時間の確認という、異なる内容です。しかし、両方の文章に「明日」「15:30」という単語が含まれており、文末に「！」が使われていることから、2としました。"}
# similarity_assessment_model(query11, 失礼しました。15分からでしたので、間に合うかもしれません。): {"similarity": 0, "comment": "文章1は予約変更の連絡、文章2は予約の確認の返信という、文脈が全く異なるため、類似度は0です。"}
#
# query12: week1-1,2の課題を提出しました。,Week1課題②、③、④提出しました。,week1-4④、2-1の課題を提出しました。よろしくお願い致します。,week2 2-1 課題を提出しました,課題2-1提出しました。
# similarity_assessment_model(query12, week1-1,2の課題を提出しました。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章のため、類似度は5です。"}
# similarity_assessment_model(query12, Week1課題②、③、④提出しました。): {"similarity":3,"comment":"文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出した課題番号が違う）、文章表現も異なっている（「-」と「、」の使い方、数字の表記などが違う）ため3とした。"}
# similarity_assessment_model(query12, week1-4④、2-1の課題を提出しました。よろしくお願い致します。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出した課題番号）、文章表現も異なっている（文章2は丁寧語を使用している）ため、3とした。"}
# similarity_assessment_model(query12, week2 2-1 課題を提出しました): {"similarity":3,"comment":"文章の大まかな内容は類似している(課題提出)が、細かい内容(weekと課題番号)が異なり、文章表現も異なっている。"}
# similarity_assessment_model(query12, 課題2-1提出しました。): {"similarity":2,"comment":"文章の大まかな内容は異なっているが、課題提出という単語が使われているため2とした。"}
#
# query13: 【返金・解約】,【返金・解約】,【返金・解約】,【受講開始後の解約】,【返金制度】
# similarity_assessment_model(query13, 【返金・解約】): {"similarity": 5, "comment": "文章1と文章2は全く同じなので、類似度は5です。"}
# similarity_assessment_model(query13, 【返金・解約】): {"similarity":5,"comment":"文章1と文章2は完全に一致しているため、類似度は5です。"}
# similarity_assessment_model(query13, 【返金・解約】): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query13, 【受講開始後の解約】): {"similarity":3,"comment":"文章の大まかな内容は類似している（解約に関する内容）が、細かい内容は異なり（文章1は返金も含む）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query13, 【返金制度】): {"similarity": 3, "comment": "文章の大まかな内容は類似している（返金に関する内容）。しかし、文章1は「返金・解約」と解約も含まれているのに対し、文章2は「返金制度」のみであり、細かい内容は異なる。文章表現も「〜」と「制度」と異なっている。"}
#
# query14: 「2-1実践課題　完了しました。リンクの共有が度々エラーになってしまい、提出ができないです。（有料版にしたんですけど・・）,立て続けに申し訳ありません。実践課題について質問させてください。2-1のコメントを提出したのですが、エラーになって書き直したところ、なぜか2-2にも2-1と同じ内容のコメントが提出されてしまいました💦2-2の課題では、画像を提出しましょう！となっていたのですが、画像を提出できないまますでに完了となってしまいました…このままでも問題ないのでしょうか？🙇‍♂️,実践課題の提出方法の共有リンクが分かりませんでしたが、下記、完了しました。1-4 実践課題①～④実施1-4 実践課題①～④提出,ご連絡失念しておりましたが、昨日「2-1実践課題」を提出いたしました。ご確認よろしくお願いいたします,3-1 実践課題3-2 実践課題提出しました。
# similarity_assessment_model(query14, 「2-1実践課題　完了しました。リンクの共有が度々エラーになってしまい、提出ができないです。（有料版にしたんですけど・・）): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query14, 立て続けに申し訳ありません。実践課題について質問させてください。2-1のコメントを提出したのですが、エラーになって書き直したところ、なぜか2-2にも2-1と同じ内容のコメントが提出されてしまいました💦2-2の課題では、画像を提出しましょう！となっていたのですが、画像を提出できないまますでに完了となってしまいました…このままでも問題ないのでしょうか？🙇‍♂️): {"similarity": "3", "comment": "文章の大まかな内容は類似しており、どちらも課題提出に関する問題について記述しています。しかし、細かい内容は異なり、文章1はリンク共有に関するエラー、文章2はコメント提出に関するエラーと画像提出に関する問題について記述しています。また、文章表現も異なります。文章1は簡潔で事務的な表現である一方、文章2は感情的な表現が多く使われています。"}
# similarity_assessment_model(query14, 実践課題の提出方法の共有リンクが分かりませんでしたが、下記、完了しました。1-4 実践課題①～④実施1-4 実践課題①～④提出): {"similarity": "3", "comment": "文章1は課題提出に関する問題点の報告、文章2は課題完了の報告。内容が異なるものの、課題に関する記述があるため、3とした。"}
# similarity_assessment_model(query14, ご連絡失念しておりましたが、昨日「2-1実践課題」を提出いたしました。ご確認よろしくお願いいたします): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なる。文章1は課題提出ができないことを伝えているのに対し、文章2は提出済みであることを伝えている。また、文章表現も丁寧な表現とカジュアルな表現で異なる。"}
# similarity_assessment_model(query14, 3-1 実践課題3-2 実践課題提出しました。): {"similarity":0,"comment":"文章1は課題提出に関する問題点について記述しているのに対し、文章2は課題提出完了の報告となっており、内容が大きく異なります。また、文章表現や単語も異なるため、類似度は0と判断しました。"}
#
# query15: 10/29.30仕事疲れで何もできず寝てしまいました。また今日から頑張ります！,藤川さん宛✨今日は予定通り進められたので良かったです！明日から仕事ですが、頑張ります！,杉本さん先日はお時間頂きありがとうございましたあれからまた余裕が持てず、そのままになってしまいました。頂いた情報を活用出来るよう、何とか無駄にしないよう頑張りたい、、、お世話かけますが、宜しくお願い致します。,藤川さんへこんばんは(月)夜分にすみません(emoji)figma制作中ですが、難易度高くなりボーっとしてます(emoji)少しずつ頑張ります(emoji),藤岡様宛ちょっと本業の方がバタバタして1週間くらいできていないです…もう落ち着くと思うので明日からまた頑張ります
# similarity_assessment_model(query15, 10/29.30仕事疲れで何もできず寝てしまいました。また今日から頑張ります！): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query15, 藤川さん宛✨今日は予定通り進められたので良かったです！明日から仕事ですが、頑張ります！): {"similarity": "3", "comment": "文章の大まかな内容は類似している（仕事に対する意気込み）が、細かい内容は異なり（文章1は疲れを訴えているが、文章2は予定通り進められたと報告している）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query15, 杉本さん先日はお時間頂きありがとうございましたあれからまた余裕が持てず、そのままになってしまいました。頂いた情報を活用出来るよう、何とか無駄にしないよう頑張りたい、、、お世話かけますが、宜しくお願い致します。): {"similarity":1,"comment":"文章1は仕事疲れで何もできずに寝てしまったという内容なのに対して、文章2は杉本さんから何かしらの情報を頂き、それを活用したいという内容である。そのため、文章の内容は大きく異なる。しかし、文章の雰囲気は、どちらも前向きな言葉遣いで、頑張りたいという意志が感じられる点で類似している。そのため、類似度は1とした。"}
# similarity_assessment_model(query15, 藤川さんへこんばんは(月)夜分にすみません(emoji)figma制作中ですが、難易度高くなりボーっとしてます(emoji)少しずつ頑張ります(emoji)): {"similarity": 1, "comment": "文章の内容は異なっていますが、文章表現や雰囲気が似ています。どちらも仕事に対する意気込みを表明しており、絵文字を用いて軽い口調で記述されています。"}
# similarity_assessment_model(query15, 藤岡様宛ちょっと本業の方がバタバタして1週間くらいできていないです…もう落ち着くと思うので明日からまた頑張ります): {"similarity":3,"comment":"文章の大まかな内容は類似している（仕事疲れで何もできない、明日から頑張る）が、細かい内容（具体的な仕事内容や期間）が異なり、文章表現も異なる。"}
#
# query16: 受講方法をお伺いしても大丈夫でしょうか,ご連絡ありがとうございます。勉強会についてお伺いします。延長を申し込まない場合、勉強会も11/1まで、となりますか？,Slackの確認はしていましたが、体調を長らく崩してしまっており全く受講出来ていませんでした。本日より受講しました。大丈夫でしょうか？,お世話になっております！宮本です。受講開始まであと1週間になりましたが、今後の流れについては、いつ頃お知らせいただけますでしょうか…。不安になってしまったので、ご連絡をさせていただきました💦お忙しいところ恐れ入りますが、ご確認をよろしくお願いいたします。,入会手続きを完了させていただいていますが、この後のスケジュールはどのようになりますでしょうか。手続き完了からしばらく時間が経過しておりますため再度確認させていただけると幸いです。よろしくお願いします。
# similarity_assessment_model(query16, 受講方法をお伺いしても大丈夫でしょうか): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query16, ご連絡ありがとうございます。勉強会についてお伺いします。延長を申し込まない場合、勉強会も11/1まで、となりますか？): {"similarity": "1", "comment": "文章1は受講方法について尋ねているのに対し、文章2は勉強会の延長について尋ねています。そのため、内容が異なります。しかし、文章の表現や雰囲気が似ているため、1と評価しました。"}
# similarity_assessment_model(query16, Slackの確認はしていましたが、体調を長らく崩してしまっており全く受講出来ていませんでした。本日より受講しました。大丈夫でしょうか？): {"similarity": 3, "comment": "文章1は受講方法について質問しているのに対し、文章2は受講の遅延について説明しています。そのため、内容としては異なります。しかし、文章表現はどちらも丁寧な口調で、疑問を呈しているという点で共通点があります。"}
# similarity_assessment_model(query16, お世話になっております！宮本です。受講開始まであと1週間になりましたが、今後の流れについては、いつ頃お知らせいただけますでしょうか…。不安になってしまったので、ご連絡をさせていただきました💦お忙しいところ恐れ入りますが、ご確認をよろしくお願いいたします。): {"similarity": "3", "comment": "文章1は受講方法について尋ねるシンプルな文面である一方、文章2は受講開始まで1週間になったことを前提に、今後の流れについて問い合わせている。文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっているため、3と評価しました。"}
# similarity_assessment_model(query16, 入会手続きを完了させていただいていますが、この後のスケジュールはどのようになりますでしょうか。手続き完了からしばらく時間が経過しておりますため再度確認させていただけると幸いです。よろしくお願いします。): {"similarity": "2", "comment": "文章1は受講方法について質問しているのに対し、文章2は入会手続き後のスケジュールについて質問しています。そのため、文章の内容は異なります。しかし、どちらも手続きに関する質問であるため、単語が似通っています。"}
#
# query17: week1-4④、2-1の課題を提出しました。よろしくお願い致します。,添削ありがとうございます(emoji)続けてWeek1-4実践課題②③④を提出しましたご確認よろしくお願いします,week1-1,2の課題を提出しました。,week1-4の課題を提出しましたご確認よろしくお願いします,WEEK2-1課題を提出しました。よろしくお願いします。
# similarity_assessment_model(query17, week1-4④、2-1の課題を提出しました。よろしくお願い致します。): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query17, 添削ありがとうございます(emoji)続けてWeek1-4実践課題②③④を提出しましたご確認よろしくお願いします): {"similarity": "3", "comment": "文章の大まかな内容は類似していますが、細かい内容が異なっています。文章1はweek1-4④、2-1の課題の提出に関する内容ですが、文章2はWeek1-4実践課題②③④の提出に関する内容です。文章表現も、文章1は丁寧な表現ですが、文章2はカジュアルな表現です。"}
# similarity_assessment_model(query17, week1-1,2の課題を提出しました。): {"similarity": "3", "comment": "文章1はweek1-4④、2-1の課題を提出したことを示しており、文章2はweek1-1,2の課題を提出したことを示しています。文章の大まかな内容は類似していますが、細かい内容（提出した課題の番号）が異なっています。文章表現は、どちらも簡潔で事務的な表現であるため、類似しています。そのため、類似度は3と判断しました。"}
# similarity_assessment_model(query17, week1-4の課題を提出しましたご確認よろしくお願いします): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている。文章1では「2-1の課題」という具体的な課題名も含まれている一方、文章2では「week1-4の課題」と、より一般的な表現となっている。文章表現は類似している。"}
# similarity_assessment_model(query17, WEEK2-1課題を提出しました。よろしくお願いします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出した課題の番号）が異なり、文章表現も若干異なる。"}
#
#
# query18: すみません、ありがとうございます🙇‍♀️,すみません解決しました,上田さんこちらこそ、さきほどはありがとうございました(ありがとう)メモ取り損なっていてすみません(emoji) リスト助かります🙇‍♀️ ありがとうございます(emoji),岡田様、お忙しいところありがとうございました🙇‍♀️短時間で、要点を説明頂いてすごくわかりやすかったです(きらきら)早々と立ち去ってすみません🙇‍♀️ありがとうございました(ありがとう),お手数をおかけしてしまい、大変申し訳ありません。迅速なご対応ありがとうございます！！💦引き続き、どうぞよろしくお願い致します🙇‍♀️
# similarity_assessment_model(query18, すみません、ありがとうございます🙇‍♀️): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query18, すみません解決しました): {"similarity": 1, "comment": "文章の内容は異なるが、短い文章で丁寧な表現を用いているという点で雰囲気が似ているため1とした。"}
# similarity_assessment_model(query18, 上田さんこちらこそ、さきほどはありがとうございました(ありがとう)メモ取り損なっていてすみません(emoji) リスト助かります🙇‍♀️ ありがとうございます(emoji)): {"similarity": "4", "comment": "文章1は感謝と謝罪の短い表現。文章2は具体的な状況を含めた感謝と謝罪の表現。内容は異なるが、感謝と謝罪という大まかな内容は同じで、文章表現も類似しているため4とした。"}
# similarity_assessment_model(query18, 岡田様、お忙しいところありがとうございました🙇‍♀️短時間で、要点を説明頂いてすごくわかりやすかったです(きらきら)早々と立ち去ってすみません🙇‍♀️ありがとうございました(ありがとう)): {"similarity": "3", "comment": "文章1は簡潔な謝辞のみだが、文章2は具体的な状況や相手への感謝の気持ちが含まれている。大まかな内容は類似しているが、細かい内容と文章表現が異なっているため、3とした。"}
# similarity_assessment_model(query18, お手数をおかけしてしまい、大変申し訳ありません。迅速なご対応ありがとうございます！！💦引き続き、どうぞよろしくお願い致します🙇‍♀️): {"similarity": "4", "comment": "文章の大まかな内容は感謝の気持ちを伝えているという点で類似している。しかし、文章2の方が丁寧な表現で、具体的な状況や今後の依頼なども含まれている。文章表現はどちらも絵文字を使用しているなど類似している。"}
#
# query19: 島戸さんお疲れ様です。本日は貴重なお時間ありがとうございました！お話していて、自分の中でまだふわふわしてる部分があるなぁと感じたので、もうちょっと目標を明確にして少しずつですが、自分のペースで頑張りたいと思います。本日はWEBデザイン基礎編1-2まで行い、10月までの目標シートを作成しました。別途添付しますので、ご確認ください。,島戸さんこんにちはお疲れ様です☀️少し涼しくなり朝は冷えますね💦連休中も仕事でバタバタで、娘もすっかり拗ねてしまって、上手く時間を作れませんでしたが、お昼頃に1-3canva演習の提出を致しました🙌またこれから仕事ですが、今日は夜に少し時間が作れそうなので1-4をしようと思います。,千賀さんお疲れ様です！今日は2-3の課題提出まで終わりました。カリキュラム1の添削をしていただいたものが返ってきていたので、明日はその再提出とwebデザインの序盤に手をつけられればと思います！,藤川さん宛✨今日は予定通り進められたので良かったです！明日から仕事ですが、頑張ります！,藤川様昨夜は遅くまで遊び続ける娘を寝かしつけ、一緒に眠ってしまったので、何も勉強が進んでいませんでした(汗)LINEの報告も遅くなりすみません🥲本日はまた少しでもポートフォリオ作成の続きを行っていきたいです！よろしくお願いいたします。
# similarity_assessment_model(query19, 島戸さんお疲れ様です。本日は貴重なお時間ありがとうございました！お話していて、自分の中でまだふわふわしてる部分があるなぁと感じたので、もうちょっと目標を明確にして少しずつですが、自分のペースで頑張りたいと思います。本日はWEBデザイン基礎編1-2まで行い、10月までの目標シートを作成しました。別途添付しますので、ご確認ください。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query19, 島戸さんこんにちはお疲れ様です☀️少し涼しくなり朝は冷えますね💦連休中も仕事でバタバタで、娘もすっかり拗ねてしまって、上手く時間を作れませんでしたが、お昼頃に1-3canva演習の提出を致しました🙌またこれから仕事ですが、今日は夜に少し時間が作れそうなので1-4をしようと思います。): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、細かい内容が異なっている。文章表現も若干異なっている。文章1は目標設定に関する内容、文章2は業務報告と今後の予定に関する内容。"}
# similarity_assessment_model(query19, 千賀さんお疲れ様です！今日は2-3の課題提出まで終わりました。カリキュラム1の添削をしていただいたものが返ってきていたので、明日はその再提出とwebデザインの序盤に手をつけられればと思います！): {"similarity": 3, "comment": "文章の大まかな内容は類似している（目標達成に向けた進捗報告）。しかし、細かい内容は異なり（文章1は目標シート作成、文章2は課題提出）、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query19, 藤川さん宛✨今日は予定通り進められたので良かったです！明日から仕事ですが、頑張ります！): {"similarity": 1, "comment": "文章1は目標達成に向けた具体的な行動と計画が示されているのに対し、文章2は抽象的な内容です。しかし、文章表現や文章の雰囲気が似ているため、1と評価しました。"}
# similarity_assessment_model(query19, 藤川様昨夜は遅くまで遊び続ける娘を寝かしつけ、一緒に眠ってしまったので、何も勉強が進んでいませんでした(汗)LINEの報告も遅くなりすみません🥲本日はまた少しでもポートフォリオ作成の続きを行っていきたいです！よろしくお願いいたします。): {"similarity": 1, "comment": "文章の内容は異なり、どちらも学習に関する内容だが、文章1は目標設定について、文章2はポートフォリオ作成についての内容である。文章表現は、どちらも丁寧な言葉遣いで、感謝の気持ちを表す言葉が含まれているため、1とした。"}
#
# query20: お早い返信ありがとうございます！！早く治します！❤️‍🔥治り次第、予約させていただきます！,嶋内様初めまして。ご連絡ありがとうございます！2土曜の、11時からでお願いしてもよろしいでしょうか？こちらの都合で申し訳ございません。どうぞよろしくお願いいたします。,ご対応ありがとうございます。11日に予約させて頂きました。よろしくお願いします🙇‍♀️,嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！,あやねさんお世話になっております。平田ななこです。本日14：30〜zoom面談の予約をしていただいていると思うのですが、体調を崩してしまい、病院へ行くことになりました😭お忙しい中、貴重なお時間を取っていただいたにも関わらず大変申し訳ございません💦お手数おかけいたしますが、面談変更をお願いしてもよろしいでしょうか？😖〈希望日〉・14日10:00〜・16日午前中・19日・24日予約の空いている日はありますでしょうか？💦何卒よろしくお願い申し上げます🙇🏻‍♀️
# similarity_assessment_model(query20, お早い返信ありがとうございます！！早く治します！❤️‍🔥治り次第、予約させていただきます！): {"similarity":5,"comment":"文章1と文章2は全く同じです。"}
# similarity_assessment_model(query20, 嶋内様初めまして。ご連絡ありがとうございます！2土曜の、11時からでお願いしてもよろしいでしょうか？こちらの都合で申し訳ございません。どうぞよろしくお願いいたします。): {"similarity":0,"comment":"文章の内容が大きく異なり、単語や表現も異なるため0としました。"}
# similarity_assessment_model(query20, ご対応ありがとうございます。11日に予約させて頂きました。よろしくお願いします🙇‍♀️): {"similarity": "3", "comment": "文章の大まかな内容は類似している（予約に関する感謝の言葉）。細かい内容は異なり（文章1は治療に関する内容、文章2は予約に関する内容）、文章表現も異なる（文章1は絵文字を使用、文章2は敬語を使用）"}
# similarity_assessment_model(query20, 嶋内さん早速ご連絡とご提案ありがとうございます！！本日15時から可能です！！): {"similarity": 3, "comment": "文章の大まかな内容は、どちらも感謝の気持ちを表明し、その後具体的な行動に移すことを伝えているため類似している。しかし、細かい内容（感謝の対象、行動の内容）が異なっており、文章表現も異なるため3点とした。"}
# similarity_assessment_model(query20, あやねさんお世話になっております。平田ななこです。本日14：30〜zoom面談の予約をしていただいていると思うのですが、体調を崩してしまい、病院へ行くことになりました😭お忙しい中、貴重なお時間を取っていただいたにも関わらず大変申し訳ございません💦お手数おかけいたしますが、面談変更をお願いしてもよろしいでしょうか？😖〈希望日〉・14日10:00〜・16日午前中・19日・24日予約の空いている日はありますでしょうか？💦何卒よろしくお願い申し上げます🙇🏻‍♀️): {"similarity": 0, "comment": "文章1は予約に対する感謝と早く治したいという気持ちを表しており、文章2は予約変更の依頼です。文章の内容、表現、単語全てが異なるため、類似度は0です。"}

# %% [markdown]
# Without category

# %%
print(search_sample(
project_id = "monobrain-development",
location = "global",                    # Values: "global", "us", "eu"
engine_id = "samplequery_1732851004864",
search_query = "今日は取り組めませんでした"
))
type(search_sample(
project_id = "monobrain-development",
location = "global",                    # Values: "global", "us", "eu"
engine_id = "samplequery_1732851004864",
search_query = "今日は取り組めませんでした"
))
# Out:
# SearchPager<results {
#   id: "2f2fda00a42f572696cc306f99c94c53"
#   document {
#     struct_data {
#       fields {
#         key: "question"
#         value {
#           string_value: "谷津さんお久しぶりです1週間程体調を崩してしまい、あまり進められませんでした。取り組みもご報告できておらず、すみませんでした。本日からまた頑張っていきます！取り組んだこと10/4・2-2 動画視聴10/5・2-2 実践課題実施10/6・2-2 実践課題提出・2-3 動画視聴10/8・勉強会・2-3 実践課題実施、提出10/14・2-3 実践課題実施、再提出・3-1 動画視聴、実践課題提出・3-2 動画視聴、実践課題提出・3-3 動画視聴、実践課題実施"
#         }
#       }
#       fields {
#         key: "id"
#         value {
#           string_value: "qa_1341"
#         }
#       }
#       fields {
#         key: "answer"
#         value {
#           string_value: "ご報告ありがとうございます！体調不良の中でも、コツコツ進めてくださり素晴らしいです🥲体調第一で、引き続きご自身の良いペースで無理はしすぎず進めていきましょう😊お取り組みお疲れ様でした👏✨"
#         }
#       }
#     }
#     name: "projects/954273464710/locations/global/collections/default_collection/dataStores/query_1732851097294/branches/0/documents/2f2fda00a42f572696cc306f99c94c53"
#     id: "2f2fda00a42f572696cc306f99c94c53"
#     derived_struct_data {
#       fields {
#         key: "snippets"
#         value {
#           list_value {
#             values {
#               struct_value {
#                 fields {
#                   key: "snippet"
#                   value {
#                     string_value: "No snippet is available for this page."
#                   }
#                 }
#                 fields {
#                   key: "snippet_status"
#                   value {
#                     string_value: "NO_SNIPPET_AVAILABLE"
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# total_size: 1
# attribution_token: "9QHw9AoLCNWAyroGEInH5HwSJDY3NTY3NWM1LTAwMDAtMmFiYS1iMmEzLWM4MmFkZDdlNTFlNCIHR0VORVJJQyq0AbeSrjC2t4wtxcvzF6CJsy3bj5oi6d3EMI6RyTCNpLQwrfizLa7Eii3ExrEwg7KaIqvEii2jibMtmd3YMObdxDDB-LwwgLKaItHmtS-b1rctwfzLMN6PmiKOvp0VqvizLZbeqC_C8J4VkKS0MKOAlyLogrEtx8axMPz2sy3k7YgttJKuMJneqC_rgrEtzua1L9SynRWY1rctxPzLMOftiC2c3dgwlJLFMPn2sy2Q97IwxPi8MDAB"
# summary {
#   summary_text: "I understand you were unable to work on the task today. [1] It\'s great that you\'re still making progress despite feeling unwell. Please prioritize your health and continue at your own pace. [1] You\'ve been working hard, so take a break if you need it.  We appreciate your efforts and look forward to seeing your continued progress. [1] \n"
#   summary_with_metadata {
#     summary: "I understand you were unable to work on the task today. It\'s great that you\'re still making progress despite feeling unwell. Please prioritize your health and continue at your own pace. You\'ve been working hard, so take a break if you need it.  We appreciate your efforts and look forward to seeing your continued progress. \n"
#     citation_metadata {
#       citations {
#         end_index: 55
#         sources {
#         }
#       }
#       citations {
#         start_index: 56
#         end_index: 185
#         sources {
#         }
#       }
#       citations {
#         start_index: 245
#         end_index: 323
#         sources {
#         }
#       }
#     }
#     references {
#       document: "projects/954273464710/locations/global/collections/default_collection/dataStores/query_1732851097294/branches/0/documents/2f2fda00a42f572696cc306f99c94c53"
#     }
#   }
# }
# query_expansion_info {
# }
# >
# google.cloud.discoveryengine_v1.services.search_service.pagers.SearchPager

# %%
# Transform the response into desired format
def transform_search_response(response: SearchPager) -> list:
    similar_chats = []
    for result in response.results:
        data = dict(result.document.struct_data)
        chat = {
            'id': data.get('id', ''),
            'question': data.get('question', ''),
            'answer': data.get('answer', ''),
        }
        similar_chats.append(chat)
    return similar_chats

# Fetch data from multiple pages
def fetch_all_data(project_id, location, engine_id, num_pages=5, page_size=20):
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )

    client = discoveryengine.SearchServiceClient(client_options=client_options)
    serving_config = f"projects/{project_id}/locations/{location}/collections/default_collection/engines/{engine_id}/servingConfigs/default_config"

    all_data = []
    for page in range(num_pages):
        request = discoveryengine.SearchRequest(
            serving_config=serving_config,
            query="",  # Broad query to fetch data
            page_size=page_size,
            offset=page * page_size
        )
        response = client.search(request)
        all_data.extend(transform_search_response(response))

    return all_data

# Function to assess similarity between two queries using Vertex AI
def similarity_assessment_model(query1, query2):
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }

    vertexai.init(project="monobrain-development", location="us-central1")
    model = GenerativeModel("gemini-1.5-flash-001")
    responses = model.generate_content([
        """あなたは日本語の小説の編集者をしており、文章のスペシャリストです。
        以下の文章を比べて類似度を数値5段階で出力してください。

        文章の大まかな内容と細かい内容、文章表現全てが類似している場合は : 5
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が類似しているものは : 4
        文章の大まかな内容は類似しているが、細かい内容が違っており、文章表現が異なっているものは : 3
        文章の大まかな内容は異なっているが、文内で使われている単語が似通っている場合 : 2
        文書の内容は間違っているが、文章表現や文章の雰囲気が似ている場合 : 1
        文章の内容が違っており、文章表現や単語も異なっている場合 : 0

        jsonの形式は{"similarity":3,"comment":"ここになぜそのような評価にしたかのコメント"}

        文章1 :""" + query1 + "\n 文章2 : " + query2],
        generation_config=generation_config,
        stream=False,
    )

    return str(responses.candidates[0].content.parts[0].text)

# Step 1: Fetch data from multiple pages
all_data = fetch_all_data(
    project_id="monobrain-development",
    location="global",
    engine_id="samplequery_1732851004864",
    num_pages=5,
    page_size=20
)

# Step 2: Randomly select 20 entries for evaluation
evaluation_data = random.sample(all_data, min(20, len(all_data)))

# Step 3: Evaluate each query and find 5 similar questions
print("Evaluating using Agent Builder:")
for idx, data in enumerate(evaluation_data, start=1):
    query = data['question']

    # Query the engine for similar questions
    similar_response = search_sample(
        project_id="monobrain-development",
        location="global",
        engine_id="samplequery_1732851004864",
        search_query=query
    )

    # Transform the response to extract similar chats
    similar_chats = transform_search_response(similar_response)[:5]

    # Display the results
    similar_questions = ','.join([chat['question'] for chat in similar_chats])
    print(f"query{idx}: {similar_questions}")
    for i, chat in enumerate(similar_chats, start=1):
        similarity_score = similarity_assessment_model(query, chat['question'])
        print(f"similarity_assessment_model(query{idx}, {chat['question']}): {similarity_score}")
    print()
# Out:
# Evaluating using Agent Builder:
# query1: お世話になっております！先ほど入金させていただきました！ご確認をよろしくお願いいたします🙇‍♀,おはようございます。本日、10時からイベント参加の予約をしておりましたが、体調不良のためキャンセルさせて頂きたくご連絡させて頂きました。欠席連絡しようとしましたが、入力が間違っているとなってしまい、ご連絡出来ていません。,こんにちは。お世話になっております。遅れておりますが、5-3、6-1、2を提出しました。よろしくお願い致します！,井関さん、こんにちは！3-3実践課題の提出終わりました！,藤川様こんばんは。体調不良からも回復して、本日はポートフォリオの作成の続きを行うことが出来ました☺️また明日も引き続き頑張りたいと思います！
# similarity_assessment_model(query1, お世話になっております！先ほど入金させていただきました！ご確認をよろしくお願いいたします🙇‍♀): {"similarity": 4, "comment": "文章の大まかな内容は類似しており、どちらも振り込みの報告をしている。細かい内容では、文章1は「振り込みました!!」と簡潔な表現である一方、文章2は「先ほど入金させていただきました！」と丁寧な表現を用いている。文章表現はどちらも口語調で類似している。"}
# similarity_assessment_model(query1, おはようございます。本日、10時からイベント参加の予約をしておりましたが、体調不良のためキャンセルさせて頂きたくご連絡させて頂きました。欠席連絡しようとしましたが、入力が間違っているとなってしまい、ご連絡出来ていません。): {"similarity": 0, "comment": "文章1と文章2は内容も表現も大きく異なるため、類似度は0です。"}
# similarity_assessment_model(query1, こんにちは。お世話になっております。遅れておりますが、5-3、6-1、2を提出しました。よろしくお願い致します！): {"similarity":0,"comment":"文章1は支払いの報告、文章2は提出物の報告であり、内容が異なる。文章表現も異なる。"}
# similarity_assessment_model(query1, 井関さん、こんにちは！3-3実践課題の提出終わりました！): {"similarity":0,"comment":"文章の内容、表現、単語が全て異なっているため"}
# similarity_assessment_model(query1, 藤川様こんばんは。体調不良からも回復して、本日はポートフォリオの作成の続きを行うことが出来ました☺️また明日も引き続き頑張りたいと思います！): {"similarity": 0, "comment": "文章1は振り込みの報告、文章2は体調不良からの回復とポートフォリオ作成の報告であり、内容や単語、文章表現が全く異なります。"}
#
# query2: 夜分にすみません、目標送るのが遅くなってしまいました💦,■HerTech受講への今の気持ち：新しくパソコンもお迎えして、ワクワクの気持ちと、ちゃんと出来るだろうかという不安もちょこちょこありつつも楽しみだったり、気持ちが忙しい状態です笑自分なりに自分で選んだ道、頑張っていきたいなと思っております😌
# similarity_assessment_model(query2, 夜分にすみません、目標送るのが遅くなってしまいました💦): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query2, ■HerTech受講への今の気持ち：新しくパソコンもお迎えして、ワクワクの気持ちと、ちゃんと出来るだろうかという不安もちょこちょこありつつも楽しみだったり、気持ちが忙しい状態です笑自分なりに自分で選んだ道、頑張っていきたいなと思っております😌): {"similarity": "0", "comment": "文章1は謝罪と説明、文章2は受講への意気込みについて記述しており、内容が大きく異なります。また、文章表現も大きく異なっています。"}
#
# query3: 実践課題8-1,8-2,8-3の提出を完了しました。ご確認よろしくお願い致します。,お疲れ様です。実践課題8-1、8-2提出いたします。宜しくお願いします。,谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。,8-3、8-4課題完了しました。,実践課題6-4を提出しました。ご確認よろしくお願い致します。
# similarity_assessment_model(query3, 実践課題8-1,8-2,8-3の提出を完了しました。ご確認よろしくお願い致します。): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query3, お疲れ様です。実践課題8-1、8-2提出いたします。宜しくお願いします。): {"similarity": "3", "comment": "文章の大まかな内容は類似しているが、細かい内容が異なり（課題8-3の提出が含まれるかどうか）、文章表現も異なります。"}
# similarity_assessment_model(query3, 谷津さん、お疲れ様です!▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・1-3の実践課題提出完了しました。完全にぴったり合わすことができませんでしたが、詳細コメントに記載いたしました。): {"similarity": 2, "comment": "文章の大まかな内容は異なっているが、提出完了という単語が共通しているため2としました。"}
# similarity_assessment_model(query3, 8-3、8-4課題完了しました。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（提出完了の報告）。細かい内容は異なり、文章表現も異なる（課題番号の表記、丁寧語の有無）。"}
# similarity_assessment_model(query3, 実践課題6-4を提出しました。ご確認よろしくお願い致します。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容は異なり（課題番号が異なる）、文章表現は類似している。"}
#
# query4: 返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします,返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします,返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします,返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします,こんばんは！しばらく進捗報告できておらず、申し訳ありません🙇🏻‍♀️💦仕事でバタバタしておりました…😵‍💫バナートレース練習3つできました！30日の勉強会でフィードバックしてもらいます☺️✨あと何個か練習してみて、4-1と4-2の任意課題にも取り組んでみます💪🏻
# similarity_assessment_model(query4, 返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query4, 返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします): {"similarity":5,"comment":"文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query4, 返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query4, 返信できておらず申し訳ございません🙇‍♀️この日程で大丈夫ですよろしくお願いします): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query4, こんばんは！しばらく進捗報告できておらず、申し訳ありません🙇🏻‍♀️💦仕事でバタバタしておりました…😵‍💫バナートレース練習3つできました！30日の勉強会でフィードバックしてもらいます☺️✨あと何個か練習してみて、4-1と4-2の任意課題にも取り組んでみます💪🏻): {"similarity": 1, "comment": "文章1は返信の確認で、文章2は報告と今後の予定なので、内容は大きく異なります。しかし、文章表現や絵文字の使用など、文の雰囲気が似ているため1としました。"}
#
#
# query5: 実践課題1ー4③④を提出しました。宜しくお願いします✨,実践課題2ー1、2ー2を提出しました。宜しくお願いします。,松丸です。Week3-1の実践課題を提出しました。よろしくお願いします。,week2-1 実践課題を提出しました。よろしくお願いします🙇‍♀️,実践課題6-1を提出しました。よろしくお願い致します。
# similarity_assessment_model(query5, 実践課題1ー4③④を提出しました。宜しくお願いします✨): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
#
# similarity_assessment_model(query5, 実践課題2ー1、2ー2を提出しました。宜しくお願いします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（提出の報告）が、細かい内容は異なり（課題番号が異なる）、文章表現も若干異なっている（絵文字の有無）ため3とした。"}
# similarity_assessment_model(query5, 松丸です。Week3-1の実践課題を提出しました。よろしくお願いします。): {"similarity":3,"comment":"文章1と文章2は、どちらも課題提出の報告であるという大まかな内容は類似している。しかし、課題番号や提出時期などの細かい内容が異なり、文章表現も異なる。そのため、類似度は3とした。"}
# similarity_assessment_model(query5, week2-1 実践課題を提出しました。よろしくお願いします🙇‍♀️): {"similarity": 3, "comment": "文章の大まかな内容は類似している（提出に関する報告）が、細かい内容（課題番号や提出先）が異なり、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query5, 実践課題6-1を提出しました。よろしくお願い致します。): {"similarity": 3, "comment": "文章の大まかな内容は類似している(提出の報告)が、課題番号が異なり、文章表現も若干異なるため3とした。"}
#
# query6: 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 申し訳ありません、９月中の面談は難しく、１０月でお願いいたします🙇‍♀️,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 明日の勉強会はこのプロンプトについて教えていただきたいと思っています。よろしくお願いいたしました。https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ありがとうございます！よろしくお願いします。,表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ご連絡ありがとうございます。本日、入金させていただければと思います。また、お手数おかけして申し訳ありませんが、契約書の方をもう一度送っていただくことは可能でしょうか？,嶋内様大変申し訳ないのですが、10月14日(月)の面談の時間を変更していただきたいのですが可能でしょうか？よろしくお願いします🙇‍♀️
# similarity_assessment_model(query6, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 申し訳ありません、９月中の面談は難しく、１０月でお願いいたします🙇‍♀️): {"similarity": 5, "comment": "文章1と文章2は完全に同一の内容、表現です。"}
# similarity_assessment_model(query6, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# 明日の勉強会はこのプロンプトについて教えていただきたいと思っています。よろしくお願いいたしました。https://chatgpt.com/share/66e80df3-3168-800c-b313-f7e550e3a68f): {"similarity": 0, "comment": "文章の内容が大きく異なり、文章表現も単語も異なっているため、類似度は0です。"}
# similarity_assessment_model(query6, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ありがとうございます！よろしくお願いします。): {"similarity":1,"comment":"文章の内容は大きく異なるが、文章表現や文末の記号などが似ている。"}
#
# similarity_assessment_model(query6, 表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。
# ご連絡ありがとうございます。本日、入金させていただければと思います。また、お手数おかけして申し訳ありませんが、契約書の方をもう一度送っていただくことは可能でしょうか？): {"similarity": 2, "comment": "文章の大まかな内容は異なっていますが、文内で使われている単語が似通っています。特に「表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。」という部分は共通しています。"}
# similarity_assessment_model(query6, 嶋内様大変申し訳ないのですが、10月14日(月)の面談の時間を変更していただきたいのですが可能でしょうか？よろしくお願いします🙇‍♀️): {"similarity": "3", "comment": "文章1は、引用元メッセージがないことを示唆し、面談の延期を依頼しています。文章2は、面談日時変更を依頼しています。文章の大まかな内容は類似していますが、細かい内容が異なり、文章表現も異なっています。"}
#
# query7:
#
# query8: お疲れさまです。イベントの予約はどこから出来ますか。
# similarity_assessment_model(query8, お疲れさまです。イベントの予約はどこから出来ますか。): {"similarity":0,"comment":"文章1はイベントへの参加に関する時間の変更の依頼、文章2はイベントの予約に関する問い合わせであり、内容が全く異なる。また、文章表現や単語も異なるため、類似度は0です。"}
#
# query9:
#
# query10: Week2-3③提出しました。,week2-3の課題を提出しましたご確認よろしくお願いします,お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇‍♀️,week6-3提出しました,week2-3 2-4 3-1の課題を提出しました
# similarity_assessment_model(query10, Week2-3③提出しました。): {"similarity":5,"comment":"文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query10, week2-3の課題を提出しましたご確認よろしくお願いします): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容（提出物の具体的な内容）や文章表現（「Week2-3③」と「week2-3の課題」）が異なっているため3とした。"}
# similarity_assessment_model(query10, お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇‍♀️): {"similarity": 3, "comment": "文章の大まかな内容は類似しているが、提出物が異なり、文章表現も異なっているため、3とした。"}
# similarity_assessment_model(query10, week6-3提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出について）が、細かい内容（提出時期や課題番号）が異なり、文章表現も一部異なる。"}
# similarity_assessment_model(query10, week2-3 2-4 3-1の課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出）が、細かい内容は異なり（提出物の範囲）、文章表現も異なっている（数字の表現方法が異なる）ため3とした。"}
#
# query11: 【その他】,【その他】,【その他】,【その他】,【その他】
# similarity_assessment_model(query11, 【その他】): {"similarity":5,"comment":"文章1と文章2は全く同じなので、類似度は5です。"}
# similarity_assessment_model(query11, 【その他】): {"similarity":5,"comment":"文章1と文章2は同一であるため、類似度は5です。"}
# similarity_assessment_model(query11, 【その他】): {"similarity":5,"comment":"文章1と文章2は全く同じ内容なので、類似度は5です。"}
# similarity_assessment_model(query11, 【その他】): {"similarity": 5, "comment": "文章1と文章2は全く同じであるため、類似度は5です。"}
# similarity_assessment_model(query11, 【その他】): {"similarity":5,"comment":"文章1と文章2は全く同じ内容のため、類似度は5です。"}
#
# query12: そうですよね😭急に仕事関連で予定が入ってしまって、19時ちょうどに始められなさそうだったので、、リスケさせていただきます！すいませんがよろしくお願いします🙇
# similarity_assessment_model(query12, そうですよね😭急に仕事関連で予定が入ってしまって、19時ちょうどに始められなさそうだったので、、リスケさせていただきます！すいませんがよろしくお願いします🙇): {"similarity": 5, "comment": "文章1と文章2は全く同じ文章です。"}
#
#
# query13:
#
# query14:
#
# query15: お世話になります2-3の課題を提出しましたよろしくお願いします,お世話になっております。Week2-4の課題を提出しました,お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇‍♀️,課題2-3を提出しました。よろしくお願いします。,いつもお世話になっております。現在、week3-1をやっているのですが間違ってweek3-1に2-3の課題を提出してしまいました。現在、week3-1の課題を提出しようと思っているところなのですが、どうしたらいいでしょうか。よろしくお願いいたします。
# similarity_assessment_model(query15, お世話になります2-3の課題を提出しましたよろしくお願いします): {"similarity":3,"comment":"文章の大まかな内容は類似しているが、細かい内容が異なり、文章表現も異なっている。文章1では「Week2-3」という具体的な週が書かれているのに対し、文章2では「2-3」となっている。また、文章1では「連投になり申し訳ありません」という謝罪の言葉が含まれているのに対し、文章2では「よろしくお願いします」という挨拶が含まれている。"}
# similarity_assessment_model(query15, お世話になっております。Week2-4の課題を提出しました): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出の報告）が、細かい内容（提出された週、謝罪の有無）が異なっており、文章表現も異なっているため3とした。"}
# similarity_assessment_model(query15, お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇‍♀️): {"similarity":3,"comment":"文章の大まかな内容は類似している(課題提出の報告)。しかし、細かい内容は異なり(文章1はWeek2-3のみ、文章2はWeek2-2とWeek2-3)、文章表現も異なる(文章1は「連投になり申し訳ありません」、文章2は「よろしくお願いします🙇‍♀️」)。"}
# similarity_assessment_model(query15, 課題2-3を提出しました。よろしくお願いします。): {"similarity": "3", "comment": "文章の大まかな内容は類似している（課題の提出について）。しかし、文章1は「Week2-3」という具体的な週の番号を記載している一方、文章2は「2-3」と抽象的な表現となっている。また、文章1は「連投になり申し訳ありません」という謝罪の言葉が含まれているのに対し、文章2は「よろしくお願いします」という丁寧な言葉遣いとなっている。そのため、細かい内容と文章表現が異なると判断した。"}
# similarity_assessment_model(query15, いつもお世話になっております。現在、week3-1をやっているのですが間違ってweek3-1に2-3の課題を提出してしまいました。現在、week3-1の課題を提出しようと思っているところなのですが、どうしたらいいでしょうか。よろしくお願いいたします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題提出に関する内容）が、細かい内容は異なっている（文章1は単に提出した旨を伝えているが、文章2は誤って提出してしまった旨を伝えている）。文章表現は、どちらも丁寧な表現を用いているが、文章1は簡潔な表現である一方、文章2は状況説明を含んだ詳細な表現となっている。"}
#
# query16: 添削ありがとうございました。6-4実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。,ご連絡ありがとうございました。プロンプトの共有ができるようになりましたので6-1実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。,坂尻です6-4実践課題をワークシートに入力しました添削をよろしくお願いします。,添削ありがとうございます(emoji)続けてWeek1-4実践課題②③④を提出しましたご確認よろしくお願いします,week1実践課題①提出しました。添削のほどよろしくお願いいたします。
# similarity_assessment_model(query16, 添削ありがとうございました。6-4実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。): {"similarity": 5, "comment": "文章1と文章2は完全に同一です。"}
# similarity_assessment_model(query16, ご連絡ありがとうございました。プロンプトの共有ができるようになりましたので6-1実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。): {"similarity": 4, "comment": "文章の大まかな内容は類似していますが、文章1では「6-4実践課題」と記載されているのに対し、文章2では「6-1実践課題」と記載されているため、細かい内容が異なります。文章表現は類似しています。"}
# similarity_assessment_model(query16, 坂尻です6-4実践課題をワークシートに入力しました添削をよろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（添削依頼）。細かい内容は異なり（文章1はプロンプト、文章2はワークシート）、文章表現も異なっている。"}
# similarity_assessment_model(query16, 添削ありがとうございます(emoji)続けてWeek1-4実践課題②③④を提出しましたご確認よろしくお願いします): {"similarity": 3, "comment": "文章の大まかな内容は類似している（添削依頼）。細かい内容（課題の番号）は異なり、文章表現も少し異なる。"}
# similarity_assessment_model(query16, week1実践課題①提出しました。添削のほどよろしくお願いいたします。): {"similarity":3,"comment":"文章の大まかな内容は類似している（どちらも課題提出に関する内容）。しかし、細かい内容（課題番号、提出時期）が異なり、文章表現も異なるため3とした。"}
#
# query17: 🎃日次報告🎃今日は5-1の課題を取り組みました。よろしくお願いいたします。,🎃日次報告🎃今日は5-1の課題を取り組みました。よろしくお願いいたします。,☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。,☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。,☂️日次報告☂️今日は課題4-4を取り組みました。よろしくお願いします。
# similarity_assessment_model(query17, 🎃日次報告🎃今日は5-1の課題を取り組みました。よろしくお願いいたします。): {"similarity": 5, "comment": "文章1と文章2は全く同じです。"}
# similarity_assessment_model(query17, 🎃日次報告🎃今日は5-1の課題を取り組みました。よろしくお願いいたします。): {"similarity":5,"comment":"文章1と文章2は全く同じ文章です。"}
# similarity_assessment_model(query17, ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（日次報告）。しかし、細かい内容は異なり（課題番号、報告の有無）、文章表現も異なっている（絵文字、言葉遣い）ため、3と評価しました。"}
# similarity_assessment_model(query17, ☂️日次報告☂️昨日は報告を失念してしまいました。申し訳ありません💦今日は課題5-2を取り組みました。よろしくお願いします。): {"similarity": 3, "comment": "文章の大まかな内容は類似している（日次報告）。しかし、細かい内容は異なり（課題番号、報告忘れ）、文章表現も異なっている（絵文字、口調）ため、3と評価しました。"}
# similarity_assessment_model(query17, ☂️日次報告☂️今日は課題4-4を取り組みました。よろしくお願いします。): {"similarity": 4, "comment": "文章の大まかな内容は類似しているが、細かい内容は課題番号が異なる。文章表現は類似している。"}
#
# query18: 谷津さんお久しぶりです1週間程体調を崩してしまい、あまり進められませんでした。取り組みもご報告できておらず、すみませんでした。本日からまた頑張っていきます！取り組んだこと10/4・2-2 動画視聴10/5・2-2 実践課題実施10/6・2-2 実践課題提出・2-3 動画視聴10/8・勉強会・2-3 実践課題実施、提出10/14・2-3 実践課題実施、再提出・3-1 動画視聴、実践課題提出・3-2 動画視聴、実践課題提出・3-3 動画視聴、実践課題実施,瀬谷さん本日はありがとうございました次回もよろしくお願いします！11月の目標シートも承知しました！取り組んだこと3-3 実践課題実施、提出3-4 動画視聴、実験課題実施面談で現在取り組み途中が、3-4とお伝えしましたが、3-3でした🙇🏻‍♂️,竹内さん宛・10/11(金) 休み・10/12(土) 2-3課題取組・10/13(日) 2-3課題提出、3-1動画視聴,谷津さんこんばんは！取り組んだこと、送らせていただきます。10/29・3-5 実践課題実施11/1・3-5 実践課題実施、提出11/2・4-1  動画視聴・4-2 動画視聴・3-5 実践課題実施、再提出11/34-1 実践課題実施、提出4-2 実践課題実施11/44-1 実践課題実施,こんにちは！平田です😊week3-1でお聞きしたいことがあるのですが、参考アカウントとはどのようなものでしょうか？💦各ペルソナに近しい個人のアカウントを探すのでしょうか？
# similarity_assessment_model(query18, 谷津さんお久しぶりです1週間程体調を崩してしまい、あまり進められませんでした。取り組みもご報告できておらず、すみませんでした。本日からまた頑張っていきます！取り組んだこと10/4・2-2 動画視聴10/5・2-2 実践課題実施10/6・2-2 実践課題提出・2-3 動画視聴10/8・勉強会・2-3 実践課題実施、提出10/14・2-3 実践課題実施、再提出・3-1 動画視聴、実践課題提出・3-2 動画視聴、実践課題提出・3-3 動画視聴、実践課題実施): {"similarity": 3, "comment": "文章の大まかな内容は類似している（課題の進捗状況を報告している）。細かい内容（具体的な課題番号や取り組み内容）は異なり、文章表現も異なっている。文章1は丁寧な口調で、文章2は簡潔な報告調である。"}
# similarity_assessment_model(query18, 瀬谷さん本日はありがとうございました次回もよろしくお願いします！11月の目標シートも承知しました！取り組んだこと3-3 実践課題実施、提出3-4 動画視聴、実験課題実施面談で現在取り組み途中が、3-4とお伝えしましたが、3-3でした🙇🏻‍♂️): {"similarity": 1, "comment": "文章1は、カラーピッカーの確認に関する返信で、課題の進捗状況について報告しています。文章2は、目標シートの確認に関する返信で、課題の取り組み状況を報告しています。文章の内容は異なりますが、課題に関する進捗報告という点で共通点があり、文章の雰囲気が似ているため、1と評価しました。"}
# similarity_assessment_model(query18, 竹内さん宛・10/11(金) 休み・10/12(土) 2-3課題取組・10/13(日) 2-3課題提出、3-1動画視聴): {"similarity": 2, "comment": "文章1は課題の進捗状況について報告しており、文章2は具体的なスケジュールを記載しています。文章の内容は異なりますが、文中に「課題」「動画視聴」といった共通の単語が使われています。"}
# similarity_assessment_model(query18, 谷津さんこんばんは！取り組んだこと、送らせていただきます。10/29・3-5 実践課題実施11/1・3-5 実践課題実施、提出11/2・4-1  動画視聴・4-2 動画視聴・3-5 実践課題実施、再提出11/34-1 実践課題実施、提出4-2 実践課題実施11/44-1 実践課題実施): {"similarity": 2, "comment": "文章1はカラーピッカーに関する問い合わせと課題の進捗状況についての内容、文章2は具体的な課題実施日と内容についての記述となっており、内容が大きく異なります。しかし、文章2には課題番号や動画視聴、実践課題などの単語が文章1と共通しているため、2と評価しました。"}
# similarity_assessment_model(query18, こんにちは！平田です😊week3-1でお聞きしたいことがあるのですが、参考アカウントとはどのようなものでしょうか？💦各ペルソナに近しい個人のアカウントを探すのでしょうか？): {"similarity": 0, "comment": "文章1は課題提出に関する進捗報告、文章2は課題に関する質問というように、内容が全く異なります。また、文章表現も異なっています。"}
#
# query19: 竹内様✴︎課題の進捗状況について・3-5 課題修正➡︎提出・canva 自習会課題バナー制作➡︎勉強会予約今週は勉強会やdogmaイベントに参加予定です。よろしくお願いいたします。,面談日を改めさせて頂きました。今日の取り組みは、午前中にCanva自習会に参加をしてバナー制作をしました。,■HerTech受講への今の気持ち：全くの未経験で不安な気持ちもありますが、新しいことを学べるのを楽しみにしている気持ちもあります。途中で投げ出さず、最後までしっかり頑張りたいです！
# similarity_assessment_model(query19, 竹内様✴︎課題の進捗状況について・3-5 課題修正➡︎提出・canva 自習会課題バナー制作➡︎勉強会予約今週は勉強会やdogmaイベントに参加予定です。よろしくお願いいたします。): {"similarity": 0, "comment": "文章1は提出に関する連絡、文章2は進捗報告と予定に関する連絡となっており、内容が大きく異なります。また、文章表現や単語も大きく異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query19, 面談日を改めさせて頂きました。今日の取り組みは、午前中にCanva自習会に参加をしてバナー制作をしました。): {"similarity": "0", "comment": "文章1は提出に関する連絡、文章2は面談と取り組みの報告という全く異なる内容であり、共通点が見当たらないため0としました。"}
# similarity_assessment_model(query19, ■HerTech受講への今の気持ち：全くの未経験で不安な気持ちもありますが、新しいことを学べるのを楽しみにしている気持ちもあります。途中で投げ出さず、最後までしっかり頑張りたいです！): {"similarity":0,"comment":"文章1は提出に関する連絡、文章2は受講に対する意気込みであり、内容や表現が全く異なるため。"}
#
# query20: https://www.canva.com/design/DAGVamU_ZfE/2P1k1gIQgAI7dfNsHeFu0g/edit?ui=eyJEIjp7IlQiOnsiQSI6IlBCZG1Hc1JSUW5Ta0dLMEwifX19&utm_content=DAGVamU_ZfE&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton,ご質問ありがとうございます◎添付いただいた画像は、もしかするとブラウザ版かもしれないと思いました😌💦画面の右上にある「デスクトップアプリを入手」からダウンロードしてみてください🙌ダウンロードができたら、講義動画を参考に取り組んでみてくださいね😊について、「デスクトップアプリを入手」を押しても動きがありません💦Macなのですが、どうしたら良いでしょうか💦,終了証ですが、何か履歴書などに書ける資格になるのでしょうか？,お疲れ様です。6-4まで完了してます。,どうでしょ？
# similarity_assessment_model(query20, https://www.canva.com/design/DAGVamU_ZfE/2P1k1gIQgAI7dfNsHeFu0g/edit?ui=eyJEIjp7IlQiOnsiQSI6IlBCZG1Hc1JSUW5Ta0dLMEwifX19&utm_content=DAGVamU_ZfE&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton): {"similarity": 5, "comment": "文章1と文章2は全く同じURLのため、内容も文章表現も完全に一致しています。"}
#
# similarity_assessment_model(query20, ご質問ありがとうございます◎添付いただいた画像は、もしかするとブラウザ版かもしれないと思いました😌💦画面の右上にある「デスクトップアプリを入手」からダウンロードしてみてください🙌ダウンロードができたら、講義動画を参考に取り組んでみてくださいね😊について、「デスクトップアプリを入手」を押しても動きがありません💦Macなのですが、どうしたら良いでしょうか💦): {"similarity": 1, "comment": "文章1はCanvaのデスクトップアプリのダウンロードに関する説明文であり、文章2はCanvaのデスクトップアプリのダウンロードに関する質問です。内容が異なるものの、文章表現や単語、文末のマークなど、文章の雰囲気が似ているため1と評価しました。"}
# similarity_assessment_model(query20, 終了証ですが、何か履歴書などに書ける資格になるのでしょうか？): {"similarity": 1, "comment": "文章1は資格取得のための講座の案内で、文章2は資格取得後の証明書について質問しています。内容としては大きく異なりますが、文章表現や単語が似ている部分があるので1と評価しました。"}
# similarity_assessment_model(query20, お疲れ様です。6-4まで完了してます。): {"similarity": 0, "comment": "文章1は、Canvaの画像編集画面のURLで、文章の内容を特定することができません。一方、文章2は、仕事の進捗状況を報告する内容です。そのため、文章の内容は全く異なっています。また、文章表現や単語も大きく異なるため、類似度は0と判断しました。"}
# similarity_assessment_model(query20, どうでしょ？): {"similarity": 0, "comment": "文章1はCanvaのデザインデータへのリンクであり、文章2は短い疑問文です。内容、表現、単語全てが異なるため類似度は0です。"}
