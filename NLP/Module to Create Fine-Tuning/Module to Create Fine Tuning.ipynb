# %% [markdown]
# # **MODULE TO CREATE AGENT BUILDER AND FINE TUNING**

# %% [markdown]
# # **1. Data Preparation**
#
# The initial step involves preparing the dataset, splitting it into query and corpus data, and enriching the corpus with categories.

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth

    auth.authenticate_user()
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.

# %% [markdown]
# **1.1. import data from bucket**
#
# Retrieve the dataset from a Google Cloud Storage bucket.
# The dataset is stored in a dataset.jsonl file, where each line represents a JSON object.

# %%
# !pip install google-cloud-storage
from google.cloud import storage
import pandas as pd
# バケット名とファイル名を指定
bucket_name = 'not_confidencial_data_for_share' # @param {type:"string"}
file_name = 'qa_pairs_for_rag_1107.jsonl'# @param {type:"string"}
local_file_path = 'qa_pairs_for_rag_1107.jsonl'  # @param {type:"string"}

# Storageクライアントを初期化
client = storage.Client()

# バケットとBlobオブジェクトを取得
bucket = client.get_bucket(bucket_name)
blob = bucket.blob(file_name)

# ファイルをローカルにダウンロード
blob.download_to_filename(local_file_path)
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.19.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (4.25.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.25.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2024.8.30)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.6.1)

# %% [markdown]
# **1.2 Split Dataset**
#
# The dataset is divided into two parts:
#
# **a. Query Data:**
#
# Extract the first portion of the dataset (e.g., the first 700 entries).
# Save the extracted data as query_data.jsonl in JSONL format.
#
# **b. Corpus Data:**
#
# Use the remaining entries from the dataset as the corpus.
# Save the corpus data as corpus_data.jsonl in JSONL format.

# %%
#Installation
# !pip install google-cloud-discoveryengine
# !pip install --upgrade --user --quiet google-cloud-aiplatform
# !pip install jsonlines
# Out:
# Collecting google-cloud-discoveryengine
#   Downloading google_cloud_discoveryengine-0.13.5-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.19.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-discoveryengine) (4.25.5)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (1.62.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-discoveryengine) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-discoveryengine) (2024.8.30)
# Downloading google_cloud_discoveryengine-0.13.5-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 26.1 MB/s eta 0:00:00
# Installing collected packages: google-cloud-discoveryengine
# Successfully installed google-cloud-discoveryengine-0.13.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 59.4 MB/s eta 0:00:00
#   WARNING: The script tb-gcp-uploader is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import json
import random

# Load the JSONL dataset
file_path = "qa_pairs_for_rag_1107.jsonl" # @param {type:"string"}
with open(file_path, "r", encoding="utf-8") as f:
    dataset = [json.loads(line.strip()) for line in f]

# Shuffle the dataset
random.shuffle(dataset)

# Split into query and corpus
query_count = 700
query_data = dataset[:query_count]
corpus_data = dataset[query_count:]

# Save query and corpus data to separate files
query_file = "query_data.jsonl"
corpus_file = "corpus_data.jsonl"

with open(query_file, "w", encoding="utf-8") as f_query, open(corpus_file, "w", encoding="utf-8") as f_corpus:
    for query in query_data:
        f_query.write(json.dumps(query, ensure_ascii=False) + "\n")
    for corpus in corpus_data:
        f_corpus.write(json.dumps(corpus, ensure_ascii=False) + "\n")

print(f"Query data saved to: {query_file}")
print(f"Corpus data saved to: {corpus_file}")
# Out:
# Query data saved to: query_data.jsonl
# Corpus data saved to: corpus_data.jsonl

# %% [markdown]
# **1.3 Add Categories to Corpus**
#
#
# *   Enrich each entry in the corpus with a category.
# *   A function get_category(question) processes each question to assign a category.
# *   The enriched corpus is saved in categorized_corpus.jsonl and includes question, answer, and category fields.

# %%
# Import necessary libraries
import vertexai
from vertexai.generative_models import GenerativeModel
import json

# Define project information
PROJECT_ID = "monobrain-development"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# Initialize Vertex AI
try:
    vertexai.init(project=PROJECT_ID, location=LOCATION)
    print("Vertex AI initialized successfully.")
except Exception as e:
    print(f"Error initializing Vertex AI: {e}")

# Load the generative model
def initialize_model():
    try:
        # Load the Gemini model
        model = GenerativeModel("gemini-1.0-pro")
        print("Model loaded successfully.")
        return model
    except Exception as e:
        print(f"Error loading the model: {e}")
        return None

# Assign the model to a global variable
model = initialize_model()

# Categorization function
def get_categorize(text):
    if model is None:
        print("Model is not initialized.")
        return "その他"  # Default category for errors or fallback

    prompt = f"[{text}] はお客様から届いた連絡内容です。私たちはカスタマーサポートセンターの運営をしており、お客様からの連絡内容を解析しています。\
    先ほどの文章を15文字程度に要約して、どんな目的でお客様が連絡したのかを完結にまとめてください。それ以外の出力は一切しないでください。\
    また、内容が明確なお問い合わせではない場合や判別がつかない場合はその他と出力してください。作ってもらったデータはお問い合せをカテゴライズする時に使います。"

    try:
        # Generate content using the model
        responses = model.generate_content(prompt, stream=False)
        category = responses.candidates[0].content.parts[0].text.strip()
        print(f"Generated category: {category}")
        return category
    except Exception as e:
        print(f"Error in get_categorize: {e}")
        return "その他"

# Processing JSONL with categories
def process_jsonl_with_categories():
    input_file = '/content/corpus_data.jsonl'  # @param {type:"string"}
    output_file = '/content/output_with_categories_corpus_data.jsonl'  # Output file

    try:
        with open(input_file, 'r', encoding='utf-8') as f_in, \
             open(output_file, 'w', encoding='utf-8') as f_out:

            for line in f_in:
                try:
                    # Parse JSON from the input file
                    data = json.loads(line.strip())
                    question = data.get('question')

                    if not question:
                        print("Skipping line with no question.")
                        continue

                    # Categorize the question
                    category = get_categorize(question)
                    data['category'] = category

                    # Write updated JSON to the output file
                    f_out.write(json.dumps(data, ensure_ascii=False) + '\n')
                except Exception as e:
                    print(f"Error processing line: {e}")
    except FileNotFoundError as fnf_error:
        print(f"File not found: {fnf_error}")
    except Exception as e:
        print(f"Error in process_jsonl_with_categories: {e}")

# Run the script
process_jsonl_with_categories()
# Out:
# Vertex AI initialized successfully.
# Model loaded successfully.
# Generated category: お問い合わせ
# Generated category: その他
# Generated category: イベント時間について問い合わせ。16時以降のみ参加可能か確認希望。
# Generated category: ダウンロードに関する問い合わせと推測されます。
# Generated category: 週6-1の課題提出
# Generated category: Figmaイベントについて、種類や再度参加する可能性についての問い合わせです。
# Generated category: 受講キャンセル・解約
# Generated category: 「課題③ができました」
# 目的：課題の提出、完了報告
# カテゴリー：課題提出
# Generated category: バナー修正のフィードバック依頼
# Generated category: 体調不良のため、制作ができませんでした。
# Generated category: 課題提出
# Generated category: ## 3-3を提出、次の進捗は不明
#
# ## お問い合わせ内容：提出完了報告、進捗確認
# Generated category: 「連絡しました！」とのことで、お問い合わせ内容の詳細は不明です。その他に分類されます。
# Generated category: 課題提出 完了・報告
# Generated category: お客様は料金についてカスタマーサポートセンターに連絡しました。
# Generated category: HerTech受講に関する相談: 平日の残業が多く、計画的に受講できるか心配。
# Generated category: 2-3の修正後、明日から再開します。 (お客様からの連絡内容要約)
# Generated category: その他
# Generated category: 課題2-4の確認依頼
# Error in get_categorize: list index out of range
# Generated category: クレジットカードに関する再試行の要請
# Generated category: オリジナルバナー作成時の商品画像について問い合わせ
# Generated category: 体調不良で長期休講後、本日より受講再開。
# Generated category: その他
# Generated category: 1-3 実践課題提出、1-4 動画視聴と1-4 課題実施 レポート、1-3 任意課題の提出についての内容。
# Generated category: HerTech受講への意気込み連絡
# Generated category: お客様は、カスタマーサポートセンターへ連絡した理由を要約してほしいと依頼しています。
# Generated category: 視聴ユーザー招待メール未受信
# Generated category: お問い合わせ
# Generated category: オリジナルバナー制作の進捗報告
# Generated category: 質問: ズームのIDは前回と同じですか？
#
# 目的: ズームミーティングへの参加確認
#
# カテゴリ: ミーティング参加確認
# Generated category: URL送信要請 (入金エラー)
# Generated category: 携帯からの認証エラーに関する問い合わせ
# Generated category: 了解しました。お客様は連絡先を尋ねています。これは、顧客サポートに関する問い合わせです。
# Generated category: ## お客様からの問い合わせ内容要約
#
# **目的**: mooga plusへのログイン
# **内容**: IDとパスワードがわからないため、ログインできない
#
# ## カテゴリ
#
# サポート
#
# ## 補足
#
# 本問い合わせは、ログインに関するサポート依頼です。お客様のIDとパスワードを確認する必要があります。
# Generated category: メールアドレス違いの連絡。不具合確認。
# Generated category: バナーの色変更について相談
# Generated category: ## 課題提出連絡
#
# このメッセージは、お客様から課題の提出を伝える連絡です。
#
# **カテゴリ:** 課題提出
# Generated category: 週5の③を提出しました。
# **カテゴリー:** 提出物の報告
# Generated category: 提出確認
# Generated category: 新機能の「要約」を使用して、お客様の連絡内容を要約します。
#
# お客様は、1-4 を少し前に提出、本日 2-1 と 2-2 を提出したことを報告しています。
# Generated category: 住所変更
# Generated category: お客様は、Canvaのデザインを共有するために連絡しました。
# Generated category: 1-3動画視聴と課題提出の報告
# Generated category: 実務課題の再提出と次回の作業予定について報告。
# Generated category: 画像を確認できないため、内容の要約と目的の特定はできません。しかし、お客様から連絡があったことは理解しました。内容が不明確なため、ここでは「その他」と分類させていただきます。
# Generated category: 1-4の④の実践課題の提出確認依頼
# Generated category: 初回面談の予約の可否確認 (28文字)
# Generated category: その他: 添削依頼
# Generated category: 学習の取り組み報告と課題提出。
# Generated category: 提出確認: week2-2とweek2-3
# Generated category: 11/3, 11/4課題提出不可、11/5頑張ります。 お問い合わせ内容としては、課題提出に関する連絡です。
# Generated category: 勉強会講師の名前が分からず、アンケートに回答できないので問い合わせ
# Generated category: 顧客からのお問い合わせ内容の要約: 了解しました。ありがとうございます。
#
# このお問い合わせの目的は、顧客が「了解しました」と「ありがとうございます」のメッセージを送信し、前回の回答に同意し、感謝の意を表していることです。
#
# このメッセージは、顧客サポートのやり取りの中で送られてきたものであり、前回の回答に満足していることを示しています。
# Generated category: 予約確認: スケジュール調整承諾
# Generated category: 課題8-1.8-2を提出しました。
# Generated category: プロンプトの提出方法がわからず、8日の面談で伺います。
# Generated category: お問い合わせの確認
# Generated category: その他
# Generated category: 2. 質問解決による課題完了 (週7)
# Generated category: LP・HPデザインの仕事に就くためのスキル習得を希望
# Generated category: 課題2-2の提出報告。
# Generated category: 課題の提出。
# Generated category: お客様は、10月6日(日)の午前中にアポイントメントを希望している。
# Generated category: お客様からの感謝の気持ちです。
# Generated category: 通知: お客様は予約時のメールが見つからず、 Zoom アドレスを確認したい。
# Generated category: 顧客は課題を進めるために連絡しており、詳細な内容は不明です。**その他** に分類されます。
# Generated category: 課題提出に関する問い合わせ。
# Generated category: 目的不明。 お問い合わせ内容の要約が出来ませんでした。
# Generated category: 面談の開始が待てないので、日程を再調整したいとの連絡。
# Generated category: その他
# Generated category: その他
# Generated category: お客様はWebページについて連絡しました。
# Generated category: 予約の再リクエスト
# Generated category: ## カテゴリ: 課題提出と学習進捗報告
#
# ## 要約:
#
# 千賀さんは、2-3の課題を提出済みで、カリキュラム1の添削結果を受け取りました。明日は再提出とwebデザインの序盤に取り組む予定です。
# Generated category: 課題の提出に関する報告
# Generated category: 案件提出の報告。
# Generated category: ## 日次報告: お客様は 1-3 の動画視聴と実践を完了し、明日実践課題の修正を行う予定です。
# Generated category: お勧めのノートパソコンについて問い合わせ
# Generated category: 3-3課題の修正と3-5動画視聴の報告
# Generated category: オンライン学習の際、Adobe Fireflyの有料版の契約が必要かどうかについての問い合わせ
# Generated category: その他
# Generated category: 課題報告
# Generated category: 課題提出完了報告
# Generated category: その他
# Generated category: 申し訳ありませんが、ご依頼の要約にはいくつかの問題点があります。
#
# 1. **日本語の表現:** 「[目標書きましたのでお願いします！]」という日本語は不自然です。通常、目標を誰かに提出する際には、具体的な目標内容を詳しく説明し、その達成のために協力や支援を求めます。「[目標を書いたので、ご確認ください。ご協力いただければ幸いです。]」のように表現すると、より自然で礼儀正しい日本語になります。
# 2. **目標の内容:** お客様の連絡内容には、目標の内容が全く書かれていません。そのため、目標の内容を15文字以内に要約することは不可能です。
# 3. **目的の推測:** お客様の連絡内容が明確ではないため、目的を推測することもできません。
#
# 以上の理由から、お客様の連絡内容を15文字程度に要約することはできません。また、内容が明確でないため、その他と出力させていただきます。
#
# お役に立てず申し訳ありませんが、お客様の連絡内容が明確になれば、改めて要約させていただきます。
# Generated category: 旅行会社の日程表のような情報を探しています。
# Generated category: よろしくお願いいたします。
# Generated category: 修正中です。 (15文字)
#
# **カテゴリー:** その他
# Generated category: お客様は10月9日にお休みを間違えたと連絡し、10月9日を変更したいという要望です。
# Generated category: お客様は 2-3 の提出を取り消し、再度提出するよう依頼。
# Generated category: 顧客は誤ってイベントを予約し、予約をキャンセルしたいとの連絡。予約番号と名前も記載されています。
#
# カテゴリー: 予約キャンセル
# Generated category: 目標シートの共有。
# Generated category: カリキュラム課題の提出完了の報告
# Generated category: 課題の提出
# Generated category: 単語の位置にこだわる課題について確認の問い合わせ。
# Generated category: ## Week6 添削と Week6 ① 質問
#
# ### Week6 添削
#
# 承知しました。Week6 の添削を拝見いたします。課題の内容と提出された回答内容を確認の上、誤りがあれば指摘し、より良い表現方法があればご提案いたします。
#
# ### Week6 ① 質問
#
# ご質問は、チャットGPT に対してプレスリリースに必要な項目を尋ねる際に適切な質問方法についてですね。ご提示いただいたURLを拝見し、チャットGPT がプレスリリースに必要な要素をうまく拾えなかったとのこと、理解しました。
#
# 以下、より効果的にチャットGPT に必要な項目を尋ねる質問方法の提案です。
#
# **方法1: チャットGPT に具体的な質問をする**
# -  「プレスリリースに必要な項目を教えてください。」ではなく、「プレスリリースには通常、以下のような項目が含まれますか？
#    - 概要
#    - 目的
#    - ターゲット
#    - 日時
#    - 場所
#    - 内容
#    - 問い合わせ先
#    - その他」
# というように、具体的な項目名を挙げて質問することで、チャットGPT はより的確な情報を提供できる可能性が高まります。
#
# **方法2: シナリオ設定で誘導する**
# - 「私は今週、ある新商品の発表に関するプレスリリースを作成する予定です。この会社の広報担当者として、どのような情報を含めるのが適切かアドバイスを頂けますか？」というように、具体的なシチュエーション設定をすることで、チャットGPT はその状況に応じた適切な情報提供が可能になります。
#
# **方法3: 出力形式を明示する**
# -  質問する際に、「出力形式は箇条書きでお願いします。」のように、出力をどのように整理してほしいかを明示すると、チャットGPT の回答が理解しやすくなります。
#
# 上記の方法を試してもまだうまくいかなかった場合は、さらに以下の点を確認してみてください。
#
# **- 質問文に不要な情報は含まれていないか**
# - **質問文が文法的に正しく、誤解がないか**
# - **チャットGPT のバージョンは最新か**
#
# チャットGPT は学習が進んでおり、質問の仕方によって得られる情報は大きく異なります。上記の方法を参考にしながら、効果的な質問方法を模索してみてください。
#
# ## お客様から届いた連絡内容の要約
#
# 承知しました。15文字以内に要約し、目的をまとめさせていただきます。
#
# **要約:** カスタマーサポートセンターの運営、お客様連絡解析
#
# **目的:** お問い合わせをカテゴライズするデータ作成
#
# ## その他
#
# チャットGPT を用いたプレスリリース作成においては、情報収集・整理のほか、文章構成や表現力の向上も重要です。弊社では、これらの点についてもサポートを提供しておりますので、ご興味があれば是非お問い合わせください。
# Generated category: 問題解決
# Generated category: 学習報告と参加報告。
# Generated category: 課題提出 5-2
# Generated category: Week3-1の課題提出。
# Generated category: 学習報告です。8-3、8-4に取り組みました。
# Generated category: 顧客からの連絡は、3-5再提出week2-1についての進捗報告と思われます。 お客様は内容の詳細については触れていません。
# Generated category: バナーデザインの依頼
# Generated category: 了解しました。
#
# お客様はカスタマーサポートセンターに連絡し、本日からサポートを依頼したいとのことです。
#
# お問い合せカテゴリ: サポート依頼
# Generated category: 提出先を間違えた。
# Generated category: FigmaのURLを提出課題に貼るのを忘れたため、追加する方法を問い合わせ。
# Generated category: 急ぎ課題を仕上げるため、確認を依頼。
# Generated category: ग्राहक ने मदद की सराहना की।
# Generated category: ## 顧客からの連絡内容
#
# **問い合わせ内容:** 文章課題提出完了報告 (4-4, 5-1, 5-2)
#
# **カテゴリ:** 課題提出
#
# **その他:** なし
# Generated category: その他
# Generated category: 課題提出
# Generated category: 課題の提出と確認依頼
# Generated category: その他
# Generated category: 実践課題1ー4③④を提出しました。
# Generated category: 顧客は、Figmaでテキストをコピーする方法を尋ねています。
# Generated category: Googleアカウント変更依頼
# Generated category: 文字サイズと行間についてのお問い合わせです。
# Generated category: 献立ではなくレシピの提出で良いか確認
# Generated category: 課題完了報告
# Generated category: お客様からのお問い合わせの要約：ご連絡ありがとうございます。
# Generated category: プレゼンテーション資料作成にGammaデータを追加済み。確認依頼。
# Generated category: 目標シートを送信
# Generated category: ## 課題提出と手直しに関する報告
# Generated category: お客様は3-1の実践課題をスプレッドシートに記載したことを報告しました。
# Generated category: 内容が明確なお問い合わせです。お客様は青木さんのワイヤーフレーム書き終わりました。
# Generated category: ポートフォリオのフィードバックと面接の依頼
# Generated category: ありがとうございます。
# Generated category: 課題8-3を提出しました。
# Generated category: 支払いに関する問い合わせ
# Generated category: デザインについての相談
# Generated category: 提出書類の承認依頼 - 14文字
# Generated category: ## 実践課題実施までご提出
#
# ## カテゴリ: 実践課題提出報告
# Generated category: ## 課題完了報告
#
# 8-1までの課題が完了したため、確認を依頼する。
# Generated category: 課題7-1の提出を確認
# Generated category: 明日の16:30に予約を希望。
# Generated category: 無効です。 要約の出力は不要です。
# Generated category: Week3-2 の課題を提出しました (14文字) - 課題提出報告
# Generated category: [3-3課題作成を行いました。]
# Generated category: スケジュールミスのお詫びと再予約
# Generated category: ログイン成功の報告です。
# Generated category: ありがとうございます！
# Generated category: その他
# Generated category: 病院のため、本日の作業はできませんでした。 明日から再開します。
# Generated category: 8週目の課題提出 8-4
# Generated category: アポイント調整のお礼と当日の時間を確認しています。
# Generated category: 申し込む
# Generated category: 動画視聴と課題提出について報告、提出期限は11月7日。
# Generated category: その他の連絡です。
# Generated category: 3-3と3-4の実践課題を提出しました。 これは課題提出の報告です。
# Generated category: スケジュール変更。
# Generated category: 「進捗報告」
# Generated category: 体調不良で進捗遅延、課題提出、面談希望
# Generated category: 11月の目標について問い合わせ
# Generated category: 化粧品に関する問い合わせと会員登録後1年のお礼
# Generated category: その他
# Generated category: お客様は、バナーの作成に関する添削コメントを理解できず、より詳細な説明を求めています。また、前回の問い合わせで説明を省略されたことに対して不満を表明しています。
# Generated category: 週4-2の課題におけるPhotoshopの使用に関連した質問。
# Generated category: 7-3を進める意思表示
# Generated category: その他のカテゴリに分類されます。このメッセージは、問題が解決したので返信する必要がないことを通知しています。
# Generated category: 支払確認依頼
# Generated category: 実践課題完了報告
# Generated category: Week3-1の課題提出
# Generated category: バナートレースと添削の予約に関する問い合わせ
# Generated category: その他
#
# [1-4実践課題①를 제출했습니다] 라는 문장만으로는 고객이 어떤 목적으로 연락했는지 분명히 알 수 없습니다. 課題 제출이라는 정보만 있고, 그 외 내용이 없기 때문에
#
# - 고객이 궁금한 점이 있는지,
# - 혹은 제출 즉시 답변을 필요로 하는지 알 수 없으며,
# - 제출 이후의 어떤 조치를 기대하는지 알 수 없습니다.
#
# 1-4実践課題① 의 제출이 어떤 과정의 일부인지, 구체적인 정보가 더 필요합니다.
# Generated category: 提出課題(提出済)
# Generated category: その他
# Generated category: 確認依頼
# Generated category: 提出課題の確認依頼
# Generated category: お客様からの連絡内容を分析した結果、お客様は顧客サポートセンターの運営について問い合わせておられます。 15文字程度の要約： 顧客サポートセンターの運営に関する問い合わせ
# Generated category: フィードバックへの感謝と 2-2 実践課題の提出。 お問い合わせ内容に該当。
# Generated category: 「HerTech受講の開始報告、無理せず進めていきたい」という内容です。お問合せカテゴリーは「受講開始報告」です。
# Generated category: 勉強会予約の確認と質問内容の確認 요청
# Generated category: パソコン到着待ちのため、Slack参加が遅れる旨の連絡
# Generated category: ## 受講準備完了連絡
# Generated category: 内田さん10月の目標シート送って。
# Generated category: 15時からの面談に少し遅刻する可能性があるとの連絡内容。
# Generated category: 実践課題8-1の添削を依頼
# Generated category: 「ユーザーガイドライン違反で画像が削除されたので原因を教えて欲しい」
#
# これはお問い合わせです。
# Generated category: 完了しました。
# Generated category: 面談のIDをラインで送付してほしいとの依頼
# Generated category: ## 要約: お客様からの連絡(カスタマーサポート)
# Generated category: 実践課題2-1、2-2を提出しました。
# Generated category: スケジュール調整。
# Generated category: ご連絡ありがとうございます。文章を解析したところ、お客様は「やってみます」と述べています。これは、お客様が何かを試してみることを示唆しているものと思われます。
#
# この文章から、お客様の具体的な目的までは特定することはできませんでした。お客様が試してみたいことについて、より具体的な情報を提供いただければ幸いです。
#
# なお、この返信には以下の情報を追加しております。
#
# * お客様からの連絡内容がお客様サポートセンターの運営に活用されていること
# * 解析の結果から、お客様の具体的な目的までは特定できなかったこと
# * 解析には、お客様の同意を得て実施していること
#
# 上記の情報は、より適切な回答を提供するための参考情報として活用させていただきます。
# Generated category: 実践課題の提出
# Generated category: ## お問い合わせ内容の要約:
#
# **SNSでのターゲット設定について、検索方法の質問。**
#
# ## カテゴリ:
#
# マーケティング・広告
# Generated category: 体調不良のため制作できませんでした。昨日はバナートレースと勉強会に参加し、バナーを訂正しました。
# Generated category: バナー制作の練習報告と勉強会予約の意思表示。
# Generated category: 製作演習完了、オリジナルバナー制作に興味、目的不明。
# Generated category: 資料提出。
# Generated category: 回復して、ポートフォリオ作成の続き。
# Generated category: 商品画像が見つからない場合の対応方法について問い合わせ。
# Generated category: 3-3実践課題の提出完了報告
# Generated category: 再提出の進捗報告
# Generated category: ## お客様からの連絡 (15文字以内要約)
#
# 課題7-2, 7-3を提出します。
# Generated category: 実戦課題提出とAdobe fire fly の確認依頼
# Generated category: 任意課題の場所がわからず、問い合わせてきた。 (15文字)
# Generated category: お客様はフォントについて問い合わせをしています。
# Generated category: その他
# Generated category: カリキュラムの提出ミスに関する問い合わせ
# Generated category: 「解決済み」のステータスで、お客様から連絡がありました。カスタマーサポートの分析に使用されます。
# Generated category: 質問:開業届は必要ですか？
# Generated category: 課題完了報告
# Generated category: PC 面談 への変更希望
# Generated category: 動画視聴の進捗状況報告
# Generated category: 旅行プランの確認
# Generated category: 予約変更希望
# Generated category: お詫びの連絡です。
# Generated category: シャボン玉、吹き出し、あしらいを切り取る方法について質問
# Generated category: 育休から復帰し、Slackの設定完了の報告。本日改めて確認予定。
# Generated category: 実践課題week2-1、2-2の提出確認依頼
# Generated category: 顧客はサポートチケットを提出しました。
# Generated category: 4-1任意課題が見つからないので、 探し方を教えてほしい。
# Generated category: 敬語使用と要約をお願いします。
# お客様からのお問い合わせは、15文字程度に要約して、お客様の目的を明確に示してください。
# また、問い合わせが不明瞭な場合は、「その他」と記載してください。
# このデータは、問い合わせの分類に使用されます。
#
# 敬語の使用と簡潔な要約を心がけます。問い合わせの内容が不明確な場合は、「その他」と記載します。
#
# **敬具**
# [お願い申し上げます🙇‍♀️] のような、お客様からいただいたお問い合わせ内容を分析しています。この内容を、15文字程度に要約して、お客様の目的を明確に示してください。
#
# **要約:**
#
# お客様は、カスタマーサポートセンターの運営についてお問い合わせをしています。
#
# **出力:**
#
# 顧客サポート
# Generated category: チャットGPTプロンプトの共有エラーについて問い合わせ。
# Generated category: バナー制作の報告
# Generated category: 翻訳状況の報告
# Generated category: お客様からメールが届き、無事受信したことを確認しました。
# Generated category: 課題提出の報告
# Generated category: 授業の課題の提出確認
# Generated category: 経費について相談したい
# Generated category: 了解しました。お客様からの連絡内容を15文字以内に要約すると、「問題が解決しました。ありがとうございます。」となります。この連絡は、お客様からの感謝の気持ちを表しており、明確な問い合わせではありません。したがって、カテゴリーは「その他」となります。
# Generated category: その他
# Generated category: 顧客はサポートセンターに連絡を取りたくないようです。
# Generated category: zoom への ログイン 障害 報告
# Generated category: 日程変更依頼
# Generated category: 7と1、7と2の課題完了通知
# Generated category: 了解しました。要約させていただきます。
#
# > お問い合わせ内容: お客様からのお礼の連絡
#
# 上記のように要約しました。
#
# **カテゴリー:** 問い合わせ以外
#
# **理由:** お客様からのお礼の連絡であるため、問い合わせには該当しません。
# Generated category: 日本語の文章が日本語で要約されています。15文字程度に短縮されており、お客様が連絡した目的が明確に示されています。これは、問い合わせをカテゴライズするための適切なデータと言えます。
#
# 以下、日本語での要約です。
#
# **目的：カスタマーサポートセンターの運営**
# Generated category: 週1課題③、④の提出
#
# その他
# Generated category: バナー素材に関する問い合わせ
# Generated category: 受講開始楽しみにしています。
# Generated category: 画像サイズ変更について問い合わせ。
# Generated category: 当日キャンセルのお願い
# Generated category: 課題提出
# Generated category: 学習開始時期の延期要請
# Generated category: スケジュール確認
# Generated category: ## 8-3、8-4課題完了報告
#
# ## カテゴリ: 課題完了報告
# Generated category: 課題進捗報告
# Generated category: 顧客は、3-5の実践課題を完了したことを報告している。
#
# > 類似カテゴリ: 実践課題の提出
# Generated category: 「ご確認ありがとうございます。内容を確認いたします。」
#
# この文章は、カスタマーサポートへの問い合わせへの受領・回答を示しています。 お客様の対応状況の確認や、対応準備完了の報告が目的と考えられます。
# Generated category: 18・19日の課題を完了し、提出する旨の連絡
# Generated category: 有料版登録したが、リンク共有エラーで提出できない。
# Generated category: その他
# Generated category: 提出課題添削依頼
# Generated category: その他
# Generated category: お客様は、昨日も作業できなかったと報告しています。
# Generated category: お客様は振込口座の情報を問い合わせています。
#
# ## カテゴリ: 支払い関連
# Generated category: 提出課題の進捗報告と今後の課題への取り組み意向
# Generated category: バナー制作 2-3課題間違えて提出 再提出希望
# Generated category: その他
# Generated category: 参加した勉強会で待機室からチャットが来たが返信方法が分からず問い合わせ
# Generated category: 4-3までの学習完了の報告と添削依頼です。
# Generated category: 受講延長の申し込み希望
# Generated category: **顧客は実習課題プロンプトの修正を依頼しています。**
# Generated category: 実践課題提出完了報告 (15文字)
# Generated category: 課題報告、6-2に取り組んだことを報告。
# Generated category: アカウント変更希望 (要約 14文字)
# Generated category: その他
# Generated category: 目標シートの記入方法についての問い合わせ
# Generated category: ## お客様からの連絡内容の要約（15文字以内）
#
# 画像の貼り付け方がわからないので教えてほしい
# Generated category: ## カテゴリ：その他
#
# **15文字要約:** 次回からSlackで連絡します。
# Generated category: お客様は4-3の課題提出についての振り返りがどの部分か質問している。
# Generated category: 24日に旅行に出発し、コースの受講と目標シートの提出を延期したい旨の連絡。
# Generated category: DALL-E有料登録に関する問い合わせ
# Generated category: トオル様はイベントの目標設定について参加された際にグループワークが苦手で苦戦し、自身の目標設定に課題を感じて緊張しやすいので克服したい旨を連絡されました。
# Generated category: 面談に遅刻する可能性と、作業進捗が遅れていることの連絡。(15文字)
# Generated category: Webデザイン基礎講座への受講準備完了の連絡
# Generated category: 「サポートセンターに連絡し、PhotoshopやIllustratorがない場合の解決策を聞きたい」
# Generated category: 課題提出の報告と体調不良による遅延のお詫び
# Generated category: その他
# Generated category: 返金制度について問い合わせ
# Generated category: 頭が痛く、昨日の動画の添削を明日に延期
# Generated category: エクセルで関数のコピーペーストが反映されない。
# Generated category: アンケート回答できない
# Generated category: その他
# Generated category: 花びらのデフォルトカラーの変更方法に関する問い合わせ
# Generated category: お客様はカスタマーサポートセンターの運営に関するお問い合わせです。
# Generated category: 閲覧権限の変更方法に関する質問。
# Generated category: 報告・勉強会参加・修正提出の報告
# Generated category: 4-2 実践課題提出しました。
# Generated category: スケジュール変更の依頼
# Generated category: お客様はパソコンの購入時期について問い合わせています。
# Generated category: ## お客様の連絡内容の要約：
#
# **7-3に提出した内容について確認。**
#
# **目的：** 提出した内容が正しく処理されているか確認するため。
#
# ## カテゴリ：
#
# **その他**
#
# ※ 提出内容の確認を求める内容のため、7-3 に提出された内容が明らかになっていないため。
# Generated category: ## 要約
#
# 体調不良のため制作できず。バナー トレース＆訂正済み。
#
# ## カテゴリ
#
# 制作に関する報告
# Generated category: 課題提出
# Generated category: 動画視聴と課題提出完了の報告。
# Generated category: カラーピッカーが表示されない画像の確認依頼
# Generated category: その他
# Generated category: クロームで試しましたが、できませんでした。
# Generated category: 課題８-4の提出です。
# Generated category: バナー制作の自習会に参加し、制作したバナーについて相談したい。
# Generated category: 課題の添削内容の確認と修正、動画視聴。
# Generated category: [課題を提出しました] 課題提出の報告
# Generated category: 料金について問い合わせ
# Generated category: 日程変更希望
# Generated category: 課題提出
# Generated category: 谷津さんの11/43-3の課題提出確認
# Generated category: 2-2課題の提出
# Generated category: 誤字報告
# Generated category: 実践課題6-1の提出報告
# Generated category: 問い合わせ目的: ハッシュタグの存在意義についての質問
# Generated category: 初回ガイダンスへの出席を希望
# Generated category: キャンバで素材から図形を選択して図形に影をつけることは可能か？
# Generated category: Adobe Farawayの有料版へのアップグレードに関するお問い合わせです。
# Generated category: 課題5-2の報告と謝罪
# Generated category: 受講期間延長問い合わせ
# Generated category: 学証明発行依頼
# Generated category: w6-2課題提出報告
# Generated category: 最終日を確認したい
# Generated category: その他
# Generated category: 課題提出
# Generated category: 不明なバグ報告。
# Generated category: 延長拒否
# Generated category: その他
# Generated category: その他
# Generated category: 案件獲得編の進捗状況の報告
# Generated category: 本日1-3、2-3の授業を受け、課題を提出、11/11のイベント予約。
# Generated category: カリキュラム再開と2-12-2提出確認依頼。
# Generated category: お客様はラップトップPCの仕様について問い合わせています。
# Generated category: ラインでCanvaの使い方を聞きたい
# Generated category: ルビーコーヒーワークシートで文字入力できない
# PC：Mac
# Generated category: お客様目標シートに記入しました。
# Generated category: 面談日変更と午前中のCanva自習会によるバナー制作報告
# Generated category: スケジュール変更 18:30に変更
# Generated category: 予約しました😊
# \
# 目的: 予約
# カテゴリ: 予約
# Generated category: 顧客は生成クレジットが不足していて、生成タスクを実行できないことを報告しています。
# Generated category: クラウドサインにて署名しました - 契約書類への署名完了
# Generated category: 口座振り込みへの支払方法変更依頼
# Generated category: ## 1-3 実践課題の提出
#
# ## お問い合わせの内容
#
# これは課題提出に関する連絡です。
# Generated category: 週間課題1,2を提出しました。
# Generated category: ## カテゴリ: 提出確認
#
# お客様は、week3の③と④の提出を完了したことを報告しています。
# Generated category: 了解しました。お客様の連絡を要約します。
#
# **要約:** お客様は、今日の予定通りに進んだことへの感謝と、明日の仕事への意欲を表明しています。
#
# **目的:** 報告と意欲表明
#
# **カテゴリ:** その他 (明確な問い合わせではない)
# Generated category: 動画視聴と課題の提出に関する問い合わせ。
# Generated category: 提出課題に関するお問い合わせです。
#
# "week6-3" に関連する提出に関する内容が含まれており、お客様が提出に関する質問や確認を希望している可能性が高いです。
# Generated category: 【その他】 お問い合わせ内容が不明瞭なため、カテゴリー分類できません。
# Generated category: Adobeロゴの削除に関する問い合わせ、有料サービスとの関連性を尋ねる。
# Error in get_categorize: 503 The service is currently unavailable.
# Generated category: 支払い完了
# Generated category: 日本語
# 顧客はカスタマーセンターの運営に関するコメントをしています。
# Generated category: 次回面談の日程確認
# Generated category: その他
# Generated category: ## 要約: お客様は回答と添削に感謝の意を表明しています。
# Generated category: その他
# Generated category: その他
# Generated category: 週5-3の課題を提出しました。
# Generated category: 任意課題が見つからず、探してほしい
# Generated category: 面談時間変更の依頼
# Generated category: その他
# Generated category: **Week3-4の課題を提出しました**
#
# 目的：課題の提出
#
# カテゴリー：課題提出
# Generated category: 週間課題2-4～3-2を提出したので確認お願いします。
#
# **目的:** 課題の提出確認
#
# **カテゴリー:** 課題提出
# Generated category: デザイン・配色に関する書籍の問い合わせ
# Generated category: 「了解しました。日程調整の承諾」
# Generated category: 顧客は挨拶をし、サービスを使用開始したことを伝えた。
# Generated category: ## 顧客からの連絡内容の要約
#
# **連絡内容:** 1-31-4を完了しました
#
# **結論:** お客様は完了した作業(1-31-4)についての報告をしている
#
# **カテゴリー:** その他(具体的な内容が不明)
# Generated category: 実践課題②の提出報告
# Generated category: 再提出に関する連絡、画面サイズ変更による作業効率化を報告。
# Generated category: カード登録に関する問い合わせ。
# Generated category: 松丸様からWeek3-4〜Week4-4の実践課題の提出に関する連絡でした。
# Generated category: 連絡内容：承諾の返答と、了解した後の行動表明。  お客様は、指示内容を理解し、了解した上で、対応することを伝えています。
# Generated category: グループ化で複数選択の方法がわかりません。
#
# **お問い合せカテゴリ:** 問い合わせ
# Generated category: 課題提出
# Generated category: 提出期限の延期を希望。
# Generated category: 提出課題の連絡のようです。
# Generated category: PC故障のため、明日のガイダンスの日程変更を希望。(14文字)
# Generated category: アポイントメントの確認。
# Generated category: 顧客からの問い合わせ内容要約: 15文字以内で要約し、問い合わせの目的を明確に示してください。
# Generated category: オンライン初回ガイダンスについて、推奨スペックのPCが必要か確認の問い合わせ。
# Generated category: 宿題の提出連絡
# Generated category: ご連絡の要約を15文字以内でお願いします。
# Generated category: お客様からのお問い合わせ内容: お礼を述べています。
#
# カテゴリー: その他
# Generated category: その他
# Generated category: 顧客が感謝の意を伝える目的で連絡。
# Generated category: 早めに入室しています。
# Generated category: お支払い確認と領収書発行の依頼
# Generated category: 課題提出
# Generated category: メンター面談日変更依頼 - 10/24 16:30 を 10/31 9:00 に変更
# Generated category: アプリ購入に関する問い合わせ
# Generated category: 病院のため制作できず、明日から再開します。
# （目的：制作状況報告）
# Generated category: 初回ガイダンスの受講方法について問い合わせ
# Generated category: 吹き出しが見つからないので、どうしたらよいか知りたい。
# Generated category: 先週末の課題をすべて完了し、今週の課題も一部完了した旨の報告。
# Generated category: 前回相談した配色のピックアップ方法の再確認
# Generated category: 残業で課題が進められませんでした。
#
# このメッセージは、進捗状況の報告であり、明確なお問い合わせではありません。
# Generated category: 動画と同じ画像を2-2の課題に提出して良いか確認
# Generated category: 提出された課題の確認を依頼。
# Generated category: 手続き完了後のスケジュール確認
# Generated category: その他の連絡 : 1週間ほど本業が忙しく、対応できていなかったが、明日から再開する旨の連絡。
# Generated category: チャットGPT有料版の申し込み希望
# Generated category: 感謝の意と今後の協力を要請する内容です.
# Generated category: 危篤で学习中断，想咨询2、3周课程能否补上。
# Generated category: 学習内容の確認と相談
# Generated category: お客様は予約したメンター面談のZoom URLが見つからないため、再送を依頼しています。
# カテゴリ: ミーティング関連の問い合わせ
# Generated category: 再提出となった課題について、3回目の提出を求められているか問い合わせ。
# Generated category: 進捗状況の報告と相談。
# Generated category: 延長プランの支払い手続き中にエラーが発生し、次にどうすればよいかわからないので問い合わせ。
# Generated category: 課題の提出
# Generated category: サイン完了の連絡。
# Generated category: ログインできない
# Generated category: ④を提出しました。 (15文字)
#
# 目的: 提出物に関する報告
#
# カテゴリー: 提出物
# Generated category: 課題提出報告
# Generated category: お問い合わせ: 3-2実施の時間が長い、時間短縮のポイントを知りたい。
# カテゴリ: その他
# Generated category: 契約書の再送依頼。
# Generated category: SMS認証で携帯ログインできない
# Generated category: 延長プランの金額についての問い合わせ
# Generated category: お客様からのお問い合わせ内容を要約すると、4週目の4回目の提出物が完了したということになります。
# Generated category: お客様は、体調不良によりスケジュールが遅れていることを報告し、今後の方針について相談しています。
# Generated category: 追加課題提出状況の確認
# Generated category: その他
# Generated category: 顧客は提出物を間違った課題に提出したため、削除を依頼。
#
# **カテゴリー：課題提出**
# Generated category: アンケート回答に必要なQRコードを読み取り忘れたため、アンケートに答えることができない。対応方法について問い合わせ。
# Generated category: 画像取り込み後の背景生成にプレミアプランが必要とのことで課題ができない
# Generated category: お礼の連絡。その他。
# Generated category: 提出物に関する問い合わせ
# Generated category: お客様は感謝と喜びを伝えています。
# Generated category: 課題提出の報告 : w5-1終了
# Generated category: 確認依頼。
# Generated category: 延長依頼
# Generated category: 勉強の進捗報告と感謝の連絡
# Generated category: [了解しました。] お客様はカスタマーサポートセンターに連絡し、お問い合わせをされています。
# Generated category: 学習課題
# Generated category: 課題2-1提出しました。
# Generated category: 明日の面談日程変更依頼
# Generated category: ## 要約：動画視聴、課題提出、バナートレースについて連絡
#
# ## カテゴリー：案件・バグ報告
# Generated category: ご確認いただきありがとうございます。 お問い合わせ内容をまとめました。
#
# **お問い合わせ内容:** 週2-1-3の提出物に関するご報告
#
# **目的:** 提出物に関する報告
#
# **カテゴリ:** 提出物情報
# Generated category: 予約継続確認
# Generated category: お客様からの連絡は、添削に関する感謝の意を伝えています。
# Generated category: お客様が連絡された理由を分析した結果、「お客様がCanvaサービスの利用に際してデザイン関連の質問を投げかけている」と要約できます。15文字以内に表現するとすると、「Canva デザイン サービスについての質問」という表現が相応しいでしょう。
# Generated category: 今週の課題提出
# Generated category: バナートレース自習会のキャンセル待ちについて、待機時間や今後の予定を確認するお問い合わせ。
# Generated category: 子供の同伴可の初回ガイダンス予約希望
# Generated category: お客様はFigmaでワイヤーフレームを作成中に、矢印の黒い枠が出なくなり、反応しなくなったため、解決方法を問い合わせています。
# Generated category: 他のサイトフリー素材 おすすめ 15文字要約
# Generated category: 予約変更
# Generated category: バナートレースの上達報告と、今後の注意
# Generated category: キャンバへの画像登録について問い合わせ
# Generated category: 「箇条書きの質問がうまく送信できません。改行は可能でしょうか？」 お客様は箇条書きで質問する際に改行する方法を確認したい、という問い合わせです。
# Generated category: お客様は何かを回答したことを連絡しています。
# Generated category: 課題の提出
# Generated category: 8-3課題の添削依頼
# Generated category: 課題提出報告
# Generated category: スケジュール調整。
# Generated category: その他
# Generated category: 顧客サポート: 課題提出
# Generated category: ワイヤーフレーム完成報告とバナートレース報告
# Generated category: 勉強会の予約と経過報告
# Generated category: 課題5-3の確認依頼。
# Generated category: 修正完了報告: 32-3 から 13-2 まで。
#
# この 15 文字の要約は、問題の修正が完了したことを示し、修正された特定の範囲を示しています。 これは、お客様が技術的な問題を報告し、サポートを受けていることを示唆しています。
# Generated category: お問合せ内容の要約: お客様は6-2、6-4を1つの原稿にまとめる作業について問い合わせをしています。
#
# カテゴリー: お客様サポート
#
# 出力: 15文字
#
# 補足: お客様はChatGPTでの作業について問い合わせをしています。
# Generated category: 体調不良のため、1-1テキスト確認と実践課題遅延の連絡
# Generated category: お客様からのお問い合わせは、カスタマーサポートセンターの運営に関する連絡でした。
# Generated category: お支払い期限の猶予を願い、お支払い完了の報告.
# Generated category: アドレス変更
# Generated category: お客様は 2-1の実践課題の実施と提出の確認を希望しています。
# Generated category: 受講延長の辞退
# Generated category: 支払確認と延長申請
# Generated category: プロンプトに関する問い合わせ, 6-1実践課題の添削依頼
# Generated category: 「7-3完了、明日8-1進める」で、進捗報告と考えられます。
# Generated category: 「自習会で作ったバナーの修正フィードバック依頼」
# Generated category: 「週4-3と週4-4の課題、提出。確認してください。」
#
# これは課題提出の報告であり問い合わせではありませんでした。
# Generated category: お礼、メモのお願い、感謝
# Generated category: その他
# Generated category: [翻訳されています]
#
# お客様からの連絡内容を解析します：
#
# * お問い合わせの目的：不明
# * お問い合わせの内容： 不明
# * その他：はい
#
# お客様からの連絡内容は 15 文字程度に要約するには情報が不足しています。また、お問い合わせの目的や内容が明確でないため、その他に分類します。この情報は、お問い合わせを分類するために使用されます。
# Generated category: お客様は、カスタマーサポートセンターの運営について問い合わせています。
# Generated category: クレジットカード入金に関する問い合わせ
# Generated category: 予約の確認
# Generated category: その他
# Generated category: 課題提出と添削依頼
# Generated category: 予約しました
# Generated category: スケジュール調整
# Generated category: バナートレース自習会イベント参加連絡
# Generated category: 課題提出
# Generated category: 課題提出に関する問い合わせ
# Generated category: 次回面談予約完了, 内容確認依頼.
# Generated category: その他
# Generated category: Pinterest の画像をキャンバスに横並びにする方法について問い合わせ。
# Generated category: 実践課題の添削依頼。
# Generated category: 4-1、4-2終了の報告。進捗確認のお問い合わせ。
# Generated category: 面談の日程変更依頼 (運動会中止のため)
# Generated category: 終了証に関する問い合わせ。履歴書に書ける資格になるか確認したい。
# Generated category: イベント参加とバナー言語化について報告。
# Generated category: お問い合わせ。
# Generated category: その他
# Generated category: ## 案件獲得に向けスキルアップを目指す
# Generated category: 顧客は連絡の目的を具体的に示していないため、その他と分類します.
# Generated category: アポイントメントの変更を希望: 日時を10日(日)18時～16日(土)19時30分～17日(日)18時に変更したい
# Generated category: ご連絡ありがとうございます。お客様は10/9を休み間違えたため、10/9に休みを取りたいと連絡されました。これは、お客様からの休暇申請に関するお問い合わせです。
# Generated category: 予約確認の問い合わせ
# Generated category: お客様からの謝罪と再登録の意思表示です。
# Generated category: メールアドレス変更依頼
# Generated category: 課題に関する報告、遅刻のお詫び。
# Generated category: その他
# Generated category: 解決しました。
# Generated category: 課題完了報告
# Generated category: ご連絡ありがとうございます。数日間WEBの勉強から離れていましたが、自宅に帰られましたね。 今後、時間を少しずつ作って、作品作りを進めたいとのことです。 了解しました。ご連絡ありがとうございました。
# Generated category: お客様は、１週目の課題４つを提出しました。 お問い合わせ内容は課題提出に関する報告とみられます。
# Generated category: 勉強会延長申し込みの有無の確認。
# Generated category: 1-1～1-3実践課題提出、2-1動画視聴の報告
# Generated category: 不明. 15文字以内で要約できません.
# Generated category: ## カテゴリー: 作業状況報告
#
# **藤川さんは昨日オリジナルバナーの制作を、今日は課題を進められていないと報告しています。明日は作業を進める予定とのことです。**
# Generated category: ご支援ありがとうございます。お客様への対応に役立ちますので、以下の情報についてお伺いしてもよろしいでしょうか。
# * 15文字の要約は、文章で顧客の連絡の目的を要約することですか、それともトピックカテゴリで顧客の連絡を要約することですか？
# * このような要約を作成する理由は何かありますか？
# * この要約が、貴社チームによってどのように使用され、顧客への対応にどのように役立つと考えているのかを教えてください。
#
# お客様からより多くの情報を得ることで、お客様のニーズに合ったより正確なサービスを提供することができます。
# Generated category: 提出課題2-3を提出しました。議事録は後日提出いたします。
# Generated category: 遅れはありますが提出完了の連絡。(3-4) 15文字 提出完了
# Generated category: その他
# Generated category: 「課題提出遅れのお詫びと完了報告」
# Generated category: 振込の確認と連絡、目的は確認と連絡。
# Generated category: 提出課題確認依頼
# Generated category: Weekly Note 獲得点数の関数が間違っているため、修正を依頼。
# Generated category: デザインカンプ画像 Pinterest検索問い合わせ
# Generated category: ミーティングの日程変更依頼
# Generated category: フィードバック: 以下の要約は、お客様が連絡した目的を正確に把握しています。
#
# 「お客様は、8-1 実践課題のプロンプトがワークシートに入力されていることを報告するために連絡しました。」
#
# この要約は簡潔で、15 文字以内に収まっており、お客様の連絡の目的を明確に示しています。また、フィードバックに従って、他の出力を含んでいません。
#
# 参考までに、他のケースの例を以下に示します。
#
# * お客様から「注文した商品がまだ届いていない」という連絡を受けた場合、要約は「注文した商品の配送状況に関する問い合わせ」となります。
# * お客様から「製品の使い方がわからない」という連絡を受けた場合、要約は「製品の使用方法に関する問い合わせ」となります。
# * お客様から「製品に不具合がある」という連絡を受けた場合、要約は「製品の不具合に関する問い合わせ」となります。
#
# これらの例のように、要約は常に簡潔で、お客様の連絡の目的を明確に示す必要があります。
# Generated category: 予約キャンセル、体調不良による
# Generated category: その他
# Generated category: 課題提出確認
# Generated category: キャンセルのため連絡
# Generated category: 時間変更に関する連絡
# Generated category: メンター面談の次回予約について問い合わせ。
# Generated category: 修正依頼の連絡
# Generated category: 週2-3 2-4 3-1の課題を提出しました - 学生から課題提出の連絡
# Generated category: 確認メールの件承諾、勉強会使用許可
# Generated category: 資料確認後、受講への意欲表明。時間確保に不安あり。
# Generated category: 提出物の報告の確認依頼。
# Generated category: その他
# Generated category: 画像のトリミング方法について問い合わせ
# Generated category: ハイペース受講希望
# Generated category: デザインカンプ再提出とバナートレースの依頼
# Generated category: その他
# Generated category: 背景色に関する問い合わせ
# Generated category: 勉強会の内容とその難易度について問い合わせ
#
# ## お問い合わせ内容
# 勉強会の内容と難易度について問い合わせ
# ## お問い合わせカテゴリー
# 勉強会
# ## お問い合わせの具体的な内容
# - 勉強会の内容
# - 受講人数
# - 難易度
# Generated category: 週5-2課題を提出しました
# Generated category: パソコン作業で子供の世話ができないことを報告
# Generated category: アレルギー状況報告と次回予約の意思表示
# Generated category: バナートレーサー課題の報告と今後の取り組みの相談
# Generated category: **その他**
#
# この問い合わせは、Figma の権限設定に関する明確な質問ではありません。お客様は、チームへのアクセス権の付与について理解しておらず、その方法を教えてほしいと述べています。
# Generated category: 提出課題を間違えたので訂正依頼。
# Generated category: パソコン購入に関する不安と期待を伝える連絡。
# Generated category: CatGTP日本語版の無料期間に関する問い合わせ。
# Generated category: ログインできません
# Generated category: 「リンクが作れなかったため、LINEで送らせていただきました。」
#
# この連絡は、リンク作成に問題があり、LINEで送信したことを報告しています。 お問い合わせの目的は、リンク作成のトラブル解決と思われます。
#
# **要約**: リンク作成トラブル
# **カテゴリー**: その他
# Generated category: キャンセル希望
# Generated category: 「2-1実践課題」の提出確認依頼
# Generated category: 1-3 再提出
# Generated category: 予約の日程変更を希望
# Generated category: 課題の進捗報告。
# 3-4動画視聴、デザインカンプ制作・提出済み。
#
# 操作にも慣れつつあるとのことです。
#
# **カテゴリ**: 課題報告
# Generated category: 体調不良のため、課題6-2のみ提出。最終面談は辞退。
# Generated category: ## 予定変更：10/14(月)12:00
# Generated category: 週2-2の課題提出を依頼。
# Generated category: 受講の意思確認と開始の連絡
# Generated category: その他
# Generated category: 急病欠席による面談のリスケ調整
# Generated category: その他
# Generated category: 提出済み課題の報告
# Generated category: 延長プラン申込
# Generated category: PCメーカー選びで相談: 15文字
# Generated category: ポートフォリオ作成の進捗報告と継続の意向を伝える連絡。
# Generated category: お客様からのお礼のメッセージです。
# Generated category: お客様からの連絡は、3-4件の課題について問い合わせしているようです。
# Generated category: アポイントメント調整：お客様は10/6（日）の午前中にアポイントメントを希望しています。
# Generated category: 課題6-1の提出依頼。
#
# ※ お問い合わせの内容が明確です。
# Generated category: 動画視聴と課題提出、Canvaの練習報告
# Generated category: 確認済み。Slack 参加完了。
# Generated category: お客様は、添付画像の直線部分のページ切り替えタイミングと、最初に作った長方形のページを増やす方法について質問しています。
# Generated category: 3-5の実践課題を途中まで実施しました。
# Generated category: その他
# Generated category: 受講準備完了の報告です。
# Generated category: バナー制作課題の提出先を誤った旨の問い合わせです。
# Generated category: 支払い完了報告
# Generated category: 2章課題提出完了報告
# Generated category: 日程変更の依頼
# Generated category: フォーム入力忘れの確認
# Generated category: ## カテゴリー: その他
#
# (5-1回答欄の消失による再提出)
# Generated category: ## 質問分類: 学習進捗報告
# Generated category: 実践課題week2-1, 2-3の添削と確認依頼
# Generated category: 11月目標進捗報告。10/26-27任意課題2つ完了、3-3課題着手、2-3任意課題実施。
# Generated category: 面談準備確認
# Generated category: メンター面談と目標シート記入について報告
# Generated category: 面談のお礼と次回までの目標達成を報告した連絡内容。
# Generated category: 画像生成に関する問い合わせです。
# Generated category: 明日の進捗確認
# Generated category: 海外在住のため、振込先口座の確認 (海外送金 or PayPal)
# Generated category: その他
# Generated category: 4-4の実践課題のプロンプトに対する添削依頼です。
# Generated category: その他
# Generated category: バナートレース自習会の準備内容問い合わせ
# Generated category: 授業課題の提出を先生に報告
# Generated category: 報告: お客様は1-3の課題に取り組んだことを報告し、進捗状況を説明しています。
# Generated category: 確認依頼: 課題提出
# Generated category: カスタマーサポートへの連絡
# Generated category: Wi-Fi 切断による再入室希望
# Generated category: 明日のご報告は申し訳ありません。
# Generated category: その他
# Generated category: 課題の提出
# Generated category: お客様は、資料作成時に誤った説明をした事について説明しています。  資料の内容ではありません。
# お問合せカテゴリ: その他
# Generated category: データ共有に関する問題についての問い合わせです。
# Generated category: カラーピッカーの使い方に関する問い合わせ。
# Generated category: パソコンのログインについて問い合わせ。
# Generated category: ## カテゴリ: 顧客フィードバック
#
# ### 要約: お客様は顧客サポートの取り組みに感謝の意を表明しています。
# Generated category: 支払い完了の報告。
# Generated category: ロゴサイズについて問い合わせがあります。
# Generated category: 容量が大きいため課題の制作物を提出できないので、小さくする方法を教えてほしいという問い合わせです。
# Generated category: 了解しました。 お客様の目的は、「カスタマーサポートセンターの改善希望」と思われます。
# Generated category: Slack関連問い合わせ
# Generated category: 面接の案内に対するお礼と明日の面談の確認
# Generated category: ワイヤーフレーム全体のコンポーネント化がうまくいっておらず、メニューの操作方法がわからないため問い合わせた。
# ※ お客様からの連絡は技術的な問い合わせに分類されます。
# Generated category: 課題完了報告
# Generated category: 実践課題の提出確認依頼
# Generated category: 今週の取り組み報告と来週の予定
# Generated category: プランの終了方法の問い合わせ
# Generated category: その他
# Generated category: ## お問い合わせ内容分析
#
# **内容：** 2-3課題再提出、1-3任意課題、3-3実践課題実施完了報告、翌日のバナートレース勉強会開催案内。
#
# **目的：** 進捗報告と勉強会案内。
#
# **カテゴリ：** 進捗報告/お知らせ
# Generated category: 大西知里様からのお問い合わせ内容を分析すると、15文字程度で要約すると「お客様から届いた連絡内容を解析しています」となります。この場合、お客様の目的は不明確であり、その他に分類されます。
# Generated category: figmaで文字が打てない不具合に関する問い合わせ
# Generated category: バナーデザインの添削依頼
# Generated category: パーソナルキックボクシングへの感謝と次回の予約希望
# Generated category: お問い合わせ内容の要約: お客様はサービスの利用開始にあたり、サポートが必要であることを表明しています。
# Generated category: 完了しました、3-4課題の完了報告
# Generated category: 日渡さん、目標シートをください。
# Generated category: 課題提出に関する連絡
# Generated category: その他
# Generated category: 課題の件でスマートフォンの画面共有。
# Generated category: その他
# Generated category: 4-1 任意課題バナー作成の進捗について報告
# Generated category: 改行に関する質問と相談。
# Generated category: 面談時間の変更を希望しています。
# Generated category: お客様からの連絡内容は明確な問い合わせではないため、その他に分類されます。
# Generated category: ワークシート提出方法についての問い合わせ
# Generated category: 最終面接の日程調整ができないため、出欠確認の回答を求める
# Generated category: 2-3件の実践課題を提出したことを報告し、対応を依頼しています。
# Generated category: 勉強会資料の要請
# Generated category: 課題2-1を提出しました。
# Generated category: ## 要約:
#
# 勉強会予約 (進捗報告+質問準備)
# ## カテゴリ:
#
# 学習サポート
# Generated category: 再提出しました
# Generated category: その他
# Generated category: 5分前から作業していますが、どんな目的で連絡したのかわかりません。内容が不明確なため、その他に分類します。
# Generated category: Canva演習 1-4進捗報告
# Generated category: その他
# Generated category: 課題の提出報告
# Generated category: 顧客から4-4のリンクが貼り付けられた。内容が不明瞭のため、カテゴリーとしては「その他」に分類される。
# Generated category: キャンセル待ちについて問い合わせ。
# Generated category: ## 課題③④の提出連絡 (15文字)
#
# ## カテゴリ: 課題提出
# Generated category: 課題提出：3件（1, 2, 4）
# Generated category: 10/30課題取り組み, 10/31課題提出
# Generated category: 仕事進捗報告
# Generated category: 動画のダウンロード方法に関する問い合わせ
# Generated category: **質問: 課題提出の延期**
#
# **目的: 課題提出の締め切りを延長すること。**
#
# **内容:**
#
# * お客様は1-2の取り組みを再視聴し、1-3の課題は明後日以降に取り組む。
# * お客様は明日と明後日は帰宅が遅くなるので、課題に取り組むことができない。
# * お客様は課題提出の延期を希望している。
# Generated category: 学習: 了解しました。要約とカテゴリーの割り当てを、15文字以内で提供します。
#
# **要約:** 顧客は、実践課題 2-3、3-1、3-2 を完了したことを報告しました。
#
# **カテゴリ:** 学習の進捗状況の更新
# Generated category: 完了報告
# Generated category: その他の分類:
#
# 顧客からカスタマーサポートセンターに連絡が来ている。顧客は、問題が生じている画面が表示されていることを報告している。
# Generated category: その他
# Generated category: 2-1課題提出、2-1準備編課題作成、1-3課題ブラッシュアップなどの報告と、勉強会への参加連絡。
#
# 目的： 課題の進捗報告と勉強会への参加連絡。
# Generated category: お客様からのお問い合わせ内容の要約:  誤って提出していた資料を再度提出したいとのご連絡
# Generated category: 完了報告
# Generated category: 受講方法についての問い合わせ
# Generated category: クレジットカード支払い完了の報告。
# Generated category: 予約確認
# Generated category: 資料2-1と2-2を確認要請。資料確認。
# Generated category: 面談の日時変更
# Generated category: その他
# Generated category: キャンセル依頼
# Generated category: お客様はカスタマーサポートセンターの運営について質問しています。
# Generated category: ID見つかりました。 顧客の連絡内容はID検索に関するものと推測されます。
# Generated category: 週3-1の課題の提出について質問
# Generated category: お客様からメッセージが届きました。メッセージの内容を要約します。
#
# **要約:** お客様は、表示されたメッセージの内容について問い合わせをしています。
#
# **目的:** お客様は、メッセージの内容を理解したいと考えている可能性があります。
#
# **カテゴリー:** その他
#
# **理由:** メッセージの内容が明確なお問い合わせではないため。
# Generated category: 2-1の実践課題が提出されたことを報告
# Generated category: 要約：プレゼン資料作成依頼
# お問い合せカテゴリー：資料作成
# Generated category: お知らせ: 目標シート完成
# 目的: お知らせ、共有
# Generated category: 顧客は課題3-3と3-4を提出しました。
# Generated category: 課題提出報告
# Generated category: 11月目標の報告
# Generated category: ZoomチャットのURL問い合わせ
# Generated category: クラウドワークスの自己PRが書けないため、プロフィールの作成方法について問い合わせ。
# Generated category: 再提出の依頼 4-2に誤って提出された4-1課題の削除依頼
# Generated category: 添削依頼
# Generated category: その他
# Generated category: 提出課題の確認。
# Generated category: カリキュラム提出の不具合報告, 15文字: 講座コメントが誤ったページに投稿される
# Generated category: 画像を貼り付けようとしたら数式エラーとなり、対処方法を希望している。
# Generated category: 確認・要約: お問い合わせありがとうございます。確認のため、ご連絡内容を要約させていただきます。
# Generated category: ポートフォリオを載せるデザインについて問い合わせ。
# Generated category: 本日の課題に取り組んだ旨の報告。内容要約のみの場合は、15文字以内を心がけています。
# Generated category: その他。内容が明確な質問ではなく、日程の調整に関する連絡です。
# Generated category: 課題6-1の提出を報告する。
# Generated category: お客様からの質問: Zoomのイベント参加時の名前について
# Generated category: [確認致しました‼️手続きいたします。]
#
# 分析結果： カスタマーは手続きの確認と実行を依頼。
#
# カテゴリー: カスタマーサポート
# Generated category: 学習完了。
# 要約: 中川さん宛カリキュラム1-3の再再提出が完了した。
# カテゴリー: 学習完了。
# Generated category: 支払いについての問い合わせです。
# Generated category: お客様はカスタマーサポートセンターの運営に関する連絡を行っている。
# Generated category: 説明会の参加確認
# Generated category: 取り組み報告
# Generated category: 承知しました。15字以内に要約します。
# Generated category: 健康上の理由による欠席連絡
# Generated category: お客様からのお礼の連絡です。
# Generated category: その他
# Generated category: お客様サポートへご連絡しました.
# Generated category: お客様は2-3の提出をしたことを報告しています。
# Generated category: 受講期間延長の相談
# Generated category: お客様からの問い合わせは、AIコースの料金についての内容です。
# Generated category: Figma の使い方に関する質問
# Generated category: 顧客は課題1-②③を完了したことを伝え、カスタマーサポートセンターに連絡しました。
# Generated category: Week5-1課題提出の連絡。
# Generated category: 週4-3の実践問題を提出しました。これは、課題提出に関するご連絡です。
# Generated category: その他
# Generated category: その他
# Generated category: 勉強会以外のイベント参加方法と進め方の目安表の見方を問い合わせ。
# Generated category: 課題の提出報告です。
# Generated category: お客様からの感謝の言葉。
# Generated category: 休みと課題提出について
# Generated category: 「お客様はカスタマーサポートの分析について問い合わせています」
# Generated category: お客様の連絡内容に基づいて、目的を分析した結果を次に示します：
#
# **再調整：** お客様は何かしらの再調整を要請されているようです。
#
# この情報がお役に立てれば幸いです。
# Generated category: 課題の確認と提出について。
# Generated category: その他
# Generated category: 課題の提出を報告する内容であり、問い合わせではないため、「その他」に分類されます。
# Generated category: ## お問い合わせ内容の要約
#
# **課題提出用フォルダへの画像保存方法がわからない。**
#
# ## カテゴリ
#
# 技術サポート
# Generated category: サイズ変更に関する質問。
# Generated category: 予約。
# Generated category: 添削内容を復習し、再度課題に取り組んでいる
# Generated category: 「課題を提出しました」
#
# 目的は、課題の提出報告です。
# Generated category: 添削課題の確認依頼
# Generated category: お客様がカスタマーサポートセンターに連絡しました。
# Generated category: 最終面接を辞退
# Generated category: 初回面談希望、3-8候補不可、7日希望
# Generated category: バナー制作の支援依頼
# Generated category: 面談の日程変更希望 (栗山祥子)
# Generated category: 実践課題提出依頼
# Generated category: その他
# Generated category: クイック選択ツールの表示方法を問い合わせ。
# Generated category: バナー トレース 練習 希望。イベント、キャンセル待ち 後、受講 間隔 について 質問。
# Generated category: お問い合わせ内容: 面談の場所確認
# Generated category: ## お問い合わせ内容: 実践課題の提出
#
# ## カテゴリ: 課題提出
#
# ## 補足: 1の実践課題の①と④を提出
# Generated category: 実践課題④の提出
# Generated category: お客様は面談の感謝と体調管理、目標シートの確認を目的として連絡しました。
# Generated category: 画像の保存方法に関する問い合わせ
# Generated category: 新しいことを学ぶための受講申し込み
# Generated category: 支払い完了報告
# Generated category: figma課題提出、イベント予約困難に関する問い合わせ
# Generated category: フィードバックイベント予約と目標シート提出
# Generated category: 谷津さんへ3-3の治しで途中まで対応。顧客の作ったバナーについて15分勉強会を開き、フィードバックを提供し改善点の共有を行った。
# Generated category: 文字起こしについて質問し、課題の進め方について確認しています。
# Generated category: 再処理のエラーにより、別のカードで再度手続きを行いたい。
# Generated category: 課題提出
# Generated category: Web制作課題のサポートを希望。
# Generated category: 遅刻の謝罪と、今後の協力のお願い
# Generated category: アポ調整
# Generated category: 課題提出の報告
# Generated category: 承知しました。15文字に要約します。
#
# 目的: カスタマーサポートセンター運営
#
# その他
# Generated category: お客様は、非表示アイコンの操作方法について問い合わせており、提供された操作方法のサイトを確認するとのことです。
# Generated category: その他
# Generated category: お客様は、カスタマーサポートセンターの運営に感謝の意を表明しています。
# Generated category: 7-1～8-4資料提出確認 request
# Generated category: 面談予定の確認/調整依頼
# Generated category: 確認依頼: 7-2までの課題完了
# Generated category: 受講開始までの流れの説明がないため、メールを送ってもらったのか確認依頼。
# Generated category: 「バナーのデザインについて質問」
# Generated category: その他
# Generated category: ## お問い合わせ要約
#
# **お客様から届いた連絡内容の要約を要請。**
#  - 連絡内容は4-1.2.3.4で提出済み。
#  - お問い合わせカテゴライズ用データとして活用。
#
# **要約:** お問い合わせ要請。
#
# **内容:** お問い合わせの内容を15文字以内に要約。
#
# **注意事項:**
# - お問い合わせの内容が明確でない場合は、"その他"と出力。
#
# **追加出力:** なし
# Generated category: 課題の進捗報告
# Generated category: 初めにご連絡いただきありがとうございます。
# Generated category: その他
# Generated category: 課題7-2の提出
# Generated category: ## 問い合わせ内容 :
# 4日 14時以降での対応可能か確認
# Generated category: お客様は、week6-2 の課題を提出したことを伝えています。
# Generated category: 本日は、バナートレイス自習会に参加。  (目的: 自習会参加報告)
# Generated category: 不鮮明な情報のため、目的を特定できませんでした。その他として分類します。
# Generated category: 面談希望：10月に調整希望
# Generated category: この連絡は、3-3の再提出と3-4の課題の提出を完了した旨の報告のためです。
# Generated category: その他
# Generated category: 提出物の提出方法について問い合わせ
# Generated category: 課題提出 2-1
# Generated category: Canva操作に苦戦しており、明日調整を続ける予定との報告
# Generated category: 入金完了報告 (14文字)
# Generated category: お客様から連絡がありました。
# Generated category: ## 週8-1,2を提出しました。よろしくお願いいたします。
#
# **目的**: 週8課題1,2の提出連絡
#
# **カテゴリー**: 課題提出
# Generated category: 体調不良による面談延期
# Generated category: 実践課題のプロンプト添削の依頼。
# Generated category: その他
# Generated category: 質問
# Generated category: 課題の提出
# Generated category: 問い合わせ内容要約：動画視聴、課題提出、Canvaトレース練習の依頼
# Generated category: お客様は10/9の予約を変更したい旨を連絡しました。
# Generated category: デザイン参考サイト/書籍紹介依頼
# Generated category: お問い合せ内容：データ保存方法の質問(PNG形式)
# Generated category: カリキュラムの学習進捗報告、明日は休み、月曜日から再開の意思表示。
#
# **カテゴリ: 学習進捗報告**
# Generated category: スケジュール調整依頼
# Generated category: 4件の課題提出
# Generated category: 2回目の面談のスキップ依頼。
# Generated category: ## 課題の進捗報告
#
# この連絡は、お客様が課題の進捗状況を報告するために送られたものです。
# Generated category: 課題の提出
# Generated category: その他 (今週の課題を提出しました。)
# Generated category: ## 顧客サポート問い合わせ要約
#
# **目的:** バナー修正に関するフィードバック依頼
#
# **カテゴリー:** デザインレビュー
# Generated category: 週5-1の課題を提出しました
# Generated category: 再提出完了報告
# Generated category: STEP1、2回答済み、要指示。
# Generated category: 課題提出の確認依頼 (13文字)
# Generated category: その他
# Generated category: 実践課題6-2の提出連絡

# %% [markdown]
# # **2. Create a Search Data Store**
# A search data store is required to manage the categorized corpus data.
#
# **2.1 Create Data Store**
#
# *   Create a new data store with a unique identifier (data_store_id).
# *   Import the categorized corpus (categorized_corpus.jsonl) from a local path into the data store.
# *   displayName need to be change to differentiate data name from the other data store id

# %%
import requests
import subprocess
import json

# Replace with your actual project ID
PROJECT_ID = "monobrain-development" # @param {type:"string"}
DATA_STORE_ID = "indah_data_1" # @param {type:"string"}
DISPLAY_NAME = "sample_module4" # @param {type:"string"}

# Get an access token
access_token = subprocess.run(
    ["gcloud", "auth", "print-access-token"],
    capture_output=True,
    text=True,
).stdout.strip()

# Define the API endpoint
url = f"https://discoveryengine.googleapis.com/v1alpha/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores?dataStoreId={DATA_STORE_ID}"

# Define the request payload
payload = {
    "displayName": DISPLAY_NAME ,
    "industryVertical": "GENERIC",
    "solutionTypes": ["SOLUTION_TYPE_SEARCH"]
}

# Define the headers
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json",
    "X-Goog-User-Project": PROJECT_ID,
}

# Make the POST request
response = requests.post(url, headers=headers, data=json.dumps(payload))

# Print the response
if response.status_code == 200:
    print("Data store created successfully!")
    print(response.json())
else:
    print("Failed to create data store.")
    print(f"Status Code: {response.status_code}")
    print(response.text)
# Out:
# Data store created successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/operations/create-data-store-14924246761857000088', 'done': True, 'response': {'@type': 'type.googleapis.com/google.cloud.discoveryengine.v1alpha.DataStore', 'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1', 'displayName': 'sample_module4', 'industryVertical': 'GENERIC', 'solutionTypes': ['SOLUTION_TYPE_SEARCH'], 'defaultSchemaId': 'default_schema', 'servingConfigDataStore': {}}}

# %% [markdown]
# **2.1 import the corpus data with category from local path.**
#
#
#
# 1.   Ensure the data_store_id is correctly defined. This is the unique identifier for the data store where the corpus will be uploaded.
# 2.   Ensure the enriched corpus data (categorized_corpus.jsonl) is available on your local path.

# %%
import requests
import subprocess
import json

# Replace with your actual project ID and data store ID
PROJECT_ID = "monobrain-development" # @param {type:"string"}
DATA_STORE_ID = "indah_data_1" # @param {type:"string"}
JSONL_FILE_PATH = "/content/output_with_categories_corpus_data.jsonl"  # @param {type:"string"}

# Get an access token using gcloud CLI
access_token = subprocess.run(
    ["gcloud", "auth", "print-access-token"],
    capture_output=True,
    text=True,
).stdout.strip()

# Read JSONL file and upload each document
def upload_documents(jsonl_file_path):
    with open(jsonl_file_path, "r", encoding="utf-8") as file:
        for line in file:
            document = json.loads(line.strip())  # Read each line as JSON
            document_id = document["id"]  # Extract document ID from JSON
            url = f"https://discoveryengine.googleapis.com/v1beta/projects/{PROJECT_ID}/locations/global/collections/default_collection/dataStores/{DATA_STORE_ID}/branches/0/documents?documentId={document_id}"

            # Prepare the payload using the original document structure
            document_data = {
                "structData": document
            }

            # Define the request headers
            headers = {
                "Authorization": f"Bearer {access_token}",
                "Content-Type": "application/json",
            }

            # Make the POST request to upload the document
            response = requests.post(url, headers=headers, data=json.dumps(document_data))

            # Print the response for each document
            if response.status_code == 200:
                print(f"Document {document_id} uploaded successfully!")
                print(response.json())
            else:
                print(f"Failed to upload document {document_id}.")
                print(f"Status Code: {response.status_code}")
                print(response.text)

# Call the function to upload documents
upload_documents(JSONL_FILE_PATH)
# Out:
# Document qa_1484 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1484', 'id': 'qa_1484', 'schemaId': 'default_schema', 'structData': {'question': '井関様1-3の実践課題、オススメバナー初級をトレースして提出しました♪', 'id': 'qa_1484', 'answer': '取り組み報告ありがとうございます！今日もしっかり進められていて素晴らしいです👏バナートレースはやればやるほどスキルアップできるので、紹介しているもの以外でもご自身の好きなテーマなどでぜひトレース挑戦してみてください✨今日も1日お疲れ様でした^^', 'category': 'お問い合わせ'}, 'parentDocumentId': 'qa_1484'}
# Document qa_1459 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1459', 'id': 'qa_1459', 'schemaId': 'default_schema', 'structData': {'category': 'その他', 'id': 'qa_1459', 'answer': '【🎉任意課題「模擬案件に応募してみよう」を追加しました🎉】こんにちは！HerTech運営事務局です😌マイページ\u30004-2：案件の取り方ページに任意課題「模擬案件に応募してみよう」を追加しました！▼内容は？本物のクラウドソーシングサービスそっくり！の架空案件で、クライアントとのやりとりや納品までの流れを体験できます✨▼こんな人におすすめ・実際の案件に挑戦する前に練習をしてみたい・実際の案件の流れを体験してみたい・今すぐに副業はできないけれど、案件にも挑戦してみたい▼確認方法１）マイページにログイン２）左側メニューの「カリキュラム＞4-2 案件の取り方＞実践課題下をスクロール取り組みしたものはポートフォリオにも掲載できますので、ぜひ挑戦してみてくださいね✨', 'question': '藤岡様宛て再提出と、2-2課題提出できました。'}, 'parentDocumentId': 'qa_1459'}
# Document qa_1290 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1290', 'id': 'qa_1290', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1290', 'category': 'イベント時間について問い合わせ。16時以降のみ参加可能か確認希望。', 'question': 'figma関連のイベントは午前中から14時までの間に行われることはありますか？参加したいのですがどの時間帯も16時以降で参加することができません…。', 'answer': 'ご相談いただき、ありがとうございます！今月は講師の都合がつかず、早い時間での開催が難しい状況となっておりました💦申し訳ございません🙇来月以降にはなりますが、日中で開催できるよう検討させていただきますので、また日程が出ましたらご確認くださいませ◎今月につきましては勉強会もご利用いただきながらFigmaについて進めていただけたらと思います😌'}, 'parentDocumentId': 'qa_1290'}
# Document qa_1303 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1303', 'id': 'qa_1303', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1303', 'answer': 'ご質問ありがとうございます◎画面の一部にロゴやメニューを固定するには、参考動画で使用しているSTUDIOで実装することができますよ😊✨STUDIOでヘッダーを固定するには、「固定位置」「絶対位置」を使うことで、スクロールしてもレイアウトが移動しないようになります🙌詳しい実装方法はこちらのサイトを参考にしてみてくださいね＾＾[https://galera.co.jp/blog/qOIcQMjZ (短縮)]', 'category': 'ダウンロードに関する問い合わせと推測されます。', 'question': '【動画】\nダウンロードはこちら'}, 'parentDocumentId': 'qa_1303'}
# Document qa_332 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_332', 'id': 'qa_332', 'schemaId': 'default_schema', 'structData': {'id': 'qa_332', 'answer': '課題のご提出ありがとうございます✨引き続きご提出お待ちしております☺', 'question': 'week 6-1の課題を提出しました。', 'category': '週6-1の課題提出'}, 'parentDocumentId': 'qa_332'}
# Document qa_1292 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1292', 'id': 'qa_1292', 'schemaId': 'default_schema', 'structData': {'question': '本日figmaのイベントに参加しました。行う内容が違うのであればまた参加しようと思うのですがfigmaのイベントは1種類だけでしょうか？', 'answer': 'イベントのご参加お疲れ様でした✨Figmaについては現在は1種類となります😌LPのトレースなど挑戦していただき、勉強会でフィードバックをもらうのも勉強になりますので、是非お時間取れるときに挑戦してみてください🙏', 'category': 'Figmaイベントについて、種類や再度参加する可能性についての問い合わせです。', 'id': 'qa_1292'}, 'parentDocumentId': 'qa_1292'}
# Document qa_859 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_859', 'id': 'qa_859', 'schemaId': 'default_schema', 'structData': {'answer': 'ご不明点をお伺いいたします👇 入会後の受講キャンセル入金後の受講キャンセル受講開始後の解約', 'category': '受講キャンセル・解約', 'id': 'qa_859', 'question': '【受講キャンセル・解約】'}, 'parentDocumentId': 'qa_859'}
# Document qa_731 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_731', 'id': 'qa_731', 'schemaId': 'default_schema', 'structData': {'id': 'qa_731', 'category': '「課題③ができました」\n目的：課題の提出、完了報告\nカテゴリー：課題提出', 'question': '！ー４\u3000課題③ができました。よろしくお願いします。', 'answer': '課題のご提出ありがとうございます☺添削完了しましたのでご確認ください♪'}, 'parentDocumentId': 'qa_731'}
# Document qa_348 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_348', 'id': 'qa_348', 'schemaId': 'default_schema', 'structData': {'question': 'こんにちは😃以前、参加した自習会で作成したバナーをこの前勉強会でアドバイスいただいて修正してみたので、フィードバックをお願いします(お願いします)2枚目は、“踊りだす”に動きをつけたので流れるような飾りをアクセントとして付けてたのですが、あまり飾らずにシンプルに仕上げたほうがいいのでしょうか？', 'id': 'qa_348', 'answer': 'お取り組みお疲れさまです🌱全体的に色がまとまっていて、とても見やすいバナーに仕上がっていますね😊「踊りだす」のレイアウトが工夫されていることで、楽しそうな雰囲気に仕上がっているのではないでしょうか✨今の状態でもいいのかなと思いますが、レイアウト以外で表現するのであれば、あしらいを加えてもいいかもしれないと感じました🌱あしらいについては以下のサイトでわかりやすく解説されていますので、こちらもぜひ参考にしてみてください^^[https://cotonoha-design.com/blog/ashirai/ (短縮)] また、「乙女ゴコロ」や「初月半額」のテキストは、背景に対して少し上に寄っている状態なので、上下の余白を整えてあげるとすっきり見えますよ🙌', 'category': 'バナー修正のフィードバック依頼'}, 'parentDocumentId': 'qa_348'}
# Document qa_340 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_340', 'id': 'qa_340', 'schemaId': 'default_schema', 'structData': {'id': 'qa_340', 'category': '体調不良のため、制作ができませんでした。', 'question': '谷津さま今日の取り組み今日は、体調がすぐれなく制作する事が出来ませんでした💦昨日は、Photoshopでのバナートレースと勉強会に参加をして、バナー訂正しました。', 'answer': 'お疲れ様でした！体調悪い日は無理せず、ご自身の良いペースで進めていきましょうね✨️'}, 'parentDocumentId': 'qa_340'}
# Document qa_195 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_195', 'id': 'qa_195', 'schemaId': 'default_schema', 'structData': {'category': '課題提出', 'answer': 'こんにちは！メンターの津幡です😊前回のご面談から1ヶ月が経ちますので、2回目の面談のご案内をいたします。ご参加は【任意】になります。スキップされる場合はLINEにて「希望しない」とご連絡ください。▼面談ついて・初回と同じくzoomを使用した面談を予定しております・所要時間は15分程度を予定しております。・学習やサービスの使い方について困っていることなどがあれば、この機会にぜひご相談ください。※皆様にお送りさせていただいています。既に2回目の面談をご予約済の方は、再度対応いただく必要はございません。▼日程調整URL[https://timerex.net/s/HerTech-mentor-GAI2/9d817cbb (短縮)] ※ご予約につきましては上記URLからご都合のよい日程をお選びいただくようお願いいたします。※ご都合のよい日程がない場合は、ご希望の日程・お時間帯をLINEにて幅広くご提示ください。◎注意◎※予約後の日程変更はなるべくお控えください※やむを得ず変更される際は【面談実施の3時間前まで】にご連絡の上、予約ツール上で変更ください（予約ツール上で参加可能な時間帯がない場合は、その旨もご連絡いただければ幸いです。）上記につきまして、ご不明点等ございましたら遠慮なくご質問ください🍀よろしくお願いします！', 'id': 'qa_195', 'question': '課題3-4を提出しました'}, 'parentDocumentId': 'qa_195'}
# Document qa_1085 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1085', 'id': 'qa_1085', 'schemaId': 'default_schema', 'structData': {'answer': 'お疲れ様でした👏✨️毎日しっかり進めてくださって、確実に成長していると思います💪無理なく、できる日にまた進めてくださいね😊', 'category': '## 3-3を提出、次の進捗は不明\n\n## お問い合わせ内容：提出完了報告、進捗確認', 'question': '谷津さんへ今日は3-3を治して再提出しました！なかなか難しくて、結構苦戦しました‥！明日は進めれるかわかりませんができそうだったら次のを進めます！✨', 'id': 'qa_1085'}, 'parentDocumentId': 'qa_1085'}
# Document qa_895 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_895', 'id': 'qa_895', 'schemaId': 'default_schema', 'structData': {'id': 'qa_895', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'category': '「連絡しました！」とのことで、お問い合わせ内容の詳細は不明です。その他に分類されます。', 'question': '出来ました！よろしくお願いします！'}, 'parentDocumentId': 'qa_895'}
# Document qa_631 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_631', 'id': 'qa_631', 'schemaId': 'default_schema', 'structData': {'question': '4-3,4-4課題提出が完了いたしました。これで全ての課題が終わりました。よろしくお願いいたします。', 'category': '課題提出 完了・報告', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'id': 'qa_631'}, 'parentDocumentId': 'qa_631'}
# Document qa_852 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_852', 'id': 'qa_852', 'schemaId': 'default_schema', 'structData': {'id': 'qa_852', 'question': '【料金】', 'category': 'お客様は料金についてカスタマーサポートセンターに連絡しました。', 'answer': 'ご不明点をお伺いいたします👇 Webデザインコースの料金動画編集コースの料金生成AIコースの料金'}, 'parentDocumentId': 'qa_852'}
# Document qa_995 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_995', 'id': 'qa_995', 'schemaId': 'default_schema', 'structData': {'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'id': 'qa_995', 'category': 'HerTech受講に関する相談: 平日の残業が多く、計画的に受講できるか心配。', 'question': '■HerTech受講への今の気持ち：平日は残業も多く帰宅時間が遅めで不規則なため、計画的に受講できるかどうかが今のところ心配です。課題の提出期限もあると思うので、そこも気になりますが、まずは楽しく学びたいと思います。'}, 'parentDocumentId': 'qa_995'}
# Document qa_956 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_956', 'id': 'qa_956', 'schemaId': 'default_schema', 'structData': {'question': 'あと、2-3の添削もしてもらったので明日はそれから始めます！', 'id': 'qa_956', 'category': '2-3の修正後、明日から再開します。 (お客様からの連絡内容要約)', 'answer': 'ご報告ありがとうございます🌱お取り組みお疲れ様でした🐿️この調子で無理なく進めていきましょう！'}, 'parentDocumentId': 'qa_956'}
# Document qa_395 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_395', 'id': 'qa_395', 'schemaId': 'default_schema', 'structData': {'id': 'qa_395', 'question': '表示範囲に引用元メッセージがありません。スクロールして過去メッセージをロードしてください。\nお世話になります。3️⃣口座振込に変更でお願いします‼︎', 'answer': 'ご連絡いただきありがとうございます😊口座振込へ変更ご希望とのこと、承知いたしました◎▼お支払い依頼書確認URL[https://drive.google.com/file/d/1R_7uIkRnUoH5LzwpRWdQ19UT0bpm_q4P/view?usp=sharing (短縮)] ▼お支払い期日11月3日(日)引き続き、どうぞよろしくお願いいたします✨', 'category': 'その他'}, 'parentDocumentId': 'qa_395'}
# Document qa_158 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_158', 'id': 'qa_158', 'schemaId': 'default_schema', 'structData': {'question': '上記回答いただきありがとうございます。課題2-4が完了しました。ご確認よろしくお願い致します。', 'id': 'qa_158', 'category': '課題2-4の確認依頼', 'answer': '課題のご提出もありがとうございます♪添削完了しましたのでご確認ください'}, 'parentDocumentId': 'qa_158'}
# Document qa_349 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_349', 'id': 'qa_349', 'schemaId': 'default_schema', 'structData': {'question': '谷津さん、お疲れ様です！当日で大変申し訳無いのですが、急遽仕事が長引いてしまい、面談に間に合いそうにありません(汗)面談をリスケしてもらうことは可能ですか😖？？', 'id': 'qa_349', 'answer': 'ご連絡ありがとうございます◎本日の実施キャンセルいたしますね🌱改めて下記よりご予約お願いできると嬉しいです😊[https://timerex.net/s/HerTech-mentor2/b4c2ae3f/ (短縮)]', 'category': 'その他'}, 'parentDocumentId': 'qa_349'}
# Document qa_840 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_840', 'id': 'qa_840', 'schemaId': 'default_schema', 'structData': {'question': 'すみませんクレジットカードをもう一度試してもいいですか？💦', 'category': 'クレジットカードに関する再試行の要請', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'id': 'qa_840'}, 'parentDocumentId': 'qa_840'}
# Document qa_1424 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1424', 'id': 'qa_1424', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1424', 'question': 'お世話になっております。質問なのですが、オリジナルバナーを制作する際、商品の画像はネットで調べた物を使用して良いのでしょうか？背景の素材などは、素材検索のサイトで調べているのですが、商品本体の画像をどうしていいのかわからず、教えて頂きたいです！よろしくお願い致します💭', 'category': 'オリジナルバナー作成時の商品画像について問い合わせ', 'answer': 'ご質問ありがとうございます◎実務でのバナー制作時の商品の画像素材については、基本的にはクライアントからいただいたものを使うようにしましょう😌ネットの画像は著作権の問題があるので、素材がない場合はまずはクライアントに相談してみるのがオススメです🌱もしご自身のポートフォリオに掲載するためのバナーの場合は、商用利用OKのフリー素材サイトから集めるようにしましょう◎'}, 'parentDocumentId': 'qa_1424'}
# Document qa_866 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_866', 'id': 'qa_866', 'schemaId': 'default_schema', 'structData': {'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'id': 'qa_866', 'category': '体調不良で長期休講後、本日より受講再開。', 'question': 'Slackの確認はしていましたが、体調を長らく崩してしまっており全く受講出来ていませんでした。本日より受講しました。大丈夫でしょうか？'}, 'parentDocumentId': 'qa_866'}
# Document qa_300 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_300', 'id': 'qa_300', 'schemaId': 'default_schema', 'structData': {'id': 'qa_300', 'answer': '面談について承知しました！ご確認とご連絡ありがとうございます！😊お困りごとやご相談ごとございましたらいつでもご予約くださいませ✨', 'question': '7-3の教材には、DALL-3やAIで編集についての記載がありましたが、有償プラン（DALL-3も別登録）のみ利用可能ということでしょうか？', 'category': 'その他'}, 'parentDocumentId': 'qa_300'}
# Document qa_990 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_990', 'id': 'qa_990', 'schemaId': 'default_schema', 'structData': {'question': '井関さん「今日取り組んだこと」1-3 実践課題実施提出1-4 動画視聴1-4 課題実施1-3 任意課題実施', 'id': 'qa_990', 'answer': 'ありがとうございます！在学証明についてはしばらくお待ちくださいませ😌お取り組み報告もありがとうございます＾＾しっかり進められていますね✨️引き続き無理なく進めていきましょう🌱', 'category': '1-3 実践課題提出、1-4 動画視聴と1-4 課題実施 レポート、1-3 任意課題の提出についての内容。'}, 'parentDocumentId': 'qa_990'}
# Document qa_1256 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1256', 'id': 'qa_1256', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1256', 'category': 'HerTech受講への意気込み連絡', 'question': '■HerTech受講への今の気持ち：いよいよ受講開始でドキドキしてますが、数ヶ月後少しでもなりたい自分になれるように頑張ります！', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。'}, 'parentDocumentId': 'qa_1256'}
# Document qa_1030 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1030', 'id': 'qa_1030', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1030', 'question': '【その他】', 'category': 'お客様は、カスタマーサポートセンターへ連絡した理由を要約してほしいと依頼しています。', 'answer': 'その他のご質問は現在準備中です。大変恐れ入りますが、LINEより直接ご質問いただけますと幸いです。'}, 'parentDocumentId': 'qa_1030'}
# Document qa_817 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_817', 'id': 'qa_817', 'schemaId': 'default_schema', 'structData': {'category': '視聴ユーザー招待メール未受信', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'id': 'qa_817', 'question': '【MOOGA Plus】視聴ユーザー招待のご案内のメールが届いていません。その他ふたつは届いています。お手数おかけしますが、よろしくお願い致します'}, 'parentDocumentId': 'qa_817'}
# Document qa_385 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_385', 'id': 'qa_385', 'schemaId': 'default_schema', 'structData': {'category': 'お問い合わせ', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'id': 'qa_385', 'question': 'week7-1提出しました'}, 'parentDocumentId': 'qa_385'}
# Document qa_1100 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1100', 'id': 'qa_1100', 'schemaId': 'default_schema', 'structData': {'category': 'オリジナルバナー制作の進捗報告', 'question': '青木さん、長らくご連絡できておらず、申し訳ございません。。。また、ご報告の日にちと曜日が少しずつズレてしまっていたのですが、曜日が合っていました💦すみません😣早速ですが、下記に進捗まとめております🙇🏻\u200d♀️✨10/16(水)〜18(金)バナートレース実施10/19(土)オリジナルバナー制作のやり方確認10/20(日)〜21(月)休み10/22(火)オリジナルバナー制作開始10/23(水)3-1,3-2動画視聴&課題提出オリジナルバナー制作以上となります。帰省から戻ったので、またペースを戻していければと思います!!✨引き続きどうぞよろしくお願いいたします🙂\u200d↕️', 'answer': '丁寧にご報告いただきありがとうございます！引き続きご自身の良いペースで無理はしすぎず進めていきましょう💪', 'id': 'qa_1100'}, 'parentDocumentId': 'qa_1100'}
# Document qa_1463 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1463', 'id': 'qa_1463', 'schemaId': 'default_schema', 'structData': {'answer': 'はい、前と同じURLでお待ちしております！', 'id': 'qa_1463', 'category': '質問: ズームのIDは前回と同じですか？\n\n目的: ズームミーティングへの参加確認\n\nカテゴリ: ミーティング参加確認', 'question': 'zoomのIDは前と同じですか？？'}, 'parentDocumentId': 'qa_1463'}
# Document qa_843 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_843', 'id': 'qa_843', 'schemaId': 'default_schema', 'structData': {'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'category': 'URL送信要請 (入金エラー)', 'question': '入金の際にエラーになってしまったため、もう一度URLの送信お願いします。', 'id': 'qa_843'}, 'parentDocumentId': 'qa_843'}
# Document qa_868 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_868', 'id': 'qa_868', 'schemaId': 'default_schema', 'structData': {'id': 'qa_868', 'category': '携帯からの認証エラーに関する問い合わせ', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'question': 'ご返信ありがとうございます。↓こちらがIDとパスワードになります。携帯から入ったのですが、認証されなかったです💦'}, 'parentDocumentId': 'qa_868'}
# Document qa_771 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_771', 'id': 'qa_771', 'schemaId': 'default_schema', 'structData': {'question': 'どこから入ればよいでしょうか', 'id': 'qa_771', 'category': '了解しました。お客様は連絡先を尋ねています。これは、顧客サポートに関する問い合わせです。', 'answer': 'ありがとうございます！'}, 'parentDocumentId': 'qa_771'}
# Document qa_825 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_825', 'id': 'qa_825', 'schemaId': 'default_schema', 'structData': {'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'question': 'こんにちは！これからよろしくお願いします(よろしく)早速ですみませんが、mooga plusのIDとパスワードがわからずログインできません。教えていただけますでしょうか？', 'category': '## お客様からの問い合わせ内容要約\n\n**目的**: mooga plusへのログイン\n**内容**: IDとパスワードがわからないため、ログインできない\n\n## カテゴリ\n\nサポート \n\n## 補足\n\n本問い合わせは、ログインに関するサポート依頼です。お客様のIDとパスワードを確認する必要があります。', 'id': 'qa_825'}, 'parentDocumentId': 'qa_825'}
# Document qa_892 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_892', 'id': 'qa_892', 'schemaId': 'default_schema', 'structData': {'id': 'qa_892', 'category': 'メールアドレス違いの連絡。不具合確認。', 'question': '夜分遅くにすみません。全て登録できたのですが、Googleアカウント使用可能なメールアドレスhm.pey1414@gmail.com    とSlackで招待していただいたメールアドレスs2pey1717@docomo.ne.jpで違うものを送ってしまったのですが、今後講義を受講するにあたって不都合はないでしょうか？何度も申し訳ございませんが何卒よろしくお願いいたします🙇', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。'}, 'parentDocumentId': 'qa_892'}
# Document qa_1408 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1408', 'id': 'qa_1408', 'schemaId': 'default_schema', 'structData': {'answer': 'ご質問ありがとうございます◎素材については解決したようで良かったです😊トンマナのカラーについては、制作していくとイメージと異なってくることがありますよね💦今回は課題なので、途中で変更しながら制作していただいて大丈夫ですよ🙌変更する際は、参考としているデザインを見返しながら、自分の設定したカラーがペルソナのイメージに合っているのかを確認しましょう🌱実務では、クライアントになぜ変更するのかを説明する必要があるので、変更する理由を言語化しながら取り組んでみてくださいね＾＾', 'category': 'バナーの色変更について相談', 'question': '先ほどの質問、解決いたしました。画像の素材が添付されていて、それが文字化けして開けなかったため気づきませんでした。すみません。もう一つ質問なのですが、トンマナで決めたカラーでバナーを作ろうと思ったのですがやって行くうちに、色を変更したいと思ったのですがトンマナで決めたカラーはその人のイメージのワードから関連した色を選んだと思うのですが、途中で変えるとその人のイメージワードとは離れてしまうような気がして迷っています。よろしくお願いいたします。', 'id': 'qa_1408'}, 'parentDocumentId': 'qa_1408'}
# Document qa_168 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_168', 'id': 'qa_168', 'schemaId': 'default_schema', 'structData': {'question': 'WEEK1-4課題④を提出しました。', 'answer': '課題のご提出ありがとうございます✨添削が完了しましたのでご確認ください🌱', 'category': '## 課題提出連絡\n\nこのメッセージは、お客様から課題の提出を伝える連絡です。\n\n**カテゴリ:** 課題提出', 'id': 'qa_168'}, 'parentDocumentId': 'qa_168'}
# Document qa_179 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_179', 'id': 'qa_179', 'schemaId': 'default_schema', 'structData': {'id': 'qa_179', 'question': 'お世話になります。week5の③を提出しました。', 'category': '週5の③を提出しました。\n**カテゴリー:** 提出物の報告', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊'}, 'parentDocumentId': 'qa_179'}
# Document qa_392 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_392', 'id': 'qa_392', 'schemaId': 'default_schema', 'structData': {'question': '実践課題6-4を提出しました。ご確認よろしくお願い致します。', 'id': 'qa_392', 'category': '提出確認', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊'}, 'parentDocumentId': 'qa_392'}
# Document qa_1174 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1174', 'id': 'qa_1174', 'schemaId': 'default_schema', 'structData': {'question': 'こんばんは🌙少し前に1-4、本日2-1と2-2を提出しました。', 'id': 'qa_1174', 'answer': 'お取り組みお疲れ様です😊良い調子ですね🌱引き続きご自身の良いペースを掴みながら、無理なく進めていきましょう✨', 'category': '新機能の「要約」を使用して、お客様の連絡内容を要約します。\n\nお客様は、1-4 を少し前に提出、本日 2-1 と 2-2 を提出したことを報告しています。'}, 'parentDocumentId': 'qa_1174'}
# Document qa_864 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_864', 'id': 'qa_864', 'schemaId': 'default_schema', 'structData': {'category': '住所変更', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'question': '氏名、生年月日共に間違いありません。住所は〒1940211東京都町田市相原町475-6です。お手数おかけしますが宜しくお願いします。', 'id': 'qa_864'}, 'parentDocumentId': 'qa_864'}
# Document qa_1151 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1151', 'id': 'qa_1151', 'schemaId': 'default_schema', 'structData': {'category': 'お客様は、Canvaのデザインを共有するために連絡しました。', 'id': 'qa_1151', 'question': 'https://www.canva.com/design/DAGVamU_ZfE/2P1k1gIQgAI7dfNsHeFu0g/edit?ui=eyJEIjp7IlQiOnsiQSI6IlBCZG1Hc1JSUW5Ta0dLMEwifX19&utm_content=DAGVamU_ZfE&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton', 'answer': 'ご対応いただきありがとうございます🙌確認させていただきます☺️'}, 'parentDocumentId': 'qa_1151'}
# Document qa_1483 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1483', 'id': 'qa_1483', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1483', 'answer': 'お取り組みお疲れ様でした✨早速目標もありがとうございます！引き続き無理のないペースで進めていきましょう～😊', 'category': '1-3動画視聴と課題提出の報告', 'question': '井関様本日、1-2までの動画視聴と課題提出をしました。明日は、1-3の動画を視聴し、Canva演習を行う予定です！'}, 'parentDocumentId': 'qa_1483'}
# Document qa_1117 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1117', 'id': 'qa_1117', 'schemaId': 'default_schema', 'structData': {'category': '実務課題の再提出と次回の作業予定について報告。', 'question': '嶋内さんおはようございます。少し日が空いてしまいましたが、本日取り組んだことをご報告させていただきます。【今日取り組んだこと】•実践課題の再提出(1-3,2-3)•3-1〜3-3まで次回の仕事休みの日にまた続きから行う予定です！', 'id': 'qa_1117', 'answer': '本日もお取り組みお疲れ様でした✨オン・オフでしっかり取り組まれていること素晴らしいです！無理のない範囲でメリハリ付けて取り組んでいきましょう💪'}, 'parentDocumentId': 'qa_1117'}
# Document qa_577 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_577', 'id': 'qa_577', 'schemaId': 'default_schema', 'structData': {'id': 'qa_577', 'category': '画像を確認できないため、内容の要約と目的の特定はできません。しかし、お客様から連絡があったことは理解しました。内容が不明確なため、ここでは「その他」と分類させていただきます。', 'answer': 'ご報告いただきありがとうございます！！お調べいたしますので今しばらくお待ちくださいませ🙇\u200d♂️', 'question': '画像貼り付けれられないのでワークシートご確認いただければと思います。'}, 'parentDocumentId': 'qa_577'}
# Document qa_249 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_249', 'id': 'qa_249', 'schemaId': 'default_schema', 'structData': {'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'question': '10月20日取り組んだ内容・1-4の④の実践課題を提出しました。ご確認を宜しくお願いいたします。', 'id': 'qa_249', 'category': '1-4の④の実践課題の提出確認依頼'}, 'parentDocumentId': 'qa_249'}
# Document qa_1031 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1031', 'id': 'qa_1031', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1031', 'category': '初回面談の予約の可否確認 (28文字)', 'question': '10/31に初回面談の空きはありますか？', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。'}, 'parentDocumentId': 'qa_1031'}
# Document qa_579 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_579', 'id': 'qa_579', 'schemaId': 'default_schema', 'structData': {'id': 'qa_579', 'question': '1-4の課題の添削もよろしくお願いします。', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'category': 'その他: 添削依頼'}, 'parentDocumentId': 'qa_579'}
# Document qa_937 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_937', 'id': 'qa_937', 'schemaId': 'default_schema', 'structData': {'category': '学習の取り組み報告と課題提出。', 'question': '島戸さんお世話になっております、榎本です。▼今日の取り組み・2-1、2-2\u3000受講・2-2 課題提出', 'id': 'qa_937', 'answer': 'ご報告ありがとうございます🐿️本日もお取り組みお疲れ様でした！'}, 'parentDocumentId': 'qa_937'}
# Document qa_136 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_136', 'id': 'qa_136', 'schemaId': 'default_schema', 'structData': {'category': '提出確認: week2-2とweek2-3', 'id': 'qa_136', 'answer': '課題のご提出ありがとうございます♪引き続きお待ちしております😊', 'question': 'お世話になっております。week2-2とweek2-3を提出しました。よろしくお願いします🙇\u200d♀️'}, 'parentDocumentId': 'qa_136'}
# Document qa_964 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_964', 'id': 'qa_964', 'schemaId': 'default_schema', 'structData': {'id': 'qa_964', 'category': '11/3, 11/4課題提出不可、11/5頑張ります。 お問い合わせ内容としては、課題提出に関する連絡です。', 'answer': 'ご報告ありがとうございます！お休みの日は休みで、できる日にまた取り組んでいきましょう💪無理なく、ご自身の良いペースで進めていってくださいね🌱', 'question': '【今日取り組んだこと】・1-1 動画視聴、課題提出・1-2 動画視聴、課題提出11/3は予定があり、出来ません。11/4も出来ない可能性ありです。11/5は頑張ります。'}, 'parentDocumentId': 'qa_964'}
# Document qa_1204 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1204', 'id': 'qa_1204', 'schemaId': 'default_schema', 'structData': {'answer': 'ご参加お疲れ様でした！担当した講師は「岡本」になります^^ぜひご回答お願い致します◎', 'category': '勉強会講師の名前が分からず、アンケートに回答できないので問い合わせ', 'question': '勉強会後のアンケートのことで質問があります。先ほど初めて15:00〜の勉強会に参加させて頂き、今アンケート入力をしているのですが、質問事項の「講師の名前」で担当してくださった方のお名前を忘れてしまったのですが、回答必須ということで困っています。すみませんがご返答よろしくお願い致します。', 'id': 'qa_1204'}, 'parentDocumentId': 'qa_1204'}
# Document qa_1403 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1403', 'id': 'qa_1403', 'schemaId': 'default_schema', 'structData': {'category': '顧客からのお問い合わせ内容の要約: 了解しました。ありがとうございます。\n\nこのお問い合わせの目的は、顧客が「了解しました」と「ありがとうございます」のメッセージを送信し、前回の回答に同意し、感謝の意を表していることです。\n\nこのメッセージは、顧客サポートのやり取りの中で送られてきたものであり、前回の回答に満足していることを示しています。', 'answer': 'こんにちは◎HerTech運営事務局です🌱本日は講義内でご案内しておりますポートフォリオ作成サービス「RESUME」についてのお知らせになります◎🚨RESUME：アクセスできない不具合について🚨RESUMEの公式Xでも発表が出ておりますとおり、現在RESUMEにアクセスできない状況が続いております。[https://twitter.com/resume_official/status/1847515993381429274 (短縮)] そのため4-1の課題につきまして、これからお取り組みされる方につきましては、代替えとして下記のサイトをご活用の上、課題のご提出をお願い致します。※RESUMEにつきましては今週目処での復旧を目指しているとの発表もございますので、使用できる状態であればRESUMEをそのまま活用いただいても問題ございません。ーーーーー▼foriio[https://www.foriio.com/ (短縮)] ▼BRIK PORTFOLIO[https://brik.co.jp/portfolio (短縮)] ▼MATCH BOX[https://matchbox.work/ (短縮)] ーーーーーご確認のうえ、引き続きお取り組みの程よろしくお願いいたします◎', 'question': '了解です。有難うございます。', 'id': 'qa_1403'}, 'parentDocumentId': 'qa_1403'}
# Document qa_014 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_014', 'id': 'qa_014', 'schemaId': 'default_schema', 'structData': {'category': '予約確認: スケジュール調整承諾', 'id': 'qa_014', 'question': '返信できておらず申し訳ございません🙇\u200d♀️この日程で大丈夫ですよろしくお願いします', 'answer': '【🎉任意課題「模擬案件に応募してみよう」を追加しました🎉】こんにちは！HerTech運営事務局です😌マイページ\u30004-2：案件の取り方ページに任意課題「模擬案件に応募してみよう」を追加しました！▼内容は？本物のクラウドソーシングサービスそっくり！の架空案件で、クライアントとのやりとりや納品までの流れを体験できます✨▼こんな人におすすめ・実際の案件に挑戦する前に練習をしてみたい・実際の案件の流れを体験してみたい・今すぐに副業はできないけれど、案件にも挑戦してみたい▼確認方法１）マイページにログイン２）左側メニューの「カリキュラム＞4-2 案件の取り方＞実践課題下をスクロール取り組みしたものはポートフォリオにも掲載できますので、ぜひ挑戦してみてくださいね✨'}, 'parentDocumentId': 'qa_014'}
# Document qa_717 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_717', 'id': 'qa_717', 'schemaId': 'default_schema', 'structData': {'category': '課題8-1.8-2を提出しました。', 'id': 'qa_717', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'question': '課題8-1.8-2を提出しました'}, 'parentDocumentId': 'qa_717'}
# Document qa_087 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_087', 'id': 'qa_087', 'schemaId': 'default_schema', 'structData': {'question': 'week4-3提出しました。プロンプトの提出方法がわかりませんでした。画像は添付しましたがこれでいいのかわかりません。8日の面談の時に伺います。', 'answer': '課題のご提出ありがとうございます♪提出方法につきましてはこちらを参照ください✨[https://support.google.com/drive/answer/2424368?hl=ja&co=GENIE.Platform%3DDesktop (短縮)]', 'id': 'qa_087', 'category': 'プロンプトの提出方法がわからず、8日の面談で伺います。'}, 'parentDocumentId': 'qa_087'}
# Document qa_821 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_821', 'id': 'qa_821', 'schemaId': 'default_schema', 'structData': {'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'id': 'qa_821', 'question': 'お世話になっております。招待メール届きました💌\xa0お手数おかけしました💦引き続きどうぞよろしくお願いいたします🙇🏻\u200d♀️', 'category': 'お問い合わせの確認'}, 'parentDocumentId': 'qa_821'}
# Document qa_288 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_288', 'id': 'qa_288', 'schemaId': 'default_schema', 'structData': {'id': 'qa_288', 'question': '8-1.8-2提出しました。', 'category': 'その他', 'answer': '7ｰ3のスライドはアクセス制限がかかっていましたので、Googleドライブ上に直接アップロードしていただければと思います。お手数ですがよろしくお願いいたします。'}, 'parentDocumentId': 'qa_288'}
# Document qa_722 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_722', 'id': 'qa_722', 'schemaId': 'default_schema', 'structData': {'id': 'qa_722', 'question': 'お世話になります。week7の課題について2以外完了しました。上記質問ご回答いただけたら2も出来ますのでよろしくお願い致します。', 'category': '2. 質問解決による課題完了 (週7)', 'answer': 'ーーーーーー①7-2 VBAコードで Windowsでパワーポイントを作りたいですが出来ません。テキスト通りにaltキーとf11を押しても添付画面になり、検索しても出てきません。Microsoft visual basicの表示方法を教えてください。ーーーーーー上記のご質問に対する回答をさせていただきます。\u2028お待たせしてしまい、申し訳ございません。Microsoft Visual Basicを表示するには、以下の手順で行います！1. Excelを開く\u2028任意のExcelファイルを開きます。2. [開発]タブを表示する\u2028もし開発タブが表示されていない場合は、以下の手順で表示します：    * [ファイル] → [オプション] をクリック。    * [リボンのユーザー設定] を選び、右側のリストから [開発] にチェックを入れてOKを押します。3. [開発]タブからVisual Basicを開く\u2028[開発]タブ が表示されたら、その中にある [Visual Basic] ボタンをクリックします。▼参考動画[https://youtu.be/mzzh7MYHc7Y?si=E9iLo43QKn7u2YX5 (短縮)]'}, 'parentDocumentId': 'qa_722'}
# Document qa_992 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_992', 'id': 'qa_992', 'schemaId': 'default_schema', 'structData': {'id': 'qa_992', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'category': 'LP・HPデザインの仕事に就くためのスキル習得を希望', 'question': '■HerTech受講への今の気持ち：現時点でCanvaを使用した制作物は可能なので、早くLPやHPデザインに取り掛かり、仕事としてやっていけるまでになりたいです'}, 'parentDocumentId': 'qa_992'}
# Document qa_621 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_621', 'id': 'qa_621', 'schemaId': 'default_schema', 'structData': {'id': 'qa_621', 'answer': '【本日中に一度ご確認ください🙇\u200d♀️】こんにちは、運営事務局の三浦です！課題のご提出ありがとうございます！担当に共有いたしますね◎また、受講延長プラン申込フォームのご回答ありがとうございます！先ほどrosegarden123@docomo.ne.jp宛に『【重要】HerTech受講延長プラン申込書/お支払い手続きのご案内』というタイトルのメールを送付しました。◆お申込み期日2024年10月12日(土)◆支払い期日2024年10月14日(月)メールが確認できない場合は、LINEにてご連絡いただけますと幸いです。よろしくお願いいたします。', 'category': '課題2-2の提出報告。', 'question': 'おはようございます。課題2-2提出しました。'}, 'parentDocumentId': 'qa_621'}
# Document qa_329 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_329', 'id': 'qa_329', 'schemaId': 'default_schema', 'structData': {'id': 'qa_329', 'question': 'Week 1-4の課題を提出しました。', 'answer': '課題のご提出ありがとうございます✨添削完了しましたのでご確認ください☺', 'category': '課題の提出。'}, 'parentDocumentId': 'qa_329'}
# Document qa_268 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_268', 'id': 'qa_268', 'schemaId': 'default_schema', 'structData': {'id': 'qa_268', 'question': '谷津さんへ返信遅れてすみません💦10/6（日）の午前中いかがでしょうか。ご検討よろしくお願いします', 'answer': 'ご連絡ありがとうございます！ただいまメンターに日程確認しておりますので、お返事いましばらくお待ちくださいね😌', 'category': 'お客様は、10月6日(日)の午前中にアポイントメントを希望している。'}, 'parentDocumentId': 'qa_268'}
# Document qa_171 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_171', 'id': 'qa_171', 'schemaId': 'default_schema', 'structData': {'id': 'qa_171', 'question': 'ありがとうございました😊', 'category': 'お客様からの感謝の気持ちです。', 'answer': 'こんにちは！メンターの安田です😊前回のご面談から1ヶ月が経ちますので、2回目の面談のご案内をいたします。ご参加は【任意】になります。スキップされる場合はLINEにて「希望しない」とご連絡ください。▼面談ついて・初回と同じくzoomを使用した面談を予定しております・所要時間は15分程度を予定しております。・学習やサービスの使い方について困っていることなどがあれば、この機会にぜひご相談ください。※皆様にお送りさせていただいています。既に2回目の面談をご予約済の方は、再度対応いただく必要はございません。▼日程調整URL[https://timerex.net/s/HerTech-mentor-GAI2/9691335b (短縮)] ※ご予約につきましては上記URLからご都合のよい日程をお選びいただくようお願いいたします。※ご都合のよい日程がない場合は、ご希望の日程・お時間帯をLINEにて幅広くご提示ください。◎注意◎※予約後の日程変更はなるべくお控えください※やむを得ず変更される際は【面談実施の3時間前まで】にご連絡の上、予約ツール上で変更ください（予約ツール上で参加可能な時間帯がない場合は、その旨もご連絡いただければ幸いです。）上記につきまして、ご不明点等ございましたら遠慮なくご質問ください🍀よろしくお願いします！'}, 'parentDocumentId': 'qa_171'}
# Document qa_686 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_686', 'id': 'qa_686', 'schemaId': 'default_schema', 'structData': {'category': '通知: お客様は予約時のメールが見つからず、 Zoom アドレスを確認したい。', 'answer': '返信が遅くなりまして申し訳ありません。ご予約の確認ができなかったため、ご予約が完了まで進んでいなかった可能性があります。お手数をおかけしますが、再度ご予約をしていただければと思います。勉強会は下記サイトより予約可能です。[https://airrsv.net/hertech-gai/calendar (短縮)] ご不明点やご質問がございましたら、いつでもお気軽にお知らせください。お待ちしております。', 'question': '予約時のメールにzoomアドレスが記載されてる様ですが、メールが届いておりませんでした。お手数をおかけしますが、ご確認頂けますでしょうか。', 'id': 'qa_686'}, 'parentDocumentId': 'qa_686'}
# Document qa_635 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_635', 'id': 'qa_635', 'schemaId': 'default_schema', 'structData': {'id': 'qa_635', 'answer': 'こんばんは！メンターの武井です😊まもなく受講終了が近づいてきましたので、最終面談のご案内をいたします。▼面談ついて・初回と同じくzoomを使用した面談を予定しております・所要時間は15分程度を予定しております。・学習やサービスの使い方について困っていることなどがあれば、この機会にぜひご相談ください。🌟ご参加は【任意】になります。スキップされる場合はLINEにて「希望しない」とご連絡ください。参加をご希望の際は下記よりご予約をお願いいたします😊※皆様にお送りさせていただいています。既に最終の面談をご予約済の方は、再度対応いただく必要はございません。▼日程調整URL[https://timerex.net/s/HerTech-mentor-GAI2/c3fb0755/ (短縮)] ※ご予約につきましては上記URLからご都合のよい日程をお選びいただくようお願いいたします。※ご都合のよい日程がない場合は、ご希望の日程・お時間帯をLINEにて幅広くご提示ください。◎注意◎※予約後の日程変更はなるべくお控えください※やむを得ず変更される際は【面談実施の3時間前まで】にご連絡の上、予約ツール上で変更ください（予約ツール上で参加可能な時間帯がない場合は、その旨もご連絡いただければ幸いです。）▼ 当日について◎Zoomで実施をいたしますので、カメラ・マイクONにできる状態でご参加ください◎当日参加URLはご予約時のお控えもしくはリマインドメールに記載されておりますので\u3000メールをご確認の上ご参加ください◎事前準備は特にございませんが、メモを取りたい方は筆記用具等ご準備の上ご参加くださいぜひご都合調整の上、ご参加いただければ嬉しいです✨なお、面談を待たずに今まで同様に受講を進めていただいても問題ございません◎上記につきまして、ご不明点等ございましたら遠慮なくご質問ください🍀よろしくお願いします！', 'category': '顧客は課題を進めるために連絡しており、詳細な内容は不明です。**その他** に分類されます。', 'question': 'ありがとうございます。そうですね。まずは課題を進めなければですね…よろしくお願いいたします。'}, 'parentDocumentId': 'qa_635'}
# Document qa_613 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_613', 'id': 'qa_613', 'schemaId': 'default_schema', 'structData': {'answer': '大変お待たせいたしました💦添削完了しましたのでご確認ください🌱', 'question': 'こんにちは。7-3の課題を提出しましたのでよろしくお願いします。ただ、プロンプトのリンクの貼り付けをどこにしたらいいのか分からず、欄外に貼り付けました。よろしくお願いします。', 'id': 'qa_613', 'category': '課題提出に関する問い合わせ。'}, 'parentDocumentId': 'qa_613'}
# Document qa_122 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_122', 'id': 'qa_122', 'schemaId': 'default_schema', 'structData': {'category': '目的不明。 お問い合わせ内容の要約が出来ませんでした。', 'question': '前回4-2.とお伝えしたのは4-3の間違えでした。', 'answer': '課題のご提出ありがとうございます✨添削が完了しましたのでご確認ください🌱', 'id': 'qa_122'}, 'parentDocumentId': 'qa_122'}
# Document qa_666 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_666', 'id': 'qa_666', 'schemaId': 'default_schema', 'structData': {'id': 'qa_666', 'question': 'こんにちは。本日9時〜面談ということでzoomで待機しておりましたが「ホストによってミーティングが開始されるのを待機しています」のまま繋がりません。日程を再調整したいのですが、10月以降のスケジュールはいつ頃選択できるでしょうか？', 'answer': '佐藤様本日ですが、私が開始時刻を30分勘違いしており、参加ができずに大変申し訳ございませんでした。折角お越しいただいたにも関わらず、貴重なお時間を無駄にしてしまい、本当に申し訳なく思っています。10月のスケジュールですが、明日送付させていただきますので、再度ご登録いただけますと幸いです。どうぞ、よろしくお願いします。', 'category': '面談の開始が待てないので、日程を再調整したいとの連絡。'}, 'parentDocumentId': 'qa_666'}
# Document qa_1321 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1321', 'id': 'qa_1321', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1321', 'category': 'その他', 'answer': '取り組み報告ありがとうございます！丁寧に進められていて素晴らしいです✨今日もお疲れ様でした👏', 'question': '【取り組んだこと】土〜火・week4-2〜5-3・勉強会'}, 'parentDocumentId': 'qa_1321'}
# Document qa_1004 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1004', 'id': 'qa_1004', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1004', 'question': 'ご連絡ありがとうございます！本日はバナーのデザイン制作まで動画を閲覧し課題を提出しました。Pinterestで参考となる素材が沢山あり見ていてとても楽しかったです☺️', 'category': 'その他', 'answer': '昨日もお取り組みお疲れ様でした！良い気付きがあり、楽しんでインプットしていただけてよかったです✨️引き続き無理なく進めていきましょう💪'}, 'parentDocumentId': 'qa_1004'}
# Document qa_939 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_939', 'id': 'qa_939', 'schemaId': 'default_schema', 'structData': {'question': '島戸さんこんばんは、榎本です。本日は1つしか行えませんでした。▼本日の報告・3-1 Webページについて', 'answer': '今日もお疲れ様でした✨️1つでも素晴らしいですよ＾＾日々のコツコツが大事です！引き続き無理なく進めていってくださいね🌱', 'category': 'お客様はWebページについて連絡しました。', 'id': 'qa_939'}, 'parentDocumentId': 'qa_939'}
# Document qa_632 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_632', 'id': 'qa_632', 'schemaId': 'default_schema', 'structData': {'question': '失念しており、申し訳ございませんでした。改めて予約いたします。よろしくお願いいたします。', 'category': '予約の再リクエスト', 'answer': 'こんにちは！HerTech運営事務局です◎先日ご案内しました「受講延長プラン」のお申込み締め切りが近づいてきましたので、再度ご連絡いたしました😌※皆さまにお送りしておりますので「受講延長プラン」を利用されない方、「すでにお申し込み済みの方」はご放念ください。＜🌟受講延長プランのご案内🌟＞現在ご受講いただいているHerTechの受講につきましては、【10/18(金)終日】をもって受講終了となります◎もし受講継続をご希望される場合は、下記をご確認のうえご検討・お申込みください🌱▽詳しくはこちら[https://nimble-impala-3ed.notion.site/AI-1aabd07c7b374c87913828c1d54ba394 (短縮)] ※受講延長プランをご利用されない場合は、10/18(金)終日で自動的に受講終了となります※なお、受講期間を終えた翌日から180日間は、引き続き講義資料の閲覧及び公式LINEへのお問い合わせは可能ですのでご安心くださいーーーーーー延長プラン申し込み締め切り：10/10(木)終日上記につきまして、ご不明点などございましたら遠慮なくご質問ください◎', 'id': 'qa_632'}, 'parentDocumentId': 'qa_632'}
# Document qa_1246 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1246', 'id': 'qa_1246', 'schemaId': 'default_schema', 'structData': {'category': '## カテゴリ: 課題提出と学習進捗報告\n\n## 要約: \n\n千賀さんは、2-3の課題を提出済みで、カリキュラム1の添削結果を受け取りました。明日は再提出とwebデザインの序盤に取り組む予定です。', 'id': 'qa_1246', 'answer': '取り組み報告ありがとうございます！しっかりと進められていて素晴らしいです✨ぜひ復習兼ねて、1-3にある任意課題にも挑戦してみてくださいね🌱今日もお疲れ様でした^^', 'question': '千賀さんお疲れ様です！今日は2-3の課題提出まで終わりました。カリキュラム1の添削をしていただいたものが返ってきていたので、明日はその再提出とwebデザインの序盤に手をつけられればと思います！'}, 'parentDocumentId': 'qa_1246'}
# Document qa_187 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_187', 'id': 'qa_187', 'schemaId': 'default_schema', 'structData': {'question': 'week1の課題（①〜④）を提出しました。まとめて提出ではなく、1つずつ提出が推奨と存じておりますが、時間の調整が難しく、申し訳ございませんがまとめて提出させていただきました。ご確認よろしくお願いいたします。', 'id': 'qa_187', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊ご提出の件かしこまりました！！', 'category': '課題の提出に関する報告'}, 'parentDocumentId': 'qa_187'}
# Document qa_161 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_161', 'id': 'qa_161', 'schemaId': 'default_schema', 'structData': {'question': '2-3まで提出しました！よろしくお願いいたします。', 'answer': '課題のご提出ありがとうございます🌱順調に進められていますね✨引き続きご提出お待ちしております♪', 'id': 'qa_161', 'category': '案件提出の報告。'}, 'parentDocumentId': 'qa_161'}
# Document qa_943 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_943', 'id': 'qa_943', 'schemaId': 'default_schema', 'structData': {'question': '谷津さん、こんばんわ。遅くに失礼いたします。▼日々の取り組み報告について「今日取り組んだこと」を報告いたします。・昨日ゆっくり休みましたので本日1-3の動画視聴完了、実践もおおまかなところまで完了しました。明日、【実践課題でつまづきやすいポイント】を確認し、細かいとこを修正します。引き続き、宜しくお願いします🙂', 'category': '## 日次報告: お客様は 1-3 の動画視聴と実践を完了し、明日実践課題の修正を行う予定です。', 'id': 'qa_943', 'answer': 'お疲れ様でした！丁寧に進められており素敵です🌱引き続き無理なく進めていきましょう✨'}, 'parentDocumentId': 'qa_943'}
# Document qa_1305 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1305', 'id': 'qa_1305', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1305', 'category': 'お勧めのノートパソコンについて問い合わせ', 'question': 'パソコンについて相談なのですが、特別セール!【P10%還元】【短納期】【公式・直販】 ノートパソコン 新品 Lenovo IdeaPad Slim 3 Gen 8 15.6インチ FHD IPS液晶 AMD Ryzen 7 7730U メモリ 16GB SSD 512GB Windows 11 送料無料 1年保証【Norton】yxe[楽天] #Rakutenichibahttps://item.rakuten.co.jp/lenovopc/82xm00fdjp/?scid=wi_ich_iphoneapp_item_shareこちら5年以内に製造されたものでしょうか？？記載がされていないです...。こちらを購入を考えているのですが、良いと思いますか？🙇\u200d♀️何度もパソコンの質問すみません。', 'answer': 'ご質問ありがとうございます◎こちらのパソコンは今年の4月に発売開始されたものなので、全く問題ないと思いますよ😊✨[https://kakaku.com/item/K0001619836/ (短縮)]'}, 'parentDocumentId': 'qa_1305'}
# Document qa_1327 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1327', 'id': 'qa_1327', 'schemaId': 'default_schema', 'structData': {'question': '谷津さま今日は3-3課題の修正と、3-5動画視聴をしました！', 'answer': 'お疲れ様でした！＾＾引き続き無理なく進めていきましょう✨', 'id': 'qa_1327', 'category': '3-3課題の修正と3-5動画視聴の報告'}, 'parentDocumentId': 'qa_1327'}
# Document qa_131 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_131', 'id': 'qa_131', 'schemaId': 'default_schema', 'structData': {'id': 'qa_131', 'question': 'こんばんは、梅木です。1点質問です。Adobe Fireflyも有料版を契約した方がいいですよね？このオンライン学習に際し、無料版でも問題ないのかどうか知りたいです。', 'answer': '有料版にする必要はありません😊業務で今後利用する場合は、有料版への変更を検討されていても良いです♪', 'category': 'オンライン学習の際、Adobe Fireflyの有料版の契約が必要かどうかについての問い合わせ'}, 'parentDocumentId': 'qa_131'}
# Document qa_524 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_524', 'id': 'qa_524', 'schemaId': 'default_schema', 'structData': {'answer': 'いえいえ！お忙しいところ明日のご予約ありがとうございます😌よろしくお願いいたします！10月29日 (火) 12:00 - 12:15Web会議室: [https://us05web.zoom.us/j/86502719202?pwd=Q6gxAwBNVarAgp75N7TtbXn2O0mckE.1 (短縮)] ミーティングID: 865 0271 9202パスワード: hQQm71', 'question': '本当に申し訳ありません家庭の事情でzoomはいれませんでした。', 'category': 'その他', 'id': 'qa_524'}, 'parentDocumentId': 'qa_524'}
# Document qa_1105 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1105', 'id': 'qa_1105', 'schemaId': 'default_schema', 'structData': {'question': '中川さん今日は2-3の動画視聴と、課題の提出をしました！', 'id': 'qa_1105', 'category': '課題報告', 'answer': 'こんにちは◎HerTech運営事務局です🌱本日は講義内でご案内しておりますポートフォリオ作成サービス「RESUME」についてのお知らせになります◎🚨RESUME：アクセスできない不具合について🚨RESUMEの公式Xでも発表が出ておりますとおり、現在RESUMEにアクセスできない状況が続いております。[https://twitter.com/resume_official/status/1847515993381429274 (短縮)] そのため4-1の課題につきまして、これからお取り組みされる方につきましては、代替えとして下記のサイトをご活用の上、課題のご提出をお願い致します。※RESUMEにつきましては今週目処での復旧を目指しているとの発表もございますので、使用できる状態であればRESUMEをそのまま活用いただいても問題ございません。ーーーーー▼foriio[https://www.foriio.com/ (短縮)] ▼BRIK PORTFOLIO[https://brik.co.jp/portfolio (短縮)] ▼MATCH BOX[https://matchbox.work/ (短縮)] ーーーーーご確認のうえ、引き続きお取り組みの程よろしくお願いいたします◎'}, 'parentDocumentId': 'qa_1105'}
# Document qa_1392 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1392', 'id': 'qa_1392', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1392', 'answer': 'お疲れ様でした！良い調子ですね🌱引き続き無理なく進めていきましょう😆', 'question': '井関さん、こんにちは！2-1、2-2の動画視聴と課題提出が終わりました！', 'category': '課題提出完了報告'}, 'parentDocumentId': 'qa_1392'}
# Document qa_986 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_986', 'id': 'qa_986', 'schemaId': 'default_schema', 'structData': {'question': '藤川さん宛', 'category': 'その他', 'answer': '目標シートの共有ありがとうございます！無理はしすぎずがベースですが、目標に向けコツコツ頑張っていきましょうね💪', 'id': 'qa_986'}, 'parentDocumentId': 'qa_986'}
# Document qa_1267 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1267', 'id': 'qa_1267', 'schemaId': 'default_schema', 'structData': {'answer': '目標シートの提出ありがとうございます✨10月も目標に向け、コツコツ進めていきましょう💪今週も無理はしすぎず頑張っていきましょうね😊', 'question': '目標書きましたのでお願いします！', 'category': '申し訳ありませんが、ご依頼の要約にはいくつかの問題点があります。\n\n1. **日本語の表現:** 「[目標書きましたのでお願いします！]」という日本語は不自然です。通常、目標を誰かに提出する際には、具体的な目標内容を詳しく説明し、その達成のために協力や支援を求めます。「[目標を書いたので、ご確認ください。ご協力いただければ幸いです。]」のように表現すると、より自然で礼儀正しい日本語になります。\n2. **目標の内容:** お客様の連絡内容には、目標の内容が全く書かれていません。そのため、目標の内容を15文字以内に要約することは不可能です。\n3. **目的の推測:** お客様の連絡内容が明確ではないため、目的を推測することもできません。\n\n以上の理由から、お客様の連絡内容を15文字程度に要約することはできません。また、内容が明確でないため、その他と出力させていただきます。\n\nお役に立てず申し訳ありませんが、お客様の連絡内容が明確になれば、改めて要約させていただきます。', 'id': 'qa_1267'}, 'parentDocumentId': 'qa_1267'}
# Document qa_103 uploaded successfully!
# ...
# Document qa_1086 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1086', 'id': 'qa_1086', 'schemaId': 'default_schema', 'structData': {'answer': 'お疲れ様です✨️はい！無理はしすぎず進めてくださいね🌱', 'category': 'この連絡は、3-3の再提出と3-4の課題の提出を完了した旨の報告のためです。', 'question': '谷津さんへ昨日は進めれなかったので、今日3-3の再提出、3-4の課題の提出まで終わりました💡明日明後日は結構時間があるので、進められると思います✨', 'id': 'qa_1086'}, 'parentDocumentId': 'qa_1086'}
# Document qa_830 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_830', 'id': 'qa_830', 'schemaId': 'default_schema', 'structData': {'category': 'その他', 'id': 'qa_830', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'question': 'すみません、回答漏れており先ほど対応いたしました。ご確認よろしくお願いいたします。'}, 'parentDocumentId': 'qa_830'}
# Document qa_290 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_290', 'id': 'qa_290', 'schemaId': 'default_schema', 'structData': {'id': 'qa_290', 'category': '提出物の提出方法について問い合わせ', 'question': 'すみません。やっぱり提出出来ていませんでした。もう一度提出のためのアドレスを７-3のところに入れていただきたいです。', 'answer': 'Google Driveのリンクを貼らせていただきましたので、よろしくお願いいたします。'}, 'parentDocumentId': 'qa_290'}
# Document qa_205 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_205', 'id': 'qa_205', 'schemaId': 'default_schema', 'structData': {'category': '課題提出 2-1', 'id': 'qa_205', 'question': '2-1課題提出しました', 'answer': '課題のご提出ありがとうございます✨添削完了しましたのでご確認ください☺'}, 'parentDocumentId': 'qa_205'}
# Document qa_1218 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1218', 'id': 'qa_1218', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1218', 'question': '今日はバナートレースの動画を見ながら、Canvaを使ってみましたが、慣れない作業で悪戦苦闘中です…💦明日は続きから微調整していきたいと思います', 'category': 'Canva操作に苦戦しており、明日調整を続ける予定との報告', 'answer': '週末もお取り組みお疲れ様でした✨はじめてのツールは最初はどうしても苦戦しますよね💦でも慣れていくので、ぜひ苦手意識を感じずに沢山触っていってもらえると嬉しいです💡苦手意識感じそうになったら、勉強会などを活用して使い方も聞いてみたりしてみてくださいね🌱今週も無理はしすぎず頑張っていきましょう😊！'}, 'parentDocumentId': 'qa_1218'}
# Document qa_921 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_921', 'id': 'qa_921', 'schemaId': 'default_schema', 'structData': {'id': 'qa_921', 'category': '入金完了報告 (14文字)', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'question': 'お世話になっております！先ほど入金させていただきました！ご確認をよろしくお願いいたします🙇\u200d♀'}, 'parentDocumentId': 'qa_921'}
# Document qa_054 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_054', 'id': 'qa_054', 'schemaId': 'default_schema', 'structData': {'answer': 'その他のご質問は現在準備中です。大変恐れ入りますが、LINEより直接ご質問いただけますと幸いです。', 'category': 'お客様から連絡がありました。', 'id': 'qa_054', 'question': '【その他】'}, 'parentDocumentId': 'qa_054'}
# Document qa_510 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_510', 'id': 'qa_510', 'schemaId': 'default_schema', 'structData': {'category': '## 週8-1,2を提出しました。よろしくお願いいたします。\n\n**目的**: 週8課題1,2の提出連絡\n\n**カテゴリー**: 課題提出', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'id': 'qa_510', 'question': 'week8-1,2を提出しました。よろしくお願いいたします。'}, 'parentDocumentId': 'qa_510'}
# Document qa_1118 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1118', 'id': 'qa_1118', 'schemaId': 'default_schema', 'structData': {'category': '体調不良による面談延期', 'id': 'qa_1118', 'question': '嶋内さん夜分遅くに失礼いたします。明日10時からの面談を予定しておりましたが、日程の変更をお願いしたくご連絡いたしました。本日体調が優れず、明日の午前中も様子を見させていただきたく存じます。可能であれば、面談を1日後に延期していただけませんでしょうか。せっかくお時間をいただいていたのに申し訳ございません。どうぞよろしくお願いいたします。', 'answer': 'お返事が遅くなってしまい、大変申し訳ございません🙇\u200d♀️体調はいかがでしょうか🥺キャンセルについてはメンターにもすでに共有すみですのでご安心ください🌱改めて予定についてメンターに確認しておりますので、今しばらくお待ちいただけると嬉しいです😌'}, 'parentDocumentId': 'qa_1118'}
# Document qa_380 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_380', 'id': 'qa_380', 'schemaId': 'default_schema', 'structData': {'category': '実践課題のプロンプト添削の依頼。', 'question': '添削ありがとうございました。5-3実践課題のプロンプトを入力しました。添削のほどよろしくお願いいたします。', 'answer': '課題のご提出ありがとうございます✨添削完了しましたのでご確認ください☺', 'id': 'qa_380'}, 'parentDocumentId': 'qa_380'}
# Document qa_673 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_673', 'id': 'qa_673', 'schemaId': 'default_schema', 'structData': {'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'question': '順番前後しましたが、5-1から3まで実施しました。', 'id': 'qa_673', 'category': 'その他'}, 'parentDocumentId': 'qa_673'}
# Document qa_318 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_318', 'id': 'qa_318', 'schemaId': 'default_schema', 'structData': {'category': '質問', 'answer': '課題のご提出ありがとうございます。添削完了しましたのでご確認ください🌱', 'id': 'qa_318', 'question': 'w6-2 まで提出しました。'}, 'parentDocumentId': 'qa_318'}
# Document qa_138 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_138', 'id': 'qa_138', 'schemaId': 'default_schema', 'structData': {'question': 'Week3-3の課題を提出しました。', 'answer': '課題のご提出ありがとうございます✨添削が完了しましたのでご確認ください🌱', 'id': 'qa_138', 'category': '課題の提出'}, 'parentDocumentId': 'qa_138'}
# Document qa_1317 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1317', 'id': 'qa_1317', 'schemaId': 'default_schema', 'structData': {'category': '問い合わせ内容要約：動画視聴、課題提出、Canvaトレース練習の依頼', 'question': '竹内さん宛11/4(月)・3-4動画視聴11/5(火)・3-4課題提出・Canvaトレース練習', 'answer': '歩未さんこんにちは！竹内です。本日11:00より面談の予定ですが、いかがでしょうか？下記URLで11:15までお待ちしています。[https://zoom.us/j/95632310758?pwd=xRABUpnvwC52O6SRkSBa5s7aKiVcG5.1 (短縮)] ミーティング ID: 956 3231 0758パスコード: BfK0TaLZ', 'id': 'qa_1317'}, 'parentDocumentId': 'qa_1317'}
# Document qa_780 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_780', 'id': 'qa_780', 'schemaId': 'default_schema', 'structData': {'category': 'お客様は10/9の予約を変更したい旨を連絡しました。', 'id': 'qa_780', 'answer': 'ご連絡ありがとうございます◎ただいまメンターに確認中ですので、今しばらくお待ちください🌱', 'question': '申し訳ございません🙇\u200d♀️休み間違えてました💦10/9はいかがでしょうか💦'}, 'parentDocumentId': 'qa_780'}
# Document qa_1003 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1003', 'id': 'qa_1003', 'schemaId': 'default_schema', 'structData': {'category': 'デザイン参考サイト/書籍紹介依頼', 'id': 'qa_1003', 'question': '竹中先生昨日はCanva演習をやってみました。提出の仕方が間違っていたようで、本日再提出しました。今日はデザインの基礎知識について学びました。まずはお手本となるバナーを沢山見たいと思いました。参考となるバナーを閲覧出来るようなおすすめサイトや本がありましたら、是非教えて頂きたいです☺️', 'answer': 'ご質問ありがとうございます◎参考のデザインについては、講義動画で紹介したピンタレストや、バナーのデザインが集められた参考ギャラリーサイトがあります✨以下のサイトで紹介されているので、ご自身が使いやすいと感じたサイトをブックマークしていただくのがオススメですよ＾＾[https://liginc.co.jp/545202 (短縮)]'}, 'parentDocumentId': 'qa_1003'}
# Document qa_1026 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1026', 'id': 'qa_1026', 'schemaId': 'default_schema', 'structData': {'answer': '早速確認していただきありがとうございます✨そして追加のご質問についても、ご自身で試してくださりありがとうございました^^ご認識の通り、Canvaは複数ページ使用しているとダウンロードの際に全てのページにチェックが入っている状態になっています😌ですので1枚だけ指定すると単体でpngデータで保存ができますので、次回また参考にして試してみてくださいね^^今日もお取り組みお疲れ様でした！！！', 'id': 'qa_1026', 'question': 'トレースをしたデータのみpngで保存するとできました。すみません。ありがとうございます。また何かあれば質問しますのでよろしくお願いします。', 'category': 'お問い合せ内容：データ保存方法の質問(PNG形式)'}, 'parentDocumentId': 'qa_1026'}
# Document qa_1245 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1245', 'id': 'qa_1245', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1245', 'question': '千賀さんおつかれ様です！今日はカリキュラム1-4まで進んで、2-2の途中まで進めました。明日は少しゆっくりして、月曜からまた頑張ります！', 'answer': '【🎉任意課題「模擬案件に応募してみよう」を追加しました🎉】こんにちは！HerTech運営事務局です😌マイページ\u30004-2：案件の取り方ページに任意課題「模擬案件に応募してみよう」を追加しました！▼内容は？本物のクラウドソーシングサービスそっくり！の架空案件で、クライアントとのやりとりや納品までの流れを体験できます✨▼こんな人におすすめ・実際の案件に挑戦する前に練習をしてみたい・実際の案件の流れを体験してみたい・今すぐに副業はできないけれど、案件にも挑戦してみたい▼確認方法１）マイページにログイン２）左側メニューの「カリキュラム＞4-2 案件の取り方＞実践課題下をスクロール取り組みしたものはポートフォリオにも掲載できますので、ぜひ挑戦してみてくださいね✨', 'category': 'カリキュラムの学習進捗報告、明日は休み、月曜日から再開の意思表示。\n\n**カテゴリ: 学習進捗報告**'}, 'parentDocumentId': 'qa_1245'}
# Document qa_1119 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1119', 'id': 'qa_1119', 'schemaId': 'default_schema', 'structData': {'category': 'スケジュール調整依頼', 'answer': '詩さん、ご連絡ありがとうございます！全然問題ないので気にされないでください😭そして、お日にちのご提案ありがとうございます！5日（火）10：00から、いかがでしょうか？しまうち🎀', 'id': 'qa_1119', 'question': '嶋内さん本日は急にキャンセルしてしまいすみません、、仕事が11時〜20時でしてちょうど休みの日も直近の日程が合いにくく…もし可能であれば、5日、8日、12日の午前中でご都合のよろしい時間帯はございますでしょうか💦よろしくお願いいたします🙇'}, 'parentDocumentId': 'qa_1119'}
# Document qa_202 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_202', 'id': 'qa_202', 'schemaId': 'default_schema', 'structData': {'id': 'qa_202', 'question': '1-4実践課題を提出しました', 'category': '4件の課題提出', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊'}, 'parentDocumentId': 'qa_202'}
# Document qa_165 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_165', 'id': 'qa_165', 'schemaId': 'default_schema', 'structData': {'id': 'qa_165', 'answer': 'ご連絡ありがとうございます。スキップの旨承知致しました。引き続きよろしくお願い致します🌱', 'question': '2回目の面談はスキップでお願いします。引き続きよろしくお願いいたします！', 'category': '2回目の面談のスキップ依頼。'}, 'parentDocumentId': 'qa_165'}
# Document qa_1417 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1417', 'id': 'qa_1417', 'schemaId': 'default_schema', 'structData': {'answer': 'こちらこそありがとうございました✨️お取り組みお疲れ様でした😊しっかりご自身でスケジュール組み立てていただいて素晴らしいです💪不明点などあればLINEや勉強会などぜひ活用してくださいね✨引き続きよろしくお願いいたします！', 'category': '## 課題の進捗報告 \n\nこの連絡は、お客様が課題の進捗状況を報告するために送られたものです。', 'question': '藤川様へ先日は面談のお時間をいただきありがとうございました！今週は課題を進めつつ、来週以降で少しずつ復習していこうと思います！以下報告になります(矢印)【10/25,26,27取り組んだこと】25：canvaデザイントレース練習26：ITビジネスパーソンスキル(イベント)参加27：3-5 実践課題【本日取り組んだこと】・3-5 実践課題続き', 'id': 'qa_1417'}, 'parentDocumentId': 'qa_1417'}
# Document qa_196 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_196', 'id': 'qa_196', 'schemaId': 'default_schema', 'structData': {'category': '課題の提出', 'question': '課題5-1から5-3を提出しました', 'id': 'qa_196', 'answer': '課題のご提出ありがとうございます。添削完了しましたのでご確認ください🌱'}, 'parentDocumentId': 'qa_196'}
# Document qa_141 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_141', 'id': 'qa_141', 'schemaId': 'default_schema', 'structData': {'answer': '課題のご提出ありがとうございます✨引き続きご提出お待ちしております☺', 'question': 'Week5-1の課題を提出しました。', 'id': 'qa_141', 'category': 'その他 (今週の課題を提出しました。)'}, 'parentDocumentId': 'qa_141'}
# Document qa_783 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_783', 'id': 'qa_783', 'schemaId': 'default_schema', 'structData': {'question': 'こんにちは😃以前、参加した自習会で作成したバナーをこの前勉強会でアドバイスいただいて修正してみたので、フィードバックをお願いします(お願いします)2枚目は、“踊りだす”に動きをつけたので流れるような飾りをアクセントとして付けてたのですが、あまり飾らずにシンプルに仕上げたほうがいいのでしょうか？', 'category': '## 顧客サポート問い合わせ要約\n\n**目的:** バナー修正に関するフィードバック依頼\n\n**カテゴリー:** デザインレビュー', 'id': 'qa_783', 'answer': 'お取り組みお疲れさまです🌱全体的に色がまとまっていて、とても見やすいバナーに仕上がっていますね😊「踊りだす」のレイアウトが工夫されていることで、楽しそうな雰囲気に仕上がっているのではないでしょうか✨今の状態でもいいのかなと思いますが、レイアウト以外で表現するのであれば、あしらいを加えてもいいかもしれないと感じました🌱あしらいについては以下のサイトでわかりやすく解説されていますので、こちらもぜひ参考にしてみてください^^[https://cotonoha-design.com/blog/ashirai/ (短縮)] また、「乙女ゴコロ」や「初月半額」のテキストは、背景に対して少し上に寄っている状態なので、上下の余白を整えてあげるとすっきり見えますよ🙌'}, 'parentDocumentId': 'qa_783'}
# Document qa_333 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_333', 'id': 'qa_333', 'schemaId': 'default_schema', 'structData': {'question': 'week 5-1の課題を提出しました。', 'id': 'qa_333', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊', 'category': '週5-1の課題を提出しました'}, 'parentDocumentId': 'qa_333'}
# Document qa_1069 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_1069', 'id': 'qa_1069', 'schemaId': 'default_schema', 'structData': {'id': 'qa_1069', 'category': '再提出完了報告', 'answer': 'お疲れ様でした！良い調子ですね💪不明点などあればLINEや勉強会などぜひ活用してくださいね✨', 'question': '藤川さんお世話になります！3-5 、4-1 再提出終わりました。よろしくお願いします！'}, 'parentDocumentId': 'qa_1069'}
# Document qa_818 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_818', 'id': 'qa_818', 'schemaId': 'default_schema', 'structData': {'id': 'qa_818', 'question': 'お世話になっております。STEP1、2共に回答完了いたしました。引き続きどうぞよろしくお願いいたします🙇🏻\u200d♀️', 'answer': 'ご連絡くださりありがとうございます！現在、順番にご返答をしておりますのでお待ちいただけますと幸いです。※お問合せ受付時間\u3000平日、土曜日\u30009時~21時時間外のお問合わせにつきましては、翌営業日より順次ご対応させていただきます。', 'category': 'STEP1、2回答済み、要指示。'}, 'parentDocumentId': 'qa_818'}
# Document qa_213 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_213', 'id': 'qa_213', 'schemaId': 'default_schema', 'structData': {'id': 'qa_213', 'answer': 'ご質問いただきありがとうございます。また、お待ちいただきありがとうございます。講師が回答させていただきます。送っていただいた写真はWeek4-3の課題でしょうか送っていただいた写真は、『テキストから画像生成』で生成された画像に対して、Adobe Expressで編集する画面を開いていただいているようです。再度お試しいただき、難しいようでしたら勉強会でご不明なところについてサポートさせていただきます。既に解決済でしたら、失礼いたしました。本件やそのほかのことでも、ご不明な点や分からないことがございましたら、LINEでご質問いただくか勉強会へのご予約をお願いいたします。引き続きよろしくお願いいたします。', 'question': 'Week5-1.2の課題を提出しました。ご確認よろしくお願いします。', 'category': '課題提出の確認依頼 (13文字)'}, 'parentDocumentId': 'qa_213'}
# Document qa_766 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_766', 'id': 'qa_766', 'schemaId': 'default_schema', 'structData': {'question': '杉本さん先日はお時間頂きありがとうございましたあれからまた余裕が持てず、そのままになってしまいました。頂いた情報を活用出来るよう、何とか無駄にしないよう頑張りたい、、、お世話かけますが、宜しくお願い致します。', 'answer': 'ご連絡ありがとうございます。残りの期間、勉強会なども活用しながら進めていきましょう♪引き続きよろしくお願いいたします。', 'category': 'その他', 'id': 'qa_766'}, 'parentDocumentId': 'qa_766'}
# Document qa_390 uploaded successfully!
# {'name': 'projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/branches/0/documents/qa_390', 'id': 'qa_390', 'schemaId': 'default_schema', 'structData': {'id': 'qa_390', 'category': '実践課題6-2の提出連絡', 'question': '実践課題6-2を提出しました。ご確認よろしくお願い致します。', 'answer': '課題のご提出ありがとうございます♪添削が完了しておりますのでご確認くださいませ😊'}, 'parentDocumentId': 'qa_390'}

# %% [markdown]
# # **3. Create Agent Builder**
# The Agent Builder serves as the interface between the search system and the user.
#
# **3.1 Create the Agent**
#
# *   Create an agent (engine) linked to the data store using a **unique engine_id.**
# *   Ensure the search system is configured with Advanced LLM Features enabled for better relevance matching.
# *   Ensure the **data store id**
# *   **display_name** need to be change
#
# **3.2 Wait for Initialization**
#
# Allow 5-10 minutes for the agent and data store to initialize fully before proceeding to training.

# %%
from google.api_core.client_options import ClientOptions
from google.cloud import discoveryengine_v1 as discoveryengine

# Configuration
PROJECT_ID = "monobrain-development" # @param {type:"string"}
LOCATION = "global" # @param {type:"string"}
ENGINE_ID = "indah_app_1" # @param {type:"string"}
DATA_STORE_IDS = "indah_data_1" # @param {type:"string"}
DISPLAY_APP_NAME = "Sample1" # @param {type:"string"}

def create_engine_with_enterprise():
    client_options = ClientOptions(api_endpoint=f"{LOCATION}-discoveryengine.googleapis.com")
    client = discoveryengine.EngineServiceClient(client_options=client_options)

    parent = f"projects/{PROJECT_ID}/locations/{LOCATION}/collections/default_collection"

    # Creating the Engine
    engine = discoveryengine.Engine(
        display_name= DISPLAY_APP_NAME,
        industry_vertical=discoveryengine.IndustryVertical.GENERIC,
        solution_type=discoveryengine.SolutionType.SOLUTION_TYPE_SEARCH,
        search_engine_config=discoveryengine.Engine.SearchEngineConfig(
            search_tier=discoveryengine.SearchTier.SEARCH_TIER_ENTERPRISE,
            search_add_ons=[discoveryengine.SearchAddOn.SEARCH_ADD_ON_LLM],  # Advanced LLM Features
        ),
        data_store_ids=DATA_STORE_IDS,
    )

    request = discoveryengine.CreateEngineRequest(
        parent=parent,
        engine=engine,
        engine_id=ENGINE_ID,
    )

    operation = client.create_engine(request=request)
    print(f"Creating engine: {operation.operation.name}")
    response = operation.result()
    print("Engine created successfully:", response)

    # Enable Enterprise Features
    enable_enterprise_features(PROJECT_ID, LOCATION, ENGINE_ID)

def enable_enterprise_features(project_id, location, engine_id):
    client_options = ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
    client = discoveryengine.EngineServiceClient(client_options=client_options)

    engine_name = f"projects/{project_id}/locations/{location}/collections/default_collection/engines/{engine_id}"

    # Attempting to patch the engine with Enterprise features enabled
    engine_patch = discoveryengine.Engine(
        name=engine_name,
        search_engine_config=discoveryengine.Engine.SearchEngineConfig(
            search_tier=discoveryengine.SearchTier.SEARCH_TIER_ENTERPRISE,
            search_add_ons=[discoveryengine.SearchAddOn.SEARCH_ADD_ON_LLM]
        )
    )

    update_mask = {"paths": ["search_engine_config.search_tier"]}

    request = discoveryengine.UpdateEngineRequest(
        engine=engine_patch,
        update_mask=update_mask,
    )

    try:
        response = client.update_engine(request=request)
        print("Updated engine to enable Enterprise Edition successfully:", response)
    except Exception as e:
        print("Failed to enable Enterprise Edition:", e)


if __name__ == "__main__":
    create_engine_with_enterprise()
# Out:
# Creating engine: projects/954273464710/locations/global/collections/default_collection/operations/create-engine-15774122029334750032
# Engine created successfully: search_engine_config {
#   search_tier: SEARCH_TIER_ENTERPRISE
#   search_add_ons: SEARCH_ADD_ON_LLM
# }
# name: "projects/954273464710/locations/global/collections/default_collection/engines/indah_app_1"
# display_name: "Sample1"
# data_store_ids: "indah_data_1"
# solution_type: SOLUTION_TYPE_SEARCH
# industry_vertical: GENERIC
#
# Updated engine to enable Enterprise Edition successfully: search_engine_config {
#   search_tier: SEARCH_TIER_ENTERPRISE
#   search_add_ons: SEARCH_ADD_ON_LLM
# }
# name: "projects/954273464710/locations/global/collections/default_collection/engines/indah_app_1"
# display_name: "Sample1"
# data_store_ids: "indah_data_1"
# solution_type: SOLUTION_TYPE_SEARCH
# industry_vertical: GENERIC

# %% [markdown]
# # **4. Generate Training Dataset**
# This step prepares the training data by pairing queries with the most relevant corpus entries.
#
# **4.1 Load Query Data:**
#
# Ensure the query data is uploaded to the specified location in your environment, such as a local file path.
#
# **4.2 Set Engine ID:**
#
# The engine_id uniquely identifies the search engine created in the earlier steps.
#
#
# **4.3 Match Query with Relevant Corpus Entries**
#
# *   For each query, evaluate similarity with the top 5 corpus entries.
# *   Use a similarity model to calculate scores for each pairing.
# *   Select the corpus entry with the highest similarity score for each query.
#
# **4.4 Generate Training Data**
#
# Save the query-corpus pairs and their similarity scores in a TSV file (train_data.tsv). The file includes the following columns:
# *   query_id
# *   corpus_id
# *   similarity_score

# %%
import json
import pandas as pd
import time
from google.cloud import discoveryengine_v1
from google.api_core.client_options import ClientOptions
from vertexai.generative_models import GenerativeModel


PROJECT_ID = "monobrain-development" # @param {type:"string"}
LOCATION = "global" # @param {type:"string"}
ENGINE_ID = "search_sample_1" # @param {type:"string"}
OUTPUT_FILE = "train_data.tsv"  # @param {type:"string"}
QUERY_DATA_PATH = "/content/query_data.jsonl"  # @param {type:"string"}

def search_relevant_docs(client, serving_config, query_text, top_k=5):
    """
    Fetch top-k most relevant documents for a given query using Discovery Engine.
    """
    request = discoveryengine_v1.SearchRequest(
        serving_config=serving_config,
        query=query_text,
        page_size=top_k,
        offset=0
    )
    try:
        response = client.search(request)
        docs = []
        for result in response.results:
            doc_id = result.document.struct_data.get("id", "N/A")
            docs.append({
                "doc_id": doc_id,
                "text": result.document.struct_data.get("question", "No question available"),
            })
        return docs
    except Exception as e:
        print(f"Error in search: {e}")
        return []

def similarity_assessment_model(query_text, doc_text, model):
    """
    Evaluate semantic similarity between query and document using Gemini.
    Args:
        query_text: Input query text
        doc_text: Document text to compare against
        model: Gemini model instance
    Returns:
        float: Similarity score (0-5)
    """
    generation_config = {
        "max_output_tokens": 8192,
        "temperature": 1,
        "top_p": 0.95,
        "response_mime_type": "application/json"
    }
    # Prompt engineering for semantic similarity assessment
    prompt = f"""Evaluate the semantic similarity between two Japanese texts on a 5-point scale:
Scoring Criteria:
5: Highly similar in content, details, and expression.
4: Similar overall, with minor differences in details or tone.
3: Moderately similar; same general topic but different specifics.
2: Slightly similar; some overlap in vocabulary or ideas.
1: Barely similar; weak connection in style or context.
0: No similarity in content, expression, or context.
Provide the output in the following JSON format:
{{
    "similarity": <score>
}}
Text 1: {query_text}
Text 2: {doc_text}"""
    try:
        response = model.generate_content(
            prompt,
            generation_config=generation_config,
        )
        response_data = json.loads(response.text)
        return float(response_data.get("similarity", 0.0))
    except Exception as e:
        print(f"Error in similarity assessment: {e}")
        return 0.0

def create_train_data(project_id, location, engine_id, queries):
    """
    Create training data by finding the most similar document for each query.
    """
    client_options = ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
    client = discoveryengine_v1.SearchServiceClient(client_options=client_options)
    serving_config = f"projects/{project_id}/locations/{location}/collections/default_collection/engines/{engine_id}/servingConfigs/default_config"
    model = GenerativeModel("gemini-1.5-flash-001")
    train_data = []

    for query in queries:
        query_id = query["id"]
        query_text = query["question"]

        # Fetch top-5 relevant documents
        relevant_docs = search_relevant_docs(client, serving_config, query_text)
        if not relevant_docs:
            print(f"No documents found for query {query_id}")
            continue

        # Find the most similar document
        best_score = 0
        best_doc_id = None
        for doc in relevant_docs:
            similarity_score = similarity_assessment_model(query_text, doc["text"], model)
            if similarity_score > best_score:
                best_score = similarity_score
                best_doc_id = doc["doc_id"]
            time.sleep(1)  # Rate limiting

        # Save the best match
        if best_doc_id:
            train_data.append({
                "query-id": query_id,
                "corpus-id": best_doc_id,
                "score": round(best_score, 2),
            })

    return train_data

def main():
    """Main execution function."""
    # Load query data
    with open(QUERY_DATA_PATH , "r", encoding="utf-8") as f:
        queries = [json.loads(line.strip()) for line in f]

    # Create training data
    train_data = create_train_data(
        project_id= PROJECT_ID ,
        location= LOCATION,
        engine_id= ENGINE_ID,
        queries=queries
    )

    # Save training data as TSV
    train_df = pd.DataFrame(train_data)
    train_df.to_csv(OUTPUT_FILE, sep="\t", header=True, index=False)
    print(train_df.head())

if __name__ == "__main__":
    main()
# Out:
#   query-id corpus-id  score
# 0   qa_790    qa_892    3.0
# 1  qa_1171    qa_949    2.0
# 2  qa_1221   qa_1220    3.0
# 3  qa_1335   qa_1334    4.0
# 4   qa_002    qa_004    3.0

# %% [markdown]
# # **5. Adjust Dataset Fields for Fine Tuning**
#
# Ensure that dataset fields meet the requirements for training.

# %% [markdown]
# **5.1 Corpus Data**
#
# Each entry must include _id, title, and text fields.
#
# Example: {"_id": "doc1", "text": "Content of doc"}

# %%
import json
import re

# Input JSONL file
input_file = "/content/corpus_data.jsonl" # @param {type:"string"}
output_file = "/content/corpus_data1.jsonl"

# Function to reformat JSONL
def reformat_jsonl(input_path, output_path):
    with open(input_path, "r", encoding="utf-8") as infile, open(output_path, "w", encoding="utf-8") as outfile:
        for line in infile:
            data = json.loads(line)
            # Extract numeric part of the id field
            id_number = re.search(r"\d+", data["id"]).group()
            new_data = {
                "_id": f"doc{id_number}",
                "text": data["question"]
            }
            outfile.write(json.dumps(new_data, ensure_ascii=False) + "\n")

# Call the function
reformat_jsonl(input_file, output_file)

# %% [markdown]
# **5.2 Query Data**
#
# Each entry must include _id and text fields.
#
# Example: {"_id": "query1", "text": "Query content"}

# %%
import json
import re

# Input JSONL file
input_file = "/content/query_data.jsonl" # @param {type:"string"}
output_file = "/content/query_data1.jsonl"

# Function to reformat JSONL
def reformat_jsonl(input_path, output_path):
    with open(input_path, "r", encoding="utf-8") as infile, open(output_path, "w", encoding="utf-8") as outfile:
        for line in infile:
            data = json.loads(line)
            # Extract numeric part of the id field
            id_number = re.search(r"\d+", data["id"]).group()
            new_data = {
                "_id": f"query{id_number}",
                "text": data["question"]
            }
            outfile.write(json.dumps(new_data, ensure_ascii=False) + "\n")

# Call the function
reformat_jsonl(input_file, output_file)

# %% [markdown]
# **5.3 Train Data**
#
# Each line in the training data (TSV file) must include:
# query_id, corpus_id, and score.

# %%
import json
import re
# Input TSV file
input_tsv = "/content/train_data.tsv" # @param {type:"string"}
output_tsv = "/content/train_data1.tsv"

# Function to reformat TSV
def reformat_tsv(input_path, output_path):
    with open(input_path, "r", encoding="utf-8") as infile, open(output_path, "w", encoding="utf-8") as outfile:
        header = infile.readline()  # Skip the header
        outfile.write("query_id\tcorpus_id\tscore\n")
        for line in infile:
            parts = line.strip().split("\t")
            query_id = parts[0].replace("qa_", "query")
            corpus_id = parts[1].replace("qa_", "doc")
            score = parts[2]
            outfile.write(f"{query-id}\t{corpus-id}\t{score}\n")

# Call the functions
reformat_jsonl(input_file, output_file)
reformat_tsv(input_tsv, output_tsv)

# %% [markdown]
# # **6. Fine-Tuning**
# Train a custom search-tuning model using the prepared datasets.
#
# **6.1 Configure Training**
#
# Use the prepared paths for corpus_data, query_data, and train_data.
# Define the test and validation data paths if needed. The data store id must be changed
#
# **6.2 Initiate Fine-Tuning**
#
# Execute the training process on the Discovery Engine platform.
# Monitor progress and ensure the model completes training successfully.
#
# **6.3 Validate the Tuned Model**
#
# Use evaluation metrics to confirm the model’s effectiveness for the intended use case.

# %%
from google.api_core.client_options import ClientOptions
from google.cloud import discoveryengine

# Replace these with your actual values
MODEL_TYPE = "search-tuning"

PROJECT_ID = "monobrain-development" # @param {type:"string"}
LOCATION = "global" # @param {type:"string"}
DATA_STORE_ID = "indah_data_1" # @param {type:"string"}
CORPUS_DATA_PATH = "gs://tuning_category/corpus_data1.jsonl" # @param {type:"string"}
QUERY_DATA_PATH = "gs://tuning_category/query_data1.jsonl" # @param {type:"string"}
TRAIN_DATA_PATH = "gs://tuning_category/train_data1.tsv" # @param {type:"string"}
TEST_DATA_PATH = None  # Optional: Auto-split if None

def train_and_monitor_model(
    project_id: str,
    location: str,
    data_store_id: str,
    corpus_data_path: str,
    query_data_path: str,
    train_data_path: str,
    test_data_path: str,
    model_type: str,
):
    """
    Train and monitor a custom model in Google Discovery Engine.

    Args:
        project_id (str): Your GCP project ID.
        location (str): The location of the data store (e.g., "global").
        data_store_id (str): The ID of the data store.
        corpus_data_path (str): Path to the corpus data in GCS.
        query_data_path (str): Path to the query data in GCS.
        train_data_path (str): Path to the training data in GCS.
        test_data_path (str): Path to the test data in GCS.
        model_type (str): The type of model (e.g., "search-tuning").

    Returns:
        None
    """
    # Initialize the client
    client_options = ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
    client = discoveryengine.SearchTuningServiceClient(client_options=client_options)

    # Define the full data store path
    data_store = f"projects/{project_id}/locations/{location}/collections/default_collection/dataStores/{data_store_id}"

    # Create the training request
    print("Starting the training operation...")
    request = discoveryengine.TrainCustomModelRequest(
        gcs_training_input=discoveryengine.TrainCustomModelRequest.GcsTrainingInput(
            corpus_data_path=corpus_data_path,
            query_data_path=query_data_path,
            train_data_path=train_data_path,
            test_data_path=test_data_path,
        ),
        data_store=data_store,
        model_type=model_type,
    )

    # Start the training operation
    operation = client.train_custom_model(request=request)
    operation_name = operation.operation.name
    print(f"Training operation started: {operation_name}")

    # Monitor the training operation
    print("Monitoring the training operation...")
    monitor_training_operation(location, operation_name)


def monitor_training_operation(location: str, operation_name: str):
    """
    Monitor the training operation until it completes.

    Args:
        location (str): The location of the data store (e.g., "global").
        operation_name (str): The full name of the operation to monitor.

    Returns:
        None
    """
    # Initialize the client
    client_options = ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
    client = discoveryengine.SearchTuningServiceClient(client_options=client_options)

    # Poll the operation
    print(f"Checking operation status for: {operation_name}")
    while True:
        operation = client.transport.operations_client.get_operation(operation_name)

        if operation.done:
            if operation.response:
                print("Training completed successfully!")
                print(operation.response)
            else:
                print("Operation finished with errors.")
                print(operation.error)
            break
        else:
            print("Operation is still in progress. Checking again in 60 seconds...")
            import time
            time.sleep(60)  # Wait for 60 seconds before polling again


# Run the training and monitoring process
if __name__ == "__main__":
    train_and_monitor_model(
        project_id=PROJECT_ID,
        location=LOCATION,
        data_store_id=DATA_STORE_ID,
        corpus_data_path=CORPUS_DATA_PATH,
        query_data_path=QUERY_DATA_PATH,
        train_data_path=TRAIN_DATA_PATH,
        test_data_path=TEST_DATA_PATH,
        model_type=MODEL_TYPE,
    )
# Out:
# Starting the training operation...
# Training operation started: projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/operations/train-custom-model-14408795834615834426
# Monitoring the training operation...
# Checking operation status for: projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/operations/train-custom-model-14408795834615834426
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Operation is still in progress. Checking again in 60 seconds...
# Training completed successfully!
# type_url: "type.googleapis.com/google.cloud.discoveryengine.v1beta.TrainCustomModelResponse"
# value: "\032\005ready\"\030\n\rndcg_10_tuned\021F\010\2176\216X\335?\"\033\n\020ndcg_10_baseline\021|\n\200\361\014\032\330?*\205\001projects/954273464710/locations/global/collections/default_collection/dataStores/indah_data_1/customTuningModels/14408795834615833782"
